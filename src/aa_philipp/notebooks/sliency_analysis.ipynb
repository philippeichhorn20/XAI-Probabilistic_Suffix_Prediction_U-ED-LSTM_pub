# %%
import pickle
import pandas as pd

with open ("results_store_integrated_gradients_helpdesk_on_case_elapsed_time.pkl", "rb") as f:
    results_df = pickle.load(f)

results_df = pd.DataFrame(results_df)
