# %%
import numpy as np
import matplotlib.pyplot as plt

from statsmodels.distributions.empirical_distribution import ECDF

# Set random seed for reproducibility
np.random.seed(42)

# %%
# Parameters
mean = 0
true_variance = 0.5
sample_variance = 0.05
n_samples = 1000

# Sample from the two distributions
samples_true_var = np.random.normal(mean, np.sqrt(true_variance), n_samples)
samples_model_var = np.random.normal(mean, np.sqrt(sample_variance), n_samples)

# Plot
plt.figure(figsize=(10, 6))
plt.hist(samples_low_var, bins=50, alpha=0.6, label=f'Low variance (σ²={low_variance})', density=True)
plt.hist(samples_high_var, bins=50, alpha=0.6, label=f'High variance (σ²={high_variance})', density=True)
plt.title('Comparison of Normal Distributions with Same Mean')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.grid(True)
plt.show()

# %%
np.mean(samples_model[0] <= samples_truth)
# Out:
# np.float64(0.513)

# %%
m_samples = 10000

samples_truth = np.random.normal(mean, np.sqrt(high_variance), n_samples)
samples_model = [np.random.normal(mean, np.sqrt(low_variance), m_samples) for i in range(n_samples)]

pit_values = np.array([
    np.mean(samples_model[i] <= samples_truth[i])
    for i in range(n_samples)
])

plt.hist(pit_values, bins=20, density=True, edgecolor='k', alpha=0.7)
plt.plot([0, 1], [1, 1], 'r--', label='Uniform(0,1)')
plt.xlabel('PIT Value')
plt.ylabel('Density')
plt.title('PIT Histogram')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Example: 100 predictive distributions with 1000 samples each
n = 100
sample_distributions = np.random.normal(loc=np.random.randn(n), scale=1.0, size=(n, 1000))
ground_truths = np.random.randn(n)

# Compute empirical CDF for each ground truth
pit_values = np.array([
    np.mean(sample_distributions[i] <= ground_truths[i])
    for i in range(n)
])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 7
#       5 # Example: 100 predictive distributions with 1000 samples each
#       6 n = 100
# ----> 7 sample_distributions = np.random.normal(loc=np.random.randn(n), scale=1.0, size=(n, 1000))
#       8 ground_truths = np.random.randn(n)
#      10 # Compute empirical CDF for each ground truth
#
# File numpy/random/mtrand.pyx:1576, in numpy.random.mtrand.RandomState.normal()
#
# File numpy/random/_common.pyx:621, in numpy.random._common.cont()
#
# File numpy/random/_common.pyx:538, in numpy.random._common.cont_broadcast_2()
#
# File ../numpy/__init__.cython-30.pxd:831, in numpy.PyArray_MultiIterNew3()
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (100, 1000) and arg 1 with shape (100,).
