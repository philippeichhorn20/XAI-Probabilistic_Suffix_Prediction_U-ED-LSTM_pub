# %%
import importlib
import sys
import pickle
import numpy as np

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')

# %%
import src.evaluation_metrics.conduct_evaluation
importlib.reload(src.evaluation_metrics.conduct_evaluation)

import src.evaluation_metrics.metrics
importlib.reload(src.evaluation_metrics.metrics)
# Out:
# <module 'src.evaluation_metrics.metrics' from '/home/LordKunkler/prob_suffix_pred_sim_framework/probabilistic_suffix_prediction_dev/src/notebooks/evaluation_metric_notebooks/eval_normal_2layer/../../../../src/evaluation_metrics/metrics.py'>

# %%
import src.evaluation_metrics.plots as plots
importlib.reload(src.evaluation_metrics.plots)

output_dirs = ['../../../../../../evaluation_results/PCR/gn']

all_results = dict()

for output_dir in output_dirs:
    evaluation_metrics = {
        #'RemainingTime_MSE_seconds' : src.evaluation_metrics.metrics.LastValueMeanMSE('case_elapsed_time'),
        #'RemainingTime_MAE_Var_seconds' : src.evaluation_metrics.metrics.LastValueMeanMedianVarMAE('case_elapsed_time', percentile=0.16),
        #'RemainingTime_MSE_Var_seconds' : src.evaluation_metrics.metrics.LastValueMeanVarMSE('case_elapsed_time', percentile=0.16),
        #'RemainingTime_CRPS_seconds' : src.evaluation_metrics.metrics.LastValueCRPS('case_elapsed_time'),
        #'Levenshtein_CRPS_activity' : src.evaluation_metrics.metrics.LevenshteinCRPS('concept:name'),
        'LevenshteinMeanVar_activity' : src.evaluation_metrics.metrics.LevenshteinMeanVar('concept:name', percentile=0.25),
        #'Raw_activity' : src.evaluation_metrics.metrics.RawAttribute('Activity'),
        #'LevenshteinMeanVar_activity' : src.evaluation_metrics.metrics.LevenshteinMeanVar('concept:name', percentile=0.16),
        #'LevenshteinMeanVar_resource' : src.evaluation_metrics.metrics.LevenshteinMeanVar('org:resource', percentile=0.16),

        #'NormalizedDamerauLevenshteinCRPS_activity' : src.evaluation_metrics.metrics.NormalizedDamerauLevenshteinDistanceCRPS('concept:name'),
        'NormalizedDamerauLevenshteinMeanVar_activity' : src.evaluation_metrics.metrics.NormalizedDamerauLevenshteinDistanceMeanVar('concept:name', percentile=0.25),
        #'FakedNormalizedDamerauLevenshteinMeanVar_activity' : src.evaluation_metrics.metrics.FakedNormalizedDamerauLevenshteinDistanceMeanVar('Activity', percentile=0.16),

        #'NormalizedDamerauLevenshteinMeanVar_resource' : src.evaluation_metrics.metrics.NormalizedDamerauLevenshteinDistanceMedianVar('Activity', percentile=0.16),
        #'RemainingTime_PIT' : src.evaluation_metrics.metrics.LastValuePIT('case_elapsed_time'),
        #'EventElapsed_PIT' : src.evaluation_metrics.metrics.LastValuePIT('event_elapsed_time'),


        #'RemainingTime_MAE_Median_Var_seconds' : src.evaluation_metrics.metrics.LastValueMedianVarMAE('case_elapsed_time', percentile=0.16),
        #'RemainingTime_MAE_Median2_Var_seconds' : src.evaluation_metrics.metrics.LastValueMedian2VarMAE('case_elapsed_time', percentile=0.16),
        #'RemainingTime_MAE_Mean_Var_seconds' : src.evaluation_metrics.metrics.LastValueMeanVarMAE('case_elapsed_time', percentile=0.16),
        'RemainingTime_MAE_Mean2_Var_seconds' : src.evaluation_metrics.metrics.LastValueMean2VarMAE('case_elapsed_time', percentile=0.25),

        #'RemainingTime_MSE_Median_Var_seconds' : src.evaluation_metrics.metrics.LastValueMedianVarMSE('case_elapsed_time', percentile=0.16),
        #'RemainingTime_MSE_Median2_Var_seconds' : src.evaluation_metrics.metrics.LastValueMedian2VarMSE('case_elapsed_time', percentile=0.16),
        #'RemainingTime_MSE_Mean_Var_seconds' : src.evaluation_metrics.metrics.LastValueMeanVarMSE('case_elapsed_time', percentile=0.16),
        #'RemainingTime_MSE_Mean2_Var_seconds' : src.evaluation_metrics.metrics.LastValueMean2VarMSE('case_elapsed_time', percentile=0.16),


        #'RemainingTime_SUM_Mean_MSE_outliers' : src.evaluation_metrics.metrics.SumValueMeanMSE('event_elapsed_time', percentile=0.16),
        'RemainingTime_SUM_Mean_MAE_outliers' : src.evaluation_metrics.metrics.SumValueMeanMAE('event_elapsed_time', percentile=0.25, value_factor = 60),
        'RemainingTime_SUM_Abs_Mean_MAE_outliers' : src.evaluation_metrics.metrics.SumAbsValueMeanMAE('event_elapsed_time', percentile=0.25, value_factor = 60),

        #'RemainingTime_SUM_Mean_MSE_2' : src.evaluation_metrics.metrics.SumValueMeanMSE('event_elapsed_time', percentile=0.16, outlier_removal=2),
        #'RemainingTime_SUM_Mean_MAE_2' : src.evaluation_metrics.metrics.SumValueMeanMAE('event_elapsed_time', percentile=0.16, outlier_removal=2),



        #'RemainingTime_MAE_Mean2_Var_seconds_outliers' : src.evaluation_metrics.metrics.LastValueMean2VarMAE('case_elapsed_time', percentile=0.16),
        #'RemainingTime_MAE_Mean2_Var_seconds_3.5' : src.evaluation_metrics.metrics.LastValueMean2VarMAE('case_elapsed_time', percentile=0.16, outlier_removal=3.5),
        #'RemainingTime_MAE_Mean2_Var_seconds_2.5' : src.evaluation_metrics.metrics.LastValueMean2VarMAE('case_elapsed_time', percentile=0.16, outlier_removal=2.5),
        #'RemainingTime_MAE_Mean2_Var_seconds_2' : src.evaluation_metrics.metrics.LastValueMean2VarMAE('case_elapsed_time', percentile=0.16, outlier_removal=2),


        #'RemainingTime_MSE_Median_Var_seconds' : src.evaluation_metrics.metrics.LastValueMedianVarMSE('case_elapsed_time', percentile=0.16),
        #'RemainingTime_MSE_Median2_Var_seconds' : src.evaluation_metrics.metrics.LastValueMedian2VarMSE('case_elapsed_time', percentile=0.16),
        #'RemainingTime_MSE_Mean_Var_seconds' : src.evaluation_metrics.metrics.LastValueMeanVarMSE('case_elapsed_time', percentile=0.16),
        #'RemainingTime_MSE_Mean2_Var_seconds_3.5' : src.evaluation_metrics.metrics.LastValueMean2VarMSE('case_elapsed_time', percentile=0.16, outlier_removal=3.5),
        #'RemainingTime_MSE_Mean2_Var_seconds_2.5' : src.evaluation_metrics.metrics.LastValueMean2VarMSE('case_elapsed_time', percentile=0.16, outlier_removal=2.5),
        #'RemainingTime_MSE_Mean2_Var_seconds_2' : src.evaluation_metrics.metrics.LastValueMean2VarMSE('case_elapsed_time', percentile=0.16, outlier_removal=2),
        #'RemainingTime_MSE_Mean2_Var_seconds_outliers' : src.evaluation_metrics.metrics.LastValueMean2VarMSE('case_elapsed_time', percentile=0.16),

        'RemainingTime_PIT' : src.evaluation_metrics.metrics.LastValuePIT('case_elapsed_time'),
        'EventElapsed_PIT' : src.evaluation_metrics.metrics.SumValuesPIT('event_elapsed_time'),
        'SuffixCount' : src.evaluation_metrics.metrics.SuffixCount(),
        'SuffixCountMAE' : src.evaluation_metrics.metrics.SuffixCountMAE(percentile=0.25)
    }

    res_raw, c = src.evaluation_metrics.conduct_evaluation.batch_evaluate(output_dir, evaluation_metrics, num_workers=32)
    #res_raw, c = src.evaluation_metrics.conduct_evaluation.evaluate_sequentially(output_dir, evaluation_metrics)
    all_results[output_dir] = (res_raw, c)


with open("PCR_gn.pkl", "wb") as file:
    pickle.dump(all_results, file)
# Out:
# Loaded: results_part_1000.pkl
# Loaded: results_part_10650.pkl
# Loaded: results_part_10350.pkl
# Loaded: results_part_10200.pkl
# Loaded: results_part_10000.pkl
# Loaded: results_part_10750.pkl
# Loaded: results_part_10150.pkl
# Loaded: results_part_10050.pkl
# Loaded: results_part_10250.pkl
# Loaded: results_part_10850.pkl
# Loaded: results_part_100.pkl
# Loaded: results_part_10100.pkl
# Loaded: results_part_1050.pkl
# Loaded: results_part_1100.pkl
# Loaded: results_part_10550.pkl
# Loaded: results_part_10700.pkl
# Loaded: results_part_050.pkl
# Loaded: results_part_10900.pkl
# Loaded: results_part_10500.pkl
# Loaded: results_part_11150.pkl
# Loaded: results_part_10950.pkl
# Loaded: results_part_10400.pkl
# Loaded: results_part_11250.pkl
# Loaded: results_part_10450.pkl
# Loaded: results_part_11050.pkl
# Loaded: results_part_10600.pkl
# Loaded: results_part_11000.pkl
# Loaded: results_part_11300.pkl
# Loaded: results_part_11100.pkl
# Loaded: results_part_10300.pkl
# Loaded: results_part_11200.pkl
# Loaded: results_part_10800.pkl
# Loaded: results_part_1150.pkl
# Loaded: results_part_11350.pkl
# Loaded: results_part_11400.pkl
# Loaded: results_part_11450.pkl
# Loaded: results_part_11650.pkl
# Loaded: results_part_11600.pkl
# Loaded: results_part_11500.pkl
# Loaded: results_part_12000.pkl
# Loaded: results_part_11550.pkl
# Loaded: results_part_11900.pkl
# Loaded: results_part_1200.pkl
# Loaded: results_part_11750.pkl
# Loaded: results_part_12750.pkl
# Loaded: results_part_12700.pkl
# Loaded: results_part_12450.pkl
# Loaded: results_part_11700.pkl
# Loaded: results_part_12650.pkl
# Loaded: results_part_12350.pkl
# Loaded: results_part_12550.pkl
# Loaded: results_part_12600.pkl
# Loaded: results_part_12100.pkl
# Loaded: results_part_12200.pkl
# Loaded: results_part_12150.pkl
# Loaded: results_part_1250.pkl
# Loaded: results_part_12050.pkl
# Loaded: results_part_11800.pkl
# Loaded: results_part_12250.pkl
# Loaded: results_part_12400.pkl
# Loaded: results_part_12500.pkl
# Loaded: results_part_11950.pkl
# Loaded: results_part_11850.pkl
# Loaded: results_part_12300.pkl
# Loaded: results_part_12850.pkl
# Loaded: results_part_12800.pkl
# Loaded: results_part_12950.pkl
# Loaded: results_part_12900.pkl
# Loaded: results_part_13000.pkl
# Loaded: results_part_13050.pkl
# Loaded: results_part_1300.pkl
# Loaded: results_part_13100.pkl
# Loaded: results_part_13150.pkl
# Loaded: results_part_13250.pkl
# Loaded: results_part_13300.pkl
# Loaded: results_part_13200.pkl
# Loaded: results_part_13350.pkl
# Loaded: results_part_1400.pkl
# Loaded: results_part_14000.pkl
# Loaded: results_part_14050.pkl
# Loaded: results_part_13850.pkl
# Loaded: results_part_13900.pkl
# Loaded: results_part_13600.pkl
# Loaded: results_part_14100.pkl
# Loaded: results_part_13500.pkl
# Loaded: results_part_13550.pkl
# Loaded: results_part_13800.pkl
# Loaded: results_part_1350.pkl
# Loaded: results_part_13950.pkl
# Loaded: results_part_13450.pkl
# Loaded: results_part_14200.pkl
# Loaded: results_part_13750.pkl
# Loaded: results_part_13650.pkl
# Loaded: results_part_13400.pkl
# Loaded: results_part_13700.pkl
# Loaded: results_part_14150.pkl
# Loaded: results_part_14250.pkl
# Loaded: results_part_14300.pkl
# Loaded: results_part_14650.pkl
# Loaded: results_part_14400.pkl
# Loaded: results_part_14350.pkl
# Loaded: results_part_14550.pkl
# Loaded: results_part_14450.pkl
# Loaded: results_part_1450.pkl
# Loaded: results_part_14500.pkl
# Loaded: results_part_14600.pkl
# Loaded: results_part_14700.pkl
# Loaded: results_part_14900.pkl
# Loaded: results_part_1500.pkl
# Loaded: results_part_14850.pkl
# Loaded: results_part_15050.pkl
# Loaded: results_part_14950.pkl
# Loaded: results_part_150.pkl
# Loaded: results_part_15100.pkl
# Loaded: results_part_15350.pkl
# Loaded: results_part_15200.pkl
# Loaded: results_part_15150.pkl
# Loaded: results_part_15300.pkl
# Loaded: results_part_1550.pkl
# Loaded: results_part_15250.pkl
# Loaded: results_part_14750.pkl
# Loaded: results_part_14800.pkl
# Loaded: results_part_15500.pkl
# Loaded: results_part_15450.pkl
# Loaded: results_part_15000.pkl
# Loaded: results_part_15400.pkl
# Loaded: results_part_15600.pkl
# Loaded: results_part_15550.pkl
# Loaded: results_part_15650.pkl
# Loaded: results_part_15900.pkl
# Loaded: results_part_15700.pkl
# Loaded: results_part_15800.pkl
# Loaded: results_part_16000.pkl
# Loaded: results_part_1600.pkl
# Loaded: results_part_15950.pkl
# Loaded: results_part_15750.pkl
# Loaded: results_part_15850.pkl
# Loaded: results_part_16050.pkl
# Loaded: results_part_16100.pkl
# Loaded: results_part_16250.pkl
# Loaded: results_part_16150.pkl
# Loaded: results_part_16450.pkl
# Loaded: results_part_16200.pkl
# Loaded: results_part_16400.pkl
# Loaded: results_part_16300.pkl
# Loaded: results_part_1650.pkl
# Loaded: results_part_16500.pkl
# Loaded: results_part_16850.pkl
# Loaded: results_part_16550.pkl
# Loaded: results_part_16350.pkl
# Loaded: results_part_16600.pkl
# Loaded: results_part_16700.pkl
# Loaded: results_part_1700.pkl
# Loaded: results_part_16950.pkl
# Loaded: results_part_16650.pkl
# Loaded: results_part_16800.pkl
# Loaded: results_part_16750.pkl
# Loaded: results_part_16900.pkl
# Loaded: results_part_17050.pkl
# Loaded: results_part_17000.pkl
# Loaded: results_part_18257.pkl
# Loaded: results_part_17100.pkl
# Loaded: results_part_17200.pkl
# Loaded: results_part_17150.pkl
# Loaded: results_part_17300.pkl
# Loaded: results_part_17250.pkl
# Loaded: results_part_17350.pkl
# Loaded: results_part_1750.pkl
# Loaded: results_part_17400.pkl
# Loaded: results_part_17700.pkl
# Loaded: results_part_17550.pkl
# Loaded: results_part_17600.pkl
# Loaded: results_part_17650.pkl
# Loaded: results_part_17750.pkl
# Loaded: results_part_17450.pkl
# Loaded: results_part_17500.pkl
# Loaded: results_part_1900.pkl
# Loaded: results_part_1800.pkl
# Loaded: results_part_17850.pkl
# Loaded: results_part_18050.pkl
# Loaded: results_part_17800.pkl
# Loaded: results_part_18250.pkl
# Loaded: results_part_17900.pkl
# Loaded: results_part_18100.pkl
# Loaded: results_part_18000.pkl
# Loaded: results_part_17950.pkl
# Loaded: results_part_18150.pkl
# Loaded: results_part_1850.pkl
# Loaded: results_part_200.pkl
# Loaded: results_part_2000.pkl
# Loaded: results_part_2050.pkl
# Loaded: results_part_18200.pkl
# Loaded: results_part_1950.pkl
# Loaded: results_part_2100.pkl
# Loaded: results_part_2150.pkl
# Loaded: results_part_2200.pkl
# Loaded: results_part_2400.pkl
# Loaded: results_part_2250.pkl
# Loaded: results_part_2300.pkl
# Loaded: results_part_2450.pkl
# Loaded: results_part_2350.pkl
# Loaded: results_part_250.pkl
# Loaded: results_part_2500.pkl
# Loaded: results_part_2600.pkl
# Loaded: results_part_2550.pkl
# Loaded: results_part_2650.pkl
# Loaded: results_part_300.pkl
# Loaded: results_part_2900.pkl
# Loaded: results_part_2750.pkl
# Loaded: results_part_3000.pkl
# Loaded: results_part_3200.pkl
# Loaded: results_part_2950.pkl
# Loaded: results_part_3050.pkl
# Loaded: results_part_3100.pkl
# Loaded: results_part_3150.pkl
# Loaded: results_part_2850.pkl
# Loaded: results_part_2800.pkl
# Loaded: results_part_3250.pkl
# Loaded: results_part_2700.pkl
# Loaded: results_part_3300.pkl
# Loaded: results_part_3350.pkl
# Loaded: results_part_3400.pkl
# Loaded: results_part_350.pkl
# Loaded: results_part_3500.pkl
# Loaded: results_part_3550.pkl
# Loaded: results_part_3450.pkl
# Loaded: results_part_3600.pkl
# Loaded: results_part_3650.pkl
# Loaded: results_part_3850.pkl
# Loaded: results_part_3800.pkl
# Loaded: results_part_3900.pkl
# Loaded: results_part_3950.pkl
# Loaded: results_part_400.pkl
# Loaded: results_part_3700.pkl
# Loaded: results_part_3750.pkl
# Loaded: results_part_4000.pkl
# Loaded: results_part_4150.pkl
# Loaded: results_part_4500.pkl
# Loaded: results_part_4050.pkl
# Loaded: results_part_4350.pkl
# Loaded: results_part_4250.pkl
# Loaded: results_part_4650.pkl
# Loaded: results_part_4700.pkl
# Loaded: results_part_4200.pkl
# Loaded: results_part_4100.pkl
# Loaded: results_part_4450.pkl
# Loaded: results_part_4400.pkl
# Loaded: results_part_450.pkl
# Loaded: results_part_4800.pkl
# Loaded: results_part_4850.pkl
# Loaded: results_part_4550.pkl
# Loaded: results_part_4600.pkl
# Loaded: results_part_4300.pkl
# Loaded: results_part_4750.pkl
# Loaded: results_part_4900.pkl
# Loaded: results_part_4950.pkl
# Loaded: results_part_500.pkl
# Loaded: results_part_5000.pkl
# Loaded: results_part_5050.pkl
# Loaded: results_part_5100.pkl
# Loaded: results_part_5150.pkl
# Loaded: results_part_5200.pkl
# Loaded: results_part_5300.pkl
# Loaded: results_part_5250.pkl
# Loaded: results_part_5350.pkl
# Loaded: results_part_550.pkl
# Loaded: results_part_5400.pkl
# Loaded: results_part_5450.pkl
# Loaded: results_part_5500.pkl
# Loaded: results_part_5700.pkl
# Loaded: results_part_5600.pkl
# Loaded: results_part_5900.pkl
# Loaded: results_part_5750.pkl
# Loaded: results_part_5800.pkl
# Loaded: results_part_6050.pkl
# Loaded: results_part_5550.pkl
# Loaded: results_part_6000.pkl
# Loaded: results_part_5650.pkl
# Loaded: results_part_600.pkl
# Loaded: results_part_5850.pkl
# Loaded: results_part_6100.pkl
# Loaded: results_part_5950.pkl
# Loaded: results_part_6200.pkl
# Loaded: results_part_6250.pkl
# Loaded: results_part_6350.pkl
# Loaded: results_part_6300.pkl
# Loaded: results_part_6150.pkl
# Loaded: results_part_6400.pkl
# Loaded: results_part_6450.pkl
# Loaded: results_part_650.pkl
# Loaded: results_part_6500.pkl
# Loaded: results_part_6550.pkl
# Loaded: results_part_6750.pkl
# Loaded: results_part_6600.pkl
# Loaded: results_part_6650.pkl
# Loaded: results_part_6850.pkl
# Loaded: results_part_6700.pkl
# Loaded: results_part_700.pkl
# Loaded: results_part_6900.pkl
# Loaded: results_part_6800.pkl
# Loaded: results_part_7400.pkl
# Loaded: results_part_7000.pkl
# Loaded: results_part_7100.pkl
# Loaded: results_part_7150.pkl
# Loaded: results_part_7050.pkl
# Loaded: results_part_7200.pkl
# Loaded: results_part_7250.pkl
# Loaded: results_part_6950.pkl
# Loaded: results_part_7350.pkl
# Loaded: results_part_7450.pkl
# Loaded: results_part_7300.pkl
# Loaded: results_part_750.pkl
# Loaded: results_part_7550.pkl
# Loaded: results_part_7500.pkl
# Loaded: results_part_7650.pkl
# Loaded: results_part_7600.pkl
# Loaded: results_part_7750.pkl
# Loaded: results_part_7700.pkl
# Loaded: results_part_7800.pkl
# Loaded: results_part_7850.pkl
# Loaded: results_part_7900.pkl
# Loaded: results_part_7950.pkl
# Loaded: results_part_800.pkl
# Loaded: results_part_8000.pkl
# Loaded: results_part_8250.pkl
# Loaded: results_part_8200.pkl
# Loaded: results_part_8150.pkl
# Loaded: results_part_8050.pkl
# Loaded: results_part_8100.pkl
# Loaded: results_part_8300.pkl
# Loaded: results_part_8450.pkl
# Loaded: results_part_850.pkl
# Loaded: results_part_8600.pkl
# Loaded: results_part_8350.pkl
# Loaded: results_part_8700.pkl
# Loaded: results_part_8500.pkl
# Loaded: results_part_8400.pkl
# Loaded: results_part_8550.pkl
# Loaded: results_part_900.pkl
# Loaded: results_part_8800.pkl
# Loaded: results_part_8750.pkl
# Loaded: results_part_8900.pkl
# Loaded: results_part_8850.pkl
# Loaded: results_part_8950.pkl
# Loaded: results_part_9000.pkl
# Loaded: results_part_8650.pkl
# Loaded: results_part_9100.pkl
# Loaded: results_part_9050.pkl
# Loaded: results_part_9150.pkl
# Loaded: results_part_9200.pkl
# Loaded: results_part_9250.pkl
# Loaded: results_part_9300.pkl
# Loaded: results_part_9350.pkl
# Loaded: results_part_9400.pkl
# Loaded: results_part_950.pkl
# Loaded: results_part_9500.pkl
# Loaded: results_part_9450.pkl
# Loaded: results_part_9700.pkl
# Loaded: results_part_9650.pkl
# Loaded: results_part_9550.pkl
# Loaded: results_part_9900.pkl
# Loaded: results_part_9600.pkl
# Loaded: results_part_9850.pkl
# Loaded: results_part_9750.pkl
# Loaded: results_part_9950.pkl
# Loaded: results_part_9800.pkl

# %%
with open("PCR_gn.pkl", "rb") as file:
    all_results = pickle.load(file)

import src.evaluation_metrics.plots as plots
importlib.reload(src.evaluation_metrics.plots)

res_raw, c = all_results['../../../../../../evaluation_results/PCR/gn']

keys_to_keep = [
                ('SuffixCountMAE', 'Suffix length MAE'),
                #'LevenshteinMeanVar_activity',
                ('NormalizedDamerauLevenshteinMeanVar_activity', 'DLS'),
                #'RemainingTime_MAE_Median_Var_seconds',
                #'RemainingTime_MAE_Median2_Var_seconds',
                #'RemainingTime_MAE_Mean_Var_seconds',
                #'RemainingTime_MAE_Mean2_Var_seconds',
                #'RemainingTime_MAE_Mean2_Var_seconds_outliers',
                
                #'RemainingTime_MSE_Median_Var_seconds',
                #'RemainingTime_MSE_Median2_Var_seconds',
                #'RemainingTime_MSE_Mean_Var_seconds',
                #'RemainingTime_MSE_Mean2_Var_seconds',
                #'RemainingTime_MSE_Mean2_Var_seconds_outlier'

                #'RemainingTime_SUM_Mean_MSE',
                #('RemainingTime_SUM_Abs_Mean_MAE_outliers', 'Remaining time MAE (minutes)'),
                ('RemainingTime_SUM_Mean_MAE_outliers', 'Rem. time (event sum) MAE (sec.)')
                #'RemainingTime_SUM_Mean_MAE_2',


                #'RemainingTime_MAE_Mean2_Var_seconds_outliers',
                #'RemainingTime_MAE_Mean2_Var_seconds_3.5',
                #'RemainingTime_MAE_Mean2_Var_seconds_2.5',
                #'RemainingTime_MAE_Mean2_Var_seconds_2',

                #'RemainingTime_MSE_Mean2_Var_seconds_outliers',
                #'RemainingTime_MSE_Mean2_Var_seconds_3.5',
                #'RemainingTime_MSE_Mean2_Var_seconds_2.5',
                #'RemainingTime_MSE_Mean2_Var_seconds_2'
]

res = {(k, label) : res_raw[k] for k, label in keys_to_keep}
print(res_raw.keys())
print(len(res_raw.keys()))
print(len(res.keys()))
print(len(keys_to_keep))
print(res.keys())
p = plots.plot_res(res, c, columns=2, caption='PCR', pgf=True)#int(len(keys_to_keep)))
with open('PCR_eval.pgf', 'wb') as f:
    f.write(p)
# Out:
# dict_keys(['LevenshteinMeanVar_activity', 'NormalizedDamerauLevenshteinMeanVar_activity', 'RemainingTime_MAE_Mean2_Var_seconds', 'RemainingTime_SUM_Mean_MAE_outliers', 'RemainingTime_SUM_Abs_Mean_MAE_outliers', 'RemainingTime_PIT', 'EventElapsed_PIT', 'SuffixCount', 'SuffixCountMAE'])
# 9
# 3
# 3
# dict_keys([('SuffixCountMAE', 'Suffix length MAE'), ('NormalizedDamerauLevenshteinMeanVar_activity', 'DLS'), ('RemainingTime_SUM_Mean_MAE_outliers', 'Rem. time (event sum) MAE (sec.)')])

# %%
import src.evaluation_metrics.plots as plots
importlib.reload(src.evaluation_metrics.plots)

res_raw, c = all_results['../../../../../../evaluation_results/PCR/gn']

print('Suffix length MAE')
print(np.mean([i['mean'] for i in res_raw['SuffixCountMAE'].values()]))
print('Probabilistic suffix length MAE')
print(np.mean([i['prob'][0] for i in res_raw['SuffixCountMAE'].values()]))

print('DLS')
print(np.mean([i['mean'] for i in res_raw['NormalizedDamerauLevenshteinMeanVar_activity'].values()]))
print('Probabilistic DLS')
print(np.mean([i['prob'][0] for i in res_raw['NormalizedDamerauLevenshteinMeanVar_activity'].values()]))

print('Mean MAE sum remaining time:')
print(np.mean([i['mean'] for i in res_raw['RemainingTime_SUM_Mean_MAE_outliers'].values()]))
print('Probabilistic MAE sum remaining time:')
print(np.mean([i['prob'][0] for i in res_raw['RemainingTime_SUM_Mean_MAE_outliers'].values()]))

print('Mean MAE last event:')
print(np.mean([i['mean'] for i in res_raw['RemainingTime_MAE_Mean2_Var_seconds'].values()]))
print('Probabilistic MAE last event:')
print(np.mean([i['prob'][0] for i in res_raw['RemainingTime_MAE_Mean2_Var_seconds'].values()]))
# Out:
# Suffix length MAE
# 1.4827189571123405
# Probabilistic suffix length MAE
# 1.9758701867776742
# DLS
# 0.8331565042912229
# Probabilistic DLS
# 0.5868167627701623
# Mean MAE sum remaining time:
# 159.18994478179636
# Probabilistic MAE sum remaining time:
# 165.90757941755862
# Mean MAE last event:
# 9340.077008374607
# Probabilistic MAE last event:
# 19237.20307863922

# %%
import src.evaluation_metrics.plots as plots
importlib.reload(src.evaluation_metrics.plots)

with open('PCR_PIT_event_elapsed.pgf', 'wb') as f:
    r = plots.plot_pits(res_raw['EventElapsed_PIT'], caption='PCR', x_label='Sum of event processing times', pgf=True)
    f.write(r)

with open('PCR_PIT_remaining_time.pgf', 'wb') as f:
    r = plots.plot_pits(res_raw['RemainingTime_PIT'], caption='PCR', x_label='Last case elapsed time', pgf=True)
    f.write(r)

# %%
res_raw['Raw_activity'].keys()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 res_raw['Raw_activity'].keys()
#
# KeyError: 'Raw_activity'

# %%
res_raw['Raw_activity'][('HCA', 1, 7)]

# %%
res_raw['Raw_RemainingTime'][('HCA', 1, 7)]
