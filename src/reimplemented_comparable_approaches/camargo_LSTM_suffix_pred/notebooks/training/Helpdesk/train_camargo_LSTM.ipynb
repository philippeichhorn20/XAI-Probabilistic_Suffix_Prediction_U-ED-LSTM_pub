# %%
"""
Use of same experimental setup as for our Probabilistic Suffix Prediction.

Reimplementation for comparison: 
- Paper: Camargo, Manuel, Marlon Dumas, and Oscar González-Rojas. "Learning accurate LSTM models of business processes." International Conference on Business Process Management. Cham: Springer International Publishing, 2019.
- Github (code) from: https://github.com/AdaptiveBProcess/GenerativeLSTM/tree/master/
"""
# Out:
# '\nUse of same experimental setup as for our Probabilistic Suffix Prediction.\n\nReimplementation for comparison: \n- Paper: Camargo, Manuel, Marlon Dumas, and Oscar González-Rojas. "Learning accurate LSTM models of business processes." International Conference on Business Process Management. Cham: Springer International Publishing, 2019.\n- Github (code) from: https://github.com/AdaptiveBProcess/GenerativeLSTM/tree/master/\n'

# %% [markdown]
# # Imports

# %%
import importlib
import sys
import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../../../encoded_data/compare_camargo/helpdesk_all_5_train.pkl'
# Load the dataset using torch.load
helpdesk_train_dataset = torch.load(file_path_train, weights_only=False)
# Check the type of the loaded dataset
print(type(helpdesk_train_dataset))

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../../../encoded_data/compare_camargo/helpdesk_all_5_val.pkl'
# Load the dataset using torch.load
helpdesk_val_dataset = torch.load(file_path_val, weights_only=False)
# Check the type of the loaded dataset
print(type(helpdesk_val_dataset))
# Out:
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>

# %% [markdown]
# ### Train Data Insights

# %%
# Helpdesk Dataset Categories, Features:
helpdesk_all_categories = helpdesk_train_dataset.all_categories

helpdesk_all_categories_cat = helpdesk_all_categories[0]
print(helpdesk_all_categories_cat)

helpdesk_all_categories_num = helpdesk_all_categories[1]
print(helpdesk_all_categories_num)

for i, cat in enumerate(helpdesk_all_categories_cat):
     print(f"Helpdesk (5) Categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk (5) Total Amount of Category labels: {cat[1]}")

print('\n')    

for i, num in enumerate(helpdesk_all_categories_num):
     print(f"Helpdesk (5) Numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk (5) Amount Numerical: {num[1]}")
     
# Get concept_name id:
concept_name = 'Activity'
concept_name_id = [i for i, cat in enumerate(helpdesk_all_categories[0]) if cat[0] == concept_name][0]
print("ID concet name in cat list: ", concept_name_id)

# Output size
concept_name = 'Activity'
concept_name_size = [cat[1] for _, cat in enumerate(helpdesk_all_categories[0]) if cat[0] == concept_name][0]
print("ID concept name in cat list: ", concept_name_size)
    
# Id of EOS token in activity
eos_value = 'EOS'
eos_id = [v for k, v in helpdesk_all_categories[0][concept_name_id][2].items() if k == eos_value][0]
# Get EOS id of concept name list:

print("ID EOS in concept name tensor: ", eos_id)
# Out:
# [('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15}), ('Resource', 24, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 11': 4, 'Value 12': 5, 'Value 13': 6, 'Value 14': 7, 'Value 15': 8, 'Value 16': 9, 'Value 17': 10, 'Value 18': 11, 'Value 19': 12, 'Value 2': 13, 'Value 20': 14, 'Value 21': 15, 'Value 22': 16, 'Value 3': 17, 'Value 4': 18, 'Value 5': 19, 'Value 6': 20, 'Value 7': 21, 'Value 8': 22, 'Value 9': 23})]
# [('case_elapsed_time', 1, {})]
# Helpdesk (5) Categorical feature: Activity, Index position in categorical data list: 0
# Helpdesk (5) Total Amount of Category labels: 16
# Helpdesk (5) Categorical feature: Resource, Index position in categorical data list: 1
# Helpdesk (5) Total Amount of Category labels: 24
#
#
# Helpdesk (5) Numerical feature: case_elapsed_time, Index position in categorical data list: 0
# Helpdesk (5) Amount Numerical: 1
# ID concet name in cat list:  0
# ID concept name in cat list:  16
# ID EOS in concept name tensor:  5

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Model features (input)
model_feat_cat = []
model_feat_num = []
for cat in helpdesk_all_categories_cat:
    model_feat_cat.append(cat[0])
for num in helpdesk_all_categories_num:
    model_feat_num.append(num[0])
model_feat = [model_feat_cat, model_feat_num]
print("Input features encoder: ", model_feat)
# Out:
# Input features encoder:  [['Activity', 'Resource'], ['case_elapsed_time']]

# %% [markdown]
# # Model

# %%
import joinLSTM.model
importlib.reload(joinLSTM.model)
from joinLSTM.model import FullShared_Join_LSTM

"""
Specific model parameters from paper: 
"""

# Size hidden layer
hidden_size = 50

# Number of LSTM cells
num_layers = 1

# STANDARD: One numerical output to predict
input_size = 1

# Hans Weytjens LSTM model
model = FullShared_Join_LSTM(data_set_categories=helpdesk_all_categories,
                             hidden_size=hidden_size,
                             num_layers=num_layers,
                             model_feat=model_feat,
                             input_size=input_size,
                             output_size_act=concept_name_size)
# Out:
# Data set categories:  ([('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15}), ('Resource', 24, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 11': 4, 'Value 12': 5, 'Value 13': 6, 'Value 14': 7, 'Value 15': 8, 'Value 16': 9, 'Value 17': 10, 'Value 18': 11, 'Value 19': 12, 'Value 2': 13, 'Value 20': 14, 'Value 21': 15, 'Value 22': 16, 'Value 3': 17, 'Value 4': 18, 'Value 5': 19, 'Value 6': 20, 'Value 7': 21, 'Value 8': 22, 'Value 9': 23})], [('case_elapsed_time', 1, {})])
# Model input features:  [['Activity', 'Resource'], ['case_elapsed_time']]
#
#
# Embeddings:  ModuleList(
#   (0): Embedding(16, 8)
#   (1): Embedding(24, 9)
# )
# Total embedding feature size:  17
# Input feature size:  18
# Cells hidden size:  50
# Number of LSTM layer:  1
# /home/LordKunkler/.local/share/virtualenvs/PrimePPM-tDGhFIeG/lib/python3.13/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn(

# %% [markdown]
# # Training Configuration

# %%
import training.train
importlib.reload(training.train)
from training.train import Training

from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_helpdesk_camargo_act")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

"""
Parameter of Probabilistic Suffix Prediction experimental design, to ensure fair comparison:
"""

# Start learning rate
learning_rate = 1e-5

# Optimizer and Scheduler
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate, weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=4, min_lr=1e-10)

# Epochs
num_epochs = 100

# Batch of model input
batch_size = 128

# shuffle data
shuffle = True

optimize_values = {"optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle}

number_tasks = len(model_feat)

trainer = Training(model=model,
                   device=device,
                   data_train=helpdesk_train_dataset,
                   data_val=helpdesk_val_dataset,
                   optimize_values=optimize_values,
                   concept_name_id=concept_name_id,
                   eos_id=eos_id,
                   writer=writer,
                   save_model_n_th_epoch=1,
                   saving_path="Helpdesk_camargo_act_1_suffix_length5.pkl")

# Train the model:
trainer.train()
# Out:
# Device:  cuda
# Optimizer:  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7f72d70d0d70>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch [1/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.7696
# Validation: Avg Validation Loss: 2.7646
# Validation Loss for Scheduler: 2.7646
# saving model
# Epoch [2/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.7589
# Validation: Avg Validation Loss: 2.7520
# Validation Loss for Scheduler: 2.7520
# saving model
# Epoch [3/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.7439
# Validation: Avg Validation Loss: 2.7339
# Validation Loss for Scheduler: 2.7339
# saving model
# Epoch [4/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.7223
# Validation: Avg Validation Loss: 2.7074
# Validation Loss for Scheduler: 2.7074
# saving model
# Epoch [5/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.6908
# Validation: Avg Validation Loss: 2.6689
# Validation Loss for Scheduler: 2.6689
# saving model
# Epoch [6/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.6452
# Validation: Avg Validation Loss: 2.6133
# Validation Loss for Scheduler: 2.6133
# saving model
# Epoch [7/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.5831
# Validation: Avg Validation Loss: 2.5424
# Validation Loss for Scheduler: 2.5424
# saving model
# Epoch [8/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.5068
# Validation: Avg Validation Loss: 2.4610
# Validation Loss for Scheduler: 2.4610
# saving model
# Epoch [9/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.4320
# Validation: Avg Validation Loss: 2.3913
# Validation Loss for Scheduler: 2.3913
# saving model
# Epoch [10/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.3705
# Validation: Avg Validation Loss: 2.3378
# Validation Loss for Scheduler: 2.3378
# saving model
# Epoch [11/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.3242
# Validation: Avg Validation Loss: 2.3008
# Validation Loss for Scheduler: 2.3008
# saving model
# Epoch [12/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2915
# Validation: Avg Validation Loss: 2.2699
# Validation Loss for Scheduler: 2.2699
# saving model
# Epoch [13/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2678
# Validation: Avg Validation Loss: 2.2482
# Validation Loss for Scheduler: 2.2482
# saving model
# Epoch [14/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2479
# Validation: Avg Validation Loss: 2.2263
# Validation Loss for Scheduler: 2.2263
# saving model
# Epoch [15/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2339
# Validation: Avg Validation Loss: 2.2197
# Validation Loss for Scheduler: 2.2197
# saving model
# Epoch [16/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2222
# Validation: Avg Validation Loss: 2.2128
# Validation Loss for Scheduler: 2.2128
# saving model
# Epoch [17/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2116
# Validation: Avg Validation Loss: 2.1971
# Validation Loss for Scheduler: 2.1971
# saving model
# Epoch [18/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2036
# Validation: Avg Validation Loss: 2.1918
# Validation Loss for Scheduler: 2.1918
# saving model
# Epoch [19/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1966
# Validation: Avg Validation Loss: 2.1856
# Validation Loss for Scheduler: 2.1856
# saving model
# Epoch [20/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1892
# Validation: Avg Validation Loss: 2.1794
# Validation Loss for Scheduler: 2.1794
# saving model
# Epoch [21/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1854
# Validation: Avg Validation Loss: 2.1726
# Validation Loss for Scheduler: 2.1726
# saving model
# Epoch [22/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1801
# Validation: Avg Validation Loss: 2.1674
# Validation Loss for Scheduler: 2.1674
# saving model
# Epoch [23/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1763
# Validation: Avg Validation Loss: 2.1640
# Validation Loss for Scheduler: 2.1640
# saving model
# Epoch [24/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1721
# Validation: Avg Validation Loss: 2.1613
# Validation Loss for Scheduler: 2.1613
# saving model
# Epoch [25/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1695
# Validation: Avg Validation Loss: 2.1544
# Validation Loss for Scheduler: 2.1544
# saving model
# Epoch [26/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1656
# Validation: Avg Validation Loss: 2.1515
# Validation Loss for Scheduler: 2.1515
# saving model
# Epoch [27/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1627
# Validation: Avg Validation Loss: 2.1529
# Validation Loss for Scheduler: 2.1529
# saving model
# Epoch [28/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1599
# Validation: Avg Validation Loss: 2.1467
# Validation Loss for Scheduler: 2.1467
# saving model
# Epoch [29/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1565
# Validation: Avg Validation Loss: 2.1423
# Validation Loss for Scheduler: 2.1423
# saving model
# Epoch [30/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1537
# Validation: Avg Validation Loss: 2.1405
# Validation Loss for Scheduler: 2.1405
# saving model
# Epoch [31/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1501
# Validation: Avg Validation Loss: 2.1355
# Validation Loss for Scheduler: 2.1355
# saving model
# Epoch [32/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1478
# Validation: Avg Validation Loss: 2.1339
# Validation Loss for Scheduler: 2.1339
# saving model
# Epoch [33/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1450
# Validation: Avg Validation Loss: 2.1298
# Validation Loss for Scheduler: 2.1298
# saving model
# Epoch [34/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1416
# Validation: Avg Validation Loss: 2.1255
# Validation Loss for Scheduler: 2.1255
# saving model
# Epoch [35/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1388
# Validation: Avg Validation Loss: 2.1259
# Validation Loss for Scheduler: 2.1259
# saving model
# Epoch [36/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1352
# Validation: Avg Validation Loss: 2.1191
# Validation Loss for Scheduler: 2.1191
# saving model
# Epoch [37/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1309
# Validation: Avg Validation Loss: 2.1129
# Validation Loss for Scheduler: 2.1129
# saving model
# Epoch [38/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1266
# Validation: Avg Validation Loss: 2.1142
# Validation Loss for Scheduler: 2.1142
# saving model
# Epoch [39/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1210
# Validation: Avg Validation Loss: 2.1034
# Validation Loss for Scheduler: 2.1034
# saving model
# Epoch [40/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1162
# Validation: Avg Validation Loss: 2.1027
# Validation Loss for Scheduler: 2.1027
# saving model
# Epoch [41/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1106
# Validation: Avg Validation Loss: 2.0990
# Validation Loss for Scheduler: 2.0990
# saving model
# Epoch [42/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1038
# Validation: Avg Validation Loss: 2.0899
# Validation Loss for Scheduler: 2.0899
# saving model
# Epoch [43/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0967
# Validation: Avg Validation Loss: 2.0817
# Validation Loss for Scheduler: 2.0817
# saving model
# Epoch [44/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0898
# Validation: Avg Validation Loss: 2.0757
# Validation Loss for Scheduler: 2.0757
# saving model
# Epoch [45/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0827
# Validation: Avg Validation Loss: 2.0670
# Validation Loss for Scheduler: 2.0670
# saving model
# Epoch [46/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0752
# Validation: Avg Validation Loss: 2.0628
# Validation Loss for Scheduler: 2.0628
# saving model
# Epoch [47/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0677
# Validation: Avg Validation Loss: 2.0555
# Validation Loss for Scheduler: 2.0555
# saving model
# Epoch [48/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0598
# Validation: Avg Validation Loss: 2.0485
# Validation Loss for Scheduler: 2.0485
# saving model
# Epoch [49/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0528
# Validation: Avg Validation Loss: 2.0392
# Validation Loss for Scheduler: 2.0392
# saving model
# Epoch [50/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0452
# Validation: Avg Validation Loss: 2.0329
# Validation Loss for Scheduler: 2.0329
# saving model
# Epoch [51/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0381
# Validation: Avg Validation Loss: 2.0274
# Validation Loss for Scheduler: 2.0274
# saving model
# Epoch [52/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0312
# Validation: Avg Validation Loss: 2.0227
# Validation Loss for Scheduler: 2.0227
# saving model
# Epoch [53/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0245
# Validation: Avg Validation Loss: 2.0109
# Validation Loss for Scheduler: 2.0109
# saving model
# Epoch [54/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0185
# Validation: Avg Validation Loss: 2.0065
# Validation Loss for Scheduler: 2.0065
# saving model
# Epoch [55/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0123
# Validation: Avg Validation Loss: 2.0034
# Validation Loss for Scheduler: 2.0034
# saving model
# Epoch [56/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0070
# Validation: Avg Validation Loss: 1.9968
# Validation Loss for Scheduler: 1.9968
# saving model
# Epoch [57/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0019
# Validation: Avg Validation Loss: 1.9923
# Validation Loss for Scheduler: 1.9923
# saving model
# Epoch [58/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9968
# Validation: Avg Validation Loss: 1.9871
# Validation Loss for Scheduler: 1.9871
# saving model
# Epoch [59/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9934
# Validation: Avg Validation Loss: 1.9850
# Validation Loss for Scheduler: 1.9850
# saving model
# Epoch [60/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9895
# Validation: Avg Validation Loss: 1.9804
# Validation Loss for Scheduler: 1.9804
# saving model
# Epoch [61/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9857
# Validation: Avg Validation Loss: 1.9763
# Validation Loss for Scheduler: 1.9763
# saving model
# Epoch [62/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9821
# Validation: Avg Validation Loss: 1.9747
# Validation Loss for Scheduler: 1.9747
# saving model
# Epoch [63/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9796
# Validation: Avg Validation Loss: 1.9712
# Validation Loss for Scheduler: 1.9712
# saving model
# Epoch [64/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9764
# Validation: Avg Validation Loss: 1.9700
# Validation Loss for Scheduler: 1.9700
# saving model
# Epoch [65/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9731
# Validation: Avg Validation Loss: 1.9674
# Validation Loss for Scheduler: 1.9674
# saving model
# Epoch [66/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9713
# Validation: Avg Validation Loss: 1.9633
# Validation Loss for Scheduler: 1.9633
# saving model
# Epoch [67/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9689
# Validation: Avg Validation Loss: 1.9650
# Validation Loss for Scheduler: 1.9650
# saving model
# Epoch [68/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9669
# Validation: Avg Validation Loss: 1.9590
# Validation Loss for Scheduler: 1.9590
# saving model
# Epoch [69/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9647
# Validation: Avg Validation Loss: 1.9593
# Validation Loss for Scheduler: 1.9593
# saving model
# Epoch [70/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9629
# Validation: Avg Validation Loss: 1.9559
# Validation Loss for Scheduler: 1.9559
# saving model
# Epoch [71/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9612
# Validation: Avg Validation Loss: 1.9558
# Validation Loss for Scheduler: 1.9558
# saving model
# Epoch [72/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9594
# Validation: Avg Validation Loss: 1.9552
# Validation Loss for Scheduler: 1.9552
# saving model
# Epoch [73/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9577
# Validation: Avg Validation Loss: 1.9519
# Validation Loss for Scheduler: 1.9519
# saving model
# Epoch [74/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9556
# Validation: Avg Validation Loss: 1.9492
# Validation Loss for Scheduler: 1.9492
# saving model
# Epoch [75/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9551
# Validation: Avg Validation Loss: 1.9500
# Validation Loss for Scheduler: 1.9500
# saving model
# Epoch [76/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9538
# Validation: Avg Validation Loss: 1.9474
# Validation Loss for Scheduler: 1.9474
# saving model
# Epoch [77/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9524
# Validation: Avg Validation Loss: 1.9473
# Validation Loss for Scheduler: 1.9473
# saving model
# Epoch [78/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9514
# Validation: Avg Validation Loss: 1.9445
# Validation Loss for Scheduler: 1.9445
# saving model
# Epoch [79/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9499
# Validation: Avg Validation Loss: 1.9453
# Validation Loss for Scheduler: 1.9453
# saving model
# Epoch [80/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9495
# Validation: Avg Validation Loss: 1.9437
# Validation Loss for Scheduler: 1.9437
# saving model
# Epoch [81/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9485
# Validation: Avg Validation Loss: 1.9416
# Validation Loss for Scheduler: 1.9416
# saving model
# Epoch [82/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9468
# Validation: Avg Validation Loss: 1.9408
# Validation Loss for Scheduler: 1.9408
# saving model
# Epoch [83/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9466
# Validation: Avg Validation Loss: 1.9392
# Validation Loss for Scheduler: 1.9392
# saving model
# Epoch [84/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9456
# Validation: Avg Validation Loss: 1.9418
# Validation Loss for Scheduler: 1.9418
# saving model
# Epoch [85/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9451
# Validation: Avg Validation Loss: 1.9386
# Validation Loss for Scheduler: 1.9386
# saving model
# Epoch [86/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9439
# Validation: Avg Validation Loss: 1.9399
# Validation Loss for Scheduler: 1.9399
# saving model
# Epoch [87/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9433
# Validation: Avg Validation Loss: 1.9364
# Validation Loss for Scheduler: 1.9364
# saving model
# Epoch [88/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9426
# Validation: Avg Validation Loss: 1.9362
# Validation Loss for Scheduler: 1.9362
# saving model
# Epoch [89/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9417
# Validation: Avg Validation Loss: 1.9360
# Validation Loss for Scheduler: 1.9360
# saving model
# Epoch [90/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9408
# Validation: Avg Validation Loss: 1.9351
# Validation Loss for Scheduler: 1.9351
# saving model
# Epoch [91/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9403
# Validation: Avg Validation Loss: 1.9341
# Validation Loss for Scheduler: 1.9341
# saving model
# Epoch [92/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9397
# Validation: Avg Validation Loss: 1.9351
# Validation Loss for Scheduler: 1.9351
# saving model
# Epoch [93/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9390
# Validation: Avg Validation Loss: 1.9333
# Validation Loss for Scheduler: 1.9333
# saving model
# Epoch [94/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9386
# Validation: Avg Validation Loss: 1.9328
# Validation Loss for Scheduler: 1.9328
# saving model
# Epoch [95/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9380
# Validation: Avg Validation Loss: 1.9356
# Validation Loss for Scheduler: 1.9356
# saving model
# Epoch [96/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9380
# Validation: Avg Validation Loss: 1.9323
# Validation Loss for Scheduler: 1.9323
# saving model
# Epoch [97/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9372
# Validation: Avg Validation Loss: 1.9308
# Validation Loss for Scheduler: 1.9308
# saving model
# Epoch [98/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9365
# Validation: Avg Validation Loss: 1.9322
# Validation Loss for Scheduler: 1.9322
# saving model
# Epoch [99/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9366
# Validation: Avg Validation Loss: 1.9337
# Validation Loss for Scheduler: 1.9337
# saving model
# Epoch [100/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9361
# Validation: Avg Validation Loss: 1.9292
# Validation Loss for Scheduler: 1.9292
# saving model
# Training complete.
# Model saved to path: Helpdesk_camargo_act_1_suffix_length5.pkl
