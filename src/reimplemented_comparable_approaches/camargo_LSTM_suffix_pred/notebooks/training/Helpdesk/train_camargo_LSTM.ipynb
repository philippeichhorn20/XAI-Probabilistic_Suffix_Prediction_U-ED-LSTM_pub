# %%
"""
Use of same experimental setup as for our Probabilistic Suffix Prediction.

Reimplementation for comparison: 
- Paper: Camargo, Manuel, Marlon Dumas, and Oscar González-Rojas. "Learning accurate LSTM models of business processes." International Conference on Business Process Management. Cham: Springer International Publishing, 2019.
- Github (code) from: https://github.com/AdaptiveBProcess/GenerativeLSTM/tree/master/
"""
# Out:
# '\nUse of same experimental setup as for our Probabilistic Suffix Prediction.\n\nReimplementation for comparison: \n- Paper: Camargo, Manuel, Marlon Dumas, and Oscar González-Rojas. "Learning accurate LSTM models of business processes." International Conference on Business Process Management. Cham: Springer International Publishing, 2019.\n- Github (code) from: https://github.com/AdaptiveBProcess/GenerativeLSTM/tree/master/\n'

# %% [markdown]
# # Imports

# %%
import importlib
import sys
import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../../../encoded_data/compare_camargo/helpdesk_all_5_train.pkl'
# Load the dataset using torch.load
helpdesk_train_dataset = torch.load(file_path_train, weights_only=False)
# Check the type of the loaded dataset
print(type(helpdesk_train_dataset))

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../../../encoded_data/compare_camargo/helpdesk_all_5_val.pkl'
# Load the dataset using torch.load
helpdesk_val_dataset = torch.load(file_path_val, weights_only=False)
# Check the type of the loaded dataset
print(type(helpdesk_val_dataset))
# Out:
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>

# %% [markdown]
# ### Train Data Insights

# %%
# Helpdesk Dataset Categories, Features:
helpdesk_all_categories = helpdesk_train_dataset.all_categories

helpdesk_all_categories_cat = helpdesk_all_categories[0]
print(helpdesk_all_categories_cat)

helpdesk_all_categories_num = helpdesk_all_categories[1]
print(helpdesk_all_categories_num)

for i, cat in enumerate(helpdesk_all_categories_cat):
     print(f"Helpdesk (5) Categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk (5) Total Amount of Category labels: {cat[1]}")

print('\n')    

for i, num in enumerate(helpdesk_all_categories_num):
     print(f"Helpdesk (5) Numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk (5) Amount Numerical: {num[1]}")
     
# Get concept_name id:
concept_name = 'Activity'
concept_name_id = [i for i, cat in enumerate(helpdesk_all_categories[0]) if cat[0] == concept_name][0]
print("ID concet name in cat list: ", concept_name_id)

# Output size
concept_name = 'Activity'
concept_name_size = [cat[1] for _, cat in enumerate(helpdesk_all_categories[0]) if cat[0] == concept_name][0]
print("ID concept name in cat list: ", concept_name_size)
    
# Id of EOS token in activity
eos_value = 'EOS'
eos_id = [v for k, v in helpdesk_all_categories[0][concept_name_id][2].items() if k == eos_value][0]
# Get EOS id of concept name list:

print("ID EOS in concept name tensor: ", eos_id)
# Out:
# [('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15}), ('Resource', 24, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 11': 4, 'Value 12': 5, 'Value 13': 6, 'Value 14': 7, 'Value 15': 8, 'Value 16': 9, 'Value 17': 10, 'Value 18': 11, 'Value 19': 12, 'Value 2': 13, 'Value 20': 14, 'Value 21': 15, 'Value 22': 16, 'Value 3': 17, 'Value 4': 18, 'Value 5': 19, 'Value 6': 20, 'Value 7': 21, 'Value 8': 22, 'Value 9': 23})]
# [('case_elapsed_time', 1, {})]
# Helpdesk (5) Categorical feature: Activity, Index position in categorical data list: 0
# Helpdesk (5) Total Amount of Category labels: 16
# Helpdesk (5) Categorical feature: Resource, Index position in categorical data list: 1
# Helpdesk (5) Total Amount of Category labels: 24
#
#
# Helpdesk (5) Numerical feature: case_elapsed_time, Index position in categorical data list: 0
# Helpdesk (5) Amount Numerical: 1
# ID concet name in cat list:  0
# ID concept name in cat list:  16
# ID EOS in concept name tensor:  5

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Model features (input)
model_feat_cat = []
model_feat_num = []
for cat in helpdesk_all_categories_cat:
    model_feat_cat.append(cat[0])
for num in helpdesk_all_categories_num:
    model_feat_num.append(num[0])
model_feat = [model_feat_cat, model_feat_num]
print("Input features encoder: ", model_feat)
# Out:
# Input features encoder:  [['Activity', 'Resource'], ['case_elapsed_time']]

# %% [markdown]
# # Model

# %%
import joinLSTM.model
importlib.reload(joinLSTM.model)
from joinLSTM.model import FullShared_Join_LSTM

"""
Specific model parameters from paper: 
"""

# Size hidden layer
hidden_size = 50

# Number of LSTM cells
num_layers = 1

# STANDARD: One numerical output to predict
input_size = 1

# Hans Weytjens LSTM model
model = FullShared_Join_LSTM(data_set_categories=helpdesk_all_categories,
                             hidden_size=hidden_size,
                             num_layers=num_layers,
                             model_feat=model_feat,
                             input_size=input_size,
                             output_size_act=concept_name_size)
# Out:
# Data set categories:  ([('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15}), ('Resource', 24, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 11': 4, 'Value 12': 5, 'Value 13': 6, 'Value 14': 7, 'Value 15': 8, 'Value 16': 9, 'Value 17': 10, 'Value 18': 11, 'Value 19': 12, 'Value 2': 13, 'Value 20': 14, 'Value 21': 15, 'Value 22': 16, 'Value 3': 17, 'Value 4': 18, 'Value 5': 19, 'Value 6': 20, 'Value 7': 21, 'Value 8': 22, 'Value 9': 23})], [('case_elapsed_time', 1, {})])
# Model input features:  [['Activity', 'Resource'], ['case_elapsed_time']]
#
#
# Embeddings:  ModuleList(
#   (0): Embedding(16, 8)
#   (1): Embedding(24, 9)
# )
# Total embedding feature size:  17
# Input feature size:  18
# Cells hidden size:  50
# Number of LSTM layer:  1
# /Users/philippeichhorn/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/torch/nn/modules/rnn.py:990: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)

# %% [markdown]
# # Training Configuration

# %%
import training.train
importlib.reload(training.train)
from training.train import Training

from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_helpdesk_camargo_act")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

"""
Parameter of Probabilistic Suffix Prediction experimental design, to ensure fair comparison:
"""

# Start learning rate
learning_rate = 1e-5

# Optimizer and Scheduler
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate, weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=4, min_lr=1e-10)

# Epochs
num_epochs = 100

# Batch of model input
batch_size = 128

# shuffle data
shuffle = True

optimize_values = {"optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle}

number_tasks = len(model_feat)

trainer = Training(model=model,
                   device=device,
                   data_train=helpdesk_train_dataset,
                   data_val=helpdesk_val_dataset,
                   optimize_values=optimize_values,
                   concept_name_id=concept_name_id,
                   eos_id=eos_id,
                   writer=writer,
                   save_model_n_th_epoch=1,
                   saving_path="Helpdesk_camargo_act_1_suffix_length5.pkl")

# Train the model:
trainer.train()
# Out:
# Device:  cpu
# Optimizer:  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x1421d2720>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/philippeichhorn/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, device pinned memory won't be used.
#   super().__init__(loader)
# Epoch [1/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.7624
# Validation: Avg Validation Loss: 2.7566
# Validation Loss for Scheduler: 2.7566
# saving model
# Epoch [2/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.7489
# Validation: Avg Validation Loss: 2.7402
# Validation Loss for Scheduler: 2.7402
# saving model
# Epoch [3/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.7266
# Validation: Avg Validation Loss: 2.7110
# Validation Loss for Scheduler: 2.7110
# saving model
# Epoch [4/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.6855
# Validation: Avg Validation Loss: 2.6544
# Validation Loss for Scheduler: 2.6544
# saving model
# Epoch [5/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.6160
# Validation: Avg Validation Loss: 2.5714
# Validation Loss for Scheduler: 2.5714
# saving model
# Epoch [6/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.5248
# Validation: Avg Validation Loss: 2.4736
# Validation Loss for Scheduler: 2.4736
# saving model
# Epoch [7/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.4370
# Validation: Avg Validation Loss: 2.3944
# Validation Loss for Scheduler: 2.3944
# saving model
# Epoch [8/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.3687
# Validation: Avg Validation Loss: 2.3352
# Validation Loss for Scheduler: 2.3352
# saving model
# Epoch [9/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.3192
# Validation: Avg Validation Loss: 2.2964
# Validation Loss for Scheduler: 2.2964
# saving model
# Epoch [10/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2858
# Validation: Avg Validation Loss: 2.2658
# Validation Loss for Scheduler: 2.2658
# saving model
# Epoch [11/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2610
# Validation: Avg Validation Loss: 2.2411
# Validation Loss for Scheduler: 2.2411
# saving model
# Epoch [12/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2408
# Validation: Avg Validation Loss: 2.2265
# Validation Loss for Scheduler: 2.2265
# saving model
# Epoch [13/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2275
# Validation: Avg Validation Loss: 2.2122
# Validation Loss for Scheduler: 2.2122
# saving model
# Epoch [14/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2152
# Validation: Avg Validation Loss: 2.2027
# Validation Loss for Scheduler: 2.2027
# saving model
# Epoch [15/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2064
# Validation: Avg Validation Loss: 2.1945
# Validation Loss for Scheduler: 2.1945
# saving model
# Epoch [16/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1968
# Validation: Avg Validation Loss: 2.1861
# Validation Loss for Scheduler: 2.1861
# saving model
# Epoch [17/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1920
# Validation: Avg Validation Loss: 2.1773
# Validation Loss for Scheduler: 2.1773
# saving model
# Epoch [18/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1877
# Validation: Avg Validation Loss: 2.1738
# Validation Loss for Scheduler: 2.1738
# saving model
# Epoch [19/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1824
# Validation: Avg Validation Loss: 2.1712
# Validation Loss for Scheduler: 2.1712
# saving model
# Epoch [20/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1779
# Validation: Avg Validation Loss: 2.1677
# Validation Loss for Scheduler: 2.1677
# saving model
# Epoch [21/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1755
# Validation: Avg Validation Loss: 2.1644
# Validation Loss for Scheduler: 2.1644
# saving model
# Epoch [22/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1708
# Validation: Avg Validation Loss: 2.1615
# Validation Loss for Scheduler: 2.1615
# saving model
# Epoch [23/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1690
# Validation: Avg Validation Loss: 2.1568
# Validation Loss for Scheduler: 2.1568
# saving model
# Epoch [24/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1657
# Validation: Avg Validation Loss: 2.1578
# Validation Loss for Scheduler: 2.1578
# saving model
# Epoch [25/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1655
# Validation: Avg Validation Loss: 2.1546
# Validation Loss for Scheduler: 2.1546
# saving model
# Epoch [26/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1621
# Validation: Avg Validation Loss: 2.1504
# Validation Loss for Scheduler: 2.1504
# saving model
# Epoch [27/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1596
# Validation: Avg Validation Loss: 2.1498
# Validation Loss for Scheduler: 2.1498
# saving model
# Epoch [28/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1565
# Validation: Avg Validation Loss: 2.1431
# Validation Loss for Scheduler: 2.1431
# saving model
# Epoch [29/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1526
# Validation: Avg Validation Loss: 2.1432
# Validation Loss for Scheduler: 2.1432
# saving model
# Epoch [30/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1502
# Validation: Avg Validation Loss: 2.1394
# Validation Loss for Scheduler: 2.1394
# saving model
# Epoch [31/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1463
# Validation: Avg Validation Loss: 2.1365
# Validation Loss for Scheduler: 2.1365
# saving model
# Epoch [32/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1436
# Validation: Avg Validation Loss: 2.1306
# Validation Loss for Scheduler: 2.1306
# saving model
# Epoch [33/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1409
# Validation: Avg Validation Loss: 2.1295
# Validation Loss for Scheduler: 2.1295
# saving model
# Epoch [34/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1369
# Validation: Avg Validation Loss: 2.1273
# Validation Loss for Scheduler: 2.1273
# saving model
# Epoch [35/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1326
# Validation: Avg Validation Loss: 2.1217
# Validation Loss for Scheduler: 2.1217
# saving model
# Epoch [36/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1291
# Validation: Avg Validation Loss: 2.1173
# Validation Loss for Scheduler: 2.1173
# saving model
# Epoch [37/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1238
# Validation: Avg Validation Loss: 2.1115
# Validation Loss for Scheduler: 2.1115
# saving model
# Epoch [38/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1177
# Validation: Avg Validation Loss: 2.1060
# Validation Loss for Scheduler: 2.1060
# saving model
# Epoch [39/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1093
# Validation: Avg Validation Loss: 2.0964
# Validation Loss for Scheduler: 2.0964
# saving model
# Epoch [40/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1014
# Validation: Avg Validation Loss: 2.0886
# Validation Loss for Scheduler: 2.0886
# saving model
# Epoch [41/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0931
# Validation: Avg Validation Loss: 2.0790
# Validation Loss for Scheduler: 2.0790
# saving model
# Epoch [42/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0831
# Validation: Avg Validation Loss: 2.0682
# Validation Loss for Scheduler: 2.0682
# saving model
# Epoch [43/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0727
# Validation: Avg Validation Loss: 2.0590
# Validation Loss for Scheduler: 2.0590
# saving model
# Epoch [44/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0633
# Validation: Avg Validation Loss: 2.0499
# Validation Loss for Scheduler: 2.0499
# saving model
# Epoch [45/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0544
# Validation: Avg Validation Loss: 2.0418
# Validation Loss for Scheduler: 2.0418
# saving model
# Epoch [46/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0479
# Validation: Avg Validation Loss: 2.0332
# Validation Loss for Scheduler: 2.0332
# saving model
# Epoch [47/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0416
# Validation: Avg Validation Loss: 2.0269
# Validation Loss for Scheduler: 2.0269
# saving model
# Epoch [48/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0355
# Validation: Avg Validation Loss: 2.0229
# Validation Loss for Scheduler: 2.0229
# saving model
# Epoch [49/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0316
# Validation: Avg Validation Loss: 2.0178
# Validation Loss for Scheduler: 2.0178
# saving model
# Epoch [50/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0266
# Validation: Avg Validation Loss: 2.0149
# Validation Loss for Scheduler: 2.0149
# saving model
# Epoch [51/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0249
# Validation: Avg Validation Loss: 2.0126
# Validation Loss for Scheduler: 2.0126
# saving model
# Epoch [52/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0215
# Validation: Avg Validation Loss: 2.0079
# Validation Loss for Scheduler: 2.0079
# saving model
# Epoch [53/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0182
# Validation: Avg Validation Loss: 2.0067
# Validation Loss for Scheduler: 2.0067
# saving model
# Epoch [54/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0183
# Validation: Avg Validation Loss: 2.0036
# Validation Loss for Scheduler: 2.0036
# saving model
# Epoch [55/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0162
# Validation: Avg Validation Loss: 2.0027
# Validation Loss for Scheduler: 2.0027
# saving model
# Epoch [56/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0148
# Validation: Avg Validation Loss: 2.0006
# Validation Loss for Scheduler: 2.0006
# saving model
# Epoch [57/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0122
# Validation: Avg Validation Loss: 1.9998
# Validation Loss for Scheduler: 1.9998
# saving model
# Epoch [58/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0096
# Validation: Avg Validation Loss: 1.9982
# Validation Loss for Scheduler: 1.9982
# saving model
# Epoch [59/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0092
# Validation: Avg Validation Loss: 1.9963
# Validation Loss for Scheduler: 1.9963
# saving model
# Epoch [60/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0078
# Validation: Avg Validation Loss: 1.9958
# Validation Loss for Scheduler: 1.9958
# saving model
# Epoch [61/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0072
# Validation: Avg Validation Loss: 1.9939
# Validation Loss for Scheduler: 1.9939
# saving model
# Epoch [62/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0058
# Validation: Avg Validation Loss: 1.9925
# Validation Loss for Scheduler: 1.9925
# saving model
# Epoch [63/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0054
# Validation: Avg Validation Loss: 1.9930
# Validation Loss for Scheduler: 1.9930
# saving model
# Epoch [64/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0034
# Validation: Avg Validation Loss: 1.9916
# Validation Loss for Scheduler: 1.9916
# saving model
# Epoch [65/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0032
# Validation: Avg Validation Loss: 1.9908
# Validation Loss for Scheduler: 1.9908
# saving model
# Epoch [66/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0019
# Validation: Avg Validation Loss: 1.9917
# Validation Loss for Scheduler: 1.9917
# saving model
# Epoch [67/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0025
# Validation: Avg Validation Loss: 1.9894
# Validation Loss for Scheduler: 1.9894
# saving model
# Epoch [68/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0008
# Validation: Avg Validation Loss: 1.9886
# Validation Loss for Scheduler: 1.9886
# saving model
# Epoch [69/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0025
# Validation: Avg Validation Loss: 1.9909
# Validation Loss for Scheduler: 1.9909
# saving model
# Epoch [70/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0006
# Validation: Avg Validation Loss: 1.9886
# Validation Loss for Scheduler: 1.9886
# saving model
# Epoch [71/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0007
# Validation: Avg Validation Loss: 1.9886
# Validation Loss for Scheduler: 1.9886
# saving model
# Epoch [72/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9992
# Validation: Avg Validation Loss: 1.9901
# Validation Loss for Scheduler: 1.9901
# saving model
# Epoch [73/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9985
# Validation: Avg Validation Loss: 1.9874
# Validation Loss for Scheduler: 1.9874
# saving model
# Epoch [74/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9996
# Validation: Avg Validation Loss: 1.9866
# Validation Loss for Scheduler: 1.9866
# saving model
# Epoch [75/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9981
# Validation: Avg Validation Loss: 1.9853
# Validation Loss for Scheduler: 1.9853
# saving model
# Epoch [76/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9989
# Validation: Avg Validation Loss: 1.9869
# Validation Loss for Scheduler: 1.9869
# saving model
# Epoch [77/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9980
# Validation: Avg Validation Loss: 1.9865
# Validation Loss for Scheduler: 1.9865
# saving model
# Epoch [78/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9965
# Validation: Avg Validation Loss: 1.9859
# Validation Loss for Scheduler: 1.9859
# saving model
# Epoch [79/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9970
# Validation: Avg Validation Loss: 1.9868
# Validation Loss for Scheduler: 1.9868
# saving model
# Epoch [80/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9971
# Validation: Avg Validation Loss: 1.9839
# Validation Loss for Scheduler: 1.9839
# saving model
# Epoch [81/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9963
# Validation: Avg Validation Loss: 1.9844
# Validation Loss for Scheduler: 1.9844
# saving model
# Epoch [82/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9960
# Validation: Avg Validation Loss: 1.9863
# Validation Loss for Scheduler: 1.9863
# saving model
# Epoch [83/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9972
# Validation: Avg Validation Loss: 1.9847
# Validation Loss for Scheduler: 1.9847
# saving model
# Epoch [84/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9959
# Validation: Avg Validation Loss: 1.9837
# Validation Loss for Scheduler: 1.9837
# saving model
# Epoch [85/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9963
# Validation: Avg Validation Loss: 1.9836
# Validation Loss for Scheduler: 1.9836
# saving model
# Epoch [86/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9962
# Validation: Avg Validation Loss: 1.9845
# Validation Loss for Scheduler: 1.9845
# saving model
# Epoch [87/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9952
# Validation: Avg Validation Loss: 1.9853
# Validation Loss for Scheduler: 1.9853
# saving model
# Epoch [88/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9950
# Validation: Avg Validation Loss: 1.9812
# Validation Loss for Scheduler: 1.9812
# saving model
# Epoch [89/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9936
# Validation: Avg Validation Loss: 1.9826
# Validation Loss for Scheduler: 1.9826
# saving model
# Epoch [90/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9888
# Validation: Avg Validation Loss: 1.9771
# Validation Loss for Scheduler: 1.9771
# saving model
# Epoch [91/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9847
# Validation: Avg Validation Loss: 1.9738
# Validation Loss for Scheduler: 1.9738
# saving model
# Epoch [92/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9811
# Validation: Avg Validation Loss: 1.9707
# Validation Loss for Scheduler: 1.9707
# saving model
# Epoch [93/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9761
# Validation: Avg Validation Loss: 1.9670
# Validation Loss for Scheduler: 1.9670
# saving model
# Epoch [94/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9736
# Validation: Avg Validation Loss: 1.9647
# Validation Loss for Scheduler: 1.9647
# saving model
# Epoch [95/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9710
# Validation: Avg Validation Loss: 1.9614
# Validation Loss for Scheduler: 1.9614
# saving model
# Epoch [96/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9670
# Validation: Avg Validation Loss: 1.9594
# Validation Loss for Scheduler: 1.9594
# saving model
# Epoch [97/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9645
# Validation: Avg Validation Loss: 1.9578
# Validation Loss for Scheduler: 1.9578
# saving model
# Epoch [98/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9627
# Validation: Avg Validation Loss: 1.9551
# Validation Loss for Scheduler: 1.9551
# saving model
# Epoch [99/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9598
# Validation: Avg Validation Loss: 1.9539
# Validation Loss for Scheduler: 1.9539
# saving model
# Epoch [100/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9576
# Validation: Avg Validation Loss: 1.9526
# Validation Loss for Scheduler: 1.9526
# saving model
# Training complete.
# Model saved to path: Helpdesk_camargo_act_1_suffix_length5.pkl
