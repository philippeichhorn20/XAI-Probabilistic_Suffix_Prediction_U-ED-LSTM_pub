# %%
import importlib
import sys
import pickle
import numpy as np

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')
sys.path.insert(0, '../../../../../..')
sys.path.insert(0, '../../../../../../..')

# %%
import src.evaluation_metrics.conduct_evaluation
importlib.reload(src.evaluation_metrics.conduct_evaluation)

import src.evaluation_metrics.metrics
importlib.reload(src.evaluation_metrics.metrics)
# Out:
# <module 'src.evaluation_metrics.metrics' from '/home/LordKunkler/probabilistic_suffix_prediction_lab/probabilistic_suffix_prediction_dev/src/reimplemented_comparable_approaches/weytjens_unc_rem_time/notebooks/evaluation/Sepsis/../../../../../../src/evaluation_metrics/metrics.py'>

# %%
import src.evaluation_metrics.plots
importlib.reload(src.evaluation_metrics.plots)

output_dirs = ['../../../../../../../../data/Sepsis/eval_weytjens_sl5/']

all_results = dict()

for output_dir in output_dirs:
    evaluation_metrics = {

        'RemainingTime_LastEvent_Mean2_Var_seconds_outliers' : src.evaluation_metrics.metrics.LastValueMean2VarMAE('case_elapsed_time', percentile=0.25, value_factor= 3600*24),
        
        'RemainingTime_PIT' : src.evaluation_metrics.metrics.LastValuePIT('case_elapsed_time'),

        'LastValueInterval_50' : src.evaluation_metrics.metrics.LastValueInterval('case_elapsed_time', percentile=0.50),
        'LastValueInterval_75' : src.evaluation_metrics.metrics.LastValueInterval('case_elapsed_time', percentile=0.75),
        'LastValueInterval_90' : src.evaluation_metrics.metrics.LastValueInterval('case_elapsed_time', percentile=0.90),
        'LastValueInterval_95' : src.evaluation_metrics.metrics.LastValueInterval('case_elapsed_time', percentile=0.95),
        'LastValueInterval_99' : src.evaluation_metrics.metrics.LastValueInterval('case_elapsed_time', percentile=0.99),
    }

    res_raw, c = src.evaluation_metrics.conduct_evaluation.batch_evaluate(output_dir, evaluation_metrics)
    #res_raw, c = src.evaluation_metrics.conduct_evaluation.evaluate_sequentially(output_dir, evaluation_metrics)
    all_results[output_dir] = (res_raw, c)

with open("Sepsis_eval.pkl", "wb") as file:
    pickle.dump(all_results, file)
# Out:
# Loaded: results_part_050.pkl
# Loaded: results_part_1000.pkl
# Loaded: results_part_1050.pklLoaded: results_part_100.pkl
#
# Loaded: results_part_1100.pkl
# Loaded: results_part_1200.pkl
# Loaded: results_part_1150.pkl
# Loaded: results_part_1250.pkl
# Loaded: results_part_1300.pkl
# Loaded: results_part_1350.pklLoaded: results_part_1450.pkl
#
# Loaded: results_part_1400.pkl
# Loaded: results_part_150.pkl
# Loaded: results_part_1500.pkl
# Loaded: results_part_1550.pkl
# Loaded: results_part_1600.pkl
# Loaded: results_part_1650.pkl
# Loaded: results_part_200.pkl
# Loaded: results_part_1700.pkl
# Loaded: results_part_250.pkl
# Loaded: results_part_350.pklLoaded: results_part_450.pklLoaded: results_part_400.pkl
#
#
# Loaded: results_part_300.pkl
# Loaded: results_part_600.pkl
# Loaded: results_part_550.pkl
# Loaded: results_part_650.pklLoaded: results_part_500.pkl
#
# Loaded: results_part_750.pkl
# Loaded: results_part_700.pkl
# Loaded: results_part_800.pklLoaded: results_part_850.pkl
#
# Loaded: results_part_900.pkl
# Loaded: results_part_950.pkl

# %%
with open("Sepsis_eval.pkl", "rb") as file:
    all_results = pickle.load(file)

import src.evaluation_metrics.plots
importlib.reload(src.evaluation_metrics.plots)

res_raw, c = all_results['../../../../../../../../data/Sepsis/eval_weytjens_sl5/']

keys_to_keep = [
                ('RemainingTime_LastEvent_Mean2_Var_seconds_outliers', 'Rem. time (last case) MAE (days) '),
]

res = {(k, label) : res_raw[k] for k, label in keys_to_keep}
print(res_raw.keys())
print(len(res_raw.keys()))
print(len(res.keys()))
print(len(keys_to_keep))
print(res.keys())
p = src.evaluation_metrics.plots.plot_res(res, c, columns=2, caption='Sepsis', pgf=True)#int(len(keys_to_keep)))
with open('Sepsis.pgf', 'wb') as f:
    f.write(p)
# Out:
# dict_keys(['RemainingTime_LastEvent_Mean2_Var_seconds_outliers', 'RemainingTime_PIT', 'LastValueInterval_50', 'LastValueInterval_75', 'LastValueInterval_90', 'LastValueInterval_95', 'LastValueInterval_99'])
# 7
# 1
# 1
# dict_keys([('RemainingTime_LastEvent_Mean2_Var_seconds_outliers', 'Rem. time (last case) MAE (days) ')])

# %%
print('Mean MAE last event:')
print(np.mean([i['mean'] for i in res_raw['RemainingTime_LastEvent_Mean2_Var_seconds_outliers'].values()]))
print('Probabilistic MAE last event:')
print(np.mean([i['prob'][0] for i in res_raw['RemainingTime_LastEvent_Mean2_Var_seconds_outliers'].values()]))
# Out:
# Mean MAE last event:
# 29.482392730827243
# Probabilistic MAE last event:
# 32.11765028169191

# %%
import src.evaluation_metrics.plots
importlib.reload(src.evaluation_metrics.plots)

with open('Sepsis_PIT_remaining_time.pgf', 'wb') as f:
    r = src.evaluation_metrics.plots.plot_pits(res_raw['RemainingTime_PIT'], caption='Sepsis', x_label='Last case elapsed time', pgf=True)
    f.write(r)

# %%
with open("Sepsis_eval.pkl", "rb") as file:
    all_results = pickle.load(file)

import src.evaluation_metrics.plots
importlib.reload(src.evaluation_metrics.plots)

res_raw, c = all_results['../../../../../../../../data/Sepsis/eval_weytjens_sl5/']

# %%
import src.evaluation_metrics.plots
importlib.reload(src.evaluation_metrics.plots)

keys_to_keep = [
                ('LastValueInterval_50', 'LastValueInterval_50'),
                ('LastValueInterval_75', 'LastValueInterval_75'),
                ('LastValueInterval_90', 'LastValueInterval_90'),
                ('LastValueInterval_95', 'LastValueInterval_95'),
                ('LastValueInterval_99', 'LastValueInterval_99'),
]

res = {(k, label) : res_raw[k] for k, label in keys_to_keep}

p = src.evaluation_metrics.plots.plot_intervals(res, caption='Remaining time', pgf=True)#int(len(keys_to_keep)))

with open('Sepsis_intervals_suffix.pgf', 'wb') as f:
    f.write(p)

# %%
res[('LastValueInterval_50', 'LastValueInterval_50')]
# Out:
# {('AAA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AAA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AAA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AAA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AAA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AAA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AAA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AAA', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AAA', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AAA', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AJ', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AJ', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AJ', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AJ', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AS', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AS', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AS', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AS', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AS', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AS', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AS', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AS', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AS', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AS', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AS', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AS', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('AS', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BBA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BBA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BBA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BBA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 16, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 17, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 18, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 19, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NEA', 26, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 27, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 28, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 29, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 30, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 31, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 32, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 33, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 34, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 35, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 36, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 37, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 38, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 39, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 40, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 41, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 42, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 43, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NEA', 44, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('NF', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NF', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NF', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NF', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NF', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NF', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NF', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NF', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NF', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NU', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BC', 20, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 16, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 17, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 18, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BFA', 19, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BH', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BH', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BH', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BH', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BH', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BH', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BH', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BH', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BH', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BIA', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BIA', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BIA', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BIA', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BIA', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BIA', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BIA', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BIA', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BIA', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BIA', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BIA', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BIA', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BJA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('NZ', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OE', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OE', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OE', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OE', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OGA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OGA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OGA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OGA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OGA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OGA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OGA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OJ', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OJ', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OJ', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OJ', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OJ', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OJ', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OJ', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OJ', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OK', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OK', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OK', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OK', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OK', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OK', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OK', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OKA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OKA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OL', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OL', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OL', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OL', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('ON', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 13, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 14, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 15, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('ON', 16, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OT', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OT', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OT', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OT', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OT', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OT', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OT', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OW', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 13, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 14, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OW', 15, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('OY', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 16, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 17, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 18, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 19, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 20, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 21, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 22, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PH', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PIA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PIA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PM', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PM', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PM', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PM', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PO', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PS', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 13, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 14, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 15, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 16, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PS', 17, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PY', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PY', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PY', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PY', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QB', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QB', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QB', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QB', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QB', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QB', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QB', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QB', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('OY', 23, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 16, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 17, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('P', 18, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PE', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PE', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PE', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PE', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PE', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PE', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PE', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PE', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PE', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PE', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PE', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PE', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PE', 13, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PEA', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PEA', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PEA', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PEA', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PEA', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PEA', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PEA', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PEA', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('PH', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PH', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PH', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PH', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PH', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PH', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PH', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PH', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PH', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('PH', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QJ', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QJ', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QJ', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QJ', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QJ', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QJ', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QJ', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QJ', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QJ', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QJ', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QJ', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QJA', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QJA', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QJA', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QJA', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QJA', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QJA', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QJA', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QJA', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QJA', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QJA', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QJA', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QJA', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QKA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QKA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QKA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QKA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QKA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QKA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QKA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QKA', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QKA', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QKA', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QKA', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QKA', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 16, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 17, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QM', 18, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QN', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QR', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 13, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 14, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 15, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 16, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 17, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 18, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 19, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 20, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 21, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 22, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 23, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 24, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 25, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 26, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 27, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 28, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 29, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 30, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 31, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 32, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 33, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 34, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QR', 35, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('QX', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('QX', 16, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RDA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RDA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RDA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RDA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RDA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RDA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RDA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RDA', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RDA', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RDA', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RDA', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RE', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RE', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RE', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RE', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RE', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RE', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RE', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RE', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RE', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RE', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RE', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RE', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RE', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RF', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RF', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RF', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RF', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RF', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RF', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RF', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SB', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SB', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SCA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 16, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 17, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 18, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SCA', 19, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SF', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SF', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SF', 16, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SF', 17, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SIA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SIA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SIA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SIA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SIA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SIA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SIA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SJ', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SJ', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SJ', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SJ', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SJ', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RFA', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('RFA', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('RFA', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('RFA', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('RFA', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('RFA', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('RFA', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('RFA', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('RFA', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('RFA', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('RFA', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('RFA', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('RFA', 13, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('RJA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RJA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RP', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RP', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RP', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RP', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RP', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RP', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RP', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RV', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RV', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RV', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RV', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RV', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RV', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RV', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RV', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RV', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RV', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RV', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RX', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RX', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RX', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RX', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RX', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RX', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('RX', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SB', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SB', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SB', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SB', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SB', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SB', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SB', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SB', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SB', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SB', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BJA', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BJA', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 16, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 17, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 18, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 19, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 20, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 21, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 22, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 23, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 24, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BJA', 25, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('BK', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BK', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BK', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BK', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BK', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BK', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BK', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BN', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BN', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BN', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('BN', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CLA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CLA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CLA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CLA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CLA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CLA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CLA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CLA', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CLA', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CM', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CM', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CM', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CM', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CM', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CM', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CM', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CM', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CM', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CM', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('CM', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DB', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('DB', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('DB', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('SJ', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SJ', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SLA', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SW', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SW', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SW', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SW', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SW', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SW', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SW', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SW', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SW', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SW', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('SW', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 16, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 17, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 18, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 19, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 20, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 21, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 22, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 23, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 24, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 25, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 26, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 27, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 28, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 29, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 30, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 31, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 32, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 33, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 34, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 35, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 36, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 37, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 38, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 39, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 40, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 41, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('THA', 42, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('TT', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 13, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 14, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 15, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 16, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 17, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 18, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 19, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 20, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 21, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 22, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 23, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 24, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 25, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 26, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 27, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 28, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 29, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 30, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 31, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 32, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 33, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 34, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 35, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 36, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 37, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 38, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 39, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 40, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 41, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 42, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 43, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 44, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('TT', 45, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UB', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UB', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UB', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UB', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UB', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UB', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UB', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UB', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UB', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UB', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UB', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 16, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 17, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 18, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 19, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UCA', 20, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UGA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UGA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UGA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UGA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UGA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UGA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UK', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 13, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 14, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 15, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 16, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UK', 17, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 13, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 14, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 15, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 16, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UN', 17, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UW', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UW', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UW', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UW', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UW', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UW', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UW', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UW', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UW', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UW', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UZ', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UZ', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UZ', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UZ', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('DB', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('DB', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('DB', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('DB', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('DB', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('DB', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('DB', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('DB', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('DB', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('DE', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DE', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DE', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DE', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DE', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DE', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DE', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DFA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DFA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DFA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DFA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DFA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DFA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DFA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DG', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DG', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DG', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DG', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DG', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DG', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DG', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DG', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DG', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 16, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 17, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 18, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('UZ', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UZ', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UZ', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UZ', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UZ', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('UZ', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VB', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VB', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VB', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VB', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VB', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VB', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VB', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VB', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VB', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VB', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VB', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VC', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VC', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VC', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VC', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VC', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VC', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VC', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VC', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VC', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VC', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VC', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VC', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VC', 13, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('VE', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VE', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VE', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VE', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VE', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VE', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VE', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VFA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VFA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VFA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VFA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VFA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VFA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VFA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VFA', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VFA', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VFA', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VFA', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VFA', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('VFA', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 19, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 20, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 21, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 22, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 23, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 24, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 25, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 26, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 27, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 28, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DK', 29, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 6, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 7, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 8, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 9, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 10, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 11, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 12, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 13, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 14, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 15, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 16, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 17, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 18, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('DLA', 19, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('EA', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EA', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EA', 3, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EA', 4, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EA', 5, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EA', 6, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EA', 7, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EA', 8, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EA', 9, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EA', 10, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EA', 11, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EA', 12, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EA', 13, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EH', 1, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('EH', 2, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('EH', 3, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('EH', 4, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('EH', 5, 1): {'mean': 0, 'prob': (np.True_, (0, 0))},
#  ('EHA', 1, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ('EHA', 2, 1): {'mean': 0, 'prob': (np.False_, (0, 0))},
#  ...}
