# %%
"""
Use of same experimental setup as for our Probabilistic Suffix Prediction.

Reimplementation for comparison: 
- Paper: Weytjens, Hans, and Jochen De Weerdt. "Learning uncertainty with artificial neural networks for predictive process monitoring." Applied Soft Computing 125 (2022): 109134.
- Github (code) from: https://github.com/hansweytjens/uncertainty-remaining_time/blob/main/LSTM.ipynb
"""
# Out:
# '\nUse of same experimental setup as for our Probabilistic Suffix Prediction.\n\nReimplementation for comparison: \n- Paper: Weytjens, Hans, and Jochen De Weerdt. "Learning uncertainty with artificial neural networks for predictive process monitoring." Applied Soft Computing 125 (2022): 109134.\n- Github (code) from: https://github.com/hansweytjens/uncertainty-remaining_time/blob/main/LSTM.ipynb\n'

# %% [markdown]
# # Imports

# %%
import importlib
import sys
import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../../../encoded_data/compare_weytjens/helpdesk_all_5_train.pkl'
# Load the dataset using torch.load
helpdesk_train_dataset = torch.load(file_path_train, weights_only=False)
# Check the type of the loaded dataset
print(type(helpdesk_train_dataset))

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../../../encoded_data/compare_weytjens/helpdesk_all_5_val.pkl'
# Load the dataset using torch.load
helpdesk_val_dataset = torch.load(file_path_val, weights_only=False)
# Check the type of the loaded dataset
print(type(helpdesk_val_dataset))
# Out:
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>

# %% [markdown]
# ### Train Data Insights

# %%
# Helpdesk Dataset Categories, Features:
helpdesk_all_categories = helpdesk_train_dataset.all_categories

helpdesk_all_categories_cat = helpdesk_all_categories[0]
print(helpdesk_all_categories_cat)

helpdesk_all_categories_num = helpdesk_all_categories[1]
print(helpdesk_all_categories_num)

for i, cat in enumerate(helpdesk_all_categories_cat):
     print(f"Helpdesk (5) Categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk (5) Total Amount of Category labels: {cat[1]}")

print('\n')    

for i, num in enumerate(helpdesk_all_categories_num):
     print(f"Helpdesk (5) Numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk (5) Amount Numerical: {num[1]}")
     
# Get concept_name id:
# 
concept_name = 'Activity'
concept_name_id = [i for i, cat in enumerate(helpdesk_all_categories[0]) if cat[0] == concept_name][0]

print("ID concet name in cat list: ", concept_name_id)
    
# Id of EOS token in activity
eos_value = 'EOS'
eos_id = [v for k, v in helpdesk_all_categories[0][concept_name_id][2].items() if k == eos_value][0]
# Get EOS id of concept name list:

print("ID EOS in concept name tensor: ", eos_id)
# Out:
# [('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15})]
# [('case_elapsed_time', 1, {})]
# Helpdesk (5) Categorical feature: Activity, Index position in categorical data list: 0
# Helpdesk (5) Total Amount of Category labels: 16
#
#
# Helpdesk (5) Numerical feature: case_elapsed_time, Index position in categorical data list: 0
# Helpdesk (5) Amount Numerical: 1
# ID concet name in cat list:  0
# ID EOS in concept name tensor:  5

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Model features (input)
model_feat_cat = ['Activity']
model_feat_num = ['case_elapsed_time']
model_feat = [model_feat_cat, model_feat_num]

print("Features model: ", model_feat)
# Out:
# Features model:  [['Activity'], ['case_elapsed_time']]

# %% [markdown]
# # Model

# %%
import stochasticLSTM.model
importlib.reload(stochasticLSTM.model)
from stochasticLSTM.model import StochasticLSTMWeytjens

"""
Specific model parameters from paper: 
"""

# Size hidden layer
hidden_size=10

# Number of LSTM cells
num_layers=2

# One numerical output to predict
input_size=1

# Fixed Dropout probability 
p_fix=0.1

# Lambda for L2 (weight, bias, dropout) regularization: According to formula: 1/2N
regularization_term = 0.1

# Hans Weytjens LSTM model
model = StochasticLSTMWeytjens(data_set_categories=helpdesk_all_categories,
                               model_feat=model_feat,
                               hidden_size=hidden_size,
                               num_layers=num_layers,
                               input_size=input_size,
                               weight_reg=regularization_term,
                               p_fix=p_fix,
                               device='cuda')
# Out:
# Data set categories:  ([('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15})], [('case_elapsed_time', 1, {})])
# Model input features:  [['Activity'], ['case_elapsed_time']]
#
#
# Embeddings:  ModuleList(
#   (0): Embedding(16, 8)
# )
# Total embedding feature size:  8
# Input feature size:  9
# Cells hidden size:  10
# Number of LSTM layer:  2
# Dropout rate:  0.1
#
#
# Output feature list of dicts (featue name, tensor index in dataset):  {'case_elapsed_time': 0}

# %% [markdown]
# # Loss Object Creation

# %%
import loss_hans.losses
importlib.reload(loss_hans.losses)
from loss_hans.losses import Loss

loss_obj = Loss()

# %% [markdown]
# # Training Configuration

# %%
import training.train
importlib.reload(training.train)
from training.train import Training

from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_helpdesk_weytjens_rem_time")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

"""
Parameter of Probabilistic Suffix Prediction experimental design, to ensure fair comparison:
"""

# Start learning rate
learning_rate = 1e-5

# Optimizer and Scheduler
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate, weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=4, min_lr=1e-10)

# Epochs
num_epochs = 100

# Batch of model input
batch_size = 128

# shuffle data
shuffle = True

optimize_values = {"optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle}

number_tasks = len(model_feat)

trainer = Training(model=model,
                   device=device,
                   data_train=helpdesk_train_dataset,
                   data_val=helpdesk_val_dataset,
                   concept_name_id=concept_name_id,
                   eos_id=eos_id,
                   loss_obj=loss_obj,
                   optimize_values=optimize_values,
                   writer=writer,
                   save_model_n_th_epoch=1,
                   saving_path="Helpdesk_weytjens_rem_time_1_suffix_length5.pkl")

# Train the model:
trainer.train()
# Out:
# Device:  cuda
# Optimizer:  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7fc8acc28d70>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch [1/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.9828
# Validation: Avg Standard Validation Loss: 6.4970
# Validation: Avg Attenuated Validation Loss: 4.4784
# Validation Loss for Scheduler: 6.4970
# saving model
# Epoch [2/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.9513
# Validation: Avg Standard Validation Loss: 6.4723
# Validation: Avg Attenuated Validation Loss: 4.4484
# Validation Loss for Scheduler: 6.4723
# saving model
# Epoch [3/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.9155
# Validation: Avg Standard Validation Loss: 6.4161
# Validation: Avg Attenuated Validation Loss: 4.4006
# Validation Loss for Scheduler: 6.4161
# saving model
# Epoch [4/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8829
# Validation: Avg Standard Validation Loss: 6.4026
# Validation: Avg Attenuated Validation Loss: 4.3786
# Validation Loss for Scheduler: 6.4026
# saving model
# Epoch [5/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8489
# Validation: Avg Standard Validation Loss: 6.3842
# Validation: Avg Attenuated Validation Loss: 4.3520
# Validation Loss for Scheduler: 6.3842
# saving model
# Epoch [6/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8160
# Validation: Avg Standard Validation Loss: 6.3468
# Validation: Avg Attenuated Validation Loss: 4.3145
# Validation Loss for Scheduler: 6.3468
# saving model
# Epoch [7/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.7807
# Validation: Avg Standard Validation Loss: 6.3321
# Validation: Avg Attenuated Validation Loss: 4.2923
# Validation Loss for Scheduler: 6.3321
# saving model
# Epoch [8/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.7487
# Validation: Avg Standard Validation Loss: 6.3026
# Validation: Avg Attenuated Validation Loss: 4.2596
# Validation Loss for Scheduler: 6.3026
# saving model
# Epoch [9/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.7177
# Validation: Avg Standard Validation Loss: 6.2385
# Validation: Avg Attenuated Validation Loss: 4.2077
# Validation Loss for Scheduler: 6.2385
# saving model
# Epoch [10/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.6843
# Validation: Avg Standard Validation Loss: 6.2197
# Validation: Avg Attenuated Validation Loss: 4.1841
# Validation Loss for Scheduler: 6.2197
# saving model
# Epoch [11/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.6548
# Validation: Avg Standard Validation Loss: 6.1577
# Validation: Avg Attenuated Validation Loss: 4.1320
# Validation Loss for Scheduler: 6.1577
# saving model
# Epoch [12/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.6203
# Validation: Avg Standard Validation Loss: 6.1592
# Validation: Avg Attenuated Validation Loss: 4.1171
# Validation Loss for Scheduler: 6.1592
# saving model
# Epoch [13/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.5889
# Validation: Avg Standard Validation Loss: 6.1055
# Validation: Avg Attenuated Validation Loss: 4.0752
# Validation Loss for Scheduler: 6.1055
# saving model
# Epoch [14/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.5561
# Validation: Avg Standard Validation Loss: 6.0711
# Validation: Avg Attenuated Validation Loss: 4.0369
# Validation Loss for Scheduler: 6.0711
# saving model
# Epoch [15/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.5235
# Validation: Avg Standard Validation Loss: 6.0111
# Validation: Avg Attenuated Validation Loss: 3.9889
# Validation Loss for Scheduler: 6.0111
# saving model
# Epoch [16/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.4928
# Validation: Avg Standard Validation Loss: 5.9923
# Validation: Avg Attenuated Validation Loss: 3.9628
# Validation Loss for Scheduler: 5.9923
# saving model
# Epoch [17/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.4585
# Validation: Avg Standard Validation Loss: 5.9473
# Validation: Avg Attenuated Validation Loss: 3.9225
# Validation Loss for Scheduler: 5.9473
# saving model
# Epoch [18/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.4268
# Validation: Avg Standard Validation Loss: 5.9186
# Validation: Avg Attenuated Validation Loss: 3.8936
# Validation Loss for Scheduler: 5.9186
# saving model
# Epoch [19/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.3952
# Validation: Avg Standard Validation Loss: 5.8848
# Validation: Avg Attenuated Validation Loss: 3.8583
# Validation Loss for Scheduler: 5.8848
# saving model
# Epoch [20/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.3664
# Validation: Avg Standard Validation Loss: 5.8248
# Validation: Avg Attenuated Validation Loss: 3.8083
# Validation Loss for Scheduler: 5.8248
# saving model
# Epoch [21/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.3293
# Validation: Avg Standard Validation Loss: 5.7723
# Validation: Avg Attenuated Validation Loss: 3.7643
# Validation Loss for Scheduler: 5.7723
# saving model
# Epoch [22/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.3008
# Validation: Avg Standard Validation Loss: 5.7431
# Validation: Avg Attenuated Validation Loss: 3.7331
# Validation Loss for Scheduler: 5.7431
# saving model
# Epoch [23/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.2725
# Validation: Avg Standard Validation Loss: 5.7031
# Validation: Avg Attenuated Validation Loss: 3.6949
# Validation Loss for Scheduler: 5.7031
# saving model
# Epoch [24/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.2430
# Validation: Avg Standard Validation Loss: 5.6631
# Validation: Avg Attenuated Validation Loss: 3.6591
# Validation Loss for Scheduler: 5.6631
# saving model
# Epoch [25/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.2113
# Validation: Avg Standard Validation Loss: 5.6281
# Validation: Avg Attenuated Validation Loss: 3.6220
# Validation Loss for Scheduler: 5.6281
# saving model
# Epoch [26/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.1780
# Validation: Avg Standard Validation Loss: 5.5546
# Validation: Avg Attenuated Validation Loss: 3.5666
# Validation Loss for Scheduler: 5.5546
# saving model
# Epoch [27/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.1501
# Validation: Avg Standard Validation Loss: 5.5117
# Validation: Avg Attenuated Validation Loss: 3.5276
# Validation Loss for Scheduler: 5.5117
# saving model
# Epoch [28/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.1177
# Validation: Avg Standard Validation Loss: 5.4648
# Validation: Avg Attenuated Validation Loss: 3.4870
# Validation Loss for Scheduler: 5.4648
# saving model
# Epoch [29/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.0894
# Validation: Avg Standard Validation Loss: 5.4074
# Validation: Avg Attenuated Validation Loss: 3.4398
# Validation Loss for Scheduler: 5.4074
# saving model
# Epoch [30/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.0609
# Validation: Avg Standard Validation Loss: 5.3660
# Validation: Avg Attenuated Validation Loss: 3.4053
# Validation Loss for Scheduler: 5.3660
# saving model
# Epoch [31/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.0333
# Validation: Avg Standard Validation Loss: 5.3141
# Validation: Avg Attenuated Validation Loss: 3.3617
# Validation Loss for Scheduler: 5.3141
# saving model
# Epoch [32/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.0045
# Validation: Avg Standard Validation Loss: 5.2531
# Validation: Avg Attenuated Validation Loss: 3.3169
# Validation Loss for Scheduler: 5.2531
# saving model
# Epoch [33/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9758
# Validation: Avg Standard Validation Loss: 5.1991
# Validation: Avg Attenuated Validation Loss: 3.2673
# Validation Loss for Scheduler: 5.1991
# saving model
# Epoch [34/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9446
# Validation: Avg Standard Validation Loss: 5.1109
# Validation: Avg Attenuated Validation Loss: 3.2109
# Validation Loss for Scheduler: 5.1109
# saving model
# Epoch [35/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9150
# Validation: Avg Standard Validation Loss: 5.0649
# Validation: Avg Attenuated Validation Loss: 3.1726
# Validation Loss for Scheduler: 5.0649
# saving model
# Epoch [36/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8908
# Validation: Avg Standard Validation Loss: 4.9927
# Validation: Avg Attenuated Validation Loss: 3.1198
# Validation Loss for Scheduler: 4.9927
# saving model
# Epoch [37/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8637
# Validation: Avg Standard Validation Loss: 4.9559
# Validation: Avg Attenuated Validation Loss: 3.0861
# Validation Loss for Scheduler: 4.9559
# saving model
# Epoch [38/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8351
# Validation: Avg Standard Validation Loss: 4.8590
# Validation: Avg Attenuated Validation Loss: 3.0263
# Validation Loss for Scheduler: 4.8590
# saving model
# Epoch [39/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8129
# Validation: Avg Standard Validation Loss: 4.7965
# Validation: Avg Attenuated Validation Loss: 2.9811
# Validation Loss for Scheduler: 4.7965
# saving model
# Epoch [40/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.7880
# Validation: Avg Standard Validation Loss: 4.7034
# Validation: Avg Attenuated Validation Loss: 2.9251
# Validation Loss for Scheduler: 4.7034
# saving model
# Epoch [41/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.7615
# Validation: Avg Standard Validation Loss: 4.6328
# Validation: Avg Attenuated Validation Loss: 2.8749
# Validation Loss for Scheduler: 4.6328
# saving model
# Epoch [42/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.7381
# Validation: Avg Standard Validation Loss: 4.5419
# Validation: Avg Attenuated Validation Loss: 2.8230
# Validation Loss for Scheduler: 4.5419
# saving model
# Epoch [43/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.7202
# Validation: Avg Standard Validation Loss: 4.4576
# Validation: Avg Attenuated Validation Loss: 2.7714
# Validation Loss for Scheduler: 4.4576
# saving model
# Epoch [44/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.7002
# Validation: Avg Standard Validation Loss: 4.3830
# Validation: Avg Attenuated Validation Loss: 2.7270
# Validation Loss for Scheduler: 4.3830
# saving model
# Epoch [45/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6807
# Validation: Avg Standard Validation Loss: 4.3076
# Validation: Avg Attenuated Validation Loss: 2.6846
# Validation Loss for Scheduler: 4.3076
# saving model
# Epoch [46/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6652
# Validation: Avg Standard Validation Loss: 4.2026
# Validation: Avg Attenuated Validation Loss: 2.6272
# Validation Loss for Scheduler: 4.2026
# saving model
# Epoch [47/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6498
# Validation: Avg Standard Validation Loss: 4.1528
# Validation: Avg Attenuated Validation Loss: 2.5974
# Validation Loss for Scheduler: 4.1528
# saving model
# Epoch [48/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6361
# Validation: Avg Standard Validation Loss: 4.0633
# Validation: Avg Attenuated Validation Loss: 2.5548
# Validation Loss for Scheduler: 4.0633
# saving model
# Epoch [49/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6248
# Validation: Avg Standard Validation Loss: 3.9550
# Validation: Avg Attenuated Validation Loss: 2.5019
# Validation Loss for Scheduler: 3.9550
# saving model
# Epoch [50/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6150
# Validation: Avg Standard Validation Loss: 3.8667
# Validation: Avg Attenuated Validation Loss: 2.4626
# Validation Loss for Scheduler: 3.8667
# saving model
# Epoch [51/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6081
# Validation: Avg Standard Validation Loss: 3.7768
# Validation: Avg Attenuated Validation Loss: 2.4213
# Validation Loss for Scheduler: 3.7768
# saving model
# Epoch [52/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.5987
# Validation: Avg Standard Validation Loss: 3.6609
# Validation: Avg Attenuated Validation Loss: 2.3680
# Validation Loss for Scheduler: 3.6609
# saving model
# Epoch [53/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.5942
# Validation: Avg Standard Validation Loss: 3.5740
# Validation: Avg Attenuated Validation Loss: 2.3307
# Validation Loss for Scheduler: 3.5740
# saving model
# Epoch [54/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.5886
# Validation: Avg Standard Validation Loss: 3.4689
# Validation: Avg Attenuated Validation Loss: 2.2876
# Validation Loss for Scheduler: 3.4689
# saving model
# Epoch [55/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.5881
# Validation: Avg Standard Validation Loss: 3.3786
# Validation: Avg Attenuated Validation Loss: 2.2560
# Validation Loss for Scheduler: 3.3786
# saving model
# Epoch [56/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.5843
# Validation: Avg Standard Validation Loss: 3.3072
# Validation: Avg Attenuated Validation Loss: 2.2274
# Validation Loss for Scheduler: 3.3072
# saving model
# Epoch [57/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.5894
# Validation: Avg Standard Validation Loss: 3.1817
# Validation: Avg Attenuated Validation Loss: 2.1819
# Validation Loss for Scheduler: 3.1817
# saving model
# Epoch [58/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.5899
# Validation: Avg Standard Validation Loss: 3.0614
# Validation: Avg Attenuated Validation Loss: 2.1378
# Validation Loss for Scheduler: 3.0614
# saving model
# Epoch [59/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.5942
# Validation: Avg Standard Validation Loss: 2.9906
# Validation: Avg Attenuated Validation Loss: 2.1117
# Validation Loss for Scheduler: 2.9906
# saving model
# Epoch [60/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6004
# Validation: Avg Standard Validation Loss: 2.8836
# Validation: Avg Attenuated Validation Loss: 2.0802
# Validation Loss for Scheduler: 2.8836
# saving model
# Epoch [61/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6032
# Validation: Avg Standard Validation Loss: 2.8168
# Validation: Avg Attenuated Validation Loss: 2.0599
# Validation Loss for Scheduler: 2.8168
# saving model
# Epoch [62/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6094
# Validation: Avg Standard Validation Loss: 2.7060
# Validation: Avg Attenuated Validation Loss: 2.0223
# Validation Loss for Scheduler: 2.7060
# saving model
# Epoch [63/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6183
# Validation: Avg Standard Validation Loss: 2.6586
# Validation: Avg Attenuated Validation Loss: 2.0097
# Validation Loss for Scheduler: 2.6586
# saving model
# Epoch [64/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6273
# Validation: Avg Standard Validation Loss: 2.5406
# Validation: Avg Attenuated Validation Loss: 1.9753
# Validation Loss for Scheduler: 2.5406
# saving model
# Epoch [65/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6392
# Validation: Avg Standard Validation Loss: 2.4667
# Validation: Avg Attenuated Validation Loss: 1.9509
# Validation Loss for Scheduler: 2.4667
# saving model
# Epoch [66/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6487
# Validation: Avg Standard Validation Loss: 2.3982
# Validation: Avg Attenuated Validation Loss: 1.9299
# Validation Loss for Scheduler: 2.3982
# saving model
# Epoch [67/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6600
# Validation: Avg Standard Validation Loss: 2.3218
# Validation: Avg Attenuated Validation Loss: 1.9064
# Validation Loss for Scheduler: 2.3218
# saving model
# Epoch [68/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6692
# Validation: Avg Standard Validation Loss: 2.2272
# Validation: Avg Attenuated Validation Loss: 1.8829
# Validation Loss for Scheduler: 2.2272
# saving model
# Epoch [69/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6817
# Validation: Avg Standard Validation Loss: 2.1703
# Validation: Avg Attenuated Validation Loss: 1.8643
# Validation Loss for Scheduler: 2.1703
# saving model
# Epoch [70/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.6960
# Validation: Avg Standard Validation Loss: 2.0916
# Validation: Avg Attenuated Validation Loss: 1.8443
# Validation Loss for Scheduler: 2.0916
# saving model
# Epoch [71/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.7090
# Validation: Avg Standard Validation Loss: 2.0095
# Validation: Avg Attenuated Validation Loss: 1.8179
# Validation Loss for Scheduler: 2.0095
# saving model
# Epoch [72/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.7181
# Validation: Avg Standard Validation Loss: 1.9734
# Validation: Avg Attenuated Validation Loss: 1.8087
# Validation Loss for Scheduler: 1.9734
# saving model
# Epoch [73/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.7304
# Validation: Avg Standard Validation Loss: 1.9043
# Validation: Avg Attenuated Validation Loss: 1.7901
# Validation Loss for Scheduler: 1.9043
# saving model
# Epoch [74/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.7411
# Validation: Avg Standard Validation Loss: 1.8343
# Validation: Avg Attenuated Validation Loss: 1.7691
# Validation Loss for Scheduler: 1.8343
# saving model
# Epoch [75/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.7543
# Validation: Avg Standard Validation Loss: 1.7808
# Validation: Avg Attenuated Validation Loss: 1.7573
# Validation Loss for Scheduler: 1.7808
# saving model
# Epoch [76/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.7677
# Validation: Avg Standard Validation Loss: 1.7473
# Validation: Avg Attenuated Validation Loss: 1.7472
# Validation Loss for Scheduler: 1.7473
# saving model
# Epoch [77/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.7798
# Validation: Avg Standard Validation Loss: 1.6759
# Validation: Avg Attenuated Validation Loss: 1.7233
# Validation Loss for Scheduler: 1.6759
# saving model
# Epoch [78/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.7887
# Validation: Avg Standard Validation Loss: 1.6377
# Validation: Avg Attenuated Validation Loss: 1.7161
# Validation Loss for Scheduler: 1.6377
# saving model
# Epoch [79/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8020
# Validation: Avg Standard Validation Loss: 1.5851
# Validation: Avg Attenuated Validation Loss: 1.6974
# Validation Loss for Scheduler: 1.5851
# saving model
# Epoch [80/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8151
# Validation: Avg Standard Validation Loss: 1.5526
# Validation: Avg Attenuated Validation Loss: 1.6900
# Validation Loss for Scheduler: 1.5526
# saving model
# Epoch [81/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8252
# Validation: Avg Standard Validation Loss: 1.4848
# Validation: Avg Attenuated Validation Loss: 1.6741
# Validation Loss for Scheduler: 1.4848
# saving model
# Epoch [82/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8363
# Validation: Avg Standard Validation Loss: 1.4576
# Validation: Avg Attenuated Validation Loss: 1.6628
# Validation Loss for Scheduler: 1.4576
# saving model
# Epoch [83/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8460
# Validation: Avg Standard Validation Loss: 1.4470
# Validation: Avg Attenuated Validation Loss: 1.6599
# Validation Loss for Scheduler: 1.4470
# saving model
# Epoch [84/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8549
# Validation: Avg Standard Validation Loss: 1.3721
# Validation: Avg Attenuated Validation Loss: 1.6335
# Validation Loss for Scheduler: 1.3721
# saving model
# Epoch [85/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8672
# Validation: Avg Standard Validation Loss: 1.3369
# Validation: Avg Attenuated Validation Loss: 1.6227
# Validation Loss for Scheduler: 1.3369
# saving model
# Epoch [86/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8751
# Validation: Avg Standard Validation Loss: 1.3120
# Validation: Avg Attenuated Validation Loss: 1.6125
# Validation Loss for Scheduler: 1.3120
# saving model
# Epoch [87/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8866
# Validation: Avg Standard Validation Loss: 1.3021
# Validation: Avg Attenuated Validation Loss: 1.6108
# Validation Loss for Scheduler: 1.3021
# saving model
# Epoch [88/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.8940
# Validation: Avg Standard Validation Loss: 1.2538
# Validation: Avg Attenuated Validation Loss: 1.5916
# Validation Loss for Scheduler: 1.2538
# saving model
# Epoch [89/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9040
# Validation: Avg Standard Validation Loss: 1.2221
# Validation: Avg Attenuated Validation Loss: 1.5790
# Validation Loss for Scheduler: 1.2221
# saving model
# Epoch [90/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9097
# Validation: Avg Standard Validation Loss: 1.2174
# Validation: Avg Attenuated Validation Loss: 1.5769
# Validation Loss for Scheduler: 1.2174
# saving model
# Epoch [91/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9201
# Validation: Avg Standard Validation Loss: 1.1688
# Validation: Avg Attenuated Validation Loss: 1.5601
# Validation Loss for Scheduler: 1.1688
# saving model
# Epoch [92/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9276
# Validation: Avg Standard Validation Loss: 1.1536
# Validation: Avg Attenuated Validation Loss: 1.5508
# Validation Loss for Scheduler: 1.1536
# saving model
# Epoch [93/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9367
# Validation: Avg Standard Validation Loss: 1.1093
# Validation: Avg Attenuated Validation Loss: 1.5326
# Validation Loss for Scheduler: 1.1093
# saving model
# Epoch [94/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9457
# Validation: Avg Standard Validation Loss: 1.1047
# Validation: Avg Attenuated Validation Loss: 1.5288
# Validation Loss for Scheduler: 1.1047
# saving model
# Epoch [95/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9519
# Validation: Avg Standard Validation Loss: 1.1025
# Validation: Avg Attenuated Validation Loss: 1.5234
# Validation Loss for Scheduler: 1.1025
# saving model
# Epoch [96/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9576
# Validation: Avg Standard Validation Loss: 1.0760
# Validation: Avg Attenuated Validation Loss: 1.5099
# Validation Loss for Scheduler: 1.0760
# saving model
# Epoch [97/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9668
# Validation: Avg Standard Validation Loss: 1.0489
# Validation: Avg Attenuated Validation Loss: 1.4967
# Validation Loss for Scheduler: 1.0489
# saving model
# Epoch [98/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9756
# Validation: Avg Standard Validation Loss: 1.0329
# Validation: Avg Attenuated Validation Loss: 1.4863
# Validation Loss for Scheduler: 1.0329
# saving model
# Epoch [99/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9825
# Validation: Avg Standard Validation Loss: 0.9917
# Validation: Avg Attenuated Validation Loss: 1.4667
# Validation Loss for Scheduler: 0.9917
# saving model
# Epoch [100/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 14.9927
# Validation: Avg Standard Validation Loss: 0.9811
# Validation: Avg Attenuated Validation Loss: 1.4584
# Validation Loss for Scheduler: 0.9811
# saving model
# Training complete.
# Model saved to path: Helpdesk_weytjens_rem_time_1_suffix_length5.pkl
