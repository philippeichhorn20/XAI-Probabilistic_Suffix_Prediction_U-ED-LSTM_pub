# %%
"""
Use of same experimental setup as for our Probabilistic Suffix Prediction.

Reimplementation for comparison: 
- Paper: Weytjens, Hans, and Jochen De Weerdt. "Learning uncertainty with artificial neural networks for predictive process monitoring." Applied Soft Computing 125 (2022): 109134.
- Github (code) from: https://github.com/hansweytjens/uncertainty-remaining_time/blob/main/LSTM.ipynb
"""
# Out:
# '\nUse of same experimental setup as for our Probabilistic Suffix Prediction.\n\nReimplementation for comparison: \n- Paper: Weytjens, Hans, and Jochen De Weerdt. "Learning uncertainty with artificial neural networks for predictive process monitoring." Applied Soft Computing 125 (2022): 109134.\n- Github (code) from: https://github.com/hansweytjens/uncertainty-remaining_time/blob/main/LSTM.ipynb\n'

# %% [markdown]
# # Imports

# %%
import importlib
import sys
import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../../../encoded_data/compare_weytjens/Sepsis_all_5_train.pkl'
# Load the dataset using torch.load
sepsis_train_dataset = torch.load(file_path_train, weights_only=False)
# Check the type of the loaded dataset
print(type(sepsis_train_dataset))

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../../../encoded_data/compare_weytjens/Sepsis_all_5_val.pkl'
# Load the dataset using torch.load
sepsis_val_dataset = torch.load(file_path_val, weights_only=False)
# Check the type of the loaded dataset
print(type(sepsis_val_dataset))
# Out:
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>

# %% [markdown]
# ### Train Data Insights

# %%
# Helpdesk Dataset Categories, Features:
sepsis_all_categories = sepsis_train_dataset.all_categories

sepsis_all_categories_cat = sepsis_all_categories[0]
print(sepsis_all_categories_cat)

sepsis_all_categories_num = sepsis_all_categories[1]
print(sepsis_all_categories_num)

for i, cat in enumerate(sepsis_all_categories_cat):
     print(f"sepsis (5) Categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"sepsis (5) Total Amount of Category labels: {cat[1]}")

print('\n')    

for i, num in enumerate(sepsis_all_categories_num):
     print(f"sepsis (5) Numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"sepsis (5) Amount Numerical: {num[1]}")
     
# Get concept_name id:
# 
concept_name = 'concept:name'
concept_name_id = [i for i, cat in enumerate(sepsis_all_categories[0]) if cat[0] == concept_name][0]

print("ID concet name in cat list: ", concept_name_id)
    
# Id of EOS token in activity
eos_value = 'EOS'
eos_id = [v for k, v in sepsis_all_categories[0][concept_name_id][2].items() if k == eos_value][0]
# Get EOS id of concept name list:

print("ID EOS in concept name tensor: ", eos_id)
# Out:
# [('concept:name', 18, {'Admission IC': 1, 'Admission NC': 2, 'CRP': 3, 'EOS': 4, 'ER Registration': 5, 'ER Sepsis Triage': 6, 'ER Triage': 7, 'IV Antibiotics': 8, 'IV Liquid': 9, 'LacticAcid': 10, 'Leucocytes': 11, 'Release A': 12, 'Release B': 13, 'Release C': 14, 'Release D': 15, 'Release E': 16, 'Return ER': 17})]
# [('case_elapsed_time', 1, {})]
# sepsis (5) Categorical feature: concept:name, Index position in categorical data list: 0
# sepsis (5) Total Amount of Category labels: 18
#
#
# sepsis (5) Numerical feature: case_elapsed_time, Index position in categorical data list: 0
# sepsis (5) Amount Numerical: 1
# ID concet name in cat list:  0
# ID EOS in concept name tensor:  4

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Model features (input)
model_feat_cat = ['concept:name']
model_feat_num = ['case_elapsed_time']
model_feat = [model_feat_cat, model_feat_num]

print("Features model: ", model_feat)
# Out:
# Features model:  [['concept:name'], ['case_elapsed_time']]

# %% [markdown]
# # Model

# %%
import stochasticLSTM.model
importlib.reload(stochasticLSTM.model)
from stochasticLSTM.model import StochasticLSTMWeytjens

"""
Specific model parameters from paper: 
"""

# Size hidden layer
hidden_size=10

# Number of LSTM cells
num_layers=2

# One numerical output to predict
input_size=1

# Fixed Dropout probability 
p_fix=0.1

# Lambda for L2 (weight, bias, dropout) regularization: According to formula: 1/2N
regularization_term = 0.1

# Hans Weytjens LSTM model
model = StochasticLSTMWeytjens(data_set_categories=sepsis_all_categories,
                               model_feat=model_feat,
                               hidden_size=hidden_size,
                               num_layers=num_layers,
                               input_size=input_size,
                               weight_reg=regularization_term,
                               p_fix=p_fix,
                               device='cuda')
# Out:
# Data set categories:  ([('concept:name', 18, {'Admission IC': 1, 'Admission NC': 2, 'CRP': 3, 'EOS': 4, 'ER Registration': 5, 'ER Sepsis Triage': 6, 'ER Triage': 7, 'IV Antibiotics': 8, 'IV Liquid': 9, 'LacticAcid': 10, 'Leucocytes': 11, 'Release A': 12, 'Release B': 13, 'Release C': 14, 'Release D': 15, 'Release E': 16, 'Return ER': 17})], [('case_elapsed_time', 1, {})])
# Model input features:  [['concept:name'], ['case_elapsed_time']]
#
#
# Embeddings:  ModuleList(
#   (0): Embedding(18, 8)
# )
# Total embedding feature size:  8
# Input feature size:  9
# Cells hidden size:  10
# Number of LSTM layer:  2
# Dropout rate:  0.1
#
#
# Output feature list of dicts (featue name, tensor index in dataset):  {'case_elapsed_time': 0}

# %% [markdown]
# # Loss Object Creation

# %%
import loss_hans.losses
importlib.reload(loss_hans.losses)
from loss_hans.losses import Loss

loss_obj = Loss()

# %% [markdown]
# # Training Configuration

# %%
import training.train
importlib.reload(training.train)
from training.train import Training

from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_Sepsis_weytjens_rem_time")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

"""
Parameter of Probabilistic Suffix Prediction experimental design, to ensure fair comparison:
"""

# Start learning rate
learning_rate = 1e-5

# Optimizer and Scheduler
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate, weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=4, min_lr=1e-9)

# Epochs
num_epochs = 100

# Batch of model input
batch_size = 128

# shuffle data
shuffle = True

optimize_values = {"regularization_term":regularization_term,
                   "optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle}

number_tasks = len(model_feat)

trainer = Training(model=model,
                   device=device,
                   data_train=sepsis_train_dataset,
                   data_val=sepsis_val_dataset,
                   concept_name_id=concept_name_id,
                   eos_id=eos_id,
                   loss_obj=loss_obj,
                   optimize_values=optimize_values,
                   writer=writer,
                   save_model_n_th_epoch=1,
                   saving_path="Sepsis_weytjens_rem_time_1_suffix_length5.pkl")

# Train the model:
trainer.train()
# Out:
# Device:  cuda
# Optimizer:  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x7faead4d4c20>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch [1/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 26.9950
# Validation: Avg Standard Validation Loss: 11.9562
# Validation: Avg Attenuated Validation Loss: 10.0290
# Validation Loss for Scheduler: 11.9562
# saving model
# Epoch [2/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.0350
# Validation: Avg Standard Validation Loss: 11.4449
# Validation: Avg Attenuated Validation Loss: 9.5957
# Validation Loss for Scheduler: 11.4449
# saving model
# Epoch [3/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 26.9615
# Validation: Avg Standard Validation Loss: 11.8994
# Validation: Avg Attenuated Validation Loss: 9.9656
# Validation Loss for Scheduler: 11.8994
# saving model
# Epoch [4/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.1821
# Validation: Avg Standard Validation Loss: 11.4107
# Validation: Avg Attenuated Validation Loss: 9.5663
# Validation Loss for Scheduler: 11.4107
# saving model
# Epoch [5/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 26.9538
# Validation: Avg Standard Validation Loss: 12.2003
# Validation: Avg Attenuated Validation Loss: 10.1966
# Validation Loss for Scheduler: 12.2003
# saving model
# Epoch [6/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 26.9969
# Validation: Avg Standard Validation Loss: 11.7878
# Validation: Avg Attenuated Validation Loss: 9.8367
# Validation Loss for Scheduler: 11.7878
# saving model
# Epoch [7/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.3444
# Validation: Avg Standard Validation Loss: 11.8307
# Validation: Avg Attenuated Validation Loss: 9.8605
# Validation Loss for Scheduler: 11.8307
# saving model
# Epoch [8/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 26.8162
# Validation: Avg Standard Validation Loss: 11.8190
# Validation: Avg Attenuated Validation Loss: 9.8351
# Validation Loss for Scheduler: 11.8190
# saving model
# Epoch [9/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 26.9928
# Validation: Avg Standard Validation Loss: 11.9134
# Validation: Avg Attenuated Validation Loss: 9.9207
# Validation Loss for Scheduler: 11.9134
# saving model
# Epoch [10/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 26.7880
# Validation: Avg Standard Validation Loss: 12.2242
# Validation: Avg Attenuated Validation Loss: 10.1659
# Validation Loss for Scheduler: 12.2242
# saving model
# Epoch [11/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 26.8581
# Validation: Avg Standard Validation Loss: 12.2407
# Validation: Avg Attenuated Validation Loss: 10.1818
# Validation Loss for Scheduler: 12.2407
# saving model
# Epoch [12/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 26.9544
# Validation: Avg Standard Validation Loss: 12.4261
# Validation: Avg Attenuated Validation Loss: 10.3303
# Validation Loss for Scheduler: 12.4261
# saving model
# Epoch [13/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 26.7251
# Validation: Avg Standard Validation Loss: 12.2827
# Validation: Avg Attenuated Validation Loss: 10.2027
# Validation Loss for Scheduler: 12.2827
# saving model
# Epoch [14/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 26.7915
# Validation: Avg Standard Validation Loss: 12.7178
# Validation: Avg Attenuated Validation Loss: 10.5609
# Validation Loss for Scheduler: 12.7178
# saving model
# Epoch [15/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 27.0191
# Validation: Avg Standard Validation Loss: 11.9000
# Validation: Avg Attenuated Validation Loss: 9.8996
# Validation Loss for Scheduler: 11.9000
# saving model
# Epoch [16/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 26.8625
# Validation: Avg Standard Validation Loss: 11.6339
# Validation: Avg Attenuated Validation Loss: 9.6845
# Validation Loss for Scheduler: 11.6339
# saving model
# Epoch [17/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 27.0699
# Validation: Avg Standard Validation Loss: 12.2198
# Validation: Avg Attenuated Validation Loss: 10.1359
# Validation Loss for Scheduler: 12.2198
# saving model
# Epoch [18/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 26.9389
# Validation: Avg Standard Validation Loss: 11.8085
# Validation: Avg Attenuated Validation Loss: 9.7895
# Validation Loss for Scheduler: 11.8085
# saving model
# Epoch [19/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 27.1049
# Validation: Avg Standard Validation Loss: 12.0037
# Validation: Avg Attenuated Validation Loss: 9.9785
# Validation Loss for Scheduler: 12.0037
# saving model
# Epoch [20/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8773
# Validation: Avg Standard Validation Loss: 12.9076
# Validation: Avg Attenuated Validation Loss: 10.7105
# Validation Loss for Scheduler: 12.9076
# saving model
# Epoch [21/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9886
# Validation: Avg Standard Validation Loss: 12.1270
# Validation: Avg Attenuated Validation Loss: 10.0934
# Validation Loss for Scheduler: 12.1270
# saving model
# Epoch [22/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9126
# Validation: Avg Standard Validation Loss: 12.0449
# Validation: Avg Attenuated Validation Loss: 10.0182
# Validation Loss for Scheduler: 12.0449
# saving model
# Epoch [23/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9338
# Validation: Avg Standard Validation Loss: 12.2993
# Validation: Avg Attenuated Validation Loss: 10.2356
# Validation Loss for Scheduler: 12.2993
# saving model
# Epoch [24/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9543
# Validation: Avg Standard Validation Loss: 13.1155
# Validation: Avg Attenuated Validation Loss: 10.8633
# Validation Loss for Scheduler: 13.1155
# saving model
# Epoch [25/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0463
# Validation: Avg Standard Validation Loss: 12.6069
# Validation: Avg Attenuated Validation Loss: 10.4686
# Validation Loss for Scheduler: 12.6069
# saving model
# Epoch [26/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9337
# Validation: Avg Standard Validation Loss: 11.6070
# Validation: Avg Attenuated Validation Loss: 9.6450
# Validation Loss for Scheduler: 11.6070
# saving model
# Epoch [27/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1017
# Validation: Avg Standard Validation Loss: 11.9563
# Validation: Avg Attenuated Validation Loss: 9.9364
# Validation Loss for Scheduler: 11.9563
# saving model
# Epoch [28/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7590
# Validation: Avg Standard Validation Loss: 12.5547
# Validation: Avg Attenuated Validation Loss: 10.4343
# Validation Loss for Scheduler: 12.5547
# saving model
# Epoch [29/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8561
# Validation: Avg Standard Validation Loss: 11.9069
# Validation: Avg Attenuated Validation Loss: 9.9002
# Validation Loss for Scheduler: 11.9069
# saving model
# Epoch [30/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7676
# Validation: Avg Standard Validation Loss: 11.9291
# Validation: Avg Attenuated Validation Loss: 9.9168
# Validation Loss for Scheduler: 11.9291
# saving model
# Epoch [31/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9165
# Validation: Avg Standard Validation Loss: 12.3756
# Validation: Avg Attenuated Validation Loss: 10.2841
# Validation Loss for Scheduler: 12.3756
# saving model
# Epoch [32/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9069
# Validation: Avg Standard Validation Loss: 13.0551
# Validation: Avg Attenuated Validation Loss: 10.8383
# Validation Loss for Scheduler: 13.0551
# saving model
# Epoch [33/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8915
# Validation: Avg Standard Validation Loss: 12.0817
# Validation: Avg Attenuated Validation Loss: 10.0320
# Validation Loss for Scheduler: 12.0817
# saving model
# Epoch [34/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8830
# Validation: Avg Standard Validation Loss: 12.0697
# Validation: Avg Attenuated Validation Loss: 10.0345
# Validation Loss for Scheduler: 12.0697
# saving model
# Epoch [35/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8668
# Validation: Avg Standard Validation Loss: 12.3159
# Validation: Avg Attenuated Validation Loss: 10.2451
# Validation Loss for Scheduler: 12.3159
# saving model
# Epoch [36/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8932
# Validation: Avg Standard Validation Loss: 11.5163
# Validation: Avg Attenuated Validation Loss: 9.6003
# Validation Loss for Scheduler: 11.5163
# saving model
# Epoch [37/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0183
# Validation: Avg Standard Validation Loss: 12.3688
# Validation: Avg Attenuated Validation Loss: 10.2588
# Validation Loss for Scheduler: 12.3688
# saving model
# Epoch [38/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7648
# Validation: Avg Standard Validation Loss: 12.0103
# Validation: Avg Attenuated Validation Loss: 10.0027
# Validation Loss for Scheduler: 12.0103
# saving model
# Epoch [39/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8128
# Validation: Avg Standard Validation Loss: 11.5224
# Validation: Avg Attenuated Validation Loss: 9.6061
# Validation Loss for Scheduler: 11.5224
# saving model
# Epoch [40/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9891
# Validation: Avg Standard Validation Loss: 12.1049
# Validation: Avg Attenuated Validation Loss: 10.0744
# Validation Loss for Scheduler: 12.1049
# saving model
# Epoch [41/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.2448
# Validation: Avg Standard Validation Loss: 12.2150
# Validation: Avg Attenuated Validation Loss: 10.1499
# Validation Loss for Scheduler: 12.2150
# saving model
# Epoch [42/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7593
# Validation: Avg Standard Validation Loss: 11.5643
# Validation: Avg Attenuated Validation Loss: 9.6184
# Validation Loss for Scheduler: 11.5643
# saving model
# Epoch [43/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7382
# Validation: Avg Standard Validation Loss: 12.0549
# Validation: Avg Attenuated Validation Loss: 10.0192
# Validation Loss for Scheduler: 12.0549
# saving model
# Epoch [44/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8917
# Validation: Avg Standard Validation Loss: 11.7930
# Validation: Avg Attenuated Validation Loss: 9.8251
# Validation Loss for Scheduler: 11.7930
# saving model
# Epoch [45/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7659
# Validation: Avg Standard Validation Loss: 12.7575
# Validation: Avg Attenuated Validation Loss: 10.5996
# Validation Loss for Scheduler: 12.7575
# saving model
# Epoch [46/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8406
# Validation: Avg Standard Validation Loss: 11.7168
# Validation: Avg Attenuated Validation Loss: 9.7588
# Validation Loss for Scheduler: 11.7168
# saving model
# Epoch [47/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7684
# Validation: Avg Standard Validation Loss: 11.7794
# Validation: Avg Attenuated Validation Loss: 9.7979
# Validation Loss for Scheduler: 11.7794
# saving model
# Epoch [48/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.3752
# Validation: Avg Standard Validation Loss: 12.2113
# Validation: Avg Attenuated Validation Loss: 10.1667
# Validation Loss for Scheduler: 12.2113
# saving model
# Epoch [49/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9952
# Validation: Avg Standard Validation Loss: 11.8435
# Validation: Avg Attenuated Validation Loss: 9.8528
# Validation Loss for Scheduler: 11.8435
# saving model
# Epoch [50/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8723
# Validation: Avg Standard Validation Loss: 12.4505
# Validation: Avg Attenuated Validation Loss: 10.3554
# Validation Loss for Scheduler: 12.4505
# saving model
# Epoch [51/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9706
# Validation: Avg Standard Validation Loss: 12.4326
# Validation: Avg Attenuated Validation Loss: 10.3394
# Validation Loss for Scheduler: 12.4326
# saving model
# Epoch [52/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7241
# Validation: Avg Standard Validation Loss: 11.6806
# Validation: Avg Attenuated Validation Loss: 9.7356
# Validation Loss for Scheduler: 11.6806
# saving model
# Epoch [53/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7300
# Validation: Avg Standard Validation Loss: 12.4237
# Validation: Avg Attenuated Validation Loss: 10.3039
# Validation Loss for Scheduler: 12.4237
# saving model
# Epoch [54/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9517
# Validation: Avg Standard Validation Loss: 12.5961
# Validation: Avg Attenuated Validation Loss: 10.4484
# Validation Loss for Scheduler: 12.5961
# saving model
# Epoch [55/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1872
# Validation: Avg Standard Validation Loss: 12.5552
# Validation: Avg Attenuated Validation Loss: 10.3948
# Validation Loss for Scheduler: 12.5552
# saving model
# Epoch [56/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0278
# Validation: Avg Standard Validation Loss: 11.8172
# Validation: Avg Attenuated Validation Loss: 9.8283
# Validation Loss for Scheduler: 11.8172
# saving model
# Epoch [57/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8550
# Validation: Avg Standard Validation Loss: 11.8255
# Validation: Avg Attenuated Validation Loss: 9.8323
# Validation Loss for Scheduler: 11.8255
# saving model
# Epoch [58/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0531
# Validation: Avg Standard Validation Loss: 11.5960
# Validation: Avg Attenuated Validation Loss: 9.6429
# Validation Loss for Scheduler: 11.5960
# saving model
# Epoch [59/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0921
# Validation: Avg Standard Validation Loss: 12.4639
# Validation: Avg Attenuated Validation Loss: 10.3639
# Validation Loss for Scheduler: 12.4639
# saving model
# Epoch [60/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8832
# Validation: Avg Standard Validation Loss: 12.1223
# Validation: Avg Attenuated Validation Loss: 10.0719
# Validation Loss for Scheduler: 12.1223
# saving model
# Epoch [61/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0417
# Validation: Avg Standard Validation Loss: 11.8214
# Validation: Avg Attenuated Validation Loss: 9.8356
# Validation Loss for Scheduler: 11.8214
# saving model
# Epoch [62/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8388
# Validation: Avg Standard Validation Loss: 11.9082
# Validation: Avg Attenuated Validation Loss: 9.9048
# Validation Loss for Scheduler: 11.9082
# saving model
# Epoch [63/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9181
# Validation: Avg Standard Validation Loss: 12.1106
# Validation: Avg Attenuated Validation Loss: 10.0731
# Validation Loss for Scheduler: 12.1106
# saving model
# Epoch [64/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8801
# Validation: Avg Standard Validation Loss: 12.5603
# Validation: Avg Attenuated Validation Loss: 10.4449
# Validation Loss for Scheduler: 12.5603
# saving model
# Epoch [65/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7490
# Validation: Avg Standard Validation Loss: 11.5914
# Validation: Avg Attenuated Validation Loss: 9.6407
# Validation Loss for Scheduler: 11.5914
# saving model
# Epoch [66/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8813
# Validation: Avg Standard Validation Loss: 12.6597
# Validation: Avg Attenuated Validation Loss: 10.5237
# Validation Loss for Scheduler: 12.6597
# saving model
# Epoch [67/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0485
# Validation: Avg Standard Validation Loss: 12.3483
# Validation: Avg Attenuated Validation Loss: 10.2561
# Validation Loss for Scheduler: 12.3483
# saving model
# Epoch [68/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7111
# Validation: Avg Standard Validation Loss: 12.2604
# Validation: Avg Attenuated Validation Loss: 10.1985
# Validation Loss for Scheduler: 12.2604
# saving model
# Epoch [69/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9784
# Validation: Avg Standard Validation Loss: 11.6302
# Validation: Avg Attenuated Validation Loss: 9.6670
# Validation Loss for Scheduler: 11.6302
# saving model
# Epoch [70/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8583
# Validation: Avg Standard Validation Loss: 12.1604
# Validation: Avg Attenuated Validation Loss: 10.0888
# Validation Loss for Scheduler: 12.1604
# saving model
# Epoch [71/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8044
# Validation: Avg Standard Validation Loss: 12.2595
# Validation: Avg Attenuated Validation Loss: 10.1818
# Validation Loss for Scheduler: 12.2595
# saving model
# Epoch [72/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8558
# Validation: Avg Standard Validation Loss: 12.7735
# Validation: Avg Attenuated Validation Loss: 10.5959
# Validation Loss for Scheduler: 12.7735
# saving model
# Epoch [73/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1120
# Validation: Avg Standard Validation Loss: 11.5809
# Validation: Avg Attenuated Validation Loss: 9.6413
# Validation Loss for Scheduler: 11.5809
# saving model
# Epoch [74/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7824
# Validation: Avg Standard Validation Loss: 12.2941
# Validation: Avg Attenuated Validation Loss: 10.2125
# Validation Loss for Scheduler: 12.2941
# saving model
# Epoch [75/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0313
# Validation: Avg Standard Validation Loss: 11.8775
# Validation: Avg Attenuated Validation Loss: 9.8795
# Validation Loss for Scheduler: 11.8775
# saving model
# Epoch [76/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0582
# Validation: Avg Standard Validation Loss: 11.5328
# Validation: Avg Attenuated Validation Loss: 9.5981
# Validation Loss for Scheduler: 11.5328
# saving model
# Epoch [77/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8849
# Validation: Avg Standard Validation Loss: 11.9943
# Validation: Avg Attenuated Validation Loss: 9.9719
# Validation Loss for Scheduler: 11.9943
# saving model
# Epoch [78/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8302
# Validation: Avg Standard Validation Loss: 11.6789
# Validation: Avg Attenuated Validation Loss: 9.7221
# Validation Loss for Scheduler: 11.6789
# saving model
# Epoch [79/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9221
# Validation: Avg Standard Validation Loss: 11.9223
# Validation: Avg Attenuated Validation Loss: 9.8977
# Validation Loss for Scheduler: 11.9223
# saving model
# Epoch [80/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8793
# Validation: Avg Standard Validation Loss: 12.5384
# Validation: Avg Attenuated Validation Loss: 10.4171
# Validation Loss for Scheduler: 12.5384
# saving model
# Epoch [81/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9289
# Validation: Avg Standard Validation Loss: 12.4348
# Validation: Avg Attenuated Validation Loss: 10.3339
# Validation Loss for Scheduler: 12.4348
# saving model
# Epoch [82/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0493
# Validation: Avg Standard Validation Loss: 12.0503
# Validation: Avg Attenuated Validation Loss: 10.0147
# Validation Loss for Scheduler: 12.0503
# saving model
# Epoch [83/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0192
# Validation: Avg Standard Validation Loss: 12.3811
# Validation: Avg Attenuated Validation Loss: 10.2844
# Validation Loss for Scheduler: 12.3811
# saving model
# Epoch [84/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8074
# Validation: Avg Standard Validation Loss: 11.4491
# Validation: Avg Attenuated Validation Loss: 9.5359
# Validation Loss for Scheduler: 11.4491
# saving model
# Epoch [85/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8522
# Validation: Avg Standard Validation Loss: 11.7494
# Validation: Avg Attenuated Validation Loss: 9.7619
# Validation Loss for Scheduler: 11.7494
# saving model
# Epoch [86/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8904
# Validation: Avg Standard Validation Loss: 11.7641
# Validation: Avg Attenuated Validation Loss: 9.7821
# Validation Loss for Scheduler: 11.7641
# saving model
# Epoch [87/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8936
# Validation: Avg Standard Validation Loss: 11.9457
# Validation: Avg Attenuated Validation Loss: 9.9420
# Validation Loss for Scheduler: 11.9457
# saving model
# Epoch [88/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7194
# Validation: Avg Standard Validation Loss: 11.4641
# Validation: Avg Attenuated Validation Loss: 9.5535
# Validation Loss for Scheduler: 11.4641
# saving model
# Epoch [89/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0229
# Validation: Avg Standard Validation Loss: 11.6680
# Validation: Avg Attenuated Validation Loss: 9.7041
# Validation Loss for Scheduler: 11.6680
# saving model
# Epoch [90/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8094
# Validation: Avg Standard Validation Loss: 11.8641
# Validation: Avg Attenuated Validation Loss: 9.8615
# Validation Loss for Scheduler: 11.8641
# saving model
# Epoch [91/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8901
# Validation: Avg Standard Validation Loss: 12.2294
# Validation: Avg Attenuated Validation Loss: 10.1780
# Validation Loss for Scheduler: 12.2294
# saving model
# Epoch [92/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8369
# Validation: Avg Standard Validation Loss: 11.8936
# Validation: Avg Attenuated Validation Loss: 9.8809
# Validation Loss for Scheduler: 11.8936
# saving model
# Epoch [93/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.2286
# Validation: Avg Standard Validation Loss: 11.8253
# Validation: Avg Attenuated Validation Loss: 9.8180
# Validation Loss for Scheduler: 11.8253
# saving model
# Epoch [94/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8342
# Validation: Avg Standard Validation Loss: 12.0623
# Validation: Avg Attenuated Validation Loss: 10.0299
# Validation Loss for Scheduler: 12.0623
# saving model
# Epoch [95/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.6945
# Validation: Avg Standard Validation Loss: 11.6430
# Validation: Avg Attenuated Validation Loss: 9.6724
# Validation Loss for Scheduler: 11.6430
# saving model
# Epoch [96/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0289
# Validation: Avg Standard Validation Loss: 12.7778
# Validation: Avg Attenuated Validation Loss: 10.5881
# Validation Loss for Scheduler: 12.7778
# saving model
# Epoch [97/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0371
# Validation: Avg Standard Validation Loss: 11.9427
# Validation: Avg Attenuated Validation Loss: 9.9177
# Validation Loss for Scheduler: 11.9427
# saving model
# Epoch [98/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.3123
# Validation: Avg Standard Validation Loss: 12.4820
# Validation: Avg Attenuated Validation Loss: 10.3678
# Validation Loss for Scheduler: 12.4820
# saving model
# Epoch [99/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0697
# Validation: Avg Standard Validation Loss: 13.1564
# Validation: Avg Attenuated Validation Loss: 10.8937
# Validation Loss for Scheduler: 13.1564
# saving model
# Epoch [100/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9585
# Validation: Avg Standard Validation Loss: 12.0544
# Validation: Avg Attenuated Validation Loss: 10.0322
# Validation Loss for Scheduler: 12.0544
# saving model
# Training complete.
# Model saved to path: Sepsis_weytjens_rem_time_1_suffix_length5.pkl
