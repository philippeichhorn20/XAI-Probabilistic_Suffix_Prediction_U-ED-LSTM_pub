# %% [markdown]
# # Camargo Sepsis — SharedCat architecture + role-grouped pickles + n-gram loader
#
# Sepsis profile mirrors the paper's BPI 2013 row (~1k cases, ~16 activities, simple SF, irregular TV). Three changes relative to the original `train_camargo_LSTM.ipynb`:
#
# 1. **Role-grouped pickles** (`Sepsis_all_5_roles_*.pkl`) — `model_feat = [['concept:name', 'org:group'], ['case_elapsed_time']]`. `org:group` is already the role analogue for Sepsis (pre-aggregated organisational group); no Song & van der Aalst clustering needed. `case_elapsed_time` is log-normalised by the loader (irregular TV).
# 2. **SharedCat architecture** — `sharedCatLSTM.model.SharedCat_LSTM` (paper Fig 6b, BPI 2013 best).
# 3. **N-gram loader (Camargo §3.1 / Table 1)** — `training.camargo_ngram_dataset.CamargoNGramDataset` with `NGRAM_SIZE = 5` (Sepsis is "simple" SF, traces are short). Replaces the U-ED-LSTM-style encoder-decoder windows.
#
# Reimplementation for comparison:
# - Camargo, Manuel, Marlon Dumas, and Oscar González-Rojas. "Learning accurate LSTM models of business processes." BPM 2019.
# - https://github.com/AdaptiveBProcess/GenerativeLSTM/

# %% [markdown]
# # Imports

# %%
import importlib
import sys
import torch
from pathlib import Path

_current = Path().resolve()
while _current != _current.parent:
    if (_current / 'src').is_dir() and (_current / 'data').is_dir():
        break
    _current = _current.parent
_project_root = _current

for p in [
    _project_root,
    _project_root / 'src',
    _project_root / 'src' / 'reimplemented_comparable_approaches' / 'camargo_LSTM_suffix_pred',
]:
    if str(p) not in sys.path:
        sys.path.insert(0, str(p))

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
file_path_train = '../../Loader/pkl/Sepsis_all_5_roles_train.pkl'
sepsis_train_dataset = torch.load(file_path_train, weights_only=False)
print(type(sepsis_train_dataset))

file_path_val = '../../Loader/pkl/Sepsis_all_5_roles_val.pkl'
sepsis_val_dataset = torch.load(file_path_val, weights_only=False)
print(type(sepsis_val_dataset))
# Out:
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>

# %% [markdown]
# ### Train Data Insights

# %%
# Sepsis Dataset Categories, Features:
sepsis_all_categories = sepsis_train_dataset.all_categories

sepsis_all_categories_cat = sepsis_all_categories[0]
print(sepsis_all_categories_cat)

sepsis_all_categories_num = sepsis_all_categories[1]
print(sepsis_all_categories_num)

for i, cat in enumerate(sepsis_all_categories_cat):
     print(f"sepsis(5) Categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"sepsis (5) Total Amount of Category labels: {cat[1]}")

print('\n')    

for i, num in enumerate(sepsis_all_categories_num):
     print(f"sepsis (5) Numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"sepsis (5) Amount Numerical: {num[1]}")
     
# Get concept_name id:
concept_name = 'concept:name'
concept_name_id = [i for i, cat in enumerate(sepsis_all_categories[0]) if cat[0] == concept_name][0]
print("ID concet name in cat list: ", concept_name_id)

# Output size
concept_name = 'concept:name'
concept_name_size = [cat[1] for _, cat in enumerate(sepsis_all_categories[0]) if cat[0] == concept_name][0]
print("ID concet name in cat list: ", concept_name_size)

# Id of EOS token in activity
eos_value = 'EOS'
eos_id = [v for k, v in sepsis_all_categories[0][concept_name_id][2].items() if k == eos_value][0]
# Get EOS id of concept name list:
print("ID EOS in concept name tensor: ", eos_id)
# Out:
# [('concept:name', 18, {'Admission IC': 1, 'Admission NC': 2, 'CRP': 3, 'EOS': 4, 'ER Registration': 5, 'ER Sepsis Triage': 6, 'ER Triage': 7, 'IV Antibiotics': 8, 'IV Liquid': 9, 'LacticAcid': 10, 'Leucocytes': 11, 'Release A': 12, 'Release B': 13, 'Release C': 14, 'Release D': 15, 'Release E': 16, 'Return ER': 17}), ('org:group', 27, {'?': 1, 'A': 2, 'B': 3, 'C': 4, 'D': 5, 'E': 6, 'EOS': 7, 'F': 8, 'G': 9, 'H': 10, 'I': 11, 'J': 12, 'K': 13, 'L': 14, 'M': 15, 'N': 16, 'O': 17, 'P': 18, 'Q': 19, 'R': 20, 'S': 21, 'T': 22, 'U': 23, 'V': 24, 'W': 25, 'X': 26})]
# [('case_elapsed_time', 1, {})]
# sepsis(5) Categorical feature: concept:name, Index position in categorical data list: 0
# sepsis (5) Total Amount of Category labels: 18
# sepsis(5) Categorical feature: org:group, Index position in categorical data list: 1
# sepsis (5) Total Amount of Category labels: 27
#
#
# sepsis (5) Numerical feature: case_elapsed_time, Index position in categorical data list: 0
# sepsis (5) Amount Numerical: 1
# ID concet name in cat list:  0
# ID concet name in cat list:  18
# ID EOS in concept name tensor:  4

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Model features (input)
model_feat_cat = []
model_feat_num = []
for cat in sepsis_all_categories_cat:
    model_feat_cat.append(cat[0])
for num in sepsis_all_categories_num:
    model_feat_num.append(num[0])
model_feat = [model_feat_cat, model_feat_num]
print("Input features encoder: ", model_feat)
# Out:
# Input features encoder:  [['concept:name', 'org:group'], ['case_elapsed_time']]

# %% [markdown]
# # Model

# %%
import sharedCatLSTM.model
importlib.reload(sharedCatLSTM.model)
from sharedCatLSTM.model import SharedCat_LSTM

# Paper hyper-parameters (BPI 2013 row).
hidden_size = 50
num_layers = 1
input_size = 1  # sentinel; SharedCat_LSTM computes the real input size from embeddings.

model = SharedCat_LSTM(
    data_set_categories=sepsis_all_categories,
    hidden_size=hidden_size,
    num_layers=num_layers,
    model_feat=model_feat,
    input_size=input_size,
    output_size_act=concept_name_size,
)
# Out:
# Data set categories:  ([('concept:name', 18, {'Admission IC': 1, 'Admission NC': 2, 'CRP': 3, 'EOS': 4, 'ER Registration': 5, 'ER Sepsis Triage': 6, 'ER Triage': 7, 'IV Antibiotics': 8, 'IV Liquid': 9, 'LacticAcid': 10, 'Leucocytes': 11, 'Release A': 12, 'Release B': 13, 'Release C': 14, 'Release D': 15, 'Release E': 16, 'Return ER': 17}), ('org:group', 27, {'?': 1, 'A': 2, 'B': 3, 'C': 4, 'D': 5, 'E': 6, 'EOS': 7, 'F': 8, 'G': 9, 'H': 10, 'I': 11, 'J': 12, 'K': 13, 'L': 14, 'M': 15, 'N': 16, 'O': 17, 'P': 18, 'Q': 19, 'R': 20, 'S': 21, 'T': 22, 'U': 23, 'V': 24, 'W': 25, 'X': 26})], [('case_elapsed_time', 1, {})])
# Model input features:  [['concept:name', 'org:group'], ['case_elapsed_time']]
# Embeddings:  ModuleList(
#   (0): Embedding(18, 8)
#   (1): Embedding(27, 10)
# )
# Total embedding feature size:  18
# Number of numerical features:  1
# Input feature size (shared LSTM, cat-only):  18
# Cells hidden size:  50
# Number of LSTM layer:  1
# /Users/philippeichhorn/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/torch/nn/modules/rnn.py:990: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)

# %% [markdown]
# # Training Configuration

# %%
import training.camargo_ngram_dataset
import training.train_ngram
importlib.reload(training.camargo_ngram_dataset)
importlib.reload(training.train_ngram)
from training.camargo_ngram_dataset import CamargoNGramDataset
from training.train_ngram import NGramTraining

from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.tensorboard import SummaryWriter

# Paper Table 3: n-gram size 5 for short-trace, simple-SF datasets (Sepsis fits this row).
NGRAM_SIZE = 5

ngram_train = CamargoNGramDataset(sepsis_train_dataset, ngram_size=NGRAM_SIZE,
                                  activity_idx=concept_name_id, eos_idx=eos_id)
ngram_val = CamargoNGramDataset(sepsis_val_dataset, ngram_size=NGRAM_SIZE,
                                activity_idx=concept_name_id, eos_idx=eos_id)
print(f'n-gram train: {len(ngram_train)} samples (from {len(sepsis_train_dataset)} base windows)')
print(f'n-gram val:   {len(ngram_val)} samples (from {len(sepsis_val_dataset)} base windows)')

writer = SummaryWriter(comment="Full_sepsis_camargo_sharedcat_ngram5")

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# lr=1e-3 (paper-aligned Adam default). The earlier 1e-5 was inherited from the
# U-ED-LSTM setup and is too small for the Camargo baseline.
learning_rate = 1e-3
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate, weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=4, min_lr=1e-10)

num_epochs = 100
batch_size = 128
shuffle = True

optimize_values = {
    "optimizer": optimizer,
    "scheduler": scheduler,
    "epochs": num_epochs,
    "mini_batches": batch_size,
    "shuffle": shuffle,
}

trainer = NGramTraining(
    model=model,
    device=device,
    data_train=ngram_train,
    data_val=ngram_val,
    optimize_values=optimize_values,
    writer=writer,
    save_model_n_th_epoch=1,
    saving_path="../pkl/Sepsis_camargo_sharedcat_ngram5.pkl",
)

trainer.train()
# Out:
# n-gram train: 10399 samples (from 11371 base windows)
# n-gram val:   2373 samples (from 2665 base windows)
# Device:  cpu
# Optimizer: Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.001
#     maximize: False
#     weight_decay: 0
# )
# Scheduler: <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x1658b1730>
# Epochs: 100  Mini-batch: 128  Shuffle: True
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch [1/100], LR: 0.001
# Training:   Avg Loss: 2.0326
# Validation: Avg Loss: 1.4136
# saving model
# Epoch [2/100], LR: 0.001
# Training:   Avg Loss: 1.2589
# Validation: Avg Loss: 1.1353
# saving model
# Epoch [3/100], LR: 0.001
# Training:   Avg Loss: 1.0886
# Validation: Avg Loss: 1.0561
# saving model
# Epoch [4/100], LR: 0.001
# Training:   Avg Loss: 1.0134
# Validation: Avg Loss: 1.0208
# saving model
# Epoch [5/100], LR: 0.001
# Training:   Avg Loss: 0.9685
# Validation: Avg Loss: 0.9877
# saving model
# Epoch [6/100], LR: 0.001
# Training:   Avg Loss: 0.9469
# Validation: Avg Loss: 0.9741
# saving model
# Epoch [7/100], LR: 0.001
# Training:   Avg Loss: 0.9299
# Validation: Avg Loss: 0.9646
# saving model
# Epoch [8/100], LR: 0.001
# Training:   Avg Loss: 0.9111
# Validation: Avg Loss: 0.9665
# saving model
# Epoch [9/100], LR: 0.001
# Training:   Avg Loss: 0.9046
# Validation: Avg Loss: 0.9561
# saving model
# Epoch [10/100], LR: 0.001
# Training:   Avg Loss: 0.8988
# Validation: Avg Loss: 0.9448
# saving model
# Epoch [11/100], LR: 0.001
# Training:   Avg Loss: 0.8878
# Validation: Avg Loss: 0.9607
# saving model
# Epoch [12/100], LR: 0.001
# Training:   Avg Loss: 0.8849
# Validation: Avg Loss: 0.9488
# saving model
# Epoch [13/100], LR: 0.001
# Training:   Avg Loss: 0.8738
# Validation: Avg Loss: 0.9447
# saving model
# Epoch [14/100], LR: 0.001
# Training:   Avg Loss: 0.8713
# Validation: Avg Loss: 0.9421
# saving model
# Epoch [15/100], LR: 0.001
# Training:   Avg Loss: 0.8632
# Validation: Avg Loss: 0.9481
# saving model
# Epoch [16/100], LR: 0.001
# Training:   Avg Loss: 0.8559
# Validation: Avg Loss: 0.9412
# saving model
# Epoch [17/100], LR: 0.001
# Training:   Avg Loss: 0.8515
# Validation: Avg Loss: 0.9376
# saving model
# Epoch [18/100], LR: 0.001
# Training:   Avg Loss: 0.8503
# Validation: Avg Loss: 0.9487
# saving model
# Epoch [19/100], LR: 0.001
# Training:   Avg Loss: 0.8460
# Validation: Avg Loss: 0.9408
# saving model
# Epoch [20/100], LR: 0.001
# Training:   Avg Loss: 0.8433
# Validation: Avg Loss: 0.9472
# saving model
# Epoch [21/100], LR: 0.001
# Training:   Avg Loss: 0.8378
# Validation: Avg Loss: 0.9449
# saving model
# Epoch [22/100], LR: 0.001
# Training:   Avg Loss: 0.8332
# Validation: Avg Loss: 0.9445
# saving model
# Epoch [23/100], LR: 0.0001
# Training:   Avg Loss: 0.8146
# Validation: Avg Loss: 0.9357
# saving model
# Epoch [24/100], LR: 0.0001
# Training:   Avg Loss: 0.8138
# Validation: Avg Loss: 0.9360
# saving model
# Epoch [25/100], LR: 0.0001
# Training:   Avg Loss: 0.8127
# Validation: Avg Loss: 0.9357
# saving model
# Epoch [26/100], LR: 0.0001
# Training:   Avg Loss: 0.8077
# Validation: Avg Loss: 0.9357
# saving model
# Epoch [27/100], LR: 0.0001
# Training:   Avg Loss: 0.8093
# Validation: Avg Loss: 0.9352
# saving model
# Epoch [28/100], LR: 0.0001
# Training:   Avg Loss: 0.8064
# Validation: Avg Loss: 0.9353
# saving model
# Epoch [29/100], LR: 0.0001
# Training:   Avg Loss: 0.8104
# Validation: Avg Loss: 0.9372
# saving model
# Epoch [30/100], LR: 0.0001
# Training:   Avg Loss: 0.8078
# Validation: Avg Loss: 0.9359
# saving model
# Epoch [31/100], LR: 0.0001
# Training:   Avg Loss: 0.8072
# Validation: Avg Loss: 0.9359
# saving model
# Epoch [32/100], LR: 0.0001
# Training:   Avg Loss: 0.8070
# Validation: Avg Loss: 0.9362
# saving model
# Epoch [33/100], LR: 1e-05
# Training:   Avg Loss: 0.8033
# Validation: Avg Loss: 0.9349
# saving model
# Epoch [34/100], LR: 1e-05
# Training:   Avg Loss: 0.8044
# Validation: Avg Loss: 0.9361
# saving model
# Epoch [35/100], LR: 1e-05
# Training:   Avg Loss: 0.8045
# Validation: Avg Loss: 0.9358
# saving model
# Epoch [36/100], LR: 1e-05
# Training:   Avg Loss: 0.8031
# Validation: Avg Loss: 0.9354
# saving model
# Epoch [37/100], LR: 1e-05
# Training:   Avg Loss: 0.8010
# Validation: Avg Loss: 0.9348
# saving model
# Epoch [38/100], LR: 1e-05
# Training:   Avg Loss: 0.7999
# Validation: Avg Loss: 0.9359
# saving model
# Epoch [39/100], LR: 1.0000000000000002e-06
# Training:   Avg Loss: 0.8026
# Validation: Avg Loss: 0.9349
# saving model
# Epoch [40/100], LR: 1.0000000000000002e-06
# Training:   Avg Loss: 0.8036
# Validation: Avg Loss: 0.9358
# saving model
# Epoch [41/100], LR: 1.0000000000000002e-06
# Training:   Avg Loss: 0.8037
# Validation: Avg Loss: 0.9351
# saving model
# Epoch [42/100], LR: 1.0000000000000002e-06
# Training:   Avg Loss: 0.8050
# Validation: Avg Loss: 0.9355
# saving model
# Epoch [43/100], LR: 1.0000000000000002e-06
# Training:   Avg Loss: 0.8030
# Validation: Avg Loss: 0.9352
# saving model
# Epoch [44/100], LR: 1.0000000000000002e-07
# Training:   Avg Loss: 0.8027
# Validation: Avg Loss: 0.9359
# saving model
# Epoch [45/100], LR: 1.0000000000000002e-07
# Training:   Avg Loss: 0.8018
# Validation: Avg Loss: 0.9360
# saving model
# Epoch [46/100], LR: 1.0000000000000002e-07
# Training:   Avg Loss: 0.8042
# Validation: Avg Loss: 0.9362
# saving model
# Epoch [47/100], LR: 1.0000000000000002e-07
# Training:   Avg Loss: 0.8032
# Validation: Avg Loss: 0.9343
# saving model
# Epoch [48/100], LR: 1.0000000000000002e-07
# Training:   Avg Loss: 0.8043
# Validation: Avg Loss: 0.9363
# saving model
# Epoch [49/100], LR: 1.0000000000000002e-07
# Training:   Avg Loss: 0.8022
# Validation: Avg Loss: 0.9355
# saving model
# Epoch [50/100], LR: 1.0000000000000002e-07
# Training:   Avg Loss: 0.7997
# Validation: Avg Loss: 0.9353
# saving model
# Epoch [51/100], LR: 1.0000000000000002e-07
# Training:   Avg Loss: 0.8054
# Validation: Avg Loss: 0.9353
# saving model
# Epoch [52/100], LR: 1.0000000000000002e-07
# Training:   Avg Loss: 0.8027
# Validation: Avg Loss: 0.9355
# saving model
# Epoch [53/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8051
# Validation: Avg Loss: 0.9353
# saving model
# Epoch [54/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8043
# Validation: Avg Loss: 0.9351
# saving model
# Epoch [55/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8012
# Validation: Avg Loss: 0.9358
# saving model
# Epoch [56/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.7997
# Validation: Avg Loss: 0.9344
# saving model
# Epoch [57/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8031
# Validation: Avg Loss: 0.9359
# saving model
# Epoch [58/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8026
# Validation: Avg Loss: 0.9364
# saving model
# Epoch [59/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8066
# Validation: Avg Loss: 0.9353
# saving model
# Epoch [60/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.7997
# Validation: Avg Loss: 0.9358
# saving model
# Epoch [61/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8048
# Validation: Avg Loss: 0.9361
# saving model
# Epoch [62/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8010
# Validation: Avg Loss: 0.9353
# saving model
# Epoch [63/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8021
# Validation: Avg Loss: 0.9356
# saving model
# Epoch [64/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8026
# Validation: Avg Loss: 0.9352
# saving model
# Epoch [65/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8015
# Validation: Avg Loss: 0.9359
# saving model
# Epoch [66/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8023
# Validation: Avg Loss: 0.9356
# saving model
# Epoch [67/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8008
# Validation: Avg Loss: 0.9350
# saving model
# Epoch [68/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8047
# Validation: Avg Loss: 0.9349
# saving model
# Epoch [69/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8051
# Validation: Avg Loss: 0.9356
# saving model
# Epoch [70/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8047
# Validation: Avg Loss: 0.9358
# saving model
# Epoch [71/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8042
# Validation: Avg Loss: 0.9356
# saving model
# Epoch [72/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8016
# Validation: Avg Loss: 0.9366
# saving model
# Epoch [73/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8028
# Validation: Avg Loss: 0.9358
# saving model
# Epoch [74/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8027
# Validation: Avg Loss: 0.9355
# saving model
# Epoch [75/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8031
# Validation: Avg Loss: 0.9350
# saving model
# Epoch [76/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8032
# Validation: Avg Loss: 0.9354
# saving model
# Epoch [77/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8015
# Validation: Avg Loss: 0.9358
# saving model
# Epoch [78/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8011
# Validation: Avg Loss: 0.9347
# saving model
# Epoch [79/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8012
# Validation: Avg Loss: 0.9354
# saving model
# Epoch [80/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8036
# Validation: Avg Loss: 0.9356
# saving model
# Epoch [81/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8035
# Validation: Avg Loss: 0.9359
# saving model
# Epoch [82/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8038
# Validation: Avg Loss: 0.9354
# saving model
# Epoch [83/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8028
# Validation: Avg Loss: 0.9358
# saving model
# Epoch [84/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8010
# Validation: Avg Loss: 0.9355
# saving model
# Epoch [85/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8026
# Validation: Avg Loss: 0.9352
# saving model
# Epoch [86/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8014
# Validation: Avg Loss: 0.9361
# saving model
# Epoch [87/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8026
# Validation: Avg Loss: 0.9351
# saving model
# Epoch [88/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8040
# Validation: Avg Loss: 0.9351
# saving model
# Epoch [89/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8054
# Validation: Avg Loss: 0.9359
# saving model
# Epoch [90/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8016
# Validation: Avg Loss: 0.9358
# saving model
# Epoch [91/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8033
# Validation: Avg Loss: 0.9359
# saving model
# Epoch [92/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8035
# Validation: Avg Loss: 0.9355
# saving model
# Epoch [93/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8044
# Validation: Avg Loss: 0.9353
# saving model
# Epoch [94/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8037
# Validation: Avg Loss: 0.9355
# saving model
# Epoch [95/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8040
# Validation: Avg Loss: 0.9354
# saving model
# Epoch [96/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8030
# Validation: Avg Loss: 0.9349
# saving model
# Epoch [97/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8019
# Validation: Avg Loss: 0.9356
# saving model
# Epoch [98/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8020
# Validation: Avg Loss: 0.9351
# saving model
# Epoch [99/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.8013
# Validation: Avg Loss: 0.9353
# saving model
# Epoch [100/100], LR: 1.0000000000000004e-08
# Training:   Avg Loss: 0.7990
# Validation: Avg Loss: 0.9351
# saving model
# Training complete.
# Model saved to path: ../pkl/Sepsis_camargo_sharedcat_ngram5.pkl
