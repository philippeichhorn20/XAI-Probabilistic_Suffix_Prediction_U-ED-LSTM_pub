# %% [markdown]
# # 22b — Surrogate Trees Only
#
# For each decision-point gateway, fit a decision tree whose target is the
# **LSTM's predicted next activity** (the "surrogate"). Shows the rules the
# LSTM effectively learned, without comparing to ground-truth process logic.
#
# See `22_gateway_decision_analysis.ipynb` for the full LSTM vs. ground-truth
# comparison.

# %%
import sys
from pathlib import Path

_current = Path().resolve()
while _current != _current.parent:
    if (_current / 'src').is_dir():
        break
    _current = _current.parent

if str(_current) not in sys.path:
    sys.path.insert(0, str(_current))

src_path = str(_current / 'src')
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# %%
import logging
logging.getLogger('matplotlib').setLevel(logging.WARNING)

import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

from src.interpretability.surrogate.c45_tree import C45Classifier

# --- Load dataset ---
data_path = _current / 'encoded_data' / 'BPIC_2017_all_5_test.pkl'
dataset = torch.load(data_path, weights_only=False)

sample = dataset[0]
n_cat = len(sample[0])
n_num = len(sample[1])
seq_len = sample[0][0].shape[0]
print(f'Dataset: {len(dataset)} sequences, {n_cat} cat, {n_num} num, seq_len={seq_len}')

# --- Load model ---
from src.model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model import DropoutUncertaintyEncoderDecoderLSTM

from src.interpretability.config.bpic17_config import CONFIG
model = DropoutUncertaintyEncoderDecoderLSTM.load(str(CONFIG.get_model_path()), dropout=0.0)
model.eval()

# --- TensorDecoder + activity vocab ---
from src.interpretability.utils.tensor_decoder import TensorDecoder

decoder = TensorDecoder(dataset)

ACTIVITY_FEATURE = 'concept:name'
activity_idx_to_label = decoder.idx_to_label[ACTIVITY_FEATURE]
max_idx = max(activity_idx_to_label.keys())
activity_names = [activity_idx_to_label.get(i, f'<unk_{i}>') for i in range(max_idx + 1)]
eos_idx = next(i for i, name in enumerate(activity_names) if name == 'EOS')

# --- Predictor ---
from src.interpretability.perturbation_methods.revised_plus.revised_plus import RevisedPlusModelPredictor

predictor = RevisedPlusModelPredictor(model, suffix_step=0, activity_feature=ACTIVITY_FEATURE)

# --- Feature indices (BPIC17) ---
ACT_IDX = decoder.cat_features.index('concept:name')       # 0
RES_IDX = decoder.cat_features.index('org:resource')        # 2
LC_IDX = decoder.cat_features.index('lifecycle:transition')  # 4
LG_IDX = decoder.cat_features.index('case:LoanGoal')        # 5
AT_IDX = decoder.cat_features.index('case:ApplicationType')  # 6

elapsed_num_idx = decoder.num_features.index('case_elapsed_time')
event_num_idx = decoder.num_features.index('event_elapsed_time')
amount_num_idx = decoder.num_features.index('case:RequestedAmount')
credit_num_idx = decoder.num_features.index('CreditScore')
day_num_idx = decoder.num_features.index('day_in_week')

print(f'Act={ACT_IDX}, Res={RES_IDX}, LC={LC_IDX}, LG={LG_IDX}, AT={AT_IDX}')
print(f'elapsed={elapsed_num_idx}, event={event_num_idx}, amount={amount_num_idx}, '
      f'credit={credit_num_idx}, day={day_num_idx}')
print(f'Activity vocabulary ({len(activity_names)}), EOS={eos_idx}')
print(f'Cat features: {decoder.cat_features}')
print(f'Num features: {decoder.num_features}')

# %% [markdown]
# ## Build DFG and identify qualifying gateways

# %%
MIN_CASES = 50       # minimum prefixes at this gateway
MIN_BRANCH = 10      # minimum cases per branch (need at least 2 branches above this)
MIN_SAMPLES_LEAF = 20

ACTIVITY_WINDOW = 40                # number of recent events to include as positional features
CASE_LEVEL_THRESHOLD = 0.95     # feature is case-level if it's constant within a case in >=95% of cases

# --- Collect unique cases (longest trace per case_id) ---
cases = {}
for i in range(len(dataset)):
    cat_t, num_t, case_id = dataset[i]
    trace_len = int((cat_t[0] != 0).sum().item())
    if case_id not in cases or trace_len > cases[case_id][1]:
        cases[case_id] = (i, trace_len)

print(f'{len(cases)} unique cases')

# --- Data-driven classification: event-level vs case-level ---
# A feature is case-level if at least CASE_LEVEL_THRESHOLD of cases have a single
# constant value across all real (non-EOS) events of the case.
_n_cat_const = [0] * n_cat
_n_num_const = [0] * n_num
_total_checked = 0
for _cid, (_idx, _L) in cases.items():
    _cat_t, _num_t, _ = dataset[_idx]
    _s = seq_len - _L
    _useful = _L
    for _j in range(_L - 1, -1, -1):
        if _cat_t[ACT_IDX][_s + _j].item() == eos_idx:
            _useful = _j
        else:
            break
    if _useful == 0:
        continue
    _total_checked += 1
    for _ci in range(n_cat):
        _vals = _cat_t[_ci][_s:_s + _useful].tolist()
        if len(set(_vals)) == 1:
            _n_cat_const[_ci] += 1
    for _ni in range(n_num):
        _vals = _num_t[_ni][_s:_s + _useful].tolist()
        if max(_vals) - min(_vals) < 1e-6:
            _n_num_const[_ni] += 1

EVENT_CAT_INDICES = [i for i in range(n_cat)
                     if _n_cat_const[i] / _total_checked < CASE_LEVEL_THRESHOLD]
EVENT_NUM_INDICES = [i for i in range(n_num)
                     if _n_num_const[i] / _total_checked < CASE_LEVEL_THRESHOLD]

print(f'\nFeature classification (threshold: {CASE_LEVEL_THRESHOLD:.0%} constant -> case-level, '
      f'based on {_total_checked} cases):')
for _ci in range(n_cat):
    _pct = _n_cat_const[_ci] / _total_checked
    _tag = 'event-level' if _ci in EVENT_CAT_INDICES else 'CASE-LEVEL'
    print(f'  cat[{_ci}] {decoder.cat_features[_ci]:35s} {_pct:5.1%} constant  -> {_tag}')
for _ni in range(n_num):
    _pct = _n_num_const[_ni] / _total_checked
    _tag = 'event-level' if _ni in EVENT_NUM_INDICES else 'CASE-LEVEL'
    print(f'  num[{_ni}] {decoder.num_features[_ni]:35s} {_pct:5.1%} constant  -> {_tag}')

# --- Build DFG ---
dfg = {}
successors_map = {}

for case_id, (ds_idx, trace_len) in cases.items():
    cat_full = dataset[ds_idx][0]
    src_start = seq_len - trace_len
    acts = cat_full[ACT_IDX][src_start:src_start + trace_len]

    # Strip trailing EOS
    useful_len = trace_len
    for j in range(trace_len - 1, -1, -1):
        if acts[j].item() == eos_idx:
            useful_len = j
        else:
            break

    act_names = [activity_names[acts[j].item()] for j in range(useful_len)]
    for k in range(len(act_names) - 1):
        edge = (act_names[k], act_names[k + 1])
        dfg[edge] = dfg.get(edge, 0) + 1

for (src, tgt), count in dfg.items():
    successors_map.setdefault(src, {})[tgt] = count

decision_points = {
    act: succs for act, succs in successors_map.items()
    if len(succs) > 1
}

print(f'\nDecision points ({len(decision_points)}):')
for act, succs in sorted(decision_points.items(), key=lambda x: -sum(x[1].values())):
    total = sum(succs.values())
    branches = ', '.join(f'{s} ({c}, {c/total*100:.0f}%)' for s, c in
                         sorted(succs.items(), key=lambda x: -x[1]))
    print(f'  {act} ({total} cases): {branches}')
# Out:
# 6301 unique cases
#
# Feature classification (threshold: 95% constant -> case-level, based on 6301 cases):
#   cat[0] concept:name                         0.0% constant  -> event-level
#   cat[1] Action                               0.0% constant  -> event-level
#   cat[2] org:resource                         0.3% constant  -> event-level
#   cat[3] EventOrigin                          0.0% constant  -> event-level
#   cat[4] lifecycle:transition                 0.0% constant  -> event-level
#   cat[5] case:LoanGoal                       100.0% constant  -> CASE-LEVEL
#   cat[6] case:ApplicationType                100.0% constant  -> CASE-LEVEL
#   cat[7] Accepted                             0.0% constant  -> event-level
#   cat[8] Selected                             0.0% constant  -> event-level
#   num[0] case_elapsed_time                    0.0% constant  -> event-level
#   num[1] event_elapsed_time                   0.0% constant  -> event-level
#   num[2] day_in_week                          0.7% constant  -> event-level
#   num[3] seconds_in_day                       0.0% constant  -> event-level
#   num[4] case:RequestedAmount                100.0% constant  -> CASE-LEVEL
#   num[5] FirstWithdrawalAmount                0.0% constant  -> event-level
#   num[6] NumberOfTerms                        0.0% constant  -> event-level
#   num[7] MonthlyCost                          0.0% constant  -> event-level
#   num[8] CreditScore                          0.0% constant  -> event-level
#
# Decision points (22):
#   W_Validate application (39038 cases): W_Validate application (23032, 59%), A_Validating (7656, 20%), W_Call incomplete files (4515, 12%), O_Accepted (2316, 6%), A_Denied (652, 2%), O_Cancelled (604, 2%), O_Returned (185, 0%), W_Assess potential fraud (48, 0%), O_Create Offer (19, 0%), A_Cancelled (11, 0%)
#   W_Call after offers (36452 cases): W_Call after offers (23236, 64%), A_Complete (6270, 17%), W_Validate application (4343, 12%), A_Cancelled (1729, 5%), O_Create Offer (787, 2%), O_Cancelled (51, 0%), A_Denied (17, 0%), W_Shortened completion  (7, 0%), O_Sent (mail and online) (6, 0%), W_Assess potential fraud (5, 0%), O_Accepted (1, 0%)
#   W_Call incomplete files (32395 cases): W_Call incomplete files (22646, 70%), A_Incomplete (4512, 14%), W_Validate application (3313, 10%), O_Accepted (909, 3%), O_Create Offer (377, 1%), O_Cancelled (268, 1%), A_Cancelled (176, 1%), O_Returned (153, 0%), A_Denied (34, 0%), W_Assess potential fraud (3, 0%), W_Call after offers (2, 0%), O_Sent (online only) (1, 0%), O_Sent (mail and online) (1, 0%)
#   W_Complete application (29857 cases): W_Complete application (13044, 44%), W_Call after offers (6270, 21%), A_Concept (5630, 19%), A_Accepted (4435, 15%), O_Create Offer (321, 1%), O_Sent (mail and online) (120, 0%), O_Cancelled (12, 0%), W_Shortened completion  (8, 0%), A_Cancelled (7, 0%), W_Assess potential fraud (4, 0%), O_Sent (online only) (4, 0%), A_Denied (2, 0%)
#   W_Handle leads (9382 cases): W_Handle leads (5304, 57%), W_Complete application (4074, 43%), W_Assess potential fraud (4, 0%)
#   O_Created (8648 cases): O_Sent (mail and online) (7145, 83%), O_Create Offer (779, 9%), O_Sent (online only) (395, 5%), W_Complete application (146, 2%), O_Cancelled (141, 2%), A_Cancelled (18, 0%), W_Call after offers (13, 0%), A_Denied (6, 0%), W_Call incomplete files (4, 0%), W_Shortened completion  (1, 0%)
#   O_Sent (mail and online) (7975 cases): W_Complete application (6178, 77%), W_Call after offers (705, 9%), O_Sent (mail and online) (628, 8%), W_Call incomplete files (157, 2%), A_Cancelled (111, 1%), O_Create Offer (99, 1%), O_Cancelled (71, 1%), O_Returned (13, 0%), W_Validate application (12, 0%), A_Denied (1, 0%)
#   A_Validating (7650 cases): O_Returned (4095, 54%), W_Validate application (3507, 46%), O_Accepted (39, 1%), A_Denied (5, 0%), A_Cancelled (4, 0%)
#   A_Create Application (6301 cases): A_Submitted (4074, 65%), W_Complete application (1556, 25%), A_Concept (671, 11%)
#   A_Concept (6301 cases): W_Complete application (4439, 70%), A_Accepted (1858, 29%), W_Shortened completion  (4, 0%)
#   A_Accepted (6300 cases): O_Create Offer (5987, 95%), W_Complete application (312, 5%), W_Shortened completion  (1, 0%)
#   A_Complete (6270 cases): W_Call after offers (6055, 97%), O_Create Offer (116, 2%), O_Cancelled (61, 1%), A_Cancelled (13, 0%), W_Shortened completion  (12, 0%), O_Sent (mail and online) (10, 0%), A_Denied (2, 0%), O_Sent (online only) (1, 0%)
#   O_Returned (4613 cases): W_Validate application (4203, 91%), W_Call incomplete files (302, 7%), O_Accepted (99, 2%), A_Denied (4, 0%), O_Returned (2, 0%), A_Cancelled (2, 0%), O_Create Offer (1, 0%)
#   A_Incomplete (4511 cases): W_Call incomplete files (4365, 97%), O_Returned (139, 3%), O_Accepted (6, 0%), O_Create Offer (1, 0%)
#   A_Pending (3362 cases): W_Validate application (2422, 72%), W_Call incomplete files (939, 28%), W_Call after offers (1, 0%)
#   O_Cancelled (3341 cases): W_Call after offers (1963, 59%), O_Cancelled (897, 27%), W_Call incomplete files (182, 5%), O_Create Offer (141, 4%), O_Sent (mail and online) (68, 2%), A_Cancelled (35, 1%), W_Complete application (24, 1%), W_Validate application (19, 1%), A_Denied (8, 0%), O_Sent (online only) (3, 0%), W_Shortened completion  (1, 0%)
#   A_Cancelled (2115 cases): O_Cancelled (2078, 98%), W_Call after offers (25, 1%), W_Call incomplete files (7, 0%), W_Complete application (5, 0%)
#   O_Refused (946 cases): W_Validate application (660, 70%), O_Refused (202, 21%), W_Call incomplete files (34, 4%), W_Assess potential fraud (22, 2%), W_Call after offers (20, 2%), W_Complete application (8, 1%)
#   A_Denied (753 cases): O_Refused (745, 99%), W_Call incomplete files (5, 1%), W_Call after offers (2, 0%), W_Complete application (1, 0%)
#   W_Assess potential fraud (639 cases): W_Assess potential fraud (575, 90%), W_Validate application (31, 5%), A_Denied (22, 3%), W_Complete application (4, 1%), W_Handle leads (4, 1%), W_Call after offers (3, 0%)
#   O_Sent (online only) (416 cases): W_Call incomplete files (184, 44%), W_Complete application (92, 22%), W_Call after offers (59, 14%), O_Returned (26, 6%), O_Create Offer (21, 5%), O_Sent (online only) (14, 3%), A_Cancelled (9, 2%), W_Validate application (5, 1%), O_Cancelled (5, 1%), O_Sent (mail and online) (1, 0%)
#   W_Shortened completion  (63 cases): W_Shortened completion  (31, 49%), W_Call after offers (18, 29%), A_Accepted (7, 11%), W_Complete application (5, 8%), O_Create Offer (1, 2%), O_Sent (mail and online) (1, 2%)

# %% [markdown]
# ## Collect per-gateway prefixes and LSTM predictions

# %%
def extract_features(cat_tuple, num_tuple, decoder):
    """Extract features for a single prefix.

    Kept minimal: prefix_length, case-level features (cat + num) at the gateway
    position, and positional encoding over the last ACTIVITY_WINDOW events for
    every event-level categorical AND numerical feature.
    """
    act_tensor = cat_tuple[ACT_IDX]
    mask = act_tensor != 0
    prefix_len = int(mask.sum().item())
    if prefix_len == 0:
        return None

    nonzero = mask.nonzero(as_tuple=True)[0]
    start = nonzero[0].item()
    end = start + prefix_len

    feats = {'prefix_length': prefix_len}

    # Case-level categorical features (event-level ones are covered by positional features below)
    for ci, feat_name in enumerate(decoder.cat_features):
        if ci in EVENT_CAT_INDICES:
            continue
        val = cat_tuple[ci][end - 1].item()
        feats[f'last_{feat_name}'] = str(decoder.decode_categorical_value(ci, val))

    # Case-level numerical features (event-level ones are covered by positional features below)
    for ni, feat_name in enumerate(decoder.num_features):
        if ni in EVENT_NUM_INDICES:
            continue
        feats[f'last_{feat_name}'] = decoder.decode_numerical_value(
            feat_name, num_tuple[ni][end - 1].item())

    # Positional features for every event-level categorical feature (last ACTIVITY_WINDOW events)
    for ci in EVENT_CAT_INDICES:
        feat_name = decoder.cat_features[ci]
        tensor = cat_tuple[ci][start:end]
        for w in range(1, ACTIVITY_WINDOW + 1):
            pos = prefix_len - w
            key = f'{feat_name}_pos_{-w}'
            if pos >= 0:
                feats[key] = decoder.decode_categorical_value(ci, tensor[pos].item())
            else:
                feats[key] = '<pad>'

    # Positional features for every event-level numerical feature (last ACTIVITY_WINDOW events)
    for ni in EVENT_NUM_INDICES:
        feat_name = decoder.num_features[ni]
        tensor = num_tuple[ni][start:end]
        for w in range(1, ACTIVITY_WINDOW + 1):
            pos = prefix_len - w
            key = f'{feat_name}_pos_{-w}'
            if pos >= 0:
                feats[key] = decoder.decode_numerical_value(feat_name, tensor[pos].item())
            else:
                feats[key] = float('nan')

    return feats


# --- Collect gateway data ---
gateway_data = {}  # gateway_name -> {X, y_lstm, y_actual, cat_list, num_list}

for gateway_act, succs in decision_points.items():
    # Check if gateway qualifies
    qualifying_branches = [s for s, c in succs.items() if c >= MIN_BRANCH]
    if len(qualifying_branches) < 2 or sum(succs.values()) < MIN_CASES:
        continue

    feature_rows = []
    actual_labels = []
    cat_list = []
    num_list = []

    for case_id, (ds_idx, trace_len) in cases.items():
        cat_full, num_full, _ = dataset[ds_idx]
        src_start = seq_len - trace_len
        acts = cat_full[ACT_IDX][src_start:src_start + trace_len]

        # Strip trailing EOS
        useful_len = trace_len
        for j in range(trace_len - 1, -1, -1):
            if acts[j].item() == eos_idx:
                useful_len = j
            else:
                break

        # Find all positions where activity == gateway and next activity exists
        for k in range(useful_len - 1):
            act_idx_val = acts[k].item()
            if activity_names[act_idx_val] != gateway_act:
                continue

            next_act_name = activity_names[acts[k + 1].item()]
            prefix_len = k + 1
            pad_len = seq_len - prefix_len

            # Build padded prefix tensors
            cat_prefix = []
            for c in cat_full:
                t = torch.zeros_like(c)
                t[pad_len:] = c[src_start:src_start + prefix_len]
                cat_prefix.append(t)
            num_prefix = []
            for n in num_full:
                t = torch.zeros_like(n)
                t[pad_len:] = n[src_start:src_start + prefix_len]
                num_prefix.append(t)

            feats = extract_features(tuple(cat_prefix), tuple(num_prefix), decoder)
            if feats is not None:
                feature_rows.append(feats)
                actual_labels.append(next_act_name)
                cat_list.append(cat_prefix)
                num_list.append(num_prefix)

    if len(feature_rows) < MIN_CASES:
        continue

    X = pd.DataFrame(feature_rows)
    y_actual = np.array(actual_labels)

    # Batch-predict LSTM labels
    N = len(X)
    cat_batch = [
        torch.stack([cat_list[i][ci] for i in range(N)])
        for ci in range(n_cat)
    ]
    num_stacked = torch.stack([
        torch.stack(num_list[i], dim=-1) for i in range(N)
    ])
    preds, probs = predictor.predict_batch(cat_batch, num_stacked, batch_size=128)
    y_lstm = np.array([activity_names[p] for p in preds])

    gateway_data[gateway_act] = {
        'X': X, 'y_lstm': y_lstm, 'y_actual': y_actual,
        'successors': succs, 'probs': probs,
    }

    # Report
    n_branches_actual = len(set(y_actual))
    n_branches_lstm = len(set(y_lstm))
    lstm_acc = (y_lstm == y_actual).mean()
    print(f'\n{gateway_act}: {N} prefixes, '
          f'{n_branches_actual} actual branches, {n_branches_lstm} LSTM branches, '
          f'LSTM accuracy={lstm_acc:.3f}')
    print(f'  Actual distribution: '
          + ', '.join(f'{a} ({c})' for a, c in
                      zip(*np.unique(y_actual, return_counts=True))))
    print(f'  LSTM   distribution: '
          + ', '.join(f'{a} ({c})' for a, c in
                      zip(*np.unique(y_lstm, return_counts=True))))

print(f'\n{len(gateway_data)} qualifying gateways: {list(gateway_data.keys())}')
# Out:
# A_Create Application: 6301 prefixes, 3 actual branches, 2 LSTM branches, LSTM accuracy=0.236
#   Actual distribution: A_Concept (671), A_Submitted (4074), W_Complete application (1556)
#   LSTM   distribution: W_Complete application (2148), W_Handle leads (4153)
#
# W_Handle leads: 9382 prefixes, 3 actual branches, 3 LSTM branches, LSTM accuracy=0.868
#   Actual distribution: W_Assess potential fraud (4), W_Complete application (4074), W_Handle leads (5304)
#   LSTM   distribution: A_Concept (25), W_Complete application (5269), W_Handle leads (4088)
#
# W_Complete application: 29857 prefixes, 12 actual branches, 6 LSTM branches, LSTM accuracy=0.721
#   Actual distribution: A_Accepted (4435), A_Cancelled (7), A_Concept (5630), A_Denied (2), O_Cancelled (12), O_Create Offer (321), O_Sent (mail and online) (120), O_Sent (online only) (4), W_Assess potential fraud (4), W_Call after offers (6270), W_Complete application (13044), W_Shortened completion  (8)
#   LSTM   distribution: A_Cancelled (1), A_Concept (6229), O_Create Offer (1), O_Created (12), W_Call after offers (6431), W_Complete application (17183)
#
# A_Concept: 6301 prefixes, 3 actual branches, 1 LSTM branches, LSTM accuracy=0.704
#   Actual distribution: A_Accepted (1858), W_Complete application (4439), W_Shortened completion  (4)
#   LSTM   distribution: W_Complete application (6301)
#
# A_Accepted: 6300 prefixes, 3 actual branches, 4 LSTM branches, LSTM accuracy=0.941
#   Actual distribution: O_Create Offer (5987), W_Complete application (312), W_Shortened completion  (1)
#   LSTM   distribution: O_Create Offer (6242), O_Created (43), W_Call after offers (3), W_Complete application (12)
#
# O_Created: 8648 prefixes, 10 actual branches, 6 LSTM branches, LSTM accuracy=0.806
#   Actual distribution: A_Cancelled (18), A_Denied (6), O_Cancelled (141), O_Create Offer (779), O_Sent (mail and online) (7145), O_Sent (online only) (395), W_Call after offers (13), W_Call incomplete files (4), W_Complete application (146), W_Shortened completion  (1)
#   LSTM   distribution: O_Cancelled (129), O_Created (40), O_Sent (mail and online) (8270), W_Call after offers (3), W_Call incomplete files (102), W_Validate application (104)
#
# O_Sent (mail and online): 7975 prefixes, 10 actual branches, 10 LSTM branches, LSTM accuracy=0.866
#   Actual distribution: A_Cancelled (111), A_Denied (1), O_Cancelled (71), O_Create Offer (99), O_Returned (13), O_Sent (mail and online) (628), W_Call after offers (705), W_Call incomplete files (157), W_Complete application (6178), W_Validate application (12)
#   LSTM   distribution: A_Cancelled (2), EOS (24), O_Cancelled (25), O_Create Offer (4), O_Created (3), O_Sent (mail and online) (15), W_Call after offers (1036), W_Call incomplete files (84), W_Complete application (6735), W_Validate application (47)
#
# W_Call after offers: 36452 prefixes, 11 actual branches, 9 LSTM branches, LSTM accuracy=0.905
#   Actual distribution: A_Cancelled (1729), A_Complete (6270), A_Denied (17), O_Accepted (1), O_Cancelled (51), O_Create Offer (787), O_Sent (mail and online) (6), W_Assess potential fraud (5), W_Call after offers (23236), W_Shortened completion  (7), W_Validate application (4343)
#   LSTM   distribution: A_Cancelled (88), A_Complete (6231), A_Incomplete (4), A_Validating (8), EOS (42), O_Cancelled (95), W_Call after offers (25515), W_Call incomplete files (196), W_Validate application (4273)
#
# A_Complete: 6270 prefixes, 8 actual branches, 1 LSTM branches, LSTM accuracy=0.966
#   Actual distribution: A_Cancelled (13), A_Denied (2), O_Cancelled (61), O_Create Offer (116), O_Sent (mail and online) (10), O_Sent (online only) (1), W_Call after offers (6055), W_Shortened completion  (12)
#   LSTM   distribution: W_Call after offers (6270)
#
# A_Cancelled: 2115 prefixes, 4 actual branches, 11 LSTM branches, LSTM accuracy=0.820
#   Actual distribution: O_Cancelled (2078), W_Call after offers (25), W_Call incomplete files (7), W_Complete application (5)
#   LSTM   distribution: A_Complete (18), A_Incomplete (1), A_Pending (16), A_Validating (1), O_Cancelled (1744), O_Created (123), O_Refused (2), O_Sent (mail and online) (69), W_Call after offers (25), W_Call incomplete files (23), W_Validate application (93)
#
# O_Cancelled: 3341 prefixes, 11 actual branches, 7 LSTM branches, LSTM accuracy=0.625
#   Actual distribution: A_Cancelled (35), A_Denied (8), O_Cancelled (897), O_Create Offer (141), O_Sent (mail and online) (68), O_Sent (online only) (3), W_Call after offers (1963), W_Call incomplete files (182), W_Complete application (24), W_Shortened completion  (1), W_Validate application (19)
#   LSTM   distribution: EOS (198), O_Cancelled (525), O_Created (22), O_Sent (mail and online) (171), W_Call after offers (2205), W_Call incomplete files (156), W_Validate application (64)
#
# W_Validate application: 39038 prefixes, 10 actual branches, 7 LSTM branches, LSTM accuracy=0.781
#   Actual distribution: A_Cancelled (11), A_Denied (652), A_Validating (7656), O_Accepted (2316), O_Cancelled (604), O_Create Offer (19), O_Returned (185), W_Assess potential fraud (48), W_Call incomplete files (4515), W_Validate application (23032)
#   LSTM   distribution: A_Incomplete (2), A_Validating (7671), EOS (591), O_Cancelled (6), W_Call after offers (7), W_Call incomplete files (10), W_Validate application (30751)
#
# A_Validating: 7650 prefixes, 5 actual branches, 3 LSTM branches, LSTM accuracy=0.603
#   Actual distribution: A_Cancelled (4), A_Denied (5), O_Accepted (39), O_Returned (4095), W_Validate application (3507)
#   LSTM   distribution: O_Returned (1233), W_Call incomplete files (2), W_Validate application (6415)
#
# O_Returned: 4613 prefixes, 7 actual branches, 3 LSTM branches, LSTM accuracy=0.892
#   Actual distribution: A_Cancelled (2), A_Denied (4), O_Accepted (99), O_Create Offer (1), O_Returned (2), W_Call incomplete files (302), W_Validate application (4203)
#   LSTM   distribution: O_Returned (83), W_Call incomplete files (9), W_Validate application (4521)
#
# O_Refused: 946 prefixes, 6 actual branches, 7 LSTM branches, LSTM accuracy=0.514
#   Actual distribution: O_Refused (202), W_Assess potential fraud (22), W_Call after offers (20), W_Call incomplete files (34), W_Complete application (8), W_Validate application (660)
#   LSTM   distribution: EOS (107), O_Cancelled (87), O_Created (4), O_Sent (mail and online) (15), W_Call after offers (12), W_Call incomplete files (138), W_Validate application (583)
#
# W_Call incomplete files: 32395 prefixes, 13 actual branches, 10 LSTM branches, LSTM accuracy=0.910
#   Actual distribution: A_Cancelled (176), A_Denied (34), A_Incomplete (4512), O_Accepted (909), O_Cancelled (268), O_Create Offer (377), O_Returned (153), O_Sent (mail and online) (1), O_Sent (online only) (1), W_Assess potential fraud (3), W_Call after offers (2), W_Call incomplete files (22646), W_Validate application (3313)
#   LSTM   distribution: A_Cancelled (1), A_Incomplete (4442), A_Pending (11), A_Validating (20), EOS (302), O_Cancelled (19), O_Create Offer (2), W_Call after offers (2), W_Call incomplete files (25109), W_Validate application (2487)
#
# A_Incomplete: 4511 prefixes, 4 actual branches, 2 LSTM branches, LSTM accuracy=0.967
#   Actual distribution: O_Accepted (6), O_Create Offer (1), O_Returned (139), W_Call incomplete files (4365)
#   LSTM   distribution: W_Call incomplete files (4507), W_Validate application (4)
#
# O_Sent (online only): 416 prefixes, 10 actual branches, 7 LSTM branches, LSTM accuracy=0.558
#   Actual distribution: A_Cancelled (9), O_Cancelled (5), O_Create Offer (21), O_Returned (26), O_Sent (mail and online) (1), O_Sent (online only) (14), W_Call after offers (59), W_Call incomplete files (184), W_Complete application (92), W_Validate application (5)
#   LSTM   distribution: O_Cancelled (1), O_Create Offer (13), O_Created (79), O_Sent (mail and online) (14), W_Call after offers (80), W_Call incomplete files (228), W_Complete application (1)
#
# A_Pending: 3362 prefixes, 3 actual branches, 4 LSTM branches, LSTM accuracy=0.632
#   Actual distribution: W_Call after offers (1), W_Call incomplete files (939), W_Validate application (2422)
#   LSTM   distribution: EOS (203), O_Cancelled (255), W_Call incomplete files (19), W_Validate application (2885)
#
# W_Assess potential fraud: 639 prefixes, 6 actual branches, 12 LSTM branches, LSTM accuracy=0.000
#   Actual distribution: A_Denied (22), W_Assess potential fraud (575), W_Call after offers (3), W_Complete application (4), W_Handle leads (4), W_Validate application (31)
#   LSTM   distribution: A_Complete (1), A_Concept (8), A_Incomplete (64), A_Pending (1), A_Validating (2), O_Create Offer (25), O_Created (6), O_Returned (1), W_Call after offers (2), W_Call incomplete files (522), W_Complete application (5), W_Validate application (2)
#
# W_Shortened completion : 63 prefixes, 6 actual branches, 5 LSTM branches, LSTM accuracy=0.349
#   Actual distribution: A_Accepted (7), O_Create Offer (1), O_Sent (mail and online) (1), W_Call after offers (18), W_Complete application (5), W_Shortened completion  (31)
#   LSTM   distribution: O_Cancelled (2), O_Create Offer (1), O_Created (1), W_Call after offers (33), W_Complete application (26)
#
# 21 qualifying gateways: ['A_Create Application', 'W_Handle leads', 'W_Complete application', 'A_Concept', 'A_Accepted', 'O_Created', 'O_Sent (mail and online)', 'W_Call after offers', 'A_Complete', 'A_Cancelled', 'O_Cancelled', 'W_Validate application', 'A_Validating', 'O_Returned', 'O_Refused', 'W_Call incomplete files', 'A_Incomplete', 'O_Sent (online only)', 'A_Pending', 'W_Assess potential fraud', 'W_Shortened completion ']

# %% [markdown]
# ## Train surrogate trees
#
# Target = LSTM's predicted next activity. A stratified 60/20/20 train/validation/test
# split is used. Depth is swept on the validation set and the shallowest tree within
# 2% of the best validation score is selected. Final fidelity (agreement with the
# LSTM on the held-out test set) is reported.

# %%
def select_best_depth(X_train, y_train, X_val, y_val, cat_features,
                      depths=(3, 4, 5, 6, 7, 8, None)):
    """Sweep depths on validation set; prefer shallowest within 2% of best."""
    results = []
    for depth in depths:
        clf = C45Classifier(
            max_depth=depth, min_samples_leaf=MIN_SAMPLES_LEAF,
            class_weight='balanced', random_state=42)
        clf.fit(X_train, y_train, categorical_features=cat_features)
        results.append({'depth': depth,
                        'train': clf.score(X_train, y_train),
                        'val': clf.score(X_val, y_val),
                        'clf': clf})
    best_idx = 0
    best_val = results[0]['val']
    for i in range(1, len(results)):
        if results[i]['val'] > best_val + 0.02:
            best_idx = i
            best_val = results[i]['val']
    return results[best_idx]['clf'], results


# --- Train surrogate tree (target: LSTM prediction) per gateway ---
surrogate_results = {}

for gateway_act, gd in gateway_data.items():
    X = gd['X']
    y_lstm = gd['y_lstm']
    y_actual = gd['y_actual']

    cat_cols = [c for c in X.columns if X[c].dtype == 'object']

    # Three-way split targeting the LSTM labels
    try:
        X_tv, X_test, y_lstm_tv, y_lstm_test, y_actual_tv, y_actual_test = \
            train_test_split(X, y_lstm, y_actual, test_size=0.2,
                             random_state=42, stratify=y_lstm)
    except ValueError:
        X_tv, X_test, y_lstm_tv, y_lstm_test, y_actual_tv, y_actual_test = \
            train_test_split(X, y_lstm, y_actual, test_size=0.2, random_state=42)
    try:
        X_train, X_val, y_lstm_train, y_lstm_val, y_actual_train, y_actual_val = \
            train_test_split(X_tv, y_lstm_tv, y_actual_tv, test_size=0.25,
                             random_state=42, stratify=y_lstm_tv)
    except ValueError:
        X_train, X_val, y_lstm_train, y_lstm_val, y_actual_train, y_actual_val = \
            train_test_split(X_tv, y_lstm_tv, y_actual_tv, test_size=0.25, random_state=42)

    clf, sweep = select_best_depth(X_train, y_lstm_train, X_val, y_lstm_val, cat_cols)

    fidelity = clf.score(X_test, y_lstm_test)
    lstm_accuracy = (y_lstm_test == y_actual_test).mean()

    surrogate_results[gateway_act] = {
        'clf': clf,
        'sweep': sweep,
        'feature_names': list(X.columns),
        'cat_cols': cat_cols,
        'X_test': X_test,
        'y_lstm_test': y_lstm_test,
        'y_actual_test': y_actual_test,
        'fidelity': fidelity,
        'lstm_accuracy': lstm_accuracy,
        'n_cases': len(X),
    }

    print(f'{gateway_act}: n={len(X)}, fidelity={fidelity:.3f}, '
          f'depth={clf.get_depth()}, leaves={clf.get_n_leaves()}, '
          f'LSTM accuracy={lstm_accuracy:.3f}')
# Out:
# A_Create Application: n=6301, fidelity=0.807, depth=3, leaves=8, LSTM accuracy=0.244
# W_Handle leads: n=9382, fidelity=0.562, depth=2, leaves=3, LSTM accuracy=0.873
# W_Complete application: n=29857, fidelity=0.703, depth=4, leaves=5, LSTM accuracy=0.721
# A_Concept: n=6301, fidelity=1.000, depth=0, leaves=1, LSTM accuracy=0.734
# A_Accepted: n=6300, fidelity=0.990, depth=3, leaves=4, LSTM accuracy=0.939
# O_Created: n=8648, fidelity=0.960, depth=3, leaves=5, LSTM accuracy=0.795
# O_Sent (mail and online): n=7975, fidelity=0.893, depth=6, leaves=10, LSTM accuracy=0.864
# W_Call after offers: n=36452, fidelity=0.700, depth=3, leaves=5, LSTM accuracy=0.905
# A_Complete: n=6270, fidelity=1.000, depth=0, leaves=1, LSTM accuracy=0.967
# A_Cancelled: n=2115, fidelity=0.846, depth=3, leaves=4, LSTM accuracy=0.830
# O_Cancelled: n=3341, fidelity=0.776, depth=3, leaves=5, LSTM accuracy=0.620
# W_Validate application: n=39038, fidelity=0.831, depth=4, leaves=6, LSTM accuracy=0.778
# A_Validating: n=7650, fidelity=0.839, depth=3, leaves=5, LSTM accuracy=0.592
# O_Returned: n=4613, fidelity=0.979, depth=3, leaves=4, LSTM accuracy=0.892
# O_Refused: n=946, fidelity=0.700, depth=3, leaves=5, LSTM accuracy=0.542
# W_Call incomplete files: n=32395, fidelity=0.852, depth=5, leaves=11, LSTM accuracy=0.910
# A_Incomplete: n=4511, fidelity=0.999, depth=1, leaves=2, LSTM accuracy=0.970
# O_Sent (online only): n=416, fidelity=0.560, depth=1, leaves=2, LSTM accuracy=0.560
# A_Pending: n=3362, fidelity=0.862, depth=3, leaves=5, LSTM accuracy=0.642
# W_Assess potential fraud: n=639, fidelity=0.828, depth=3, leaves=4, LSTM accuracy=0.000
# W_Shortened completion : n=63, fidelity=0.462, depth=0, leaves=1, LSTM accuracy=0.231

# %% [markdown]
# ## Summary table

# %%
summary_rows = []
for gateway_act, gr in surrogate_results.items():
    fn = gr['feature_names']
    imp = gr['clf'].feature_importances_
    top = fn[int(np.argmax(imp))]
    summary_rows.append({
        'Gateway': gateway_act,
        '#Cases': gr['n_cases'],
        'LSTM Accuracy': f'{gr["lstm_accuracy"]:.3f}',
        'Surrogate Fidelity': f'{gr["fidelity"]:.3f}',
        'Depth': gr['clf'].get_depth(),
        'Leaves': gr['clf'].get_n_leaves(),
        'Top Feature': top,
    })

df_summary = pd.DataFrame(summary_rows)
display(df_summary)
# Out:
#                      Gateway  #Cases LSTM Accuracy Surrogate Fidelity  Depth  \
# 0       A_Create Application    6301         0.244              0.807      3
# 1             W_Handle leads    9382         0.873              0.562      2
# 2     W_Complete application   29857         0.721              0.703      4
# 3                  A_Concept    6301         0.734              1.000      0
# 4                 A_Accepted    6300         0.939              0.990      3
# 5                  O_Created    8648         0.795              0.960      3
# 6   O_Sent (mail and online)    7975         0.864              0.893      6
# 7        W_Call after offers   36452         0.905              0.700      3
# 8                 A_Complete    6270         0.967              1.000      0
# 9                A_Cancelled    2115         0.830              0.846      3
# 10               O_Cancelled    3341         0.620              0.776      3
# 11    W_Validate application   39038         0.778              0.831      4
# 12              A_Validating    7650         0.592              0.839      3
# 13                O_Returned    4613         0.892              0.979      3
# 14                 O_Refused     946         0.542              0.700      3
# 15   W_Call incomplete files   32395         0.910              0.852      5
# 16              A_Incomplete    4511         0.970              0.999      1
# 17      O_Sent (online only)     416         0.560              0.560      1
# 18                 A_Pending    3362         0.642              0.862      3
# 19  W_Assess potential fraud     639         0.000              0.828      3
# 20   W_Shortened completion       63         0.231              0.462      0
#
#     Leaves                 Top Feature
# 0        8   last_case:ApplicationType
# 1        3    case_elapsed_time_pos_-4
# 2        5    case_elapsed_time_pos_-8
# 3        1               prefix_length
# 4        4       seconds_in_day_pos_-6
# 5        5   case_elapsed_time_pos_-21
# 6       10    case_elapsed_time_pos_-7
# 7        5       NumberOfTerms_pos_-22
# 8        1               prefix_length
# 9        4      seconds_in_day_pos_-27
# 10       5   case_elapsed_time_pos_-37
# 11       6         CreditScore_pos_-34
# 12       5   case_elapsed_time_pos_-34
# 13       4   case_elapsed_time_pos_-36
# 14       5      seconds_in_day_pos_-32
# 15      11   case_elapsed_time_pos_-39
# 16       2    case_elapsed_time_pos_-1
# 17       2   case_elapsed_time_pos_-36
# 18       5       NumberOfTerms_pos_-40
# 19       4  event_elapsed_time_pos_-34
# 20       1               prefix_length

# %% [markdown]
# ## Feature importance (surrogate)

# %%
for gateway_act, gr in surrogate_results.items():
    fn = gr['feature_names']
    imp = gr['clf'].feature_importances_

    mask = imp > 0
    fn_nz = [f for f, m in zip(fn, mask) if m]
    imp_nz = imp[mask]
    order = np.argsort(imp_nz)[::-1]
    fn_nz = [fn_nz[i] for i in order]
    imp_nz = imp_nz[order]

    fig, ax = plt.subplots(figsize=(10, max(3, len(fn_nz) * 0.4)))
    y_pos = np.arange(len(fn_nz))
    ax.barh(y_pos, imp_nz, color='steelblue')
    ax.set_yticks(y_pos)
    ax.set_yticklabels(fn_nz, fontsize=9)
    ax.invert_yaxis()
    ax.set_xlabel('Gini Importance')
    ax.set_title(f'{gateway_act} — Surrogate Feature Importance '
                 f'(fidelity={gr["fidelity"]:.3f})')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Decision rules (surrogate)

# %%
for gateway_act, gr in surrogate_results.items():
    clf = gr['clf']
    print(f'{"=" * 80}')
    print(f'GATEWAY: {gateway_act}')
    print(f'  fidelity={gr["fidelity"]:.3f}, depth={clf.get_depth()}, leaves={clf.get_n_leaves()}')
    print(f'  {"-" * 70}')

    rules = clf.extract_rules()
    for i, rule in enumerate(rules):
        conds = '\n      AND '.join(rule['conditions']) or '(root)'
        print(f'  Rule {i + 1} (n={rule["n_samples"]}, {rule["confidence"]:.0%} confidence):')
        print(f'    IF  {conds}')
        print(f'    THEN -> {rule["prediction"]}')
        print()
# Out:
# ================================================================================
# GATEWAY: A_Create Application
#   fidelity=0.807, depth=3, leaves=8
#   ----------------------------------------------------------------------
#   Rule 1 (n=2790, 77% confidence):
#     IF  last_case:ApplicationType = New credit
#       AND last_case:RequestedAmount > 2500
#       AND seconds_in_day_pos_-1 <= 7.196e+04
#     THEN -> W_Handle leads
#
#   Rule 2 (n=322, 100% confidence):
#     IF  last_case:ApplicationType = New credit
#       AND last_case:RequestedAmount > 2500
#       AND seconds_in_day_pos_-1 > 7.196e+04
#     THEN -> W_Handle leads
#
#   Rule 3 (n=248, 100% confidence):
#     IF  last_case:ApplicationType = Limit raise
#       AND last_case:RequestedAmount > 2500
#       AND seconds_in_day_pos_-1 <= 5.743e+04
#     THEN -> W_Complete application
#
#   Rule 4 (n=228, 87% confidence):
#     IF  last_case:ApplicationType = New credit
#       AND last_case:RequestedAmount <= 2500
#       AND seconds_in_day_pos_-1 <= 6.052e+04
#     THEN -> W_Complete application
#
#   Rule 5 (n=73, 97% confidence):
#     IF  last_case:ApplicationType = Limit raise
#       AND last_case:RequestedAmount <= 2500
#       AND seconds_in_day_pos_-1 > 3.352e+04
#     THEN -> W_Complete application
#
#   Rule 6 (n=65, 98% confidence):
#     IF  last_case:ApplicationType = Limit raise
#       AND last_case:RequestedAmount > 2500
#       AND seconds_in_day_pos_-1 > 5.743e+04
#     THEN -> W_Complete application
#
#   Rule 7 (n=32, 94% confidence):
#     IF  last_case:ApplicationType = Limit raise
#       AND last_case:RequestedAmount <= 2500
#       AND seconds_in_day_pos_-1 <= 3.352e+04
#     THEN -> W_Complete application
#
#   Rule 8 (n=22, 100% confidence):
#     IF  last_case:ApplicationType = New credit
#       AND last_case:RequestedAmount <= 2500
#       AND seconds_in_day_pos_-1 > 6.052e+04
#     THEN -> W_Complete application
#
# ================================================================================
# GATEWAY: W_Handle leads
#   fidelity=0.562, depth=2, leaves=3
#   ----------------------------------------------------------------------
#   Rule 1 (n=107, 100% confidence):
#     IF  case_elapsed_time_pos_-4 <= 4.355e+04
#       AND case_elapsed_time_pos_-8 <= 6377
#     THEN -> W_Complete application
#
#   Rule 2 (n=20, 100% confidence):
#     IF  case_elapsed_time_pos_-4 <= 4.355e+04
#       AND case_elapsed_time_pos_-8 > 6377
#     THEN -> W_Complete application
#
#   Rule 3 (n=20, 100% confidence):
#     IF  case_elapsed_time_pos_-4 > 4.355e+04
#     THEN -> W_Complete application
#
# ================================================================================
# GATEWAY: W_Complete application
#   fidelity=0.703, depth=4, leaves=5
#   ----------------------------------------------------------------------
#   Rule 1 (n=2561, 98% confidence):
#     IF  case_elapsed_time_pos_-8 <= 1.294e+06
#       AND event_elapsed_time_pos_-1 <= 6.08e+05
#       AND event_elapsed_time_pos_-12 <= 2.21e+05
#       AND event_elapsed_time_pos_-1 <= 0.7159
#     THEN -> W_Call after offers
#
#   Rule 2 (n=1886, 97% confidence):
#     IF  case_elapsed_time_pos_-8 <= 1.294e+06
#       AND event_elapsed_time_pos_-1 <= 6.08e+05
#       AND event_elapsed_time_pos_-12 <= 2.21e+05
#       AND event_elapsed_time_pos_-1 > 0.7159
#     THEN -> W_Complete application
#
#   Rule 3 (n=40, 70% confidence):
#     IF  case_elapsed_time_pos_-8 <= 1.294e+06
#       AND event_elapsed_time_pos_-1 > 6.08e+05
#     THEN -> W_Complete application
#
#   Rule 4 (n=20, 75% confidence):
#     IF  case_elapsed_time_pos_-8 <= 1.294e+06
#       AND event_elapsed_time_pos_-1 <= 6.08e+05
#       AND event_elapsed_time_pos_-12 > 2.21e+05
#     THEN -> W_Call after offers
#
#   Rule 5 (n=20, 95% confidence):
#     IF  case_elapsed_time_pos_-8 > 1.294e+06
#     THEN -> W_Call after offers
#
# ================================================================================
# GATEWAY: A_Concept
#   fidelity=1.000, depth=0, leaves=1
#   ----------------------------------------------------------------------
#   Rule 1 (n=3780, 100% confidence):
#     IF  (root)
#     THEN -> W_Complete application
#
# ================================================================================
# GATEWAY: A_Accepted
#   fidelity=0.990, depth=3, leaves=4
#   ----------------------------------------------------------------------
#   Rule 1 (n=884, 98% confidence):
#     IF  case_elapsed_time_pos_-1 <= 1.734e+06
#       AND seconds_in_day_pos_-6 > 9495
#       AND case_elapsed_time_pos_-11 <= 1.531e+05
#     THEN -> O_Create Offer
#
#   Rule 2 (n=20, 100% confidence):
#     IF  case_elapsed_time_pos_-1 <= 1.734e+06
#       AND seconds_in_day_pos_-6 <= 9495
#     THEN -> O_Create Offer
#
#   Rule 3 (n=20, 100% confidence):
#     IF  case_elapsed_time_pos_-1 <= 1.734e+06
#       AND seconds_in_day_pos_-6 > 9495
#       AND case_elapsed_time_pos_-11 > 1.531e+05
#     THEN -> O_Create Offer
#
#   Rule 4 (n=20, 75% confidence):
#     IF  case_elapsed_time_pos_-1 > 1.734e+06
#     THEN -> O_Create Offer
#
# ================================================================================
# GATEWAY: O_Created
#   fidelity=0.960, depth=3, leaves=5
#   ----------------------------------------------------------------------
#   Rule 1 (n=358, 57% confidence):
#     IF  case_elapsed_time_pos_-21 <= 2.049e+06
#       AND case_elapsed_time_pos_-1 <= 2.195e+06
#       AND prefix_length > 24.5
#     THEN -> O_Sent (mail and online)
#
#   Rule 2 (n=247, 100% confidence):
#     IF  case_elapsed_time_pos_-21 <= 2.049e+06
#       AND case_elapsed_time_pos_-1 <= 2.195e+06
#       AND prefix_length <= 24.5
#     THEN -> O_Sent (mail and online)
#
#   Rule 3 (n=66, 62% confidence):
#     IF  case_elapsed_time_pos_-21 <= 2.049e+06
#       AND case_elapsed_time_pos_-1 > 2.195e+06
#       AND event_elapsed_time_pos_-10 <= 258.4
#     THEN -> O_Sent (mail and online)
#
#   Rule 4 (n=20, 70% confidence):
#     IF  case_elapsed_time_pos_-21 <= 2.049e+06
#       AND case_elapsed_time_pos_-1 > 2.195e+06
#       AND event_elapsed_time_pos_-10 > 258.4
#     THEN -> O_Cancelled
#
#   Rule 5 (n=20, 95% confidence):
#     IF  case_elapsed_time_pos_-21 > 2.049e+06
#     THEN -> O_Cancelled
#
# ================================================================================
# GATEWAY: O_Sent (mail and online)
#   fidelity=0.893, depth=6, leaves=10
#   ----------------------------------------------------------------------
#   Rule 1 (n=788, 57% confidence):
#     IF  case_elapsed_time_pos_-1 <= 3.055e+06
#       AND prefix_length <= 53.5
#       AND case_elapsed_time_pos_-6 <= 1.987e+06
#       AND case_elapsed_time_pos_-7 <= 5.039e+05
#       AND case_elapsed_time_pos_-10 <= 3.912e+05
#       AND seconds_in_day_pos_-18 > 2.268e+04
#     THEN -> W_Call after offers
#
#   Rule 2 (n=55, 40% confidence):
#     IF  case_elapsed_time_pos_-1 <= 3.055e+06
#       AND prefix_length <= 53.5
#       AND case_elapsed_time_pos_-6 <= 1.987e+06
#       AND case_elapsed_time_pos_-7 > 5.039e+05
#       AND prefix_length > 29.5
#       AND case_elapsed_time_pos_-5 <= 1.177e+06
#     THEN -> W_Call after offers
#
#   Rule 3 (n=32, 41% confidence):
#     IF  case_elapsed_time_pos_-1 <= 3.055e+06
#       AND prefix_length <= 53.5
#       AND case_elapsed_time_pos_-6 <= 1.987e+06
#       AND case_elapsed_time_pos_-7 > 5.039e+05
#       AND prefix_length > 29.5
#       AND case_elapsed_time_pos_-5 > 1.177e+06
#     THEN -> W_Call incomplete files
#
#   Rule 4 (n=31, 42% confidence):
#     IF  case_elapsed_time_pos_-1 <= 3.055e+06
#       AND prefix_length <= 53.5
#       AND case_elapsed_time_pos_-6 > 1.987e+06
#     THEN -> W_Call after offers
#
#   Rule 5 (n=27, 52% confidence):
#     IF  case_elapsed_time_pos_-1 > 3.055e+06
#     THEN -> O_Cancelled
#
#   Rule 6 (n=22, 59% confidence):
#     IF  case_elapsed_time_pos_-1 <= 3.055e+06
#       AND prefix_length <= 53.5
#       AND case_elapsed_time_pos_-6 <= 1.987e+06
#       AND case_elapsed_time_pos_-7 > 5.039e+05
#       AND prefix_length <= 29.5
#       AND case_elapsed_time_pos_-23 <= 46.75
#     THEN -> W_Complete application
#
#   Rule 7 (n=21, 52% confidence):
#     IF  case_elapsed_time_pos_-1 <= 3.055e+06
#       AND prefix_length > 53.5
#     THEN -> W_Call incomplete files
#
#   Rule 8 (n=20, 75% confidence):
#     IF  case_elapsed_time_pos_-1 <= 3.055e+06
#       AND prefix_length <= 53.5
#       AND case_elapsed_time_pos_-6 <= 1.987e+06
#       AND case_elapsed_time_pos_-7 <= 5.039e+05
#       AND case_elapsed_time_pos_-10 <= 3.912e+05
#       AND seconds_in_day_pos_-18 <= 2.268e+04
#     THEN -> W_Complete application
#
#   Rule 9 (n=20, 45% confidence):
#     IF  case_elapsed_time_pos_-1 <= 3.055e+06
#       AND prefix_length <= 53.5
#       AND case_elapsed_time_pos_-6 <= 1.987e+06
#       AND case_elapsed_time_pos_-7 <= 5.039e+05
#       AND case_elapsed_time_pos_-10 > 3.912e+05
#     THEN -> W_Call after offers
#
#   Rule 10 (n=20, 85% confidence):
#     IF  case_elapsed_time_pos_-1 <= 3.055e+06
#       AND prefix_length <= 53.5
#       AND case_elapsed_time_pos_-6 <= 1.987e+06
#       AND case_elapsed_time_pos_-7 > 5.039e+05
#       AND prefix_length <= 29.5
#       AND case_elapsed_time_pos_-23 > 46.75
#     THEN -> W_Call after offers
#
# ================================================================================
# GATEWAY: W_Call after offers
#   fidelity=0.700, depth=3, leaves=5
#   ----------------------------------------------------------------------
#   Rule 1 (n=1340, 60% confidence):
#     IF  prefix_length <= 46.5
#       AND NumberOfTerms_pos_-22 > 64.5
#       AND case_elapsed_time_pos_-26 <= 3.49e+05
#     THEN -> W_Call after offers
#
#   Rule 2 (n=36, 53% confidence):
#     IF  prefix_length > 46.5
#       AND seconds_in_day_pos_-34 <= 4.385e+04
#     THEN -> W_Call incomplete files
#
#   Rule 3 (n=22, 36% confidence):
#     IF  prefix_length > 46.5
#       AND seconds_in_day_pos_-34 > 4.385e+04
#     THEN -> W_Call incomplete files
#
#   Rule 4 (n=20, 40% confidence):
#     IF  prefix_length <= 46.5
#       AND NumberOfTerms_pos_-22 <= 64.5
#     THEN -> W_Validate application
#
#   Rule 5 (n=20, 35% confidence):
#     IF  prefix_length <= 46.5
#       AND NumberOfTerms_pos_-22 > 64.5
#       AND case_elapsed_time_pos_-26 > 3.49e+05
#     THEN -> W_Validate application
#
# ================================================================================
# GATEWAY: A_Complete
#   fidelity=1.000, depth=0, leaves=1
#   ----------------------------------------------------------------------
#   Rule 1 (n=3762, 100% confidence):
#     IF  (root)
#     THEN -> W_Call after offers
#
# ================================================================================
# GATEWAY: A_Cancelled
#   fidelity=0.846, depth=3, leaves=4
#   ----------------------------------------------------------------------
#   Rule 1 (n=124, 100% confidence):
#     IF  seconds_in_day_pos_-27 > 2.679e+04
#       AND case_elapsed_time_pos_-1 > 2.886e+06
#     THEN -> O_Cancelled
#
#   Rule 2 (n=82, 54% confidence):
#     IF  seconds_in_day_pos_-27 > 2.679e+04
#       AND case_elapsed_time_pos_-1 <= 2.886e+06
#       AND event_elapsed_time_pos_-1 <= 1.05e+06
#     THEN -> W_Validate application
#
#   Rule 3 (n=34, 100% confidence):
#     IF  seconds_in_day_pos_-27 > 2.679e+04
#       AND case_elapsed_time_pos_-1 <= 2.886e+06
#       AND event_elapsed_time_pos_-1 > 1.05e+06
#     THEN -> O_Cancelled
#
#   Rule 4 (n=20, 85% confidence):
#     IF  seconds_in_day_pos_-27 <= 2.679e+04
#     THEN -> O_Cancelled
#
# ================================================================================
# GATEWAY: O_Cancelled
#   fidelity=0.776, depth=3, leaves=5
#   ----------------------------------------------------------------------
#   Rule 1 (n=135, 73% confidence):
#     IF  case_elapsed_time_pos_-37 <= 2.356e+06
#       AND case_elapsed_time_pos_-1 <= 3.775e+06
#       AND event_elapsed_time_pos_-3 <= 1.784
#     THEN -> EOS
#
#   Rule 2 (n=113, 62% confidence):
#     IF  case_elapsed_time_pos_-37 <= 2.356e+06
#       AND case_elapsed_time_pos_-1 <= 3.775e+06
#       AND event_elapsed_time_pos_-3 > 1.784
#     THEN -> W_Call incomplete files
#
#   Rule 3 (n=44, 100% confidence):
#     IF  case_elapsed_time_pos_-37 <= 2.356e+06
#       AND case_elapsed_time_pos_-1 > 3.775e+06
#       AND case_elapsed_time_pos_-39 > 4856
#     THEN -> O_Cancelled
#
#   Rule 4 (n=20, 100% confidence):
#     IF  case_elapsed_time_pos_-37 <= 2.356e+06
#       AND case_elapsed_time_pos_-1 > 3.775e+06
#       AND case_elapsed_time_pos_-39 <= 4856
#     THEN -> O_Cancelled
#
#   Rule 5 (n=20, 90% confidence):
#     IF  case_elapsed_time_pos_-37 > 2.356e+06
#     THEN -> O_Cancelled
#
# ================================================================================
# GATEWAY: W_Validate application
#   fidelity=0.831, depth=4, leaves=6
#   ----------------------------------------------------------------------
#   Rule 1 (n=5324, 99% confidence):
#     IF  CreditScore_pos_-34 <= 1019
#       AND case_elapsed_time_pos_-40 <= 4.361e+06
#       AND case_elapsed_time_pos_-7 <= 3.873e+06
#       AND event_elapsed_time_pos_-2 > 0.05612
#     THEN -> W_Validate application
#
#   Rule 2 (n=1422, 74% confidence):
#     IF  CreditScore_pos_-34 <= 1019
#       AND case_elapsed_time_pos_-40 <= 4.361e+06
#       AND case_elapsed_time_pos_-7 <= 3.873e+06
#       AND event_elapsed_time_pos_-2 <= 0.05612
#     THEN -> A_Validating
#
#   Rule 3 (n=204, 100% confidence):
#     IF  CreditScore_pos_-34 <= 1019
#       AND case_elapsed_time_pos_-40 <= 4.361e+06
#       AND case_elapsed_time_pos_-7 > 3.873e+06
#       AND event_elapsed_time_pos_-1 > 0.02509
#     THEN -> W_Validate application
#
#   Rule 4 (n=97, 53% confidence):
#     IF  CreditScore_pos_-34 <= 1019
#       AND case_elapsed_time_pos_-40 <= 4.361e+06
#       AND case_elapsed_time_pos_-7 > 3.873e+06
#       AND event_elapsed_time_pos_-1 <= 0.02509
#     THEN -> W_Validate application
#
#   Rule 5 (n=20, 95% confidence):
#     IF  CreditScore_pos_-34 <= 1019
#       AND case_elapsed_time_pos_-40 > 4.361e+06
#     THEN -> W_Validate application
#
#   Rule 6 (n=20, 80% confidence):
#     IF  CreditScore_pos_-34 > 1019
#     THEN -> W_Validate application
#
# ================================================================================
# GATEWAY: A_Validating
#   fidelity=0.839, depth=3, leaves=5
#   ----------------------------------------------------------------------
#   Rule 1 (n=1262, 100% confidence):
#     IF  event_elapsed_time_pos_-18 <= 7.005e+05
#       AND case_elapsed_time_pos_-34 <= 2.816e+06
#       AND case_elapsed_time_pos_-39 <= 1.982e+06
#     THEN -> W_Validate application
#
#   Rule 2 (n=23, 100% confidence):
#     IF  event_elapsed_time_pos_-18 > 7.005e+05
#       AND case_elapsed_time_pos_-19 <= 5.619e+05
#     THEN -> W_Validate application
#
#   Rule 3 (n=20, 100% confidence):
#     IF  event_elapsed_time_pos_-18 <= 7.005e+05
#       AND case_elapsed_time_pos_-34 <= 2.816e+06
#       AND case_elapsed_time_pos_-39 > 1.982e+06
#     THEN -> W_Validate application
#
#   Rule 4 (n=20, 100% confidence):
#     IF  event_elapsed_time_pos_-18 <= 7.005e+05
#       AND case_elapsed_time_pos_-34 > 2.816e+06
#     THEN -> W_Validate application
#
#   Rule 5 (n=20, 90% confidence):
#     IF  event_elapsed_time_pos_-18 > 7.005e+05
#       AND case_elapsed_time_pos_-19 > 5.619e+05
#     THEN -> W_Validate application
#
# ================================================================================
# GATEWAY: O_Returned
#   fidelity=0.979, depth=3, leaves=4
#   ----------------------------------------------------------------------
#   Rule 1 (n=183, 100% confidence):
#     IF  case_elapsed_time_pos_-36 <= 1.601e+06
#       AND seconds_in_day_pos_-22 > 3.185e+04
#     THEN -> W_Validate application
#
#   Rule 2 (n=31, 100% confidence):
#     IF  case_elapsed_time_pos_-36 <= 1.601e+06
#       AND seconds_in_day_pos_-22 <= 3.185e+04
#       AND event_elapsed_time_pos_-35 <= 23.33
#     THEN -> W_Validate application
#
#   Rule 3 (n=20, 75% confidence):
#     IF  case_elapsed_time_pos_-36 <= 1.601e+06
#       AND seconds_in_day_pos_-22 <= 3.185e+04
#       AND event_elapsed_time_pos_-35 > 23.33
#     THEN -> W_Validate application
#
#   Rule 4 (n=20, 100% confidence):
#     IF  case_elapsed_time_pos_-36 > 1.601e+06
#     THEN -> W_Validate application
#
# ================================================================================
# GATEWAY: O_Refused
#   fidelity=0.700, depth=3, leaves=5
#   ----------------------------------------------------------------------
#   Rule 1 (n=227, 81% confidence):
#     IF  seconds_in_day_pos_-32 > 2.353e+04
#       AND case_elapsed_time_pos_-1 <= 2.618e+06
#       AND concept:name_pos_-2 = A_Denied
#     THEN -> W_Validate application
#
#   Rule 2 (n=66, 64% confidence):
#     IF  seconds_in_day_pos_-32 > 2.353e+04
#       AND case_elapsed_time_pos_-1 <= 2.618e+06
#       AND concept:name_pos_-2 = O_Refused
#     THEN -> EOS
#
#   Rule 3 (n=45, 53% confidence):
#     IF  seconds_in_day_pos_-32 > 2.353e+04
#       AND case_elapsed_time_pos_-1 > 2.618e+06
#       AND event_elapsed_time_pos_-40 > 1.274
#     THEN -> O_Cancelled
#
#   Rule 4 (n=25, 72% confidence):
#     IF  seconds_in_day_pos_-32 > 2.353e+04
#       AND case_elapsed_time_pos_-1 > 2.618e+06
#       AND event_elapsed_time_pos_-40 <= 1.274
#     THEN -> O_Cancelled
#
#   Rule 5 (n=20, 65% confidence):
#     IF  seconds_in_day_pos_-32 <= 2.353e+04
#     THEN -> W_Validate application
#
# ================================================================================
# GATEWAY: W_Call incomplete files
#   fidelity=0.852, depth=5, leaves=11
#   ----------------------------------------------------------------------
#   Rule 1 (n=3344, 100% confidence):
#     IF  case_elapsed_time_pos_-39 <= 5.064e+06
#       AND NumberOfTerms_pos_-5 > 45.5
#       AND event_elapsed_time_pos_-1 <= 1.602e+06
#       AND case_elapsed_time_pos_-3 <= 4.748e+06
#       AND lifecycle:transition_pos_-1 = suspend
#     THEN -> W_Call incomplete files
#
#   Rule 2 (n=2229, 100% confidence):
#     IF  case_elapsed_time_pos_-39 <= 5.064e+06
#       AND NumberOfTerms_pos_-5 > 45.5
#       AND event_elapsed_time_pos_-1 <= 1.602e+06
#       AND case_elapsed_time_pos_-3 <= 4.748e+06
#       AND lifecycle:transition_pos_-1 = resume
#     THEN -> W_Call incomplete files
#
#   Rule 3 (n=1006, 75% confidence):
#     IF  case_elapsed_time_pos_-39 <= 5.064e+06
#       AND NumberOfTerms_pos_-5 > 45.5
#       AND event_elapsed_time_pos_-1 <= 1.602e+06
#       AND case_elapsed_time_pos_-3 <= 4.748e+06
#       AND lifecycle:transition_pos_-1 = ate_abort
#     THEN -> W_Validate application
#
#   Rule 4 (n=904, 98% confidence):
#     IF  case_elapsed_time_pos_-39 <= 5.064e+06
#       AND NumberOfTerms_pos_-5 > 45.5
#       AND event_elapsed_time_pos_-1 <= 1.602e+06
#       AND case_elapsed_time_pos_-3 <= 4.748e+06
#       AND lifecycle:transition_pos_-1 = start
#     THEN -> A_Incomplete
#
#   Rule 5 (n=840, 100% confidence):
#     IF  case_elapsed_time_pos_-39 <= 5.064e+06
#       AND NumberOfTerms_pos_-5 > 45.5
#       AND event_elapsed_time_pos_-1 <= 1.602e+06
#       AND case_elapsed_time_pos_-3 <= 4.748e+06
#       AND lifecycle:transition_pos_-1 = schedule
#     THEN -> W_Call incomplete files
#
#   Rule 6 (n=188, 84% confidence):
#     IF  case_elapsed_time_pos_-39 <= 5.064e+06
#       AND NumberOfTerms_pos_-5 > 45.5
#       AND event_elapsed_time_pos_-1 <= 1.602e+06
#       AND case_elapsed_time_pos_-3 > 4.748e+06
#       AND event_elapsed_time_pos_-2 <= 2253
#     THEN -> W_Call incomplete files
#
#   Rule 7 (n=143, 99% confidence):
#     IF  case_elapsed_time_pos_-39 <= 5.064e+06
#       AND NumberOfTerms_pos_-5 > 45.5
#       AND event_elapsed_time_pos_-1 <= 1.602e+06
#       AND case_elapsed_time_pos_-3 <= 4.748e+06
#       AND lifecycle:transition_pos_-1 = complete
#     THEN -> W_Call incomplete files
#
#   Rule 8 (n=87, 100% confidence):
#     IF  case_elapsed_time_pos_-39 <= 5.064e+06
#       AND NumberOfTerms_pos_-5 > 45.5
#       AND event_elapsed_time_pos_-1 <= 1.602e+06
#       AND case_elapsed_time_pos_-3 > 4.748e+06
#       AND event_elapsed_time_pos_-2 > 2253
#     THEN -> W_Call incomplete files
#
#   Rule 9 (n=20, 45% confidence):
#     IF  case_elapsed_time_pos_-39 <= 5.064e+06
#       AND NumberOfTerms_pos_-5 <= 45.5
#     THEN -> W_Validate application
#
#   Rule 10 (n=20, 45% confidence):
#     IF  case_elapsed_time_pos_-39 <= 5.064e+06
#       AND NumberOfTerms_pos_-5 > 45.5
#       AND event_elapsed_time_pos_-1 > 1.602e+06
#     THEN -> W_Call incomplete files
#
#   Rule 11 (n=20, 90% confidence):
#     IF  case_elapsed_time_pos_-39 > 5.064e+06
#     THEN -> W_Call incomplete files
#
# ================================================================================
# GATEWAY: A_Incomplete
#   fidelity=0.999, depth=1, leaves=2
#   ----------------------------------------------------------------------
#   Rule 1 (n=2686, 100% confidence):
#     IF  case_elapsed_time_pos_-1 > 5.903e+04
#     THEN -> W_Call incomplete files
#
#   Rule 2 (n=20, 90% confidence):
#     IF  case_elapsed_time_pos_-1 <= 5.903e+04
#     THEN -> W_Call incomplete files
#
# ================================================================================
# GATEWAY: O_Sent (online only)
#   fidelity=0.560, depth=1, leaves=2
#   ----------------------------------------------------------------------
#   Rule 1 (n=85, 100% confidence):
#     IF  case_elapsed_time_pos_-36 <= 6.094e+05
#     THEN -> W_Call incomplete files
#
#   Rule 2 (n=20, 95% confidence):
#     IF  case_elapsed_time_pos_-36 > 6.094e+05
#     THEN -> W_Call incomplete files
#
# ================================================================================
# GATEWAY: A_Pending
#   fidelity=0.862, depth=3, leaves=5
#   ----------------------------------------------------------------------
#   Rule 1 (n=744, 93% confidence):
#     IF  NumberOfTerms_pos_-40 > 71
#       AND case_elapsed_time_pos_-1 <= 2.424e+06
#       AND case_elapsed_time_pos_-6 <= 2.248e+06
#     THEN -> W_Validate application
#
#   Rule 2 (n=190, 55% confidence):
#     IF  NumberOfTerms_pos_-40 > 71
#       AND case_elapsed_time_pos_-1 > 2.424e+06
#       AND event_elapsed_time_pos_-4 > 0.06102
#     THEN -> O_Cancelled
#
#   Rule 3 (n=33, 45% confidence):
#     IF  NumberOfTerms_pos_-40 > 71
#       AND case_elapsed_time_pos_-1 > 2.424e+06
#       AND event_elapsed_time_pos_-4 <= 0.06102
#     THEN -> O_Cancelled
#
#   Rule 4 (n=26, 85% confidence):
#     IF  NumberOfTerms_pos_-40 > 71
#       AND case_elapsed_time_pos_-1 <= 2.424e+06
#       AND case_elapsed_time_pos_-6 > 2.248e+06
#     THEN -> W_Validate application
#
#   Rule 5 (n=20, 95% confidence):
#     IF  NumberOfTerms_pos_-40 <= 71
#     THEN -> W_Validate application
#
# ================================================================================
# GATEWAY: W_Assess potential fraud
#   fidelity=0.828, depth=3, leaves=4
#   ----------------------------------------------------------------------
#   Rule 1 (n=198, 97% confidence):
#     IF  event_elapsed_time_pos_-34 <= 7.085e+04
#       AND event_elapsed_time_pos_-3 <= 1.052e+05
#       AND event_elapsed_time_pos_-1 > 0.008758
#     THEN -> W_Call incomplete files
#
#   Rule 2 (n=23, 65% confidence):
#     IF  event_elapsed_time_pos_-34 <= 7.085e+04
#       AND event_elapsed_time_pos_-3 <= 1.052e+05
#       AND event_elapsed_time_pos_-1 <= 0.008758
#     THEN -> W_Call incomplete files
#
#   Rule 3 (n=20, 75% confidence):
#     IF  event_elapsed_time_pos_-34 <= 7.085e+04
#       AND event_elapsed_time_pos_-3 > 1.052e+05
#     THEN -> W_Call incomplete files
#
#   Rule 4 (n=20, 75% confidence):
#     IF  event_elapsed_time_pos_-34 > 7.085e+04
#     THEN -> W_Call incomplete files
#
# ================================================================================
# GATEWAY: W_Shortened completion
#   fidelity=0.462, depth=0, leaves=1
#   ----------------------------------------------------------------------
#   Rule 1 (n=37, 54% confidence):
#     IF  (root)
#     THEN -> W_Call after offers

# %% [markdown]
# ## Surrogate trees rendered as images
#
# One matplotlib figure per gateway. Orange nodes are internal splits; blue nodes
# are leaves with the predicted class, sample count and confidence.

# %%
def plot_c45_tree(clf, title=''):
    """Render a C4.5 surrogate tree as a matplotlib figure."""
    root = clf.root_
    if root is None:
        return None

    positions = {}
    leaf_counter = [0]

    def assign_x(node, depth):
        if not node.children:
            positions[id(node)] = (leaf_counter[0], -depth)
            leaf_counter[0] += 1
            return positions[id(node)][0]
        child_xs = [assign_x(c, depth + 1) for c in node.children]
        x = (min(child_xs) + max(child_xs)) / 2.0
        positions[id(node)] = (x, -depth)
        return x

    assign_x(root, 0)
    max_depth = clf.get_depth()
    n_leaves = clf.get_n_leaves()

    fig_w = min(22, max(7, n_leaves * 1.8))
    fig_h = min(18, max(3.5, (max_depth + 1) * 1.6))
    fig, ax = plt.subplots(figsize=(fig_w, fig_h))

    def fmt_cat_label(lbl):
        if isinstance(lbl, (list, tuple, set, frozenset)):
            vals = [str(v) for v in lbl]
            if len(vals) > 3:
                return '{' + ', '.join(vals[:3]) + f', +{len(vals) - 3}' + '}'
            return '{' + ', '.join(vals) + '}'
        return str(lbl)

    def draw(node):
        x, y = positions[id(node)]
        is_leaf = not node.children
        if is_leaf:
            total = sum(node.class_distribution.values())
            conf = (node.class_distribution.get(node.majority_class, 0) / total) if total else 0
            text = f'{node.majority_class}\nn={node.n_samples}, {conf:.0%}'
            color = '#d8ecff'
        else:
            if node.is_categorical:
                text = f'{node.feature}\nn={node.n_samples}'
            else:
                text = f'{node.feature}\n<= {node.threshold:.3g}\nn={node.n_samples}'
            color = '#ffe9b3'

        ax.text(x, y, text, ha='center', va='center', fontsize=8,
                bbox=dict(boxstyle='round,pad=0.35', facecolor=color,
                          edgecolor='black', linewidth=0.7))

        if is_leaf:
            return

        for i, child in enumerate(node.children):
            cx, cy = positions[id(child)]
            ax.plot([x, cx], [y - 0.18, cy + 0.18], 'k-', lw=0.8)
            if node.is_categorical:
                lbl = node.branch_labels[i] if i < len(node.branch_labels) else str(i)
                edge_text = fmt_cat_label(lbl)
            else:
                edge_text = '<=' if i == 0 else '>'
            mx, my = (x + cx) / 2, (y + cy) / 2
            ax.text(mx, my, edge_text, fontsize=7, ha='center', va='center',
                    bbox=dict(boxstyle='round,pad=0.18', facecolor='white',
                              edgecolor='none', alpha=0.85))
            draw(child)

    draw(root)

    ax.set_xlim(-0.8, max(n_leaves - 0.2, 1))
    ax.set_ylim(-max_depth - 0.8, 0.8)
    ax.set_axis_off()
    if title:
        ax.set_title(title, fontsize=11)
    plt.tight_layout()
    return fig


for gateway_act, gr in surrogate_results.items():
    clf = gr['clf']
    title = (f'{gateway_act} — Surrogate tree  '
             f'(fidelity={gr["fidelity"]:.3f}, depth={clf.get_depth()}, '
             f'leaves={clf.get_n_leaves()})')
    plot_c45_tree(clf, title=title)
    plt.show()
