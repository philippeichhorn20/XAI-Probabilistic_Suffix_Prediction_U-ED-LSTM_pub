# %% [markdown]
# # 20 — CART Global Surrogate Model — BPIC17
#
# Trains an interpretable decision tree (CART) to approximate the LSTM's
# next-activity predictions across all inputs. Reveals **model-level** decision
# logic — which features and thresholds drive the model's behaviour globally.
#
# Uses engineered aggregate features (prefix-level statistics) rather than
# raw per-position values.
#
# BPIC17 is large (253K entries) so we sample ~10K prefixes for the surrogate.

# %%
import sys
from pathlib import Path

_current = Path().resolve()
while _current != _current.parent:
    if (_current / 'src').is_dir():
        break
    _current = _current.parent

if str(_current) not in sys.path:
    sys.path.insert(0, str(_current))

src_path = str(_current / 'src')
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# %%
import torch
import numpy as np
import pandas as pd

# --- Load dataset ---
data_path = _current / 'encoded_data' / 'BPIC_2017_all_5_test.pkl'
dataset = torch.load(data_path, weights_only=False)

sample = dataset[0]
n_cat = len(sample[0])
n_num = len(sample[1])
seq_len = sample[0][0].shape[0]
print(f'Dataset: {len(dataset)} sequences, {n_cat} cat, {n_num} num, seq_len={seq_len}')

# --- Load model ---
from src.model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model import DropoutUncertaintyEncoderDecoderLSTM

from src.interpretability.config.bpic17_config import CONFIG
CONFIG.use_improved = False  # set True for the improved variant
model = DropoutUncertaintyEncoderDecoderLSTM.load(str(CONFIG.get_model_path()), dropout=0.0)
model.eval()

# --- TensorDecoder + activity vocab ---
from src.interpretability.utils.tensor_decoder import TensorDecoder

decoder = TensorDecoder(dataset)

ACTIVITY_FEATURE = 'concept:name'
activity_idx_to_label = decoder.idx_to_label[ACTIVITY_FEATURE]
max_idx = max(activity_idx_to_label.keys())
activity_names = [activity_idx_to_label.get(i, f'<unk_{i}>') for i in range(max_idx + 1)]
eos_idx = next(i for i, name in enumerate(activity_names) if name == 'EOS')

# --- Predictor ---
from src.interpretability.perturbation_methods.revised_plus.revised_plus import RevisedPlusModelPredictor

predictor = RevisedPlusModelPredictor(model, suffix_step=0, activity_feature=ACTIVITY_FEATURE)

print(f'Model: {sum(p.numel() for p in model.parameters()):,} parameters')
print(f'Activity vocabulary ({len(activity_names)}), EOS={eos_idx}')
print(f'Cat features: {decoder.cat_features}')
print(f'Num features: {decoder.num_features}')

# %%
# Feature indices (BPIC17)
ACT_IDX = decoder.cat_features.index('concept:name')       # 0
RES_IDX = decoder.cat_features.index('org:resource')        # 2
LC_IDX = decoder.cat_features.index('lifecycle:transition')  # 4
LG_IDX = decoder.cat_features.index('case:LoanGoal')        # 5
AT_IDX = decoder.cat_features.index('case:ApplicationType')  # 6

elapsed_num_idx = decoder.num_features.index('case_elapsed_time')
event_num_idx = decoder.num_features.index('event_elapsed_time')
amount_num_idx = decoder.num_features.index('case:RequestedAmount')
credit_num_idx = decoder.num_features.index('CreditScore')
day_num_idx = decoder.num_features.index('day_in_week')

print(f'Act={ACT_IDX}, Res={RES_IDX}, LC={LC_IDX}, LG={LG_IDX}, AT={AT_IDX}')
print(f'elapsed={elapsed_num_idx}, event={event_num_idx}, amount={amount_num_idx}, '
      f'credit={credit_num_idx}, day={day_num_idx}')


def extract_features(cat_tuple, num_tuple, decoder):
    """Extract engineered aggregate features from a single BPIC17 prefix."""
    act_tensor = cat_tuple[ACT_IDX]
    mask = act_tensor != 0
    prefix_len = int(mask.sum().item())
    if prefix_len == 0:
        return None

    nonzero = mask.nonzero(as_tuple=True)[0]
    start = nonzero[0].item()
    end = start + prefix_len

    acts = act_tensor[start:end]

    # Trailing repetitions of last activity
    last_act = acts[-1].item()
    repeated = 1
    for k in range(len(acts) - 2, -1, -1):
        if acts[k].item() == last_act:
            repeated += 1
        else:
            break

    # Time features (inverse-transformed)
    total_elapsed = decoder.decode_numerical_value(
        'case_elapsed_time', num_tuple[elapsed_num_idx][end - 1].item())
    last_event_dur = decoder.decode_numerical_value(
        'event_elapsed_time', num_tuple[event_num_idx][end - 1].item())
    event_durs = [decoder.decode_numerical_value(
        'event_elapsed_time', num_tuple[event_num_idx][j].item())
        for j in range(start, end)]
    mean_event_dur = float(np.mean(event_durs))

    # Resource features
    res_tensor = cat_tuple[RES_IDX]
    resources = res_tensor[start:end].tolist()
    n_unique_res = len(set(resources))

    # BPIC17-specific numerical features
    requested_amount = decoder.decode_numerical_value(
        'case:RequestedAmount', num_tuple[amount_num_idx][end - 1].item())
    credit_score = decoder.decode_numerical_value(
        'CreditScore', num_tuple[credit_num_idx][end - 1].item())
    day_in_week = decoder.decode_numerical_value(
        'day_in_week', num_tuple[day_num_idx][end - 1].item())

    return {
        'prefix_length': prefix_len,
        'last_activity': decoder.decode_categorical_value(ACT_IDX, acts[-1].item()),
        'first_activity': decoder.decode_categorical_value(ACT_IDX, acts[0].item()),
        'n_unique_activities': len(set(acts.tolist())),
        'last_activity_repeated': repeated,
        'total_elapsed_time': total_elapsed,
        'last_event_duration': last_event_dur,
        'mean_event_duration': mean_event_dur,
        'last_resource': decoder.decode_categorical_value(RES_IDX, res_tensor[end - 1].item()),
        'n_unique_resources': n_unique_res,
        'loan_goal': decoder.decode_categorical_value(LG_IDX, cat_tuple[LG_IDX][end - 1].item()),
        'application_type': decoder.decode_categorical_value(AT_IDX, cat_tuple[AT_IDX][end - 1].item()),
        'requested_amount': requested_amount,
        'credit_score': credit_score,
        'last_lifecycle': decoder.decode_categorical_value(LC_IDX, cat_tuple[LC_IDX][end - 1].item()),
        'day_in_week': day_in_week,
    }


# Quick test
sample_feats = extract_features(dataset[0][0], dataset[0][1], decoder)
print('Sample features:')
for k, v in sample_feats.items():
    print(f'  {k}: {v}')
# Out:
# Act=0, Res=2, LC=4, LG=5, AT=6
# elapsed=0, event=1, amount=4, credit=8, day=2
# Sample features:
#   prefix_length: 5
#   last_activity: W_Complete application
#   first_activity: A_Create Application
#   n_unique_activities: 4
#   last_activity_repeated: 1
#   total_elapsed_time: 66.63107480097096
#   last_event_duration: 0.010391339965281077
#   mean_event_duration: 10192.748938894987
#   last_resource: User_1
#   n_unique_resources: 1
#   loan_goal: Other, see explanation
#   application_type: New credit
#   requested_amount: 4999.999862728651
#   credit_score: 319.19134544389766
#   last_lifecycle: schedule
#   day_in_week: 1.9999999000630373

# %%
SAMPLE_CASES = 1500  # sample this many unique cases, then slice into prefixes

# Collect unique cases (keep entry with longest trace)
print('Scanning dataset for unique cases...')
cases = {}
for i in range(len(dataset)):
    cat_t, num_t, case_id = dataset[i]
    trace_len = int((cat_t[0] != 0).sum().item())
    if case_id not in cases or trace_len > cases[case_id][1]:
        cases[case_id] = (i, trace_len)
    if (i + 1) % 50000 == 0:
        print(f'  Scanned {i + 1}/{len(dataset)}, found {len(cases)} unique cases...')

print(f'Found {len(cases)} unique cases')

# Sample cases
rng = np.random.RandomState(42)
all_case_ids = list(cases.keys())
if len(all_case_ids) > SAMPLE_CASES:
    sampled_case_ids = list(rng.choice(all_case_ids, size=SAMPLE_CASES, replace=False))
else:
    sampled_case_ids = all_case_ids
print(f'Using {len(sampled_case_ids)} cases')

# Slice each case into prefixes of varying lengths.
# Strip trailing EOS so prefixes end with real activities.
feature_rows = []
sliced_cat_list = []
sliced_num_list = []

for count, case_id in enumerate(sampled_case_ids):
    ds_idx, trace_len = cases[case_id]
    cat_full, num_full, _ = dataset[ds_idx]
    src_start = seq_len - trace_len

    # Find useful trace length (strip trailing EOS)
    acts = cat_full[ACT_IDX][src_start:src_start + trace_len]
    useful_len = trace_len
    for j in range(trace_len - 1, -1, -1):
        if acts[j].item() == eos_idx:
            useful_len = j
        else:
            break
    if useful_len == 0:
        continue

    # Generate prefixes of length 1 .. useful_len
    for k in range(1, useful_len + 1):
        pad_len = seq_len - k
        cat_prefix = []
        for c in cat_full:
            t = torch.zeros_like(c)
            t[pad_len:] = c[src_start:src_start + k]
            cat_prefix.append(t)

        num_prefix = []
        for n in num_full:
            t = torch.zeros_like(n)
            t[pad_len:] = n[src_start:src_start + k]
            num_prefix.append(t)

        feats = extract_features(tuple(cat_prefix), tuple(num_prefix), decoder)
        if feats is not None:
            feature_rows.append(feats)
            sliced_cat_list.append(cat_prefix)
            sliced_num_list.append(num_prefix)

    if (count + 1) % 500 == 0:
        print(f'  {count + 1}/{len(sampled_case_ids)} cases, {len(feature_rows)} prefixes...')

X = pd.DataFrame(feature_rows)
N_total = len(X)
print(f'Generated {N_total} prefixes from {len(sampled_case_ids)} cases')
print(f'\nPrefix length distribution:')
print(X['prefix_length'].value_counts().sort_index())
display(X.describe(include='all'))

# --- Batch-predict LSTM labels ---
print(f'\nBatch-predicting with LSTM...')
cat_batch = [
    torch.stack([sliced_cat_list[i][ci] for i in range(N_total)])
    for ci in range(n_cat)
]
num_stacked = torch.stack([
    torch.stack(sliced_num_list[i], dim=-1)
    for i in range(N_total)
])

preds, probs = predictor.predict_batch(cat_batch, num_stacked, batch_size=128)
y = np.array([activity_names[p] for p in preds])

print(f'\nLSTM prediction distribution:')
unique, counts = np.unique(y, return_counts=True)
for cls, cnt in sorted(zip(unique, counts), key=lambda x: -x[1]):
    print(f'  {cls}: {cnt} ({cnt / len(y) * 100:.1f}%)')
# Out:
# Scanning dataset for unique cases...
#   Scanned 50000/253196, found 1235 unique cases...
#   Scanned 100000/253196, found 2465 unique cases...
#   Scanned 150000/253196, found 3730 unique cases...
#   Scanned 200000/253196, found 4961 unique cases...
#   Scanned 250000/253196, found 6222 unique cases...
# Found 6301 unique cases
# Using 1500 cases
#   500/1500 cases, 18916 prefixes...
#   1000/1500 cases, 37747 prefixes...
#   1500/1500 cases, 56679 prefixes...
# Generated 56679 prefixes from 1500 cases
#
# Prefix length distribution:
# prefix_length
# 1     1500
# 2     1500
# 3     1500
# 4     1500
# 5     1500
#       ...
# 92      13
# 93      13
# 94      11
# 95      10
# 96      10
# Name: count, Length: 96, dtype: int64
#         prefix_length           last_activity        first_activity  \
# count    56679.000000                   56679                 56679
# unique            NaN                      25                     1
# top               NaN  W_Validate application  A_Create Application
# freq              NaN                    9837                 56679
# mean        22.820074                     NaN                   NaN
# std         16.647917                     NaN                   NaN
# min          1.000000                     NaN                   NaN
# 25%         10.000000                     NaN                   NaN
# 50%         19.000000                     NaN                   NaN
# 75%         32.000000                     NaN                   NaN
# max         96.000000                     NaN                   NaN
#
#         n_unique_activities  last_activity_repeated  total_elapsed_time  \
# count          56679.000000            56679.000000        5.667900e+04
# unique                  NaN                     NaN                 NaN
# top                     NaN                     NaN                 NaN
# freq                    NaN                     NaN                 NaN
# mean              10.304681                1.941760        7.713849e+05
# std                4.694288                2.174223        9.674270e+05
# min                1.000000                1.000000        1.396174e-02
# 25%                6.000000                1.000000        2.796980e+04
# 50%               11.000000                1.000000        4.435126e+05
# 75%               14.000000                2.000000        1.135176e+06
# max               21.000000               46.000000        9.739598e+06
#
#         last_event_duration  mean_event_duration last_resource  \
# count          5.667900e+04         56679.000000         56679
# unique                  NaN                  NaN           145
# top                     NaN                  NaN        User_1
# freq                    NaN                  NaN          7010
# mean           5.139372e+04         31039.927562           NaN
# std            2.343459e+05         26991.938185           NaN
# min            3.858799e-03          1697.037972           NaN
# 25%            1.039134e-02         12737.383956           NaN
# 50%            1.083808e+01         25001.810468           NaN
# 75%            3.957109e+02         39107.439633           NaN
# max            3.625372e+06        289044.152144           NaN
#
#         n_unique_resources loan_goal application_type  requested_amount  \
# count         56679.000000     56679            56679      56679.000000
# unique                 NaN        13                2               NaN
# top                    NaN       Car       New credit               NaN
# freq                   NaN     16055            51639               NaN
# mean              4.439228       NaN              NaN      16500.236750
# std               3.208963       NaN              NaN      15962.194717
# min               1.000000       NaN              NaN         -0.000193
# 25%               2.000000       NaN              NaN       6000.000220
# 50%               4.000000       NaN              NaN      13500.000087
# 75%               6.000000       NaN              NaN      21999.999879
# max              21.000000       NaN              NaN     250000.000856
#
#         credit_score last_lifecycle   day_in_week
# count   56679.000000          56679  5.667900e+04
# unique           NaN              7           NaN
# top              NaN       complete           NaN
# freq             NaN          22364           NaN
# mean      319.797749            NaN  2.158365e+00
# std        82.460524            NaN  1.653987e+00
# min        -0.000005            NaN -1.671387e-07
# 25%       319.191345            NaN  9.999999e-01
# 50%       319.191345            NaN  2.000000e+00
# 75%       319.191345            NaN  3.000000e+00
# max      1126.999972            NaN  6.000000e+00
# Batch-predicting with LSTM...
#
# LSTM prediction distribution:
#   W_Validate application: 12792 (22.6%)
#   W_Call after offers: 10118 (17.9%)
#   W_Complete application: 8752 (15.4%)
#   W_Call incomplete files: 7765 (13.7%)
#   W_Handle leads: 2902 (5.1%)
#   O_Sent (mail and online): 2041 (3.6%)
#   A_Validating: 1839 (3.2%)
#   O_Created: 1706 (3.0%)
#   EOS: 1697 (3.0%)
#   A_Concept: 1507 (2.7%)
#   O_Create Offer: 1488 (2.6%)
#   A_Complete: 1483 (2.6%)
#   A_Incomplete: 1111 (2.0%)
#   O_Cancelled: 758 (1.3%)
#   A_Pending: 364 (0.6%)
#   O_Returned: 308 (0.5%)
#   A_Cancelled: 29 (0.1%)
#   O_Refused: 19 (0.0%)

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split

cat_cols = [c for c in X.columns if X[c].dtype == 'object']
num_cols = [c for c in X.columns if c not in cat_cols]
print(f'Categorical columns ({len(cat_cols)}): {cat_cols}')
print(f'Numerical columns ({len(num_cols)}): {num_cols}')

ord_encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
X_encoded = X.copy()
X_encoded[cat_cols] = ord_encoder.fit_transform(X[cat_cols].astype(str))

cat_mappings = {}
for i, col in enumerate(cat_cols):
    cat_mappings[col] = list(ord_encoder.categories_[i])
    print(f'  {col}: {len(cat_mappings[col])} categories')

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.2, random_state=42, stratify=y)
print(f'\nTrain: {len(X_train)}, Test: {len(X_test)}')
# Out:
# Categorical columns (6): ['last_activity', 'first_activity', 'last_resource', 'loan_goal', 'application_type', 'last_lifecycle']
# Numerical columns (10): ['prefix_length', 'n_unique_activities', 'last_activity_repeated', 'total_elapsed_time', 'last_event_duration', 'mean_event_duration', 'n_unique_resources', 'requested_amount', 'credit_score', 'day_in_week']
#   last_activity: 25 categories
#   first_activity: 1 categories
#   last_resource: 145 categories
#   loan_goal: 13 categories
#   application_type: 2 categories
#   last_lifecycle: 7 categories
#
# Train: 45343, Test: 11336

# %%
from sklearn.tree import DecisionTreeClassifier

# min_samples_leaf: increase to reduce scatter (fewer, larger leaves)
MIN_SAMPLES_LEAF = 20

depths = [3, 4, 5, 6, 8, None]
results = []

for depth in depths:
    clf = DecisionTreeClassifier(
        max_depth=depth, min_samples_leaf=MIN_SAMPLES_LEAF, random_state=42)
    clf.fit(X_train, y_train)
    train_fid = clf.score(X_train, y_train)
    test_fid = clf.score(X_test, y_test)
    n_leaves = clf.get_n_leaves()
    results.append({
        'max_depth': depth if depth is not None else 'None',
        'min_samples_leaf': MIN_SAMPLES_LEAF,
        'train_fidelity': f'{train_fid:.4f}',
        'test_fidelity': f'{test_fid:.4f}',
        'n_leaves': n_leaves,
        'model': clf,
    })
    print(f'depth={str(depth):>4s}  train={train_fid:.4f}  test={test_fid:.4f}  leaves={n_leaves}')

df_results = pd.DataFrame([{k: v for k, v in r.items() if k != 'model'} for r in results])
display(df_results)

best_idx = 0
best_test = float(results[0]['test_fidelity'])
for i in range(1, len(results)):
    ti = float(results[i]['test_fidelity'])
    if ti > best_test + 0.02:
        best_idx = i
        best_test = ti

best = results[best_idx]
clf_best = best['model']
print(f'\nSelected: depth={best["max_depth"]} (test fidelity={best["test_fidelity"]}, '
      f'leaves={best["n_leaves"]})')

if float(best['test_fidelity']) < 0.60:
    print('\nWARNING: Fidelity below 60% -- surrogate may not be meaningful!')
elif float(best['test_fidelity']) < 0.70:
    print('\nNote: Fidelity below 70% -- interpret surrogate rules with caution.')
# Out:
# depth=   3  train=0.6517  test=0.6448  leaves=8
# depth=   4  train=0.7597  test=0.7554  leaves=16
# depth=   5  train=0.8161  test=0.8149  leaves=31
# depth=   6  train=0.8743  test=0.8712  leaves=55
# depth=   8  train=0.9137  test=0.9119  leaves=139
# depth=None  train=0.9612  test=0.9521  leaves=427
#   max_depth  min_samples_leaf train_fidelity test_fidelity  n_leaves
# 0         3                20         0.6517        0.6448         8
# 1         4                20         0.7597        0.7554        16
# 2         5                20         0.8161        0.8149        31
# 3         6                20         0.8743        0.8712        55
# 4         8                20         0.9137        0.9119       139
# 5      None                20         0.9612        0.9521       427
# Selected: depth=None (test fidelity=0.9521, leaves=427)

# %%
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

y_pred = clf_best.predict(X_test)
fidelity = (y_pred == y_test).mean()

print('=' * 60)
print(f'  OVERALL FIDELITY (surrogate vs LSTM): {fidelity:.4f}')
print('=' * 60)
print()
print(classification_report(y_test, y_pred, zero_division=0))

labels = sorted(set(y_test) | set(y_pred))
cm = confusion_matrix(y_test, y_pred, labels=labels)

fig, ax = plt.subplots(figsize=(12, 10))
im = ax.imshow(cm, cmap='Blues')
ax.set_xticks(range(len(labels)))
ax.set_yticks(range(len(labels)))
ax.set_xticklabels(labels, rotation=45, ha='right', fontsize=6)
ax.set_yticklabels(labels, fontsize=6)
ax.set_xlabel('Surrogate prediction')
ax.set_ylabel('LSTM prediction')
ax.set_title(f'Confusion Matrix: CART Surrogate vs LSTM (fidelity={fidelity:.3f})')
for i in range(len(labels)):
    for j in range(len(labels)):
        ax.text(j, i, cm[i, j], ha='center', va='center',
                color='white' if cm[i, j] > cm.max() / 2 else 'black', fontsize=5)
plt.colorbar(im)
plt.tight_layout()
plt.show()
# Out:
# DEBUG:matplotlib.colorbar:locator: <matplotlib.ticker.AutoLocator object at 0x41a3a2330>
# ============================================================
#   OVERALL FIDELITY (surrogate vs LSTM): 0.9521
# ============================================================
#
#                           precision    recall  f1-score   support
#
#              A_Cancelled       0.17      0.17      0.17         6
#               A_Complete       0.98      0.98      0.98       297
#                A_Concept       0.87      0.89      0.88       301
#             A_Incomplete       0.92      0.98      0.95       222
#                A_Pending       0.57      0.63      0.60        73
#             A_Validating       0.98      0.99      0.99       368
#                      EOS       0.91      0.89      0.90       339
#              O_Cancelled       0.94      0.79      0.86       152
#           O_Create Offer       0.99      0.99      0.99       298
#                O_Created       0.92      0.94      0.93       341
#                O_Refused       0.00      0.00      0.00         4
#               O_Returned       0.81      0.42      0.55        62
# O_Sent (mail and online)       0.99      0.89      0.94       408
#      W_Call after offers       0.96      0.97      0.97      2024
#  W_Call incomplete files       0.96      0.96      0.96      1553
#   W_Complete application       0.97      0.97      0.97      1750
#           W_Handle leads       0.99      1.00      1.00       580
#   W_Validate application       0.94      0.95      0.95      2558
#
#                 accuracy                           0.95     11336
#                macro avg       0.83      0.80      0.81     11336
#             weighted avg       0.95      0.95      0.95     11336

# %%
from sklearn.tree import plot_tree, export_text
import re

feature_names = list(X_encoded.columns)

fig, ax = plt.subplots(figsize=(28, 14))
plot_tree(clf_best, feature_names=feature_names,
          class_names=clf_best.classes_.tolist(),
          filled=True, rounded=True, ax=ax, fontsize=6)
ax.set_title(f'CART Surrogate (depth={best["max_depth"]}, fidelity={best["test_fidelity"]})')
plt.tight_layout()
plt.show()

tree_text = export_text(clf_best, feature_names=feature_names)


def decode_tree_text(text, cat_cols, cat_mappings):
    """Replace ordinal split thresholds with actual category names."""
    decoded = []
    for line in text.split('\n'):
        out = line
        for col in cat_cols:
            pattern = rf'({re.escape(col)})\s*(<=|>)\s*([\d.]+)'
            m = re.search(pattern, line)
            if m:
                feat, op, thresh = m.group(1), m.group(2), float(m.group(3))
                cats = cat_mappings[feat]
                if op == '<=':
                    incl = [c for i, c in enumerate(cats) if i <= thresh]
                else:
                    incl = [c for i, c in enumerate(cats) if i > thresh]
                if len(incl) <= 8:
                    out += f'  [{feat} in {{{", ".join(incl)}}}]'
                else:
                    out += f'  [{feat} in {{{", ".join(incl[:6])}, ... ({len(incl)} total)}}]'
                break
        decoded.append(out)
    return '\n'.join(decoded)


print(decode_tree_text(tree_text, cat_cols, cat_mappings))
# Out:
# |--- n_unique_activities <= 11.50
# |   |--- n_unique_activities <= 7.50
# |   |   |--- prefix_length <= 3.50
# |   |   |   |--- last_resource <= 0.50  [last_resource in {User_1}]
# |   |   |   |   |--- class: W_Handle leads
# |   |   |   |--- last_resource >  0.50  [last_resource in {User_10, User_100, User_101, User_102, User_103, User_104, ... (144 total)}]
# |   |   |   |   |--- last_activity <= 12.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (13 total)}]
# |   |   |   |   |   |--- requested_amount <= 1750.00
# |   |   |   |   |   |   |--- last_resource <= 81.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (82 total)}]
# |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |--- last_resource >  81.50  [last_resource in {User_42, User_43, User_44, User_45, User_46, User_47, ... (63 total)}]
# |   |   |   |   |   |   |   |--- last_resource <= 84.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (85 total)}]
# |   |   |   |   |   |   |   |   |--- class: W_Handle leads
# |   |   |   |   |   |   |   |--- last_resource >  84.50  [last_resource in {User_45, User_46, User_47, User_48, User_49, User_5, ... (60 total)}]
# |   |   |   |   |   |   |   |   |--- last_resource <= 113.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (114 total)}]
# |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |   |--- last_resource >  113.50  [last_resource in {User_71, User_72, User_73, User_74, User_75, User_76, ... (31 total)}]
# |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |--- requested_amount >  1750.00
# |   |   |   |   |   |   |--- last_resource <= 81.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (82 total)}]
# |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |--- last_resource >  81.50  [last_resource in {User_42, User_43, User_44, User_45, User_46, User_47, ... (63 total)}]
# |   |   |   |   |   |   |   |--- last_resource <= 83.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (84 total)}]
# |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |--- last_resource >  83.50  [last_resource in {User_44, User_45, User_46, User_47, User_48, User_49, ... (61 total)}]
# |   |   |   |   |   |   |   |   |--- day_in_week <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |   |--- day_in_week >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |--- last_activity >  12.50  [last_activity in {O_Created, O_Refused, O_Returned, O_Sent (mail and online), O_Sent (online only), W_Assess potential fraud, ... (12 total)}]
# |   |   |   |   |   |--- last_lifecycle <= 3.50  [last_lifecycle in {ate_abort, complete, resume, schedule}]
# |   |   |   |   |   |   |--- last_resource <= 55.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (56 total)}]
# |   |   |   |   |   |   |   |--- last_resource <= 48.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (49 total)}]
# |   |   |   |   |   |   |   |   |--- last_resource <= 27.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (28 total)}]
# |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |   |--- last_resource >  27.50  [last_resource in {User_125, User_126, User_127, User_128, User_129, User_13, ... (117 total)}]
# |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |--- last_resource >  48.00  [last_resource in {User_144, User_145, User_146, User_15, User_16, User_17, ... (96 total)}]
# |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |--- last_resource >  55.50  [last_resource in {User_19, User_2, User_20, User_21, User_22, User_23, ... (89 total)}]
# |   |   |   |   |   |   |   |--- last_resource <= 61.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (62 total)}]
# |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |--- last_resource >  61.50  [last_resource in {User_24, User_25, User_26, User_27, User_28, User_29, ... (83 total)}]
# |   |   |   |   |   |   |   |   |--- last_resource <= 69.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (70 total)}]
# |   |   |   |   |   |   |   |   |   |--- mean_event_duration <= 25448.56
# |   |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |   |   |--- mean_event_duration >  25448.56
# |   |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |   |--- last_resource >  69.00  [last_resource in {User_31, User_32, User_33, User_34, User_35, User_36, ... (75 total)}]
# |   |   |   |   |   |   |   |   |   |--- last_resource <= 77.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (78 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |   |   |--- last_resource >  77.50  [last_resource in {User_39, User_4, User_40, User_41, User_42, User_43, ... (67 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- last_resource <= 81.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (82 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |   |   |   |--- last_resource >  81.50  [last_resource in {User_42, User_43, User_44, User_45, User_46, User_47, ... (63 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |--- last_lifecycle >  3.50  [last_lifecycle in {start, suspend, withdraw}]
# |   |   |   |   |   |   |--- last_resource <= 55.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (56 total)}]
# |   |   |   |   |   |   |   |--- last_resource <= 48.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (49 total)}]
# |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |--- last_resource >  48.00  [last_resource in {User_144, User_145, User_146, User_15, User_16, User_17, ... (96 total)}]
# |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |--- last_resource >  55.50  [last_resource in {User_19, User_2, User_20, User_21, User_22, User_23, ... (89 total)}]
# |   |   |   |   |   |   |   |--- last_resource <= 107.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (108 total)}]
# |   |   |   |   |   |   |   |   |--- requested_amount <= 2500.00
# |   |   |   |   |   |   |   |   |   |--- loan_goal <= 11.50  [loan_goal in {Boat, Car, Caravan / Camper, Debt restructuring, Existing loan takeover, Extra spending limit, ... (12 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |   |   |--- loan_goal >  11.50  [loan_goal in {Unknown}]
# |   |   |   |   |   |   |   |   |   |   |--- last_resource <= 83.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (84 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |   |   |   |--- last_resource >  83.00  [last_resource in {User_44, User_45, User_46, User_47, User_48, User_49, ... (61 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |   |--- requested_amount >  2500.00
# |   |   |   |   |   |   |   |   |   |--- last_resource <= 85.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (86 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- last_resource <= 67.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (68 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |   |   |   |--- last_resource >  67.00  [last_resource in {User_3, User_30, User_31, User_32, User_33, User_34, ... (77 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- last_resource >  85.50  [last_resource in {User_46, User_47, User_48, User_49, User_5, User_50, ... (59 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- requested_amount <= 17459.68
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |   |   |   |--- requested_amount >  17459.68
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |--- last_resource >  107.50  [last_resource in {User_66, User_67, User_68, User_69, User_7, User_70, ... (37 total)}]
# |   |   |   |   |   |   |   |   |--- requested_amount <= 7500.00
# |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |   |--- requested_amount >  7500.00
# |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |--- prefix_length >  3.50
# |   |   |   |--- last_activity <= 0.50  [last_activity in {A_Accepted}]
# |   |   |   |   |--- total_elapsed_time <= 691809.78
# |   |   |   |   |   |--- last_event_duration <= 254378.60
# |   |   |   |   |   |   |--- total_elapsed_time <= 247.65
# |   |   |   |   |   |   |   |--- last_resource <= 96.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (97 total)}]
# |   |   |   |   |   |   |   |   |--- class: O_Create Offer
# |   |   |   |   |   |   |   |--- last_resource >  96.00  [last_resource in {User_56, User_57, User_58, User_59, User_6, User_60, ... (48 total)}]
# |   |   |   |   |   |   |   |   |--- class: O_Create Offer
# |   |   |   |   |   |   |--- total_elapsed_time >  247.65
# |   |   |   |   |   |   |   |--- class: O_Create Offer
# |   |   |   |   |   |--- last_event_duration >  254378.60
# |   |   |   |   |   |   |--- class: O_Create Offer
# |   |   |   |   |--- total_elapsed_time >  691809.78
# |   |   |   |   |   |--- class: O_Create Offer
# |   |   |   |--- last_activity >  0.50  [last_activity in {A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, A_Incomplete, ... (24 total)}]
# |   |   |   |   |--- credit_score <= 159.60
# |   |   |   |   |   |--- mean_event_duration <= 56371.12
# |   |   |   |   |   |   |--- mean_event_duration <= 6491.00
# |   |   |   |   |   |   |   |--- n_unique_resources <= 1.50
# |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |--- n_unique_resources >  1.50
# |   |   |   |   |   |   |   |   |--- mean_event_duration <= 5597.43
# |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |   |--- mean_event_duration >  5597.43
# |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |--- mean_event_duration >  6491.00
# |   |   |   |   |   |   |   |--- total_elapsed_time <= 681.38
# |   |   |   |   |   |   |   |   |--- last_resource <= 96.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (97 total)}]
# |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |   |--- last_resource >  96.50  [last_resource in {User_56, User_57, User_58, User_59, User_6, User_60, ... (48 total)}]
# |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |--- total_elapsed_time >  681.38
# |   |   |   |   |   |   |   |   |--- last_event_duration <= 44.83
# |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |   |--- last_event_duration >  44.83
# |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |--- mean_event_duration >  56371.12
# |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |--- credit_score >  159.60
# |   |   |   |   |   |--- credit_score <= 460.10
# |   |   |   |   |   |   |--- last_event_duration <= 2.03
# |   |   |   |   |   |   |   |--- last_activity <= 8.00  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (9 total)}]
# |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |--- last_activity >  8.00  [last_activity in {A_Validating, O_Accepted, O_Cancelled, O_Create Offer, O_Created, O_Refused, ... (16 total)}]
# |   |   |   |   |   |   |   |   |--- last_lifecycle <= 2.00  [last_lifecycle in {ate_abort, complete, resume}]
# |   |   |   |   |   |   |   |   |   |--- last_activity <= 14.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (15 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- class: O_Sent (mail and online)
# |   |   |   |   |   |   |   |   |   |--- last_activity >  14.50  [last_activity in {O_Returned, O_Sent (mail and online), O_Sent (online only), W_Assess potential fraud, W_Call after offers, W_Call incomplete files, ... (10 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- last_activity <= 18.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (19 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |   |   |   |--- last_activity >  18.50  [last_activity in {W_Call after offers, W_Call incomplete files, W_Complete application, W_Handle leads, W_Shortened completion , W_Validate application}]
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |--- last_lifecycle >  2.00  [last_lifecycle in {schedule, start, suspend, withdraw}]
# |   |   |   |   |   |   |   |   |   |--- last_resource <= 0.50  [last_resource in {User_1}]
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 103.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time >  103.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Concept
# |   |   |   |   |   |   |   |   |   |--- last_resource >  0.50  [last_resource in {User_10, User_100, User_101, User_102, User_103, User_104, ... (144 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- last_resource <= 48.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (49 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- last_resource >  48.00  [last_resource in {User_144, User_145, User_146, User_15, User_16, User_17, ... (96 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |--- last_event_duration >  2.03
# |   |   |   |   |   |   |   |--- total_elapsed_time <= 1467817.75
# |   |   |   |   |   |   |   |   |--- loan_goal <= 11.50  [loan_goal in {Boat, Car, Caravan / Camper, Debt restructuring, Existing loan takeover, Extra spending limit, ... (12 total)}]
# |   |   |   |   |   |   |   |   |   |--- n_unique_activities <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- mean_event_duration <= 63510.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- mean_event_duration >  63510.88
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |   |   |--- n_unique_activities >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- last_event_duration <= 505.47
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- last_event_duration >  505.47
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |   |--- loan_goal >  11.50  [loan_goal in {Unknown}]
# |   |   |   |   |   |   |   |   |   |--- last_activity <= 16.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (17 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 874.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time >  874.03
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |   |   |--- last_activity >  16.50  [last_activity in {O_Sent (online only), W_Assess potential fraud, W_Call after offers, W_Call incomplete files, W_Complete application, W_Handle leads, W_Shortened completion , W_Validate application}]
# |   |   |   |   |   |   |   |   |   |   |--- n_unique_activities <= 5.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |   |   |   |--- n_unique_activities >  5.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |--- total_elapsed_time >  1467817.75
# |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |--- credit_score >  460.10
# |   |   |   |   |   |   |--- total_elapsed_time <= 443581.08
# |   |   |   |   |   |   |   |--- mean_event_duration <= 6607.44
# |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 2308.01
# |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |   |--- total_elapsed_time >  2308.01
# |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |--- mean_event_duration >  6607.44
# |   |   |   |   |   |   |   |   |--- last_event_duration <= 363.34
# |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |   |--- last_event_duration >  363.34
# |   |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 17144.38
# |   |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |   |   |--- total_elapsed_time >  17144.38
# |   |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |--- total_elapsed_time >  443581.08
# |   |   |   |   |   |   |   |--- class: O_Created
# |   |--- n_unique_activities >  7.50
# |   |   |--- last_resource <= 43.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (44 total)}]
# |   |   |   |--- last_resource <= 13.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (14 total)}]
# |   |   |   |   |--- last_event_duration <= 864417.97
# |   |   |   |   |   |--- total_elapsed_time <= 810118.25
# |   |   |   |   |   |   |--- n_unique_activities <= 8.50
# |   |   |   |   |   |   |   |--- last_activity <= 14.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (15 total)}]
# |   |   |   |   |   |   |   |   |--- class: O_Sent (mail and online)
# |   |   |   |   |   |   |   |--- last_activity >  14.50  [last_activity in {O_Returned, O_Sent (mail and online), O_Sent (online only), W_Assess potential fraud, W_Call after offers, W_Call incomplete files, ... (10 total)}]
# |   |   |   |   |   |   |   |   |--- last_lifecycle <= 3.50  [last_lifecycle in {ate_abort, complete, resume, schedule}]
# |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |--- last_lifecycle >  3.50  [last_lifecycle in {start, suspend, withdraw}]
# |   |   |   |   |   |   |   |   |   |--- class: A_Complete
# |   |   |   |   |   |   |--- n_unique_activities >  8.50
# |   |   |   |   |   |   |   |--- last_activity <= 17.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (18 total)}]
# |   |   |   |   |   |   |   |   |--- last_activity <= 12.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (13 total)}]
# |   |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 200633.23
# |   |   |   |   |   |   |   |   |   |   |--- mean_event_duration <= 4279.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |   |   |--- mean_event_duration >  4279.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |   |--- total_elapsed_time >  200633.23
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |--- last_activity >  12.50  [last_activity in {O_Created, O_Refused, O_Returned, O_Sent (mail and online), O_Sent (online only), W_Assess potential fraud, ... (12 total)}]
# |   |   |   |   |   |   |   |   |   |--- last_event_duration <= 20.56
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |   |   |--- last_event_duration >  20.56
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |--- last_activity >  17.50  [last_activity in {W_Assess potential fraud, W_Call after offers, W_Call incomplete files, W_Complete application, W_Handle leads, W_Shortened completion , W_Validate application}]
# |   |   |   |   |   |   |   |   |--- last_event_duration <= 0.01
# |   |   |   |   |   |   |   |   |   |--- last_resource <= 0.50  [last_resource in {User_1}]
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |   |--- last_resource >  0.50  [last_resource in {User_10, User_100, User_101, User_102, User_103, User_104, ... (144 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- day_in_week <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Complete
# |   |   |   |   |   |   |   |   |   |   |--- day_in_week >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Complete
# |   |   |   |   |   |   |   |   |--- last_event_duration >  0.01
# |   |   |   |   |   |   |   |   |   |--- loan_goal <= 11.50  [loan_goal in {Boat, Car, Caravan / Camper, Debt restructuring, Existing loan takeover, Extra spending limit, ... (12 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 416104.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time >  416104.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- loan_goal >  11.50  [loan_goal in {Unknown}]
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |--- total_elapsed_time >  810118.25
# |   |   |   |   |   |   |--- last_activity <= 17.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (18 total)}]
# |   |   |   |   |   |   |   |--- last_event_duration <= 0.06
# |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 2929887.38
# |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |--- total_elapsed_time >  2929887.38
# |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |--- last_event_duration >  0.06
# |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |--- last_activity >  17.50  [last_activity in {W_Assess potential fraud, W_Call after offers, W_Call incomplete files, W_Complete application, W_Handle leads, W_Shortened completion , W_Validate application}]
# |   |   |   |   |   |   |   |--- mean_event_duration <= 118044.34
# |   |   |   |   |   |   |   |   |--- class: EOS
# |   |   |   |   |   |   |   |--- mean_event_duration >  118044.34
# |   |   |   |   |   |   |   |   |--- class: EOS
# |   |   |   |   |--- last_event_duration >  864417.97
# |   |   |   |   |   |--- last_event_duration <= 2226018.62
# |   |   |   |   |   |   |--- class: O_Cancelled
# |   |   |   |   |   |--- last_event_duration >  2226018.62
# |   |   |   |   |   |   |--- class: O_Cancelled
# |   |   |   |--- last_resource >  13.00  [last_resource in {User_112, User_113, User_114, User_115, User_116, User_117, ... (131 total)}]
# |   |   |   |   |--- last_lifecycle <= 3.50  [last_lifecycle in {ate_abort, complete, resume, schedule}]
# |   |   |   |   |   |--- total_elapsed_time <= 153043.38
# |   |   |   |   |   |   |--- last_event_duration <= 0.38
# |   |   |   |   |   |   |   |--- last_activity <= 20.00  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (21 total)}]
# |   |   |   |   |   |   |   |   |--- n_unique_activities <= 9.50
# |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |--- n_unique_activities >  9.50
# |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |--- last_activity >  20.00  [last_activity in {W_Complete application, W_Handle leads, W_Shortened completion , W_Validate application}]
# |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |--- last_event_duration >  0.38
# |   |   |   |   |   |   |   |--- last_event_duration <= 6.23
# |   |   |   |   |   |   |   |   |--- class: O_Sent (mail and online)
# |   |   |   |   |   |   |   |--- last_event_duration >  6.23
# |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |--- total_elapsed_time >  153043.38
# |   |   |   |   |   |   |--- last_resource <= 32.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (33 total)}]
# |   |   |   |   |   |   |   |--- last_activity <= 18.00  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (19 total)}]
# |   |   |   |   |   |   |   |   |--- last_resource <= 17.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (18 total)}]
# |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |--- last_resource >  17.00  [last_resource in {User_116, User_117, User_118, User_119, User_12, User_120, ... (127 total)}]
# |   |   |   |   |   |   |   |   |   |--- last_resource <= 28.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (29 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- prefix_length <= 23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- prefix_length >  23.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |   |--- last_resource >  28.50  [last_resource in {User_126, User_127, User_128, User_129, User_13, User_130, ... (116 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |--- last_activity >  18.00  [last_activity in {W_Call after offers, W_Call incomplete files, W_Complete application, W_Handle leads, W_Shortened completion , W_Validate application}]
# |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 250913.73
# |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |--- total_elapsed_time >  250913.73
# |   |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 2148316.75
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 391220.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time >  391220.89
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- total_elapsed_time >  2148316.75
# |   |   |   |   |   |   |   |   |   |   |--- last_resource <= 22.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (23 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |   |   |--- last_resource >  22.00  [last_resource in {User_120, User_121, User_122, User_123, User_124, User_125, ... (122 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |--- last_resource >  32.50  [last_resource in {User_13, User_130, User_131, User_132, User_133, User_134, ... (112 total)}]
# |   |   |   |   |   |   |   |--- total_elapsed_time <= 492871.75
# |   |   |   |   |   |   |   |   |--- last_event_duration <= 252628.91
# |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |--- last_event_duration >  252628.91
# |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |--- total_elapsed_time >  492871.75
# |   |   |   |   |   |   |   |   |--- last_activity <= 17.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (18 total)}]
# |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |--- last_activity >  17.50  [last_activity in {W_Assess potential fraud, W_Call after offers, W_Call incomplete files, W_Complete application, W_Handle leads, W_Shortened completion , W_Validate application}]
# |   |   |   |   |   |   |   |   |   |--- last_event_duration <= 293807.92
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |   |--- last_event_duration >  293807.92
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |--- last_lifecycle >  3.50  [last_lifecycle in {start, suspend, withdraw}]
# |   |   |   |   |   |--- last_activity <= 22.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (23 total)}]
# |   |   |   |   |   |   |--- last_event_duration <= 12626.12
# |   |   |   |   |   |   |   |--- last_lifecycle <= 4.50  [last_lifecycle in {ate_abort, complete, resume, schedule, start}]
# |   |   |   |   |   |   |   |   |--- class: A_Complete
# |   |   |   |   |   |   |   |--- last_lifecycle >  4.50  [last_lifecycle in {suspend, withdraw}]
# |   |   |   |   |   |   |   |   |--- last_event_duration <= 22.43
# |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |--- last_event_duration >  22.43
# |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |--- last_event_duration >  12626.12
# |   |   |   |   |   |   |   |--- total_elapsed_time <= 1149308.50
# |   |   |   |   |   |   |   |   |--- requested_amount <= 11150.00
# |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |--- requested_amount >  11150.00
# |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |--- total_elapsed_time >  1149308.50
# |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |--- last_activity >  22.50  [last_activity in {W_Shortened completion , W_Validate application}]
# |   |   |   |   |   |   |--- n_unique_activities <= 10.50
# |   |   |   |   |   |   |   |--- total_elapsed_time <= 271061.88
# |   |   |   |   |   |   |   |   |--- class: A_Validating
# |   |   |   |   |   |   |   |--- total_elapsed_time >  271061.88
# |   |   |   |   |   |   |   |   |--- class: A_Validating
# |   |   |   |   |   |   |--- n_unique_activities >  10.50
# |   |   |   |   |   |   |   |--- class: A_Validating
# |   |   |--- last_resource >  43.00  [last_resource in {User_14, User_140, User_141, User_142, User_143, User_144, ... (101 total)}]
# |   |   |   |--- n_unique_activities <= 8.50
# |   |   |   |   |--- last_activity <= 14.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (15 total)}]
# |   |   |   |   |   |--- last_event_duration <= 14.28
# |   |   |   |   |   |   |--- last_event_duration <= 1.92
# |   |   |   |   |   |   |   |--- class: O_Sent (mail and online)
# |   |   |   |   |   |   |--- last_event_duration >  1.92
# |   |   |   |   |   |   |   |--- class: O_Sent (mail and online)
# |   |   |   |   |   |--- last_event_duration >  14.28
# |   |   |   |   |   |   |--- last_resource <= 67.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (68 total)}]
# |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |--- last_resource >  67.00  [last_resource in {User_3, User_30, User_31, User_32, User_33, User_34, ... (77 total)}]
# |   |   |   |   |   |   |   |--- last_resource <= 83.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (84 total)}]
# |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |--- last_resource >  83.50  [last_resource in {User_44, User_45, User_46, User_47, User_48, User_49, ... (61 total)}]
# |   |   |   |   |   |   |   |   |--- requested_amount <= 12250.00
# |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |   |--- requested_amount >  12250.00
# |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |--- last_activity >  14.50  [last_activity in {O_Returned, O_Sent (mail and online), O_Sent (online only), W_Assess potential fraud, W_Call after offers, W_Call incomplete files, ... (10 total)}]
# |   |   |   |   |   |--- last_lifecycle <= 3.50  [last_lifecycle in {ate_abort, complete, resume, schedule}]
# |   |   |   |   |   |   |--- last_event_duration <= 0.07
# |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |--- last_event_duration >  0.07
# |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |--- last_lifecycle >  3.50  [last_lifecycle in {start, suspend, withdraw}]
# |   |   |   |   |   |   |--- last_event_duration <= 0.03
# |   |   |   |   |   |   |   |--- total_elapsed_time <= 252190.31
# |   |   |   |   |   |   |   |   |--- class: A_Complete
# |   |   |   |   |   |   |   |--- total_elapsed_time >  252190.31
# |   |   |   |   |   |   |   |   |--- class: A_Complete
# |   |   |   |   |   |   |--- last_event_duration >  0.03
# |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |--- n_unique_activities >  8.50
# |   |   |   |   |--- last_activity <= 18.00  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (19 total)}]
# |   |   |   |   |   |--- last_activity <= 12.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (13 total)}]
# |   |   |   |   |   |   |--- last_event_duration <= 0.32
# |   |   |   |   |   |   |   |--- last_activity <= 6.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, A_Incomplete}]
# |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |--- last_activity >  6.50  [last_activity in {A_Pending, A_Submitted, A_Validating, O_Accepted, O_Cancelled, O_Create Offer, ... (18 total)}]
# |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |--- last_event_duration >  0.32
# |   |   |   |   |   |   |   |--- last_activity <= 10.00  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (11 total)}]
# |   |   |   |   |   |   |   |   |--- last_event_duration <= 1.07
# |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |--- last_event_duration >  1.07
# |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |--- last_activity >  10.00  [last_activity in {O_Cancelled, O_Create Offer, O_Created, O_Refused, O_Returned, O_Sent (mail and online), ... (14 total)}]
# |   |   |   |   |   |   |   |   |--- last_event_duration <= 936703.72
# |   |   |   |   |   |   |   |   |   |--- last_activity <= 11.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (12 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |   |--- last_activity >  11.50  [last_activity in {O_Create Offer, O_Created, O_Refused, O_Returned, O_Sent (mail and online), O_Sent (online only), ... (13 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 974187.81
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time >  974187.81
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |--- last_event_duration >  936703.72
# |   |   |   |   |   |   |   |   |   |--- class: O_Cancelled
# |   |   |   |   |   |--- last_activity >  12.50  [last_activity in {O_Created, O_Refused, O_Returned, O_Sent (mail and online), O_Sent (online only), W_Assess potential fraud, ... (12 total)}]
# |   |   |   |   |   |   |--- last_activity <= 15.00  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (16 total)}]
# |   |   |   |   |   |   |   |--- total_elapsed_time <= 2330853.38
# |   |   |   |   |   |   |   |   |--- last_event_duration <= 1.62
# |   |   |   |   |   |   |   |   |   |--- class: O_Sent (mail and online)
# |   |   |   |   |   |   |   |   |--- last_event_duration >  1.62
# |   |   |   |   |   |   |   |   |   |--- class: O_Sent (mail and online)
# |   |   |   |   |   |   |   |--- total_elapsed_time >  2330853.38
# |   |   |   |   |   |   |   |   |--- class: O_Sent (mail and online)
# |   |   |   |   |   |   |--- last_activity >  15.00  [last_activity in {O_Sent (mail and online), O_Sent (online only), W_Assess potential fraud, W_Call after offers, W_Call incomplete files, W_Complete application, ... (9 total)}]
# |   |   |   |   |   |   |   |--- n_unique_activities <= 9.50
# |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 1076400.47
# |   |   |   |   |   |   |   |   |   |--- prefix_length <= 14.50
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Complete application
# |   |   |   |   |   |   |   |   |   |--- prefix_length >  14.50
# |   |   |   |   |   |   |   |   |   |   |--- n_unique_resources <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- n_unique_resources >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- total_elapsed_time >  1076400.47
# |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |--- n_unique_activities >  9.50
# |   |   |   |   |   |   |   |   |--- n_unique_activities <= 10.50
# |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |--- n_unique_activities >  10.50
# |   |   |   |   |   |   |   |   |   |--- prefix_length <= 24.50
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |   |--- prefix_length >  24.50
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |--- last_activity >  18.00  [last_activity in {W_Call after offers, W_Call incomplete files, W_Complete application, W_Handle leads, W_Shortened completion , W_Validate application}]
# |   |   |   |   |   |--- last_event_duration <= 0.01
# |   |   |   |   |   |   |--- last_lifecycle <= 3.50  [last_lifecycle in {ate_abort, complete, resume, schedule}]
# |   |   |   |   |   |   |   |--- last_resource <= 84.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (85 total)}]
# |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |--- last_resource >  84.50  [last_resource in {User_45, User_46, User_47, User_48, User_49, User_5, ... (60 total)}]
# |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |--- last_lifecycle >  3.50  [last_lifecycle in {start, suspend, withdraw}]
# |   |   |   |   |   |   |   |--- last_activity <= 21.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (22 total)}]
# |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 585857.88
# |   |   |   |   |   |   |   |   |   |--- loan_goal <= 9.50  [loan_goal in {Boat, Car, Caravan / Camper, Debt restructuring, Existing loan takeover, Extra spending limit, ... (10 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- class: A_Complete
# |   |   |   |   |   |   |   |   |   |--- loan_goal >  9.50  [loan_goal in {Remaining debt home, Tax payments, Unknown}]
# |   |   |   |   |   |   |   |   |   |   |--- class: A_Complete
# |   |   |   |   |   |   |   |   |--- total_elapsed_time >  585857.88
# |   |   |   |   |   |   |   |   |   |--- class: A_Complete
# |   |   |   |   |   |   |   |--- last_activity >  21.50  [last_activity in {W_Handle leads, W_Shortened completion , W_Validate application}]
# |   |   |   |   |   |   |   |   |--- class: A_Validating
# |   |   |   |   |   |--- last_event_duration >  0.01
# |   |   |   |   |   |   |--- last_activity_repeated <= 9.50
# |   |   |   |   |   |   |   |--- last_activity <= 22.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (23 total)}]
# |   |   |   |   |   |   |   |   |--- last_activity_repeated <= 3.50
# |   |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 2397585.00
# |   |   |   |   |   |   |   |   |   |   |--- last_event_duration <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- last_event_duration >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- total_elapsed_time >  2397585.00
# |   |   |   |   |   |   |   |   |   |   |--- class: A_Cancelled
# |   |   |   |   |   |   |   |   |--- last_activity_repeated >  3.50
# |   |   |   |   |   |   |   |   |   |--- last_lifecycle <= 1.00  [last_lifecycle in {ate_abort, complete}]
# |   |   |   |   |   |   |   |   |   |   |--- requested_amount <= 13500.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |   |   |--- requested_amount >  13500.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |   |--- last_lifecycle >  1.00  [last_lifecycle in {resume, schedule, start, suspend, withdraw}]
# |   |   |   |   |   |   |   |   |   |   |--- last_event_duration <= 304189.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- last_event_duration >  304189.22
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |--- last_activity >  22.50  [last_activity in {W_Shortened completion , W_Validate application}]
# |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |--- last_activity_repeated >  9.50
# |   |   |   |   |   |   |   |--- last_lifecycle <= 3.50  [last_lifecycle in {ate_abort, complete, resume, schedule}]
# |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |--- last_lifecycle >  3.50  [last_lifecycle in {start, suspend, withdraw}]
# |   |   |   |   |   |   |   |   |--- class: W_Call incomplete files
# |--- n_unique_activities >  11.50
# |   |--- last_activity <= 23.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (24 total)}]
# |   |   |--- last_lifecycle <= 1.50  [last_lifecycle in {ate_abort, complete}]
# |   |   |   |--- last_activity <= 6.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, A_Incomplete}]
# |   |   |   |   |--- last_activity <= 5.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied}]
# |   |   |   |   |   |--- mean_event_duration <= 81817.02
# |   |   |   |   |   |   |--- last_activity <= 3.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept}]
# |   |   |   |   |   |   |   |--- last_event_duration <= 91.03
# |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |--- last_event_duration >  91.03
# |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 1214457.19
# |   |   |   |   |   |   |   |   |   |--- class: O_Created
# |   |   |   |   |   |   |   |   |--- total_elapsed_time >  1214457.19
# |   |   |   |   |   |   |   |   |   |--- class: O_Cancelled
# |   |   |   |   |   |   |--- last_activity >  3.50  [last_activity in {A_Create Application, A_Denied, A_Incomplete, A_Pending, A_Submitted, A_Validating, ... (21 total)}]
# |   |   |   |   |   |   |   |--- total_elapsed_time <= 1343870.12
# |   |   |   |   |   |   |   |   |--- last_resource <= 129.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (130 total)}]
# |   |   |   |   |   |   |   |   |   |--- class: A_Incomplete
# |   |   |   |   |   |   |   |   |--- last_resource >  129.00  [last_resource in {User_86, User_87, User_88, User_89, User_9, User_90, ... (15 total)}]
# |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |--- total_elapsed_time >  1343870.12
# |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 1839190.81
# |   |   |   |   |   |   |   |   |   |--- class: A_Pending
# |   |   |   |   |   |   |   |   |--- total_elapsed_time >  1839190.81
# |   |   |   |   |   |   |   |   |   |--- class: A_Pending
# |   |   |   |   |   |--- mean_event_duration >  81817.02
# |   |   |   |   |   |   |--- last_event_duration <= 1616546.00
# |   |   |   |   |   |   |   |--- class: O_Cancelled
# |   |   |   |   |   |   |--- last_event_duration >  1616546.00
# |   |   |   |   |   |   |   |--- class: O_Cancelled
# |   |   |   |   |--- last_activity >  5.50  [last_activity in {A_Incomplete, A_Pending, A_Submitted, A_Validating, O_Accepted, O_Cancelled, ... (19 total)}]
# |   |   |   |   |   |--- total_elapsed_time <= 252693.50
# |   |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |   |   |--- total_elapsed_time >  252693.50
# |   |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |--- last_activity >  6.50  [last_activity in {A_Pending, A_Submitted, A_Validating, O_Accepted, O_Cancelled, O_Create Offer, ... (18 total)}]
# |   |   |   |   |--- last_resource <= 0.50  [last_resource in {User_1}]
# |   |   |   |   |   |--- last_lifecycle <= 0.50  [last_lifecycle in {ate_abort}]
# |   |   |   |   |   |   |--- total_elapsed_time <= 2670479.50
# |   |   |   |   |   |   |   |--- class: EOS
# |   |   |   |   |   |   |--- total_elapsed_time >  2670479.50
# |   |   |   |   |   |   |   |--- mean_event_duration <= 139318.16
# |   |   |   |   |   |   |   |   |--- class: EOS
# |   |   |   |   |   |   |   |--- mean_event_duration >  139318.16
# |   |   |   |   |   |   |   |   |--- class: EOS
# |   |   |   |   |   |--- last_lifecycle >  0.50  [last_lifecycle in {complete, resume, schedule, start, suspend, withdraw}]
# |   |   |   |   |   |   |--- total_elapsed_time <= 3661563.75
# |   |   |   |   |   |   |   |--- prefix_length <= 30.50
# |   |   |   |   |   |   |   |   |--- mean_event_duration <= 107496.23
# |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |--- mean_event_duration >  107496.23
# |   |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 3024110.25
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |   |   |--- total_elapsed_time >  3024110.25
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |   |--- prefix_length >  30.50
# |   |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |--- total_elapsed_time >  3661563.75
# |   |   |   |   |   |   |   |--- class: O_Cancelled
# |   |   |   |   |--- last_resource >  0.50  [last_resource in {User_10, User_100, User_101, User_102, User_103, User_104, ... (144 total)}]
# ...
# |   |   |   |   |   |   |   |   |   |--- last_activity <= 10.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (11 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- last_resource <= 3.00  [last_resource in {User_1, User_10, User_100, User_101}]
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |   |   |   |   |   |   |   |--- last_resource >  3.00  [last_resource in {User_102, User_103, User_104, User_105, User_106, User_107, ... (141 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- last_activity >  10.50  [last_activity in {O_Cancelled, O_Create Offer, O_Created, O_Refused, O_Returned, O_Sent (mail and online), ... (14 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- n_unique_resources <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |   |   |--- n_unique_resources >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |   |   |   |   |   |--- last_resource >  13.50  [last_resource in {User_112, User_113, User_114, User_115, User_116, User_117, ... (131 total)}]
# |   |   |   |   |   |   |   |   |   |--- last_event_duration <= 734784.25
# |   |   |   |   |   |   |   |   |   |   |--- last_resource <= 29.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (30 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- last_resource >  29.50  [last_resource in {User_127, User_128, User_129, User_13, User_130, User_131, ... (115 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- last_event_duration >  734784.25
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |--- last_resource >  41.50  [last_resource in {User_138, User_139, User_14, User_140, User_141, User_142, ... (103 total)}]
# |   |   |   |   |   |   |   |   |--- last_resource <= 117.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (118 total)}]
# |   |   |   |   |   |   |   |   |   |--- n_unique_activities <= 13.50
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 606983.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time >  606983.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- n_unique_activities >  13.50
# |   |   |   |   |   |   |   |   |   |   |--- last_resource <= 65.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (66 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- last_resource >  65.50  [last_resource in {User_28, User_29, User_3, User_30, User_31, User_32, ... (79 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- last_resource >  117.50  [last_resource in {User_75, User_76, User_77, User_78, User_79, User_8, ... (27 total)}]
# |   |   |   |   |   |   |   |   |   |--- last_event_duration <= 37580.46
# |   |   |   |   |   |   |   |   |   |   |--- last_resource <= 129.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (130 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- last_resource >  129.50  [last_resource in {User_86, User_87, User_88, User_89, User_9, User_90, ... (15 total)}]
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- last_event_duration >  37580.46
# |   |   |   |   |   |   |   |   |   |   |--- mean_event_duration <= 39050.86
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Pending
# |   |   |   |   |   |   |   |   |   |   |--- mean_event_duration >  39050.86
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Pending
# |   |   |--- last_lifecycle >  1.50  [last_lifecycle in {resume, schedule, start, suspend, withdraw}]
# |   |   |   |--- last_event_duration <= 0.01
# |   |   |   |   |--- last_lifecycle <= 3.50  [last_lifecycle in {ate_abort, complete, resume, schedule}]
# |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |   |--- last_lifecycle >  3.50  [last_lifecycle in {start, suspend, withdraw}]
# |   |   |   |   |   |--- total_elapsed_time <= 3696557.38
# |   |   |   |   |   |   |--- n_unique_activities <= 12.50
# |   |   |   |   |   |   |   |--- class: A_Incomplete
# |   |   |   |   |   |   |--- n_unique_activities >  12.50
# |   |   |   |   |   |   |   |--- prefix_length <= 63.50
# |   |   |   |   |   |   |   |   |--- loan_goal <= 9.50  [loan_goal in {Boat, Car, Caravan / Camper, Debt restructuring, Existing loan takeover, Extra spending limit, ... (10 total)}]
# |   |   |   |   |   |   |   |   |   |--- n_unique_resources <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time <= 2826054.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- total_elapsed_time >  2826054.88
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Incomplete
# |   |   |   |   |   |   |   |   |   |--- n_unique_resources >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- requested_amount <= 11500.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Incomplete
# |   |   |   |   |   |   |   |   |   |   |--- requested_amount >  11500.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Incomplete
# |   |   |   |   |   |   |   |   |--- loan_goal >  9.50  [loan_goal in {Remaining debt home, Tax payments, Unknown}]
# |   |   |   |   |   |   |   |   |   |--- requested_amount <= 25800.00
# |   |   |   |   |   |   |   |   |   |   |--- n_unique_resources <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Incomplete
# |   |   |   |   |   |   |   |   |   |   |--- n_unique_resources >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: A_Incomplete
# |   |   |   |   |   |   |   |   |   |--- requested_amount >  25800.00
# |   |   |   |   |   |   |   |   |   |   |--- class: A_Incomplete
# |   |   |   |   |   |   |   |--- prefix_length >  63.50
# |   |   |   |   |   |   |   |   |--- class: A_Incomplete
# |   |   |   |   |   |--- total_elapsed_time >  3696557.38
# |   |   |   |   |   |   |--- class: A_Incomplete
# |   |   |   |--- last_event_duration >  0.01
# |   |   |   |   |--- n_unique_activities <= 12.50
# |   |   |   |   |   |--- last_event_duration <= 2.14
# |   |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |   |   |--- last_event_duration >  2.14
# |   |   |   |   |   |   |--- total_elapsed_time <= 626310.31
# |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |   |   |--- total_elapsed_time >  626310.31
# |   |   |   |   |   |   |   |--- class: W_Call after offers
# |   |   |   |   |--- n_unique_activities >  12.50
# |   |   |   |   |   |--- last_lifecycle <= 5.50  [last_lifecycle in {ate_abort, complete, resume, schedule, start, suspend}]
# |   |   |   |   |   |   |--- last_event_duration <= 0.19
# |   |   |   |   |   |   |   |--- last_lifecycle <= 3.50  [last_lifecycle in {ate_abort, complete, resume, schedule}]
# |   |   |   |   |   |   |   |   |--- n_unique_activities <= 16.50
# |   |   |   |   |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |   |   |   |   |   |--- n_unique_activities >  16.50
# |   |   |   |   |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |   |   |   |   |--- last_lifecycle >  3.50  [last_lifecycle in {start, suspend, withdraw}]
# |   |   |   |   |   |   |   |   |--- last_resource <= 2.50  [last_resource in {User_1, User_10, User_100}]
# |   |   |   |   |   |   |   |   |   |--- class: A_Incomplete
# |   |   |   |   |   |   |   |   |--- last_resource >  2.50  [last_resource in {User_101, User_102, User_103, User_104, User_105, User_106, ... (142 total)}]
# |   |   |   |   |   |   |   |   |   |--- class: A_Incomplete
# |   |   |   |   |   |   |--- last_event_duration >  0.19
# |   |   |   |   |   |   |   |--- last_event_duration <= 1197462.38
# |   |   |   |   |   |   |   |   |--- last_activity <= 19.50  [last_activity in {A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, A_Denied, ... (20 total)}]
# |   |   |   |   |   |   |   |   |   |--- prefix_length <= 36.50
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |   |   |   |   |   |   |--- prefix_length >  36.50
# |   |   |   |   |   |   |   |   |   |   |--- mean_event_duration <= 42982.11
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |   |   |   |   |   |   |   |--- mean_event_duration >  42982.11
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |   |   |   |   |   |--- last_activity >  19.50  [last_activity in {W_Call incomplete files, W_Complete application, W_Handle leads, W_Shortened completion , W_Validate application}]
# |   |   |   |   |   |   |   |   |   |--- day_in_week <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- last_activity_repeated <= 12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- last_activity_repeated >  12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- day_in_week >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- last_event_duration <= 69.82
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |   |   |   |   |   |   |   |--- last_event_duration >  69.82
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |   |   |   |   |--- last_event_duration >  1197462.38
# |   |   |   |   |   |   |   |   |--- class: W_Call incomplete files
# |   |   |   |   |   |--- last_lifecycle >  5.50  [last_lifecycle in {withdraw}]
# |   |   |   |   |   |   |--- class: EOS
# |   |--- last_activity >  23.50  [last_activity in {W_Validate application}]
# |   |   |--- last_event_duration <= 0.01
# |   |   |   |--- last_activity_repeated <= 1.50
# |   |   |   |   |--- last_lifecycle <= 2.00  [last_lifecycle in {ate_abort, complete, resume}]
# |   |   |   |   |   |--- last_resource <= 139.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (140 total)}]
# |   |   |   |   |   |   |--- total_elapsed_time <= 594141.62
# |   |   |   |   |   |   |   |--- class: EOS
# |   |   |   |   |   |   |--- total_elapsed_time >  594141.62
# |   |   |   |   |   |   |   |--- class: EOS
# |   |   |   |   |   |--- last_resource >  139.00  [last_resource in {User_95, User_96, User_97, User_98, User_99}]
# |   |   |   |   |   |   |--- class: EOS
# |   |   |   |   |--- last_lifecycle >  2.00  [last_lifecycle in {schedule, start, suspend, withdraw}]
# |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |--- last_activity_repeated >  1.50
# |   |   |   |   |--- last_resource <= 0.50  [last_resource in {User_1}]
# |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |--- last_resource >  0.50  [last_resource in {User_10, User_100, User_101, User_102, User_103, User_104, ... (144 total)}]
# |   |   |   |   |   |--- total_elapsed_time <= 3202217.38
# |   |   |   |   |   |   |--- total_elapsed_time <= 355145.11
# |   |   |   |   |   |   |   |--- class: A_Validating
# |   |   |   |   |   |   |--- total_elapsed_time >  355145.11
# |   |   |   |   |   |   |   |--- class: A_Validating
# |   |   |   |   |   |--- total_elapsed_time >  3202217.38
# |   |   |   |   |   |   |--- prefix_length <= 54.50
# |   |   |   |   |   |   |   |--- class: A_Validating
# |   |   |   |   |   |   |--- prefix_length >  54.50
# |   |   |   |   |   |   |   |--- class: A_Validating
# |   |   |--- last_event_duration >  0.01
# |   |   |   |--- n_unique_activities <= 17.50
# |   |   |   |   |--- last_event_duration <= 0.10
# |   |   |   |   |   |--- last_lifecycle <= 2.00  [last_lifecycle in {ate_abort, complete, resume}]
# |   |   |   |   |   |   |--- last_resource <= 139.00  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (140 total)}]
# |   |   |   |   |   |   |   |--- mean_event_duration <= 23400.51
# |   |   |   |   |   |   |   |   |--- class: EOS
# |   |   |   |   |   |   |   |--- mean_event_duration >  23400.51
# |   |   |   |   |   |   |   |   |--- mean_event_duration <= 55685.74
# |   |   |   |   |   |   |   |   |   |--- class: EOS
# |   |   |   |   |   |   |   |   |--- mean_event_duration >  55685.74
# |   |   |   |   |   |   |   |   |   |--- class: EOS
# |   |   |   |   |   |   |--- last_resource >  139.00  [last_resource in {User_95, User_96, User_97, User_98, User_99}]
# |   |   |   |   |   |   |   |--- class: EOS
# |   |   |   |   |   |--- last_lifecycle >  2.00  [last_lifecycle in {schedule, start, suspend, withdraw}]
# |   |   |   |   |   |   |--- last_activity_repeated <= 1.50
# |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |--- last_activity_repeated >  1.50
# |   |   |   |   |   |   |   |--- last_resource <= 14.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, ... (15 total)}]
# |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |--- last_resource >  14.50  [last_resource in {User_113, User_114, User_115, User_116, User_117, User_118, ... (130 total)}]
# |   |   |   |   |   |   |   |   |--- requested_amount <= 6250.00
# |   |   |   |   |   |   |   |   |   |--- class: A_Validating
# |   |   |   |   |   |   |   |   |--- requested_amount >  6250.00
# |   |   |   |   |   |   |   |   |   |--- class: A_Validating
# |   |   |   |   |--- last_event_duration >  0.10
# |   |   |   |   |   |--- last_lifecycle <= 4.50  [last_lifecycle in {ate_abort, complete, resume, schedule, start}]
# |   |   |   |   |   |   |--- last_lifecycle <= 3.50  [last_lifecycle in {ate_abort, complete, resume, schedule}]
# |   |   |   |   |   |   |   |--- mean_event_duration <= 108341.41
# |   |   |   |   |   |   |   |   |--- mean_event_duration <= 63111.21
# |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |--- mean_event_duration >  63111.21
# |   |   |   |   |   |   |   |   |   |--- last_resource <= 7.50  [last_resource in {User_1, User_10, User_100, User_101, User_102, User_103, User_104, User_105}]
# |   |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |   |--- last_resource >  7.50  [last_resource in {User_106, User_107, User_108, User_109, User_11, User_111, ... (137 total)}]
# |   |   |   |   |   |   |   |   |   |   |--- mean_event_duration <= 65046.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |   |   |   |--- mean_event_duration >  65046.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |   |--- mean_event_duration >  108341.41
# |   |   |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |   |   |   |--- last_lifecycle >  3.50  [last_lifecycle in {start, suspend, withdraw}]
# |   |   |   |   |   |   |   |--- class: A_Validating
# |   |   |   |   |   |--- last_lifecycle >  4.50  [last_lifecycle in {suspend, withdraw}]
# |   |   |   |   |   |   |--- class: W_Validate application
# |   |   |   |--- n_unique_activities >  17.50
# |   |   |   |   |--- last_lifecycle <= 0.50  [last_lifecycle in {ate_abort}]
# |   |   |   |   |   |--- class: EOS
# |   |   |   |   |--- last_lifecycle >  0.50  [last_lifecycle in {complete, resume, schedule, start, suspend, withdraw}]
# |   |   |   |   |   |--- class: EOS

# %%
importances = clf_best.feature_importances_
importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': importances,
}).sort_values('importance', ascending=False)

print('Feature importances (CART surrogate):')
display(importance_df)

fig, ax = plt.subplots(figsize=(10, 6))
imp_nz = importance_df[importance_df['importance'] > 0].copy()
ax.barh(imp_nz['feature'], imp_nz['importance'])
ax.set_xlabel('Gini Importance')
ax.set_title('CART Surrogate Feature Importance (BPIC17)')
ax.invert_yaxis()
plt.tight_layout()
plt.show()
# Out:
# Feature importances (CART surrogate):
#                    feature  importance
# 3      n_unique_activities    0.255071
# 1            last_activity    0.243771
# 6      last_event_duration    0.133393
# 14          last_lifecycle    0.126919
# 8            last_resource    0.109155
# 13            credit_score    0.043792
# 0            prefix_length    0.041615
# 4   last_activity_repeated    0.026331
# 5       total_elapsed_time    0.013653
# 7      mean_event_duration    0.003962
# 9       n_unique_resources    0.000921
# 12        requested_amount    0.000744
# 15             day_in_week    0.000380
# 10               loan_goal    0.000289
# 11        application_type    0.000002
# 2           first_activity    0.000000

# %%
from sklearn.tree import _tree


def explain_decision_path(clf, sample, feature_names, cat_cols, cat_mappings):
    """Show the decision path for a single sample through the tree."""
    sample_df = sample.to_frame().T
    node_indicator = clf.decision_path(sample_df)
    node_ids = node_indicator.indices
    tree = clf.tree_

    steps = []
    for node_id in node_ids:
        if tree.feature[node_id] != _tree.TREE_UNDEFINED:
            feat_idx = tree.feature[node_id]
            feat_name = feature_names[feat_idx]
            threshold = tree.threshold[node_id]
            value = sample.iloc[feat_idx]
            direction = '<=' if value <= threshold else '>'

            step = f'{feat_name} = {value:.2f} {direction} {threshold:.2f}'

            if feat_name in cat_cols:
                cats = cat_mappings[feat_name]
                if direction == '<=':
                    incl = [c for i, c in enumerate(cats) if i <= threshold]
                else:
                    incl = [c for i, c in enumerate(cats) if i > threshold]
                preview = ', '.join(incl[:5])
                if len(incl) > 5:
                    preview += f', ... ({len(incl)} total)'
                step += f'  (categories: {preview})'
            steps.append(step)
    return steps


n_examples = 5
rng = np.random.RandomState(42)
example_positions = rng.choice(len(X_test), size=min(n_examples, len(X_test)), replace=False)

for pos in example_positions:
    sample = X_test.iloc[pos]
    lstm_label = y_test[pos]
    surrogate_pred = clf_best.predict(sample.to_frame().T)[0]
    match = 'MATCH' if lstm_label == surrogate_pred else 'MISMATCH'

    la_val = sample['last_activity']
    la_name = cat_mappings['last_activity'][int(la_val)] if 'last_activity' in cat_cols else la_val

    print(f'\n{"=" * 80}')
    print(f'LSTM: {lstm_label} | Surrogate: {surrogate_pred} [{match}]')
    print(f'prefix_len={sample["prefix_length"]:.0f}, last_activity={la_name}')

    path = explain_decision_path(clf_best, sample, feature_names, cat_cols, cat_mappings)
    for i, step in enumerate(path):
        print(f'  Step {i + 1}: {step}')
    print(f'  -> Prediction: {surrogate_pred}')
# Out:
# ================================================================================
# LSTM: W_Complete application | Surrogate: W_Complete application [MATCH]
# prefix_len=10, last_activity=O_Sent (mail and online)
#   Step 1: n_unique_activities = 9.00 <= 11.50
#   Step 2: n_unique_activities = 9.00 > 7.50
#   Step 3: last_resource = 136.00 > 43.00  (categories: User_14, User_140, User_141, User_142, User_143, ... (101 total))
#   Step 4: n_unique_activities = 9.00 > 8.50
#   Step 5: last_activity = 16.00 <= 18.00  (categories: A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, ... (19 total))
#   Step 6: last_activity = 16.00 > 12.50  (categories: O_Created, O_Refused, O_Returned, O_Sent (mail and online), O_Sent (online only), ... (12 total))
#   Step 7: last_activity = 16.00 > 15.00  (categories: O_Sent (mail and online), O_Sent (online only), W_Assess potential fraud, W_Call after offers, W_Call incomplete files, ... (9 total))
#   Step 8: n_unique_activities = 9.00 <= 9.50
#   Step 9: total_elapsed_time = 141516.16 <= 1076400.47
#   Step 10: prefix_length = 10.00 <= 14.50
#   -> Prediction: W_Complete application
#
# ================================================================================
# LSTM: W_Call after offers | Surrogate: W_Call after offers [MATCH]
# prefix_len=21, last_activity=O_Cancelled
#   Step 1: n_unique_activities = 13.00 > 11.50
#   Step 2: last_activity = 11.00 <= 23.50  (categories: A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, ... (24 total))
#   Step 3: last_lifecycle = 1.00 <= 1.50  (categories: ate_abort, complete)
#   Step 4: last_activity = 11.00 > 6.50  (categories: A_Pending, A_Submitted, A_Validating, O_Accepted, O_Cancelled, ... (18 total))
#   Step 5: last_resource = 0.00 <= 0.50  (categories: User_1)
#   Step 6: last_lifecycle = 1.00 > 0.50  (categories: complete, resume, schedule, start, suspend, ... (6 total))
#   Step 7: total_elapsed_time = 2818199.54 <= 3661563.75
#   Step 8: prefix_length = 21.00 <= 30.50
#   Step 9: mean_event_duration = 136623.65 > 107496.23
#   Step 10: total_elapsed_time = 2818199.54 <= 3024110.25
#   -> Prediction: W_Call after offers
#
# ================================================================================
# LSTM: W_Call incomplete files | Surrogate: W_Call incomplete files [MATCH]
# prefix_len=32, last_activity=W_Call incomplete files
#   Step 1: n_unique_activities = 14.00 > 11.50
#   Step 2: last_activity = 20.00 <= 23.50  (categories: A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, ... (24 total))
#   Step 3: last_lifecycle = 2.00 > 1.50  (categories: resume, schedule, start, suspend, withdraw)
#   Step 4: last_event_duration = 70109.19 > 0.01
#   Step 5: n_unique_activities = 14.00 > 12.50
#   Step 6: last_lifecycle = 2.00 <= 5.50  (categories: ate_abort, complete, resume, schedule, start, ... (6 total))
#   Step 7: last_event_duration = 70109.19 > 0.19
#   Step 8: last_event_duration = 70109.19 <= 1197462.38
#   Step 9: last_activity = 20.00 > 19.50  (categories: W_Call incomplete files, W_Complete application, W_Handle leads, W_Shortened completion , W_Validate application)
#   Step 10: day_in_week = 4.00 <= 4.50
#   Step 11: last_activity_repeated = 2.00 <= 12.50
#   Step 12: n_unique_resources = 7.00 <= 11.50
#   Step 13: mean_event_duration = 25056.89 > 20518.62
#   -> Prediction: W_Call incomplete files
#
# ================================================================================
# LSTM: W_Validate application | Surrogate: W_Validate application [MATCH]
# prefix_len=25, last_activity=W_Call after offers
#   Step 1: n_unique_activities = 11.00 <= 11.50
#   Step 2: n_unique_activities = 11.00 > 7.50
#   Step 3: last_resource = 20.00 <= 43.00  (categories: User_1, User_10, User_100, User_101, User_102, ... (44 total))
#   Step 4: last_resource = 20.00 > 13.00  (categories: User_112, User_113, User_114, User_115, User_116, ... (131 total))
#   Step 5: last_lifecycle = 0.00 <= 3.50  (categories: ate_abort, complete, resume, schedule)
#   Step 6: total_elapsed_time = 508966.72 > 153043.38
#   Step 7: last_resource = 20.00 <= 32.50  (categories: User_1, User_10, User_100, User_101, User_102, ... (33 total))
#   Step 8: last_activity = 19.00 > 18.00  (categories: W_Call after offers, W_Call incomplete files, W_Complete application, W_Handle leads, W_Shortened completion , ... (6 total))
#   Step 9: total_elapsed_time = 508966.72 > 250913.73
#   Step 10: total_elapsed_time = 508966.72 <= 2148316.75
#   Step 11: total_elapsed_time = 508966.72 > 391220.89
#   Step 12: last_activity_repeated = 4.00 > 2.50
#   -> Prediction: W_Validate application
#
# ================================================================================
# LSTM: W_Call after offers | Surrogate: W_Call after offers [MATCH]
# prefix_len=18, last_activity=W_Call after offers
#   Step 1: n_unique_activities = 11.00 <= 11.50
#   Step 2: n_unique_activities = 11.00 > 7.50
#   Step 3: last_resource = 76.00 > 43.00  (categories: User_14, User_140, User_141, User_142, User_143, ... (101 total))
#   Step 4: n_unique_activities = 11.00 > 8.50
#   Step 5: last_activity = 19.00 > 18.00  (categories: W_Call after offers, W_Call incomplete files, W_Complete application, W_Handle leads, W_Shortened completion , ... (6 total))
#   Step 6: last_event_duration = 79.99 > 0.01
#   Step 7: last_activity_repeated = 1.00 <= 9.50
#   Step 8: last_activity = 19.00 <= 22.50  (categories: A_Accepted, A_Cancelled, A_Complete, A_Concept, A_Create Application, ... (23 total))
#   Step 9: last_activity_repeated = 1.00 <= 3.50
#   Step 10: total_elapsed_time = 78365.78 <= 2397585.00
#   Step 11: last_event_duration = 79.99 > 0.06
#   Step 12: total_elapsed_time = 78365.78 <= 1799379.88
#   Step 13: last_lifecycle = 5.00 > 1.50  (categories: resume, schedule, start, suspend, withdraw)
#   Step 14: total_elapsed_time = 78365.78 <= 144117.23
#   Step 15: mean_event_duration = 7181.27 <= 10816.05
#   -> Prediction: W_Call after offers
