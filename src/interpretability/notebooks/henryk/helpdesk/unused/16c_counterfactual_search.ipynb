# %% [markdown]
# # 16c — Counterfactual Search — Helpdesk
#
# Loads pre-mined constraints (from 16a) and pre-trained VAE (from 16b),
# then runs REVISED+ counterfactual search. No mining or training happens here.

# %%
import sys
import os
from pathlib import Path

_current = Path().resolve()
while _current != _current.parent:
    if (_current / 'src').is_dir():
        break
    _current = _current.parent

if str(_current) not in sys.path:
    sys.path.insert(0, str(_current))

# src/ must be on sys.path for torch.load to unpickle event_log_loader classes
src_path = str(_current / 'src')
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# %%
# ===== TEST MODE =====
TEST_MODE = False
CONFIG.use_improved = False  # set True for the improved variant
TEST_N_SEQUENCES = 50

# %%
import torch

# --- Load dataset + prediction model ---
data_path = _current / 'encoded_data' / 'test_philipp' / 'helpdesk_all_5_test.pkl'
full_dataset = torch.load(data_path, weights_only=False)

if TEST_MODE:
    dataset = [full_dataset[i] for i in range(min(TEST_N_SEQUENCES, len(full_dataset)))]
    print(f'TEST MODE: Using {len(dataset)} sequences (subset of {len(full_dataset)})')
else:
    dataset = full_dataset

sample = dataset[0]
n_cat = len(sample[0])
n_num = len(sample[1])
seq_len = sample[0][0].shape[0]
print(f'Dataset: {len(dataset)} sequences, {n_cat} cat, {n_num} num, seq_len={seq_len}')

from src.model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model import DropoutUncertaintyEncoderDecoderLSTM

from src.interpretability.config.helpdesk_config import CONFIG
model = DropoutUncertaintyEncoderDecoderLSTM.load(str(CONFIG.get_model_path()), dropout=0.0)
model.eval()
print(f'Model loaded: {sum(p.numel() for p in model.parameters()):,} parameters')

# --- TensorDecoder + activity vocabulary ---
from src.interpretability.utils.tensor_decoder import TensorDecoder

decoder = TensorDecoder(full_dataset)

ACTIVITY_FEATURE = 'Activity'
activity_idx_to_label = decoder.idx_to_label[ACTIVITY_FEATURE]
max_idx = max(activity_idx_to_label.keys())
activity_names = [activity_idx_to_label.get(i, f'<unk_{i}>') for i in range(max_idx + 1)]
eos_idx = next(i for i, name in enumerate(activity_names) if name == 'EOS')

print(f'Activity vocabulary ({len(activity_names)}), EOS={eos_idx}')

# %%
# Load pre-mined constraints + pre-trained VAE
import pickle

constraints_pkl_path = _current / 'encoded_data' / 'helpdesk_constraints.pkl'
with open(constraints_pkl_path, 'rb') as f:
    constraints_data = pickle.load(f)

all_constraints = constraints_data['all']
data_conditions = constraints_data['data_conditions']
print(f'Constraints: {len(all_constraints)} (from {constraints_pkl_path.name})')

vae_path = str(_current / 'encoded_data' / 'helpdesk_vae.pkl')
print(f'VAE path: {vae_path}')
# Out:
# /Users/philippeichhorn/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/lark/utils.py:163: DeprecationWarning: module 'sre_parse' is deprecated
#   import sre_parse
# /Users/philippeichhorn/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/lark/utils.py:164: DeprecationWarning: module 'sre_constants' is deprecated
#   import sre_constants
# Constraints: 23 (from helpdesk_constraints.pkl)
# VAE path: /Users/philippeichhorn/IdeaProjects/XAI-Probabilistic_Suffix_Prediction_U-ED-LSTM_pub/encoded_data/helpdesk_vae.pkl

# %%
from src.interpretability.perturbation_methods import RevisedPlus, RevisedPlusConfig, create_revised_plus_for_model

device = 'mps' if torch.backends.mps.is_available() else 'cpu'

config = RevisedPlusConfig(
    vae_encoder_hidden=50,
    vae_decoder_hidden=50,
    vae_latent_dim=20,
    vae_num_layers=2,
    vae_dropout=0.3,
    vae_kl_weight=0.1,
    n_candidates_per_round=200,
    n_search_rounds=5,
    top_k=5,
    min_plausibility=0.0,
    device=device,
    activity_feature=ACTIVITY_FEATURE,
)

# Create RevisedPlus with pre-mined constraints and pre-trained VAE
# No mining, no training — just loads both
rp = create_revised_plus_for_model(
    model=model,
    dataset=dataset,
    activity_names=activity_names,
    config=config,
    vae_path=vae_path,
    constraints=all_constraints,
    data_conditions=data_conditions,
)
print(f'\nREVISED+ ready (no mining, no training):')
print(f'  VAE parameters: {sum(p.numel() for p in rp.vae.parameters()):,}')
print(f'  All constraints: {len(rp.all_constraints)}')
print(f'  Prefix-safe constraints: {len(rp.prefix_safe_constraints)}')
# Out:
# Using 23 pre-mined constraints (16 prefix-safe, 11 with data conditions)
# Loading VAE from /Users/philippeichhorn/IdeaProjects/XAI-Probabilistic_Suffix_Prediction_U-ED-LSTM_pub/encoded_data/helpdesk_vae.pkl
#
# REVISED+ ready (no mining, no training):
#   VAE parameters: 293,978
#   All constraints: 23
#   Prefix-safe constraints: 16

# %%
import numpy as np
import pandas as pd

# === Scan dataset for candidate sequences ===
N_CANDIDATES = 50
scan_limit = min(500, len(dataset))

candidates = []
seen_cases = set()
for i in range(scan_limit):
    cat_t, num_t, case_id = dataset[i]
    act = cat_t[0]

    # Deduplicate by case (dataset has multiple prefix lengths per case)
    if case_id in seen_cases:
        continue
    seen_cases.add(case_id)

    # Full trace length (non-padding events)
    trace_len = int((act != 0).sum().item())
    act_seq = [activity_names[a.item()] for a in act if a.item() != 0]

    candidates.append({
        'dataset_idx': i,
        'case_id': case_id,
        'trace_len': trace_len,
        'activities': ' -> '.join(act_seq),
    })

    if len(candidates) >= N_CANDIDATES:
        break

df_candidates = pd.DataFrame(candidates)
print(f'Found {len(candidates)} unique cases (scanned {scan_limit})')
print('Set SELECTED_ROW and PREFIX_LEN below to pick a case and prefix length.\n')
display(df_candidates)
# Out:
# Found 50 unique cases (scanned 500)
# Set SELECTED_ROW and PREFIX_LEN below to pick a case and prefix length.
#     dataset_idx    case_id  trace_len  \
# 0             0  Case 1016          5
# 1             6   Case 102          5
# 2            12  Case 1032          5
# 3            19  Case 1034          5
# 4            25  Case 1039          5
# 5            31  Case 1040          5
# 6            37   Case 105          5
# 7            44  Case 1058          5
# 8            51  Case 1061          5
# 9            59  Case 1066          5
# 10           65  Case 1067          5
# 11           71   Case 108          5
# 12           77  Case 1080          5
# 13           86  Case 1085          5
# 14           96   Case 109          5
# 15          104  Case 1092          5
# 16          109   Case 110          5
# 17          115  Case 1100          5
# 18          123  Case 1108          5
# 19          129  Case 1114          5
# 20          142  Case 1123          5
# 21          148  Case 1125          5
# 22          154  Case 1132          5
# 23          160  Case 1134          5
# 24          166  Case 1142          5
# 25          175  Case 1145          5
# 26          182  Case 1150          5
# 27          188  Case 1153          5
# 28          195  Case 1157          5
# 29          201  Case 1161          5
# 30          207  Case 1167          5
# 31          215  Case 1169          5
# 32          220  Case 1170          5
# 33          226  Case 1178          5
# 34          232   Case 118          5
# 35          238  Case 1181          5
# 36          244  Case 1189          5
# 37          252  Case 1190          5
# 38          259  Case 1205          5
# 39          265   Case 121          5
# 40          271  Case 1210          5
# 41          277  Case 1220          5
# 42          283  Case 1224          5
# 43          289  Case 1232          5
# 44          295  Case 1233          5
# 45          301  Case 1235          5
# 46          309  Case 1236          5
# 47          316  Case 1239          5
# 48          323  Case 1242          5
# 49          329  Case 1253          5
#
#                                            activities
# 0   Assign seriousness -> Take in charge ticket ->...
# 1   Assign seriousness -> Take in charge ticket ->...
# 2   Assign seriousness -> Take in charge ticket ->...
# 3   Assign seriousness -> Take in charge ticket ->...
# 4   Assign seriousness -> Take in charge ticket ->...
# 5   Assign seriousness -> Take in charge ticket ->...
# 6   Assign seriousness -> Take in charge ticket ->...
# 7   Assign seriousness -> Take in charge ticket ->...
# 8   Assign seriousness -> Assign seriousness -> Ta...
# 9   Assign seriousness -> Take in charge ticket ->...
# 10  Assign seriousness -> Take in charge ticket ->...
# 11  Assign seriousness -> Take in charge ticket ->...
# 12  Insert ticket -> Assign seriousness -> Take in...
# 13  Assign seriousness -> Take in charge ticket ->...
# 14  Assign seriousness -> Take in charge ticket ->...
# 15  Assign seriousness -> Resolve ticket -> Closed...
# 16  Assign seriousness -> Take in charge ticket ->...
# 17  Assign seriousness -> Take in charge ticket ->...
# 18  Assign seriousness -> Take in charge ticket ->...
# 19  Assign seriousness -> Take in charge ticket ->...
# 20  Assign seriousness -> Take in charge ticket ->...
# 21  Assign seriousness -> Take in charge ticket ->...
# 22  Assign seriousness -> Take in charge ticket ->...
# 23  Assign seriousness -> Take in charge ticket ->...
# 24  Assign seriousness -> Take in charge ticket ->...
# 25  Assign seriousness -> Take in charge ticket ->...
# 26  Assign seriousness -> Take in charge ticket ->...
# 27  Assign seriousness -> Take in charge ticket ->...
# 28  Assign seriousness -> Take in charge ticket ->...
# 29  Assign seriousness -> Take in charge ticket ->...
# 30  Assign seriousness -> Take in charge ticket ->...
# 31  Assign seriousness -> Resolve ticket -> Closed...
# 32  Assign seriousness -> Take in charge ticket ->...
# 33  Assign seriousness -> Take in charge ticket ->...
# 34  Assign seriousness -> Take in charge ticket ->...
# 35  Assign seriousness -> Take in charge ticket ->...
# 36  Assign seriousness -> Take in charge ticket ->...
# 37  Assign seriousness -> Take in charge ticket ->...
# 38  Assign seriousness -> Take in charge ticket ->...
# 39  Assign seriousness -> Take in charge ticket ->...
# 40  Assign seriousness -> Wait -> Resolve ticket -...
# 41  Assign seriousness -> Take in charge ticket ->...
# 42  Assign seriousness -> Take in charge ticket ->...
# 43  Assign seriousness -> Take in charge ticket ->...
# 44  Assign seriousness -> Take in charge ticket ->...
# 45  Assign seriousness -> Take in charge ticket ->...
# 46  Assign seriousness -> Take in charge ticket ->...
# 47  Assign seriousness -> Take in charge ticket ->...
# 48  Assign seriousness -> Take in charge ticket ->...
# 49  Assign seriousness -> Take in charge ticket ->...

# %%
# ============================================
# SELECT A CASE AND PREFIX LENGTH
# ============================================
SELECTED_ROW = 0   # row index in the candidates table above
PREFIX_LEN = 3     # how many events to use as prefix (1 .. trace_len)

# --- Load and truncate to prefix ---
selected = df_candidates.iloc[SELECTED_ROW]
test_idx = selected['dataset_idx']
trace_len = selected['trace_len']
cat_tuple_full, num_tuple_full, case_id = dataset[test_idx]

# Clamp prefix length
prefix_len = max(1, min(PREFIX_LEN, trace_len))
if prefix_len != PREFIX_LEN:
    print(f'Note: PREFIX_LEN clamped to {prefix_len} (trace has {trace_len} events)')

# Build left-padded prefix tensors (keep only first `prefix_len` events)
pad_len = seq_len - prefix_len
cat_tuple = []
for c in cat_tuple_full:
    t = torch.zeros_like(c)
    # Original is left-padded: real events start at (seq_len - trace_len)
    src_start = seq_len - trace_len
    t[pad_len:] = c[src_start:src_start + prefix_len]
    cat_tuple.append(t)
cat_tuple = tuple(cat_tuple)

num_tuple = []
for n in num_tuple_full:
    t = torch.zeros_like(n)
    src_start = seq_len - trace_len
    t[pad_len:] = n[src_start:src_start + prefix_len]
    num_tuple.append(t)
num_tuple = tuple(num_tuple)

# Show what the model predicts for this prefix
prefix_acts = [activity_names[cat_tuple[0][j].item()] for j in range(pad_len, seq_len)]
full_acts = [activity_names[a.item()] for a in cat_tuple_full[0] if a.item() != 0]

cat_in = [c.unsqueeze(0) for c in cat_tuple]
num_in = [n.unsqueeze(0) for n in num_tuple]
with torch.no_grad():
    preds = model((cat_in, num_in))[0]
    logits = preds[0][f'{ACTIVITY_FEATURE}_mean'][0]
    p = torch.softmax(logits, dim=-1)
    top_p, top_idx = p.max(dim=-1)

print(f'Case: {case_id}')
print(f'Full trace ({trace_len}): {" -> ".join(full_acts)}')
print(f'Prefix ({prefix_len}/{trace_len}):  {" -> ".join(prefix_acts)}')
print(f'Predicted next: {activity_names[top_idx.item()]} (p={top_p.item():.3f})')
print()
df_orig = decoder.decode_sequence(cat_tuple, num_tuple, case_id=case_id)
display(df_orig)
# Out:
# Case: Case 1016
# Full trace (5): Assign seriousness -> Take in charge ticket -> Resolve ticket -> Closed -> EOS
# Prefix (3/5):  Assign seriousness -> Take in charge ticket -> Resolve ticket
# Predicted next: Closed (p=0.911)
#                 Activity  Resource Variant index seriousness customer  \
# 0     Assign seriousness   Value 8           1.0     Value 1  Value 8
# 1  Take in charge ticket   Value 8           1.0     Value 1  Value 8
# 2         Resolve ticket  Value 16           1.0     Value 1  Value 8
#
#    product responsible_section seriousness_2 service_level service_type  \
# 0  Value 3             Value 1       Value 2       Value 2      Value 2
# 1  Value 3             Value 1       Value 2       Value 2      Value 2
# 2  Value 3             Value 1       Value 2       Value 2      Value 2
#
#   support_section workgroup  case_elapsed_time  event_elapsed_time  \
# 0         Value 1   Value 2                0.0         963303.3125
# 1         Value 1   Value 2              149.0            148.9375
# 2         Value 1   Value 2            26072.0          25923.0000
#
#    day_in_week  seconds_in_day    Case ID
# 0          2.0    27781.000000  Case 1016
# 1          2.0    27930.000000  Case 1016
# 2          2.0    53852.996094  Case 1016

# %%
# === Run counterfactual search ===
cat_tensors = [c.unsqueeze(0) for c in cat_tuple]
num_tensors = [n.unsqueeze(0) for n in num_tuple]

explanation = rp.explain(cat_tensors, num_tensors, target_class=None)
print(explanation)
# Out:
# Original: Closed (p=0.911), prefix_len=3
# Direct mutations: 630 candidates (3 positions × 15 activities, max 2 positions)
#   → 0 changed prediction, 0 passed scoring
# REVISED+ Counterfactual Explanation
# ============================================================
# Original: Closed (idx=2, p=0.911)
# Prefix length: 3 events
# Target: any different class
# Constraints: 16 prefix-safe, 23 total
# Search: 1630 evaluated, 601 valid, 21.5s
#
# Top 5 counterfactuals:
#   [1] -> Resolve ticket (p=0.620) | prox=8.560 sparse=3 feas=1.196 plaus_def=1.00 plaus_opt=0.91 score=1.2979
#   [2] -> Take in charge ticket (p=0.393) | prox=17.937 sparse=3 feas=1.245 plaus_def=1.00 plaus_opt=0.91 score=1.4982
#   [3] -> EOS (p=0.998) | prox=19.211 sparse=4 feas=2.693 plaus_def=1.00 plaus_opt=1.00 score=1.5695
#   [4] -> EOS (p=0.998) | prox=30.713 sparse=5 feas=3.117 plaus_def=1.00 plaus_opt=1.00 score=1.6956
#   [5] -> EOS (p=0.998) | prox=18.135 sparse=3 feas=3.554 plaus_def=1.00 plaus_opt=1.00 score=1.7332

# %%
# === Display all counterfactuals ===
if not explanation.counterfactuals:
    print('No counterfactuals found. Try increasing n_search_rounds or noise_scale.')
else:
    # --- Summary table ---
    rows = []
    for i, cf in enumerate(explanation.counterfactuals):
        rows.append({
            'rank': i + 1,
            'prediction': cf.counterfactual_prediction_name,
            'probability': f'{cf.counterfactual_probability:.3f}',
            'prefix_len': len(cf.activity_sequence),
            'activities': ' -> '.join(activity_names[a] for a in cf.activity_sequence),
            'proximity': f'{cf.proximity:.2f}',
            'sparsity': cf.sparsity,
            'feasibility': f'{cf.feasibility:.3f}',
            'plaus_def': f'{cf.plausibility_definite:.2f}',
            'plaus_opt': f'{cf.plausibility_optimistic:.2f}',
            'score': f'{cf.combined_score:.4f}',
        })

    print('=' * 100)
    print(f'ORIGINAL PREFIX  —  Case: {case_id}')
    print(f'  Activities: {" -> ".join(activity_names[a] for a in explanation.original_activity_sequence)}')
    print(f'  Prediction: {explanation.original_prediction_name} (p={explanation.original_probability:.3f})')
    print(f'  Prefix length: {explanation.prefix_len} events')
    print('=' * 100)
    display(df_orig)

    print(f'\n{"=" * 100}')
    print(f'ALL COUNTERFACTUALS ({len(explanation.counterfactuals)})')
    print('=' * 100)
    display(pd.DataFrame(rows))

    # --- Detailed view of each counterfactual ---
    for i, cf in enumerate(explanation.counterfactuals):
        print(f'\n{"—" * 100}')
        print(f'COUNTERFACTUAL #{i+1}')
        print(f'  Prediction: {cf.counterfactual_prediction_name} (p={cf.counterfactual_probability:.3f})')
        cf_prefix_len = len(cf.activity_sequence)
        print(f'  Prefix length: {cf_prefix_len} events (delta={cf_prefix_len - explanation.prefix_len:+d})')
        print(f'  Activities: {" -> ".join(activity_names[a] for a in cf.activity_sequence)}')
        print(f'  Proximity: {cf.proximity:.3f}  |  Sparsity: {cf.sparsity}  |  Feasibility: {cf.feasibility:.3f}')
        print(f'  Plausibility (definite): {cf.plausibility_definite:.2f}  |  Plausibility (optimistic): {cf.plausibility_optimistic:.2f}')
        print(f'  Combined score: {cf.combined_score:.4f}')

        cf_cat = tuple(cf.cat_sequence)
        cf_num = tuple(cf.num_sequence[:, j] for j in range(cf.num_sequence.shape[1])) if cf.num_sequence is not None else num_tuple
        df_cf = decoder.decode_sequence(cf_cat, cf_num, skip_padding=False)
        display(df_cf)
# Out:
# ====================================================================================================
# ORIGINAL PREFIX  —  Case: Case 1016
#   Activities: Assign seriousness -> Take in charge ticket -> Resolve ticket
#   Prediction: Closed (p=0.911)
#   Prefix length: 3 events
# ====================================================================================================
#                 Activity  Resource Variant index seriousness customer  \
# 0     Assign seriousness   Value 8           1.0     Value 1  Value 8
# 1  Take in charge ticket   Value 8           1.0     Value 1  Value 8
# 2         Resolve ticket  Value 16           1.0     Value 1  Value 8
#
#    product responsible_section seriousness_2 service_level service_type  \
# 0  Value 3             Value 1       Value 2       Value 2      Value 2
# 1  Value 3             Value 1       Value 2       Value 2      Value 2
# 2  Value 3             Value 1       Value 2       Value 2      Value 2
#
#   support_section workgroup  case_elapsed_time  event_elapsed_time  \
# 0         Value 1   Value 2                0.0         963303.3125
# 1         Value 1   Value 2              149.0            148.9375
# 2         Value 1   Value 2            26072.0          25923.0000
#
#    day_in_week  seconds_in_day    Case ID
# 0          2.0    27781.000000  Case 1016
# 1          2.0    27930.000000  Case 1016
# 2          2.0    53852.996094  Case 1016
# ====================================================================================================
# ALL COUNTERFACTUALS (5)
# ====================================================================================================
#    rank             prediction probability  prefix_len  \
# 0     1         Resolve ticket       0.620           3
# 1     2  Take in charge ticket       0.393           2
# 2     3                    EOS       0.998           4
# 3     4                    EOS       0.998           5
# 4     5                    EOS       0.998           3
#
#                                           activities proximity  sparsity  \
# 0  Assign seriousness -> Take in charge ticket ->...      8.56         3
# 1        Assign seriousness -> Take in charge ticket     17.94         3
# 2  Assign seriousness -> Take in charge ticket ->...     19.21         4
# 3  Assign seriousness -> Take in charge ticket ->...     30.71         5
# 4     Assign seriousness -> Resolve ticket -> Closed     18.13         3
#
#   feasibility plaus_def plaus_opt   score
# 0       1.196      1.00      0.91  1.2979
# 1       1.245      1.00      0.91  1.4982
# 2       2.693      1.00      1.00  1.5695
# 3       3.117      1.00      1.00  1.6956
# 4       3.554      1.00      1.00  1.7332
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# COUNTERFACTUAL #1
#   Prediction: Resolve ticket (p=0.620)
#   Prefix length: 3 events (delta=+0)
#   Activities: Assign seriousness -> Take in charge ticket -> Take in charge ticket
#   Proximity: 8.560  |  Sparsity: 3  |  Feasibility: 1.196
#   Plausibility (definite): 1.00  |  Plausibility (optimistic): 0.91
#   Combined score: 1.2979
#                  Activity  Resource Variant index seriousness customer  \
# 0                   <pad>     <pad>         <pad>       <pad>    <pad>
# 1                   <pad>     <pad>         <pad>       <pad>    <pad>
# 2                   <pad>     <pad>         <pad>       <pad>    <pad>
# 3                   <pad>     <pad>         <pad>       <pad>    <pad>
# 4                   <pad>     <pad>         <pad>       <pad>    <pad>
# 5                   <pad>     <pad>         <pad>       <pad>    <pad>
# 6                   <pad>     <pad>         <pad>       <pad>    <pad>
# 7                   <pad>     <pad>         <pad>       <pad>    <pad>
# 8                   <pad>     <pad>         <pad>       <pad>    <pad>
# 9                   <pad>     <pad>         <pad>       <pad>    <pad>
# 10                  <pad>     <pad>         <pad>       <pad>    <pad>
# 11                  <pad>     <pad>         <pad>       <pad>    <pad>
# 12                  <pad>     <pad>         <pad>       <pad>    <pad>
# 13                  <pad>     <pad>         <pad>       <pad>    <pad>
# 14                  <pad>     <pad>         <pad>       <pad>    <pad>
# 15     Assign seriousness   Value 8           3.0     Value 1  Value 9
# 16  Take in charge ticket   Value 2           3.0     Value 1  Value 8
# 17  Take in charge ticket  Value 16           7.0     Value 1  Value 8
#
#     product responsible_section seriousness_2 service_level service_type  \
# 0     <pad>               <pad>         <pad>         <pad>        <pad>
# 1     <pad>               <pad>         <pad>         <pad>        <pad>
# 2     <pad>               <pad>         <pad>         <pad>        <pad>
# 3     <pad>               <pad>         <pad>         <pad>        <pad>
# 4     <pad>               <pad>         <pad>         <pad>        <pad>
# 5     <pad>               <pad>         <pad>         <pad>        <pad>
# 6     <pad>               <pad>         <pad>         <pad>        <pad>
# 7     <pad>               <pad>         <pad>         <pad>        <pad>
# 8     <pad>               <pad>         <pad>         <pad>        <pad>
# 9     <pad>               <pad>         <pad>         <pad>        <pad>
# 10    <pad>               <pad>         <pad>         <pad>        <pad>
# 11    <pad>               <pad>         <pad>         <pad>        <pad>
# 12    <pad>               <pad>         <pad>         <pad>        <pad>
# 13    <pad>               <pad>         <pad>         <pad>        <pad>
# 14    <pad>               <pad>         <pad>         <pad>        <pad>
# 15  Value 3             Value 1       Value 2       Value 2      Value 2
# 16  Value 3             Value 1       Value 2       Value 2      Value 2
# 17  Value 3             Value 1       Value 2       Value 2      Value 2
#
#    support_section workgroup  case_elapsed_time  event_elapsed_time  \
# 0            <pad>     <pad>       1.156143e+06         963303.3125
# 1            <pad>     <pad>       1.156143e+06         963303.3125
# 2            <pad>     <pad>       1.156143e+06         963303.3125
# 3            <pad>     <pad>       1.156143e+06         963303.3125
# 4            <pad>     <pad>       1.156143e+06         963303.3125
# 5            <pad>     <pad>       1.156143e+06         963303.3125
# 6            <pad>     <pad>       1.156143e+06         963303.3125
# 7            <pad>     <pad>       1.156143e+06         963303.3125
# 8            <pad>     <pad>       1.156143e+06         963303.3125
# 9            <pad>     <pad>       1.156143e+06         963303.3125
# 10           <pad>     <pad>       1.156143e+06         963303.3125
# 11           <pad>     <pad>       1.156143e+06         963303.3125
# 12           <pad>     <pad>       1.156143e+06         963303.3125
# 13           <pad>     <pad>       1.156143e+06         963303.3125
# 14           <pad>     <pad>       1.156143e+06         963303.3125
# 15         Value 1   Value 2       7.508062e+04         918874.5000
# 16         Value 1   Value 2       1.345639e+05         119034.1875
# 17         Value 1   Value 2       1.907548e+05         149436.9375
#
#     day_in_week  seconds_in_day
# 0      2.299828    42690.386719
# 1      2.299828    42690.386719
# 2      2.299828    42690.386719
# 3      2.299828    42690.386719
# 4      2.299828    42690.386719
# 5      2.299828    42690.386719
# 6      2.299828    42690.386719
# 7      2.299828    42690.386719
# 8      2.299828    42690.386719
# 9      2.299828    42690.386719
# 10     2.299828    42690.386719
# 11     2.299828    42690.386719
# 12     2.299828    42690.386719
# 13     2.299828    42690.386719
# 14     2.299828    42690.386719
# 15     2.945460    38122.410156
# 16     2.783394    40897.210938
# 17     2.028107    53434.320312
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# COUNTERFACTUAL #2
#   Prediction: Take in charge ticket (p=0.393)
#   Prefix length: 2 events (delta=-1)
#   Activities: Assign seriousness -> Take in charge ticket
#   Proximity: 17.937  |  Sparsity: 3  |  Feasibility: 1.245
#   Plausibility (definite): 1.00  |  Plausibility (optimistic): 0.91
#   Combined score: 1.4982
#                  Activity Resource Variant index seriousness customer  \
# 0                   <pad>    <pad>         <pad>       <pad>    <pad>
# 1                   <pad>    <pad>         <pad>       <pad>    <pad>
# 2                   <pad>    <pad>         <pad>       <pad>    <pad>
# 3                   <pad>    <pad>         <pad>       <pad>    <pad>
# 4                   <pad>    <pad>         <pad>       <pad>    <pad>
# 5                   <pad>    <pad>         <pad>       <pad>    <pad>
# 6                   <pad>    <pad>         <pad>       <pad>    <pad>
# 7                   <pad>    <pad>         <pad>       <pad>    <pad>
# 8                   <pad>    <pad>         <pad>       <pad>    <pad>
# 9                   <pad>    <pad>         <pad>       <pad>    <pad>
# 10                  <pad>    <pad>         <pad>       <pad>    <pad>
# 11                  <pad>    <pad>         <pad>       <pad>    <pad>
# 12                  <pad>    <pad>         <pad>       <pad>    <pad>
# 13                  <pad>    <pad>         <pad>       <pad>    <pad>
# 14                  <pad>    <pad>         <pad>       <pad>    <pad>
# 15                  <pad>  Value 8         <pad>     Value 1    <pad>
# 16     Assign seriousness  Value 2           3.0     Value 1  Value 9
# 17  Take in charge ticket  Value 2           3.0     Value 1  Value 9
#
#     product responsible_section seriousness_2 service_level service_type  \
# 0     <pad>               <pad>         <pad>         <pad>        <pad>
# 1     <pad>               <pad>         <pad>         <pad>        <pad>
# 2     <pad>               <pad>         <pad>         <pad>        <pad>
# 3     <pad>               <pad>         <pad>         <pad>        <pad>
# 4     <pad>               <pad>         <pad>         <pad>        <pad>
# 5     <pad>               <pad>         <pad>         <pad>        <pad>
# 6     <pad>               <pad>         <pad>         <pad>        <pad>
# 7     <pad>               <pad>         <pad>         <pad>        <pad>
# 8     <pad>               <pad>         <pad>         <pad>        <pad>
# 9     <pad>               <pad>         <pad>         <pad>        <pad>
# 10    <pad>               <pad>         <pad>         <pad>        <pad>
# 11    <pad>               <pad>         <pad>         <pad>        <pad>
# 12    <pad>               <pad>         <pad>         <pad>        <pad>
# 13    <pad>               <pad>         <pad>         <pad>        <pad>
# 14    <pad>               <pad>         <pad>         <pad>        <pad>
# 15  Value 3             Value 1       Value 2       Value 2      Value 1
# 16  Value 3             Value 1       Value 2       Value 2      Value 2
# 17  Value 3             Value 1       Value 2       Value 2      Value 2
#
#    support_section workgroup  case_elapsed_time  event_elapsed_time  \
# 0            <pad>     <pad>        1156142.750         963303.3125
# 1            <pad>     <pad>        1156142.750         963303.3125
# 2            <pad>     <pad>        1156142.750         963303.3125
# 3            <pad>     <pad>        1156142.750         963303.3125
# 4            <pad>     <pad>        1156142.750         963303.3125
# 5            <pad>     <pad>        1156142.750         963303.3125
# 6            <pad>     <pad>        1156142.750         963303.3125
# 7            <pad>     <pad>        1156142.750         963303.3125
# 8            <pad>     <pad>        1156142.750         963303.3125
# 9            <pad>     <pad>        1156142.750         963303.3125
# 10           <pad>     <pad>        1156142.750         963303.3125
# 11           <pad>     <pad>        1156142.750         963303.3125
# 12           <pad>     <pad>        1156142.750         963303.3125
# 13           <pad>     <pad>        1156142.750         963303.3125
# 14           <pad>     <pad>        1156142.750         963303.3125
# 15         Value 1   Value 1        1156142.750         963303.3125
# 16         Value 1   Value 1          66670.000         932257.2500
# 17         Value 1   Value 2         123166.125          92141.5000
#
#     day_in_week  seconds_in_day
# 0      2.299828    42690.386719
# 1      2.299828    42690.386719
# 2      2.299828    42690.386719
# 3      2.299828    42690.386719
# 4      2.299828    42690.386719
# 5      2.299828    42690.386719
# 6      2.299828    42690.386719
# 7      2.299828    42690.386719
# 8      2.299828    42690.386719
# 9      2.299828    42690.386719
# 10     2.299828    42690.386719
# 11     2.299828    42690.386719
# 12     2.299828    42690.386719
# 13     2.299828    42690.386719
# 14     2.299828    42690.386719
# 15     2.299828    42690.386719
# 16     3.168203    32723.416016
# 17     3.227742    36540.949219
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# COUNTERFACTUAL #3
#   Prediction: EOS (p=0.998)
#   Prefix length: 4 events (delta=+1)
#   Activities: Assign seriousness -> Take in charge ticket -> Resolve ticket -> Closed
#   Proximity: 19.211  |  Sparsity: 4  |  Feasibility: 2.693
#   Plausibility (definite): 1.00  |  Plausibility (optimistic): 1.00
#   Combined score: 1.5695
#                  Activity Resource Variant index seriousness  customer  \
# 0                   <pad>    <pad>         <pad>       <pad>     <pad>
# 1                   <pad>    <pad>         <pad>       <pad>     <pad>
# 2                   <pad>    <pad>         <pad>       <pad>     <pad>
# 3                   <pad>    <pad>         <pad>       <pad>     <pad>
# 4                   <pad>    <pad>         <pad>       <pad>     <pad>
# 5                   <pad>    <pad>         <pad>       <pad>     <pad>
# 6                   <pad>    <pad>         <pad>       <pad>     <pad>
# 7                   <pad>    <pad>         <pad>       <pad>     <pad>
# 8                   <pad>    <pad>         <pad>       <pad>     <pad>
# 9                   <pad>    <pad>         <pad>       <pad>     <pad>
# 10                  <pad>    <pad>         <pad>       <pad>     <pad>
# 11                  <pad>    <pad>         <pad>       <pad>     <pad>
# 12                  <pad>    <pad>         <pad>       <pad>     <pad>
# 13                  <pad>    <pad>         <pad>       <pad>     <pad>
# 14     Assign seriousness  Value 1         <pad>       <pad>     <pad>
# 15  Take in charge ticket  Value 6           1.0     Value 1  Value 92
# 16         Resolve ticket  Value 6           1.0     Value 1  Value 92
# 17                 Closed  Value 5           1.0     Value 1  Value 92
#
#     product responsible_section seriousness_2 service_level service_type  \
# 0     <pad>               <pad>         <pad>         <pad>        <pad>
# 1     <pad>               <pad>         <pad>         <pad>        <pad>
# 2     <pad>               <pad>         <pad>         <pad>        <pad>
# 3     <pad>               <pad>         <pad>         <pad>        <pad>
# 4     <pad>               <pad>         <pad>         <pad>        <pad>
# 5     <pad>               <pad>         <pad>         <pad>        <pad>
# 6     <pad>               <pad>         <pad>         <pad>        <pad>
# 7     <pad>               <pad>         <pad>         <pad>        <pad>
# 8     <pad>               <pad>         <pad>         <pad>        <pad>
# 9     <pad>               <pad>         <pad>         <pad>        <pad>
# 10    <pad>               <pad>         <pad>         <pad>        <pad>
# 11    <pad>               <pad>         <pad>         <pad>        <pad>
# 12    <pad>               <pad>         <pad>         <pad>        <pad>
# 13    <pad>               <pad>         <pad>         <pad>        <pad>
# 14    <pad>               <pad>         <pad>         <pad>        <pad>
# 15  Value 3             Value 1       Value 2       Value 2      Value 2
# 16  Value 3             Value 1       Value 2       Value 2      Value 2
# 17  Value 3             Value 1       Value 2       Value 2      Value 2
#
#    support_section workgroup  case_elapsed_time  event_elapsed_time  \
# 0            <pad>     <pad>        1156142.750        9.633033e+05
# 1            <pad>     <pad>        1156142.750        9.633033e+05
# 2            <pad>     <pad>        1156142.750        9.633033e+05
# 3            <pad>     <pad>        1156142.750        9.633033e+05
# 4            <pad>     <pad>        1156142.750        9.633033e+05
# 5            <pad>     <pad>        1156142.750        9.633033e+05
# 6            <pad>     <pad>        1156142.750        9.633033e+05
# 7            <pad>     <pad>        1156142.750        9.633033e+05
# 8            <pad>     <pad>        1156142.750        9.633033e+05
# 9            <pad>     <pad>        1156142.750        9.633033e+05
# 10           <pad>     <pad>        1156142.750        9.633033e+05
# 11           <pad>     <pad>        1156142.750        9.633033e+05
# 12           <pad>     <pad>        1156142.750        9.633033e+05
# 13           <pad>     <pad>        1156142.750        9.633033e+05
# 14           <pad>     <pad>          75344.125        9.505528e+05
# 15         Value 1   Value 2         131389.250        6.320788e+04
# 16         Value 1   Value 2         272430.625        1.743232e+05
# 17         Value 1   Value 2        4086990.750        3.829529e+06
#
#     day_in_week  seconds_in_day
# 0      2.299828    42690.386719
# 1      2.299828    42690.386719
# 2      2.299828    42690.386719
# 3      2.299828    42690.386719
# 4      2.299828    42690.386719
# 5      2.299828    42690.386719
# 6      2.299828    42690.386719
# 7      2.299828    42690.386719
# 8      2.299828    42690.386719
# 9      2.299828    42690.386719
# 10     2.299828    42690.386719
# 11     2.299828    42690.386719
# 12     2.299828    42690.386719
# 13     2.299828    42690.386719
# 14     3.745764    34806.847656
# 15     3.680734    35704.007812
# 16     2.030198    54155.378906
# 17     4.407205    48080.511719
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# COUNTERFACTUAL #4
#   Prediction: EOS (p=0.998)
#   Prefix length: 5 events (delta=+2)
#   Activities: Assign seriousness -> Take in charge ticket -> Resolve ticket -> Resolve ticket -> Closed
#   Proximity: 30.713  |  Sparsity: 5  |  Feasibility: 3.117
#   Plausibility (definite): 1.00  |  Plausibility (optimistic): 1.00
#   Combined score: 1.6956
#                  Activity Resource Variant index seriousness  customer  \
# 0                   <pad>    <pad>         <pad>       <pad>     <pad>
# 1                   <pad>    <pad>         <pad>       <pad>     <pad>
# 2                   <pad>    <pad>         <pad>       <pad>     <pad>
# 3                   <pad>    <pad>         <pad>       <pad>     <pad>
# 4                   <pad>    <pad>         <pad>       <pad>     <pad>
# 5                   <pad>    <pad>         <pad>       <pad>     <pad>
# 6                   <pad>    <pad>         <pad>       <pad>     <pad>
# 7                   <pad>    <pad>         <pad>       <pad>     <pad>
# 8                   <pad>    <pad>         <pad>       <pad>     <pad>
# 9                   <pad>    <pad>         <pad>       <pad>     <pad>
# 10                  <pad>    <pad>         <pad>       <pad>     <pad>
# 11                  <pad>    <pad>         <pad>       <pad>     <pad>
# 12                  <pad>    <pad>         <pad>       <pad>     <pad>
# 13     Assign seriousness  Value 8         <pad>       <pad>     <pad>
# 14  Take in charge ticket  Value 6           1.0     Value 1  Value 92
# 15         Resolve ticket  Value 6           1.0     Value 1   Value 8
# 16         Resolve ticket  Value 6           4.0     Value 1   Value 8
# 17                 Closed  Value 5           4.0     Value 1   Value 8
#
#     product responsible_section seriousness_2 service_level service_type  \
# 0     <pad>               <pad>         <pad>         <pad>        <pad>
# 1     <pad>               <pad>         <pad>         <pad>        <pad>
# 2     <pad>               <pad>         <pad>         <pad>        <pad>
# 3     <pad>               <pad>         <pad>         <pad>        <pad>
# 4     <pad>               <pad>         <pad>         <pad>        <pad>
# 5     <pad>               <pad>         <pad>         <pad>        <pad>
# 6     <pad>               <pad>         <pad>         <pad>        <pad>
# 7     <pad>               <pad>         <pad>         <pad>        <pad>
# 8     <pad>               <pad>         <pad>         <pad>        <pad>
# 9     <pad>               <pad>         <pad>         <pad>        <pad>
# 10    <pad>               <pad>         <pad>         <pad>        <pad>
# 11    <pad>               <pad>         <pad>         <pad>        <pad>
# 12    <pad>               <pad>         <pad>         <pad>        <pad>
# 13    <pad>               <pad>         <pad>         <pad>        <pad>
# 14  Value 3             Value 1       Value 2       Value 2      Value 2
# 15  Value 3             Value 1       Value 2       Value 2      Value 2
# 16  Value 3             Value 1       Value 2       Value 2      Value 2
# 17  Value 3             Value 1       Value 2       Value 2      Value 2
#
#    support_section workgroup  case_elapsed_time  event_elapsed_time  \
# 0            <pad>     <pad>       1.156143e+06        9.633033e+05
# 1            <pad>     <pad>       1.156143e+06        9.633033e+05
# 2            <pad>     <pad>       1.156143e+06        9.633033e+05
# 3            <pad>     <pad>       1.156143e+06        9.633033e+05
# 4            <pad>     <pad>       1.156143e+06        9.633033e+05
# 5            <pad>     <pad>       1.156143e+06        9.633033e+05
# 6            <pad>     <pad>       1.156143e+06        9.633033e+05
# 7            <pad>     <pad>       1.156143e+06        9.633033e+05
# 8            <pad>     <pad>       1.156143e+06        9.633033e+05
# 9            <pad>     <pad>       1.156143e+06        9.633033e+05
# 10           <pad>     <pad>       1.156143e+06        9.633033e+05
# 11           <pad>     <pad>       1.156143e+06        9.633033e+05
# 12           <pad>     <pad>       1.156143e+06        9.633033e+05
# 13           <pad>     <pad>       6.142838e+04        9.319342e+05
# 14         Value 1   Value 2       1.315695e+05        1.090195e+05
# 15         Value 1   Value 2       1.906247e+05        1.023151e+05
# 16         Value 1   Value 2       9.213086e+05        8.187137e+05
# 17         Value 1   Value 2       4.432248e+06        3.970865e+06
#
#     day_in_week  seconds_in_day
# 0      2.299828    42690.386719
# 1      2.299828    42690.386719
# 2      2.299828    42690.386719
# 3      2.299828    42690.386719
# 4      2.299828    42690.386719
# 5      2.299828    42690.386719
# 6      2.299828    42690.386719
# 7      2.299828    42690.386719
# 8      2.299828    42690.386719
# 9      2.299828    42690.386719
# 10     2.299828    42690.386719
# 11     2.299828    42690.386719
# 12     2.299828    42690.386719
# 13     2.141478    30335.144531
# 14     2.418500    33493.714844
# 15     2.715877    53718.441406
# 16     1.366830    39692.144531
# 17     3.551384    42688.121094
# ————————————————————————————————————————————————————————————————————————————————————————————————————
# COUNTERFACTUAL #5
#   Prediction: EOS (p=0.998)
#   Prefix length: 3 events (delta=+0)
#   Activities: Assign seriousness -> Resolve ticket -> Closed
#   Proximity: 18.135  |  Sparsity: 3  |  Feasibility: 3.554
#   Plausibility (definite): 1.00  |  Plausibility (optimistic): 1.00
#   Combined score: 1.7332
#               Activity Resource Variant index seriousness  customer  product  \
# 0                <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 1                <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 2                <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 3                <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 4                <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 5                <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 6                <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 7                <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 8                <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 9                <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 10               <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 11               <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 12               <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 13               <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 14               <pad>    <pad>         <pad>       <pad>     <pad>    <pad>
# 15  Assign seriousness  Value 1           1.0     Value 1  Value 92  Value 3
# 16      Resolve ticket  Value 6           1.0     Value 1  Value 92  Value 3
# 17              Closed  Value 5           1.0     Value 1   Value 9  Value 3
#
#    responsible_section seriousness_2 service_level service_type  \
# 0                <pad>         <pad>         <pad>        <pad>
# 1                <pad>         <pad>         <pad>        <pad>
# 2                <pad>         <pad>         <pad>        <pad>
# 3                <pad>         <pad>         <pad>        <pad>
# 4                <pad>         <pad>         <pad>        <pad>
# 5                <pad>         <pad>         <pad>        <pad>
# 6                <pad>         <pad>         <pad>        <pad>
# 7                <pad>         <pad>         <pad>        <pad>
# 8                <pad>         <pad>         <pad>        <pad>
# 9                <pad>         <pad>         <pad>        <pad>
# 10               <pad>         <pad>         <pad>        <pad>
# 11               <pad>         <pad>         <pad>        <pad>
# 12               <pad>         <pad>         <pad>        <pad>
# 13               <pad>         <pad>         <pad>        <pad>
# 14               <pad>         <pad>         <pad>        <pad>
# 15             Value 1       Value 2       Value 2      Value 1
# 16             Value 1       Value 2       Value 2      Value 2
# 17             Value 1       Value 2       Value 2      Value 1
#
#    support_section workgroup  case_elapsed_time  event_elapsed_time  \
# 0            <pad>     <pad>        1156142.750        9.633033e+05
# 1            <pad>     <pad>        1156142.750        9.633033e+05
# 2            <pad>     <pad>        1156142.750        9.633033e+05
# 3            <pad>     <pad>        1156142.750        9.633033e+05
# 4            <pad>     <pad>        1156142.750        9.633033e+05
# 5            <pad>     <pad>        1156142.750        9.633033e+05
# 6            <pad>     <pad>        1156142.750        9.633033e+05
# 7            <pad>     <pad>        1156142.750        9.633033e+05
# 8            <pad>     <pad>        1156142.750        9.633033e+05
# 9            <pad>     <pad>        1156142.750        9.633033e+05
# 10           <pad>     <pad>        1156142.750        9.633033e+05
# 11           <pad>     <pad>        1156142.750        9.633033e+05
# 12           <pad>     <pad>        1156142.750        9.633033e+05
# 13           <pad>     <pad>        1156142.750        9.633033e+05
# 14           <pad>     <pad>        1156142.750        9.633033e+05
# 15         Value 1   Value 1          43528.125        9.085219e+05
# 16         Value 1   Value 2         194419.750        1.565508e+05
# 17         Value 1   Value 1        3460519.750        3.297372e+06
#
#     day_in_week  seconds_in_day
# 0      2.299828    42690.386719
# 1      2.299828    42690.386719
# 2      2.299828    42690.386719
# 3      2.299828    42690.386719
# 4      2.299828    42690.386719
# 5      2.299828    42690.386719
# 6      2.299828    42690.386719
# 7      2.299828    42690.386719
# 8      2.299828    42690.386719
# 9      2.299828    42690.386719
# 10     2.299828    42690.386719
# 11     2.299828    42690.386719
# 12     2.299828    42690.386719
# 13     2.299828    42690.386719
# 14     2.299828    42690.386719
# 15     3.258226    28681.632812
# 16     1.820193    34883.878906
# 17     4.690962    55281.687500
