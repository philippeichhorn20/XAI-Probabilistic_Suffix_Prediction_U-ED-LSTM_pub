# %% [markdown]
# # MP-Declare Constraint Mining
#
# Mining MP-Declare constraints with data conditions from the Helpdesk event log using RuM's MINERful + MpEnhancer.

# %%
import sys
import os
from pathlib import Path

os.environ['JAVA_HOME'] = '/opt/homebrew/opt/openjdk@21/libexec/openjdk.jdk/Contents/Home'

_current = Path().resolve()
while _current != _current.parent:
    if (_current / 'src').is_dir():
        break
    _current = _current.parent

if str(_current) not in sys.path:
    sys.path.insert(0, str(_current))

from src.interpretability.perturbation_methods import csv_to_xes, discover_mpdeclare
# Out:
# /Users/philippeichhorn/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/lark/utils.py:163: DeprecationWarning: module 'sre_parse' is deprecated
#   import sre_parse
# /Users/philippeichhorn/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/lark/utils.py:164: DeprecationWarning: module 'sre_constants' is deprecated
#   import sre_constants

# %%
csv_path = _current / 'data' / 'helpdesk.csv'
xes_path = _current / 'data' / 'helpdesk.xes'

csv_to_xes(csv_path, xes_path, case_id_col="Case ID", activity_col="Activity", timestamp_col="Complete Timestamp")
print("Converted CSV to XES")
# Out:
# /Users/philippeichhorn/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/pm4py/utils.py:1000: UserWarning: Install the optional requirement `rustxes` to import/export files faster.
#   warnings.warn(
# exporting log, completed traces ::   0%|          | 0/4580 [00:00<?, ?it/s]
# Converted CSV to XES

# %%
# Mine MP-Declare constraints with data conditions
# data_conditions: "ACTIVATIONS" mines conditions on activation event attributes
#                  "CORRELATIONS" mines correlations between activation/target (may fail with timestamps)
#                  "NONE" mines activity-only constraints
constraints = discover_mpdeclare(xes_path, min_support=0.99, data_conditions='ACTIVATIONS')
print(f"Mined {len(constraints)} MP-Declare constraints")
# Out:
# log4j:WARN No appenders could be found for logger (minerful.miner.core.MinerFulKBCore).
# log4j:WARN Please initialize the log4j system properly.
# log4j:WARN See http://logging.apache.org/log4j/1.2/faq.html#noconfig for more info.
# ||||||||||||||||||||||||||||||||||||||||
# 2026-03-01 11:44:31,753 INFO    [main] task.discovery.mp_enhancer.MpEnhancer - MpEnhancer (588449070) started at: 1772361871751
# 2026-03-01 11:44:31,756 DEBUG   [main] task.discovery.mp_enhancer.CorrelationMiner - Number of constraints to process: 5
# 2026-03-01 11:44:31,758 DEBUG   [main] task.discovery.mp_enhancer.CorrelationMiner - Processing constraint 1: Constraint(supp=0.9963548): Response[Assign seriousness, Closed] | |
# Mar 01, 2026 11:44:34 AM com.github.fommil.jni.JniNamer arch
# WARNING: unrecognised architecture: aarch64
# Mar 01, 2026 11:44:34 AM com.github.fommil.netlib.ARPACK <clinit>
# WARNING: Failed to load implementation from: com.github.fommil.netlib.NativeSystemARPACK
# Mar 01, 2026 11:44:34 AM com.github.fommil.jni.JniNamer arch
# WARNING: unrecognised architecture: aarch64
# Mar 01, 2026 11:44:34 AM com.github.fommil.netlib.ARPACK <clinit>
# WARNING: Failed to load implementation from: com.github.fommil.netlib.NativeRefARPACK
# 2026-03-01 11:44:46,557 DEBUG   [main] task.discovery.mp_enhancer.CorrelationMiner - Processing constraint 2: Constraint(supp=1.0): Precedence[Require upgrade, Assign seriousness] | |
# 2026-03-01 11:44:46,576 DEBUG   [main] task.discovery.mp_enhancer.CorrelationMiner - Processing constraint 3: Constraint(supp=0.9983799): Response[Assign seriousness, Resolve ticket] | |
# 2026-03-01 11:45:02,576 DEBUG   [main] task.discovery.mp_enhancer.CorrelationMiner - Processing constraint 4: Constraint(supp=0.9979932): Response[Resolve ticket, Closed] | |
# 2026-03-01 11:45:23,045 DEBUG   [main] task.discovery.mp_enhancer.CorrelationMiner - Processing constraint 5: Constraint(supp=1.0): Precedence[Closed, Resolve ticket] | |
# 2026-03-01 11:45:23,199 INFO    [main] task.discovery.mp_enhancer.MpEnhancer - MpEnhancer (588449070) completed at: 1772361923198 - total time: 51447
# Mined 11 MP-Declare constraints

# %%
# Show constraints WITH data conditions
print("=" * 100)
print("MP-DECLARE CONSTRAINTS WITH DATA CONDITIONS")
print("=" * 100)
print()

with_data = [c for c in constraints if c.data_condition]
print(f"Found {len(with_data)} constraints with data conditions:\n")

for i, c in enumerate(with_data, 1):
    print(f"{i}. {c.template}[{c.activation}, {c.target}]")
    print(f"   Support: {c.support:.1%}")
    print(f"   Data condition: {c.data_condition}")
    print()
# Out:
# ====================================================================================================
# MP-DECLARE CONSTRAINTS WITH DATA CONDITIONS
# ====================================================================================================
#
# Found 0 constraints with data conditions:

# %%
# Show ALL constraints
print("=" * 100)
print("ALL MINED CONSTRAINTS")
print("=" * 100)
print()

for i, c in enumerate(constraints, 1):
    print(f"{i:3}. {c}")
# Out:
# ====================================================================================================
# ALL MINED CONSTRAINTS
# ====================================================================================================
#
#   1. Absence[Activity: "DUPLICATE" (supp=0.99978167)] (support=100.0%)
#   2. Absence[Activity: "INVALID" (supp=0.99956334)] (support=100.0%)
#   3. Absence[Activity: "RESOLVED" (supp=0.99956334)] (support=100.0%)
#   4. Absence[Activity: "Resolve SW anomaly" (supp=0.9982533)] (support=99.8%)
#   5. Absence[Activity: "Schedule intervention" (supp=0.9989083)] (support=99.9%)
#   6. Absence[Activity: "VERIFIED" (supp=0.999345)] (support=99.9%)
#   7. Response[Activity: "Assign seriousness" (supp=0.9963548), Activity: "Closed" (supp=0.9963548)] (support=99.6%)
#   8. Precedence[Activity: "Assign seriousness" (supp=1.0), Activity: "Require upgrade" (supp=1.0)] (support=100.0%)
#   9. Response[Activity: "Assign seriousness" (supp=0.9983799), Activity: "Resolve ticket" (supp=0.9983799)] (support=99.8%)
#  10. Response[Activity: "Resolve ticket" (supp=0.9979932), Activity: "Closed" (supp=0.9979932)] (support=99.8%)
#  11. Precedence[Activity: "Resolve ticket" (supp=1.0), Activity: "Closed" (supp=1.0)] (support=100.0%)

# %% [markdown]
# # REVISED+ Counterfactual Explanations
#
# Generate counterfactual prefixes using the REVISED+ orchestrator:
# - VAE trained on **random-length prefixes** (learns the prefix manifold)
# - **Two-tier plausibility**: prefix-safe constraints for search penalty, all constraints for validity gate
# - Latent space elite-sampling search

# %%
import torch

# Add src to path for event_log_loader module (needed by torch.load)
import sys
src_path = str(_current / 'src')
if src_path not in sys.path:
    sys.path.insert(0, src_path)

# --- Load dataset ---
data_path = _current / 'encoded_data' / 'test_philipp' / 'helpdesk_all_5_test.pkl'
dataset = torch.load(data_path, weights_only=False)

sample = dataset[0]
n_cat = len(sample[0])
n_num = len(sample[1])
seq_len = sample[0][0].shape[0]
print(f"Dataset: {len(dataset)} sequences, {n_cat} cat, {n_num} num, seq_len={seq_len}")

# --- Load trained prediction model ---
from src.model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model import DropoutUncertaintyEncoderDecoderLSTM

from src.interpretability.config.helpdesk_config import CONFIG
CONFIG.use_improved = False  # set True for the improved variant
model = DropoutUncertaintyEncoderDecoderLSTM.load(str(CONFIG.get_model_path()), dropout=0.0)
model.eval()
print(f"Model loaded: {sum(p.numel() for p in model.parameters()):,} parameters")

# %%
# --- Setup TensorDecoder and activity names ---
from src.interpretability.utils.tensor_decoder import TensorDecoder

decoder = TensorDecoder(dataset)

# Build activity_names list: index -> name (for the REVISED+ orchestrator)
activity_idx_to_label = decoder.idx_to_label['Activity']
max_idx = max(activity_idx_to_label.keys())
activity_names = [activity_idx_to_label.get(i, f'<unk_{i}>') for i in range(max_idx + 1)]

print(f"Activity vocabulary ({len(activity_names)}):")
for i, name in enumerate(activity_names):
    print(f"  {i}: {name}")
# Out:
# Activity vocabulary (16):
#   0: <pad>
#   1: Assign seriousness
#   2: Closed
#   3: Create SW anomaly
#   4: DUPLICATE
#   5: EOS
#   6: INVALID
#   7: Insert ticket
#   8: RESOLVED
#   9: Require upgrade
#   10: Resolve SW anomaly
#   11: Resolve ticket
#   12: Schedule intervention
#   13: Take in charge ticket
#   14: VERIFIED
#   15: Wait

# %%
# --- Create and fit REVISED+ ---
# This trains the VAE on random-length prefixes and mines Declare constraints.
# The VAE is saved to disk after first training and loaded on subsequent runs.
from src.interpretability.perturbation_methods import RevisedPlus, RevisedPlusConfig, create_revised_plus_for_model

device = 'mps' if torch.backends.mps.is_available() else 'cpu'

config = RevisedPlusConfig(
    vae_epochs=100,
    vae_kl_weight=0.1,
    declare_min_support=0.9,
    n_candidates_per_round=200,
    n_search_rounds=5,
    top_k=5,
    min_plausibility=0.0,  # no hard filter for now
    device=device,
)

vae_path = str(_current / 'encoded_data' / 'test_philipp' / 'helpdesk_vae.pkl')

rp = create_revised_plus_for_model(
    model=model,
    dataset=dataset,
    activity_names=activity_names,
    config=config,
    vae_path=vae_path,
)
print(f"\nREVISED+ ready:")
print(f"  VAE parameters: {sum(p.numel() for p in rp.vae.parameters()):,}")
print(f"  VAE path: {vae_path}")
print(f"  All constraints: {len(rp.all_constraints)}")
print(f"  Prefix-safe constraints: {len(rp.prefix_safe_constraints)}")
# Out:
# Loading VAE from /Users/philippeichhorn/IdeaProjects/XAI-Probabilistic_Suffix_Prediction_U-ED-LSTM_pub/encoded_data/test_philipp/helpdesk_vae.pkl
# Extracting activity sequences...
# Mined 1088 constraints (507 prefix-safe)
#
# REVISED+ ready:
#   VAE parameters: 278,487
#   VAE path: /Users/philippeichhorn/IdeaProjects/XAI-Probabilistic_Suffix_Prediction_U-ED-LSTM_pub/encoded_data/test_philipp/helpdesk_vae.pkl
#   All constraints: 1088
#   Prefix-safe constraints: 507

# %%
# --- Show mined Declare constraints with human-readable names ---
print("PREFIX-SAFE constraints (used in search penalty):")
print("-" * 60)
for c in sorted(rp.prefix_safe_constraints, key=lambda x: (x.template.value, x.activities)):
    print(f"  {c.format(activity_names)}")

print(f"\nNOT prefix-safe constraints (used in validity gate):")
print("-" * 60)
not_safe = rp.all_constraints - rp.prefix_safe_constraints
for c in sorted(not_safe, key=lambda x: (x.template.value, x.activities)):
    print(f"  {c.format(activity_names)}")
# Out:
# PREFIX-SAFE constraints (used in search penalty):
# ------------------------------------------------------------
#   absence(Create SW anomaly, n=1)
#   absence(INVALID, n=1)
#   absence(Insert ticket, n=1)
#   absence(RESOLVED, n=1)
#   absence(Require upgrade, n=1)
#   absence(Resolve SW anomaly, n=1)
#   absence(Schedule intervention, n=1)
#   absence(VERIFIED, n=1)
#   alternate_precedence(Assign seriousness, Closed)
#   alternate_precedence(Assign seriousness, Create SW anomaly)
#   alternate_precedence(Assign seriousness, INVALID)
#   alternate_precedence(Assign seriousness, Insert ticket)
#   alternate_precedence(Assign seriousness, RESOLVED)
#   alternate_precedence(Assign seriousness, Require upgrade)
#   alternate_precedence(Assign seriousness, Resolve SW anomaly)
#   alternate_precedence(Assign seriousness, Schedule intervention)
#   alternate_precedence(Assign seriousness, VERIFIED)
#   alternate_precedence(Assign seriousness, Wait)
#   alternate_precedence(Closed, Create SW anomaly)
#   alternate_precedence(Closed, INVALID)
#   alternate_precedence(Closed, Insert ticket)
#   alternate_precedence(Closed, RESOLVED)
#   alternate_precedence(Closed, Require upgrade)
#   alternate_precedence(Closed, Resolve SW anomaly)
#   alternate_precedence(Closed, Schedule intervention)
#   alternate_precedence(Closed, VERIFIED)
#   alternate_precedence(Create SW anomaly, INVALID)
#   alternate_precedence(Create SW anomaly, Insert ticket)
#   alternate_precedence(Create SW anomaly, RESOLVED)
#   alternate_precedence(Create SW anomaly, Require upgrade)
#   alternate_precedence(Create SW anomaly, Resolve SW anomaly)
#   alternate_precedence(Create SW anomaly, Schedule intervention)
#   alternate_precedence(Create SW anomaly, VERIFIED)
#   alternate_precedence(EOS, Create SW anomaly)
#   alternate_precedence(EOS, INVALID)
#   alternate_precedence(EOS, Insert ticket)
#   alternate_precedence(EOS, RESOLVED)
#   alternate_precedence(EOS, Require upgrade)
#   alternate_precedence(EOS, Resolve SW anomaly)
#   alternate_precedence(EOS, Schedule intervention)
#   alternate_precedence(EOS, VERIFIED)
#   alternate_precedence(INVALID, Create SW anomaly)
#   alternate_precedence(INVALID, Insert ticket)
#   alternate_precedence(INVALID, RESOLVED)
#   alternate_precedence(INVALID, Require upgrade)
#   alternate_precedence(INVALID, Resolve SW anomaly)
#   alternate_precedence(INVALID, Schedule intervention)
#   alternate_precedence(INVALID, VERIFIED)
#   alternate_precedence(Insert ticket, Create SW anomaly)
#   alternate_precedence(Insert ticket, INVALID)
#   alternate_precedence(Insert ticket, RESOLVED)
#   alternate_precedence(Insert ticket, Require upgrade)
#   alternate_precedence(Insert ticket, Resolve SW anomaly)
#   alternate_precedence(Insert ticket, Schedule intervention)
#   alternate_precedence(Insert ticket, VERIFIED)
#   alternate_precedence(RESOLVED, Create SW anomaly)
#   alternate_precedence(RESOLVED, INVALID)
#   alternate_precedence(RESOLVED, Insert ticket)
#   alternate_precedence(RESOLVED, Require upgrade)
#   alternate_precedence(RESOLVED, Resolve SW anomaly)
#   alternate_precedence(RESOLVED, Schedule intervention)
#   alternate_precedence(RESOLVED, VERIFIED)
#   alternate_precedence(Require upgrade, Create SW anomaly)
#   alternate_precedence(Require upgrade, INVALID)
#   alternate_precedence(Require upgrade, Insert ticket)
#   alternate_precedence(Require upgrade, RESOLVED)
#   alternate_precedence(Require upgrade, Resolve SW anomaly)
#   alternate_precedence(Require upgrade, Schedule intervention)
#   alternate_precedence(Require upgrade, VERIFIED)
#   alternate_precedence(Resolve SW anomaly, Create SW anomaly)
#   alternate_precedence(Resolve SW anomaly, INVALID)
#   alternate_precedence(Resolve SW anomaly, Insert ticket)
#   alternate_precedence(Resolve SW anomaly, RESOLVED)
#   alternate_precedence(Resolve SW anomaly, Require upgrade)
#   alternate_precedence(Resolve SW anomaly, Schedule intervention)
#   alternate_precedence(Resolve SW anomaly, VERIFIED)
#   alternate_precedence(Resolve ticket, Closed)
#   alternate_precedence(Resolve ticket, Create SW anomaly)
#   alternate_precedence(Resolve ticket, INVALID)
#   alternate_precedence(Resolve ticket, Insert ticket)
#   alternate_precedence(Resolve ticket, RESOLVED)
#   alternate_precedence(Resolve ticket, Require upgrade)
#   alternate_precedence(Resolve ticket, Resolve SW anomaly)
#   alternate_precedence(Resolve ticket, Schedule intervention)
#   alternate_precedence(Resolve ticket, VERIFIED)
#   alternate_precedence(Schedule intervention, Create SW anomaly)
#   alternate_precedence(Schedule intervention, INVALID)
#   alternate_precedence(Schedule intervention, Insert ticket)
#   alternate_precedence(Schedule intervention, RESOLVED)
#   alternate_precedence(Schedule intervention, Require upgrade)
#   alternate_precedence(Schedule intervention, Resolve SW anomaly)
#   alternate_precedence(Schedule intervention, VERIFIED)
#   alternate_precedence(Take in charge ticket, Closed)
#   alternate_precedence(Take in charge ticket, Create SW anomaly)
#   alternate_precedence(Take in charge ticket, INVALID)
#   alternate_precedence(Take in charge ticket, Insert ticket)
#   alternate_precedence(Take in charge ticket, RESOLVED)
#   alternate_precedence(Take in charge ticket, Require upgrade)
#   alternate_precedence(Take in charge ticket, Resolve SW anomaly)
#   alternate_precedence(Take in charge ticket, Resolve ticket)
#   alternate_precedence(Take in charge ticket, Schedule intervention)
#   alternate_precedence(Take in charge ticket, VERIFIED)
#   alternate_precedence(Take in charge ticket, Wait)
#   alternate_precedence(VERIFIED, Create SW anomaly)
#   alternate_precedence(VERIFIED, INVALID)
#   alternate_precedence(VERIFIED, Insert ticket)
#   alternate_precedence(VERIFIED, RESOLVED)
#   alternate_precedence(VERIFIED, Require upgrade)
#   alternate_precedence(VERIFIED, Resolve SW anomaly)
#   alternate_precedence(VERIFIED, Schedule intervention)
#   alternate_precedence(Wait, Create SW anomaly)
#   alternate_precedence(Wait, INVALID)
#   alternate_precedence(Wait, Insert ticket)
#   alternate_precedence(Wait, RESOLVED)
#   alternate_precedence(Wait, Require upgrade)
#   alternate_precedence(Wait, Resolve SW anomaly)
#   alternate_precedence(Wait, Schedule intervention)
#   alternate_precedence(Wait, VERIFIED)
#   chain_precedence(Assign seriousness, Create SW anomaly)
#   chain_precedence(Assign seriousness, INVALID)
#   chain_precedence(Assign seriousness, Insert ticket)
#   chain_precedence(Assign seriousness, RESOLVED)
#   chain_precedence(Assign seriousness, Require upgrade)
#   chain_precedence(Assign seriousness, Resolve SW anomaly)
#   chain_precedence(Assign seriousness, Schedule intervention)
#   chain_precedence(Assign seriousness, VERIFIED)
#   chain_precedence(Closed, Create SW anomaly)
#   chain_precedence(Closed, INVALID)
#   chain_precedence(Closed, Insert ticket)
#   chain_precedence(Closed, RESOLVED)
#   chain_precedence(Closed, Require upgrade)
#   chain_precedence(Closed, Resolve SW anomaly)
#   chain_precedence(Closed, Schedule intervention)
#   chain_precedence(Closed, VERIFIED)
#   chain_precedence(Create SW anomaly, INVALID)
#   chain_precedence(Create SW anomaly, Insert ticket)
#   chain_precedence(Create SW anomaly, RESOLVED)
#   chain_precedence(Create SW anomaly, Require upgrade)
#   chain_precedence(Create SW anomaly, Resolve SW anomaly)
#   chain_precedence(Create SW anomaly, Schedule intervention)
#   chain_precedence(Create SW anomaly, VERIFIED)
#   chain_precedence(EOS, Create SW anomaly)
#   chain_precedence(EOS, INVALID)
#   chain_precedence(EOS, Insert ticket)
#   chain_precedence(EOS, RESOLVED)
#   chain_precedence(EOS, Require upgrade)
#   chain_precedence(EOS, Resolve SW anomaly)
#   chain_precedence(EOS, Schedule intervention)
#   chain_precedence(EOS, VERIFIED)
#   chain_precedence(INVALID, Create SW anomaly)
#   chain_precedence(INVALID, Insert ticket)
#   chain_precedence(INVALID, RESOLVED)
#   chain_precedence(INVALID, Require upgrade)
#   chain_precedence(INVALID, Resolve SW anomaly)
#   chain_precedence(INVALID, Schedule intervention)
#   chain_precedence(INVALID, VERIFIED)
#   chain_precedence(Insert ticket, Create SW anomaly)
#   chain_precedence(Insert ticket, INVALID)
#   chain_precedence(Insert ticket, RESOLVED)
#   chain_precedence(Insert ticket, Require upgrade)
#   chain_precedence(Insert ticket, Resolve SW anomaly)
#   chain_precedence(Insert ticket, Schedule intervention)
#   chain_precedence(Insert ticket, VERIFIED)
#   chain_precedence(RESOLVED, Create SW anomaly)
#   chain_precedence(RESOLVED, INVALID)
#   chain_precedence(RESOLVED, Insert ticket)
#   chain_precedence(RESOLVED, Require upgrade)
#   chain_precedence(RESOLVED, Resolve SW anomaly)
#   chain_precedence(RESOLVED, Schedule intervention)
#   chain_precedence(RESOLVED, VERIFIED)
#   chain_precedence(Require upgrade, Create SW anomaly)
#   chain_precedence(Require upgrade, INVALID)
#   chain_precedence(Require upgrade, Insert ticket)
#   chain_precedence(Require upgrade, RESOLVED)
#   chain_precedence(Require upgrade, Resolve SW anomaly)
#   chain_precedence(Require upgrade, Schedule intervention)
#   chain_precedence(Require upgrade, VERIFIED)
#   chain_precedence(Resolve SW anomaly, Create SW anomaly)
#   chain_precedence(Resolve SW anomaly, INVALID)
#   chain_precedence(Resolve SW anomaly, Insert ticket)
#   chain_precedence(Resolve SW anomaly, RESOLVED)
#   chain_precedence(Resolve SW anomaly, Require upgrade)
#   chain_precedence(Resolve SW anomaly, Schedule intervention)
#   chain_precedence(Resolve SW anomaly, VERIFIED)
#   chain_precedence(Resolve ticket, Closed)
#   chain_precedence(Resolve ticket, Create SW anomaly)
#   chain_precedence(Resolve ticket, INVALID)
#   chain_precedence(Resolve ticket, Insert ticket)
#   chain_precedence(Resolve ticket, RESOLVED)
#   chain_precedence(Resolve ticket, Require upgrade)
#   chain_precedence(Resolve ticket, Resolve SW anomaly)
#   chain_precedence(Resolve ticket, Schedule intervention)
#   chain_precedence(Resolve ticket, VERIFIED)
#   chain_precedence(Schedule intervention, Create SW anomaly)
#   chain_precedence(Schedule intervention, INVALID)
#   chain_precedence(Schedule intervention, Insert ticket)
#   chain_precedence(Schedule intervention, RESOLVED)
#   chain_precedence(Schedule intervention, Require upgrade)
#   chain_precedence(Schedule intervention, Resolve SW anomaly)
#   chain_precedence(Schedule intervention, VERIFIED)
#   chain_precedence(Take in charge ticket, Create SW anomaly)
#   chain_precedence(Take in charge ticket, INVALID)
#   chain_precedence(Take in charge ticket, Insert ticket)
#   chain_precedence(Take in charge ticket, RESOLVED)
#   chain_precedence(Take in charge ticket, Require upgrade)
#   chain_precedence(Take in charge ticket, Resolve SW anomaly)
#   chain_precedence(Take in charge ticket, Schedule intervention)
#   chain_precedence(Take in charge ticket, VERIFIED)
#   chain_precedence(Take in charge ticket, Wait)
#   chain_precedence(VERIFIED, Create SW anomaly)
#   chain_precedence(VERIFIED, INVALID)
#   chain_precedence(VERIFIED, Insert ticket)
#   chain_precedence(VERIFIED, RESOLVED)
#   chain_precedence(VERIFIED, Require upgrade)
#   chain_precedence(VERIFIED, Resolve SW anomaly)
#   chain_precedence(VERIFIED, Schedule intervention)
#   chain_precedence(Wait, Create SW anomaly)
#   chain_precedence(Wait, INVALID)
#   chain_precedence(Wait, Insert ticket)
#   chain_precedence(Wait, RESOLVED)
#   chain_precedence(Wait, Require upgrade)
#   chain_precedence(Wait, Resolve SW anomaly)
#   chain_precedence(Wait, Schedule intervention)
#   chain_precedence(Wait, VERIFIED)
#   init(Assign seriousness)
#   not_succession(Assign seriousness, Create SW anomaly)
#   not_succession(Assign seriousness, INVALID)
#   not_succession(Assign seriousness, Insert ticket)
#   not_succession(Assign seriousness, RESOLVED)
#   not_succession(Assign seriousness, Require upgrade)
#   not_succession(Assign seriousness, Resolve SW anomaly)
#   not_succession(Assign seriousness, Schedule intervention)
#   not_succession(Assign seriousness, VERIFIED)
#   not_succession(Closed, Assign seriousness)
#   not_succession(Closed, Create SW anomaly)
#   not_succession(Closed, INVALID)
#   not_succession(Closed, Insert ticket)
#   not_succession(Closed, RESOLVED)
#   not_succession(Closed, Require upgrade)
#   not_succession(Closed, Resolve SW anomaly)
#   not_succession(Closed, Resolve ticket)
#   not_succession(Closed, Schedule intervention)
#   not_succession(Closed, Take in charge ticket)
#   not_succession(Closed, VERIFIED)
#   not_succession(Closed, Wait)
#   not_succession(Create SW anomaly, Assign seriousness)
#   not_succession(Create SW anomaly, Closed)
#   not_succession(Create SW anomaly, EOS)
#   not_succession(Create SW anomaly, INVALID)
#   not_succession(Create SW anomaly, Insert ticket)
#   not_succession(Create SW anomaly, RESOLVED)
#   not_succession(Create SW anomaly, Require upgrade)
#   not_succession(Create SW anomaly, Resolve SW anomaly)
#   not_succession(Create SW anomaly, Resolve ticket)
#   not_succession(Create SW anomaly, Schedule intervention)
#   not_succession(Create SW anomaly, Take in charge ticket)
#   not_succession(Create SW anomaly, VERIFIED)
#   not_succession(Create SW anomaly, Wait)
#   not_succession(EOS, Assign seriousness)
#   not_succession(EOS, Closed)
#   not_succession(EOS, Create SW anomaly)
#   not_succession(EOS, INVALID)
#   not_succession(EOS, Insert ticket)
#   not_succession(EOS, RESOLVED)
#   not_succession(EOS, Require upgrade)
#   not_succession(EOS, Resolve SW anomaly)
#   not_succession(EOS, Resolve ticket)
#   not_succession(EOS, Schedule intervention)
#   not_succession(EOS, Take in charge ticket)
#   not_succession(EOS, VERIFIED)
#   not_succession(EOS, Wait)
#   not_succession(INVALID, Assign seriousness)
#   not_succession(INVALID, Closed)
#   not_succession(INVALID, Create SW anomaly)
#   not_succession(INVALID, EOS)
#   not_succession(INVALID, Insert ticket)
#   not_succession(INVALID, RESOLVED)
#   not_succession(INVALID, Require upgrade)
#   not_succession(INVALID, Resolve SW anomaly)
#   not_succession(INVALID, Resolve ticket)
#   not_succession(INVALID, Schedule intervention)
#   not_succession(INVALID, Take in charge ticket)
#   not_succession(INVALID, VERIFIED)
#   not_succession(INVALID, Wait)
#   not_succession(Insert ticket, Assign seriousness)
#   not_succession(Insert ticket, Closed)
#   not_succession(Insert ticket, Create SW anomaly)
#   not_succession(Insert ticket, EOS)
#   not_succession(Insert ticket, INVALID)
#   not_succession(Insert ticket, RESOLVED)
#   not_succession(Insert ticket, Require upgrade)
#   not_succession(Insert ticket, Resolve SW anomaly)
#   not_succession(Insert ticket, Resolve ticket)
#   not_succession(Insert ticket, Schedule intervention)
#   not_succession(Insert ticket, Take in charge ticket)
#   not_succession(Insert ticket, VERIFIED)
#   not_succession(Insert ticket, Wait)
#   not_succession(RESOLVED, Assign seriousness)
#   not_succession(RESOLVED, Closed)
#   not_succession(RESOLVED, Create SW anomaly)
#   not_succession(RESOLVED, EOS)
#   not_succession(RESOLVED, INVALID)
#   not_succession(RESOLVED, Insert ticket)
#   not_succession(RESOLVED, Require upgrade)
#   not_succession(RESOLVED, Resolve SW anomaly)
#   not_succession(RESOLVED, Resolve ticket)
#   not_succession(RESOLVED, Schedule intervention)
#   not_succession(RESOLVED, Take in charge ticket)
#   not_succession(RESOLVED, VERIFIED)
#   not_succession(RESOLVED, Wait)
#   not_succession(Require upgrade, Assign seriousness)
#   not_succession(Require upgrade, Closed)
#   not_succession(Require upgrade, Create SW anomaly)
#   not_succession(Require upgrade, EOS)
#   not_succession(Require upgrade, INVALID)
#   not_succession(Require upgrade, Insert ticket)
#   not_succession(Require upgrade, RESOLVED)
#   not_succession(Require upgrade, Resolve SW anomaly)
#   not_succession(Require upgrade, Resolve ticket)
#   not_succession(Require upgrade, Schedule intervention)
#   not_succession(Require upgrade, Take in charge ticket)
#   not_succession(Require upgrade, VERIFIED)
#   not_succession(Require upgrade, Wait)
#   not_succession(Resolve SW anomaly, Assign seriousness)
#   not_succession(Resolve SW anomaly, Closed)
#   not_succession(Resolve SW anomaly, Create SW anomaly)
#   not_succession(Resolve SW anomaly, EOS)
#   not_succession(Resolve SW anomaly, INVALID)
#   not_succession(Resolve SW anomaly, Insert ticket)
#   not_succession(Resolve SW anomaly, RESOLVED)
#   not_succession(Resolve SW anomaly, Require upgrade)
#   not_succession(Resolve SW anomaly, Resolve ticket)
#   not_succession(Resolve SW anomaly, Schedule intervention)
#   not_succession(Resolve SW anomaly, Take in charge ticket)
#   not_succession(Resolve SW anomaly, VERIFIED)
#   not_succession(Resolve SW anomaly, Wait)
#   not_succession(Resolve ticket, Assign seriousness)
#   not_succession(Resolve ticket, Create SW anomaly)
#   not_succession(Resolve ticket, INVALID)
#   not_succession(Resolve ticket, Insert ticket)
#   not_succession(Resolve ticket, RESOLVED)
#   not_succession(Resolve ticket, Require upgrade)
#   not_succession(Resolve ticket, Resolve SW anomaly)
#   not_succession(Resolve ticket, Schedule intervention)
#   not_succession(Resolve ticket, Take in charge ticket)
#   not_succession(Resolve ticket, VERIFIED)
#   not_succession(Resolve ticket, Wait)
#   not_succession(Schedule intervention, Assign seriousness)
#   not_succession(Schedule intervention, Closed)
#   not_succession(Schedule intervention, Create SW anomaly)
#   not_succession(Schedule intervention, EOS)
#   not_succession(Schedule intervention, INVALID)
#   not_succession(Schedule intervention, Insert ticket)
#   not_succession(Schedule intervention, RESOLVED)
#   not_succession(Schedule intervention, Require upgrade)
#   not_succession(Schedule intervention, Resolve SW anomaly)
#   not_succession(Schedule intervention, Resolve ticket)
#   not_succession(Schedule intervention, Take in charge ticket)
#   not_succession(Schedule intervention, VERIFIED)
#   not_succession(Schedule intervention, Wait)
#   not_succession(Take in charge ticket, Assign seriousness)
#   not_succession(Take in charge ticket, Create SW anomaly)
#   not_succession(Take in charge ticket, INVALID)
#   not_succession(Take in charge ticket, Insert ticket)
#   not_succession(Take in charge ticket, RESOLVED)
#   not_succession(Take in charge ticket, Require upgrade)
#   not_succession(Take in charge ticket, Resolve SW anomaly)
#   not_succession(Take in charge ticket, Schedule intervention)
#   not_succession(Take in charge ticket, VERIFIED)
#   not_succession(VERIFIED, Assign seriousness)
#   not_succession(VERIFIED, Closed)
#   not_succession(VERIFIED, Create SW anomaly)
#   not_succession(VERIFIED, EOS)
#   not_succession(VERIFIED, INVALID)
#   not_succession(VERIFIED, Insert ticket)
#   not_succession(VERIFIED, RESOLVED)
#   not_succession(VERIFIED, Require upgrade)
#   not_succession(VERIFIED, Resolve SW anomaly)
#   not_succession(VERIFIED, Resolve ticket)
#   not_succession(VERIFIED, Schedule intervention)
#   not_succession(VERIFIED, Take in charge ticket)
#   not_succession(VERIFIED, Wait)
#   not_succession(Wait, Assign seriousness)
#   not_succession(Wait, Create SW anomaly)
#   not_succession(Wait, INVALID)
#   not_succession(Wait, Insert ticket)
#   not_succession(Wait, RESOLVED)
#   not_succession(Wait, Require upgrade)
#   not_succession(Wait, Resolve SW anomaly)
#   not_succession(Wait, Schedule intervention)
#   not_succession(Wait, VERIFIED)
#   precedence(Assign seriousness, Closed)
#   precedence(Assign seriousness, Create SW anomaly)
#   precedence(Assign seriousness, EOS)
#   precedence(Assign seriousness, INVALID)
#   precedence(Assign seriousness, Insert ticket)
#   precedence(Assign seriousness, RESOLVED)
#   precedence(Assign seriousness, Require upgrade)
#   precedence(Assign seriousness, Resolve SW anomaly)
#   precedence(Assign seriousness, Resolve ticket)
#   precedence(Assign seriousness, Schedule intervention)
#   precedence(Assign seriousness, Take in charge ticket)
#   precedence(Assign seriousness, VERIFIED)
#   precedence(Assign seriousness, Wait)
#   precedence(Closed, Create SW anomaly)
#   precedence(Closed, EOS)
#   precedence(Closed, INVALID)
#   precedence(Closed, Insert ticket)
#   precedence(Closed, RESOLVED)
#   precedence(Closed, Require upgrade)
#   precedence(Closed, Resolve SW anomaly)
#   precedence(Closed, Schedule intervention)
#   precedence(Closed, VERIFIED)
#   precedence(Create SW anomaly, INVALID)
#   precedence(Create SW anomaly, Insert ticket)
#   precedence(Create SW anomaly, RESOLVED)
#   precedence(Create SW anomaly, Require upgrade)
#   precedence(Create SW anomaly, Resolve SW anomaly)
#   precedence(Create SW anomaly, Schedule intervention)
#   precedence(Create SW anomaly, VERIFIED)
#   precedence(EOS, Create SW anomaly)
#   precedence(EOS, INVALID)
#   precedence(EOS, Insert ticket)
#   precedence(EOS, RESOLVED)
#   precedence(EOS, Require upgrade)
#   precedence(EOS, Resolve SW anomaly)
#   precedence(EOS, Schedule intervention)
#   precedence(EOS, VERIFIED)
#   precedence(INVALID, Create SW anomaly)
#   precedence(INVALID, Insert ticket)
#   precedence(INVALID, RESOLVED)
#   precedence(INVALID, Require upgrade)
#   precedence(INVALID, Resolve SW anomaly)
#   precedence(INVALID, Schedule intervention)
#   precedence(INVALID, VERIFIED)
#   precedence(Insert ticket, Create SW anomaly)
#   precedence(Insert ticket, INVALID)
#   precedence(Insert ticket, RESOLVED)
#   precedence(Insert ticket, Require upgrade)
#   precedence(Insert ticket, Resolve SW anomaly)
#   precedence(Insert ticket, Schedule intervention)
#   precedence(Insert ticket, VERIFIED)
#   precedence(RESOLVED, Create SW anomaly)
#   precedence(RESOLVED, INVALID)
#   precedence(RESOLVED, Insert ticket)
#   precedence(RESOLVED, Require upgrade)
#   precedence(RESOLVED, Resolve SW anomaly)
#   precedence(RESOLVED, Schedule intervention)
#   precedence(RESOLVED, VERIFIED)
#   precedence(Require upgrade, Create SW anomaly)
#   precedence(Require upgrade, INVALID)
#   precedence(Require upgrade, Insert ticket)
#   precedence(Require upgrade, RESOLVED)
#   precedence(Require upgrade, Resolve SW anomaly)
#   precedence(Require upgrade, Schedule intervention)
#   precedence(Require upgrade, VERIFIED)
#   precedence(Resolve SW anomaly, Create SW anomaly)
#   precedence(Resolve SW anomaly, INVALID)
#   precedence(Resolve SW anomaly, Insert ticket)
#   precedence(Resolve SW anomaly, RESOLVED)
#   precedence(Resolve SW anomaly, Require upgrade)
#   precedence(Resolve SW anomaly, Schedule intervention)
#   precedence(Resolve SW anomaly, VERIFIED)
#   precedence(Resolve ticket, Closed)
#   precedence(Resolve ticket, Create SW anomaly)
#   precedence(Resolve ticket, EOS)
#   precedence(Resolve ticket, INVALID)
#   precedence(Resolve ticket, Insert ticket)
#   precedence(Resolve ticket, RESOLVED)
#   precedence(Resolve ticket, Require upgrade)
#   precedence(Resolve ticket, Resolve SW anomaly)
#   precedence(Resolve ticket, Schedule intervention)
#   precedence(Resolve ticket, VERIFIED)
#   precedence(Schedule intervention, Create SW anomaly)
#   precedence(Schedule intervention, INVALID)
#   precedence(Schedule intervention, Insert ticket)
#   precedence(Schedule intervention, RESOLVED)
#   precedence(Schedule intervention, Require upgrade)
#   precedence(Schedule intervention, Resolve SW anomaly)
#   precedence(Schedule intervention, VERIFIED)
#   precedence(Take in charge ticket, Closed)
#   precedence(Take in charge ticket, Create SW anomaly)
#   precedence(Take in charge ticket, EOS)
#   precedence(Take in charge ticket, INVALID)
#   precedence(Take in charge ticket, Insert ticket)
#   precedence(Take in charge ticket, RESOLVED)
#   precedence(Take in charge ticket, Require upgrade)
#   precedence(Take in charge ticket, Resolve SW anomaly)
#   precedence(Take in charge ticket, Resolve ticket)
#   precedence(Take in charge ticket, Schedule intervention)
#   precedence(Take in charge ticket, VERIFIED)
#   precedence(Take in charge ticket, Wait)
#   precedence(VERIFIED, Create SW anomaly)
#   precedence(VERIFIED, INVALID)
#   precedence(VERIFIED, Insert ticket)
#   precedence(VERIFIED, RESOLVED)
#   precedence(VERIFIED, Require upgrade)
#   precedence(VERIFIED, Resolve SW anomaly)
#   precedence(VERIFIED, Schedule intervention)
#   precedence(Wait, Create SW anomaly)
#   precedence(Wait, INVALID)
#   precedence(Wait, Insert ticket)
#   precedence(Wait, RESOLVED)
#   precedence(Wait, Require upgrade)
#   precedence(Wait, Resolve SW anomaly)
#   precedence(Wait, Schedule intervention)
#   precedence(Wait, VERIFIED)
#
# NOT prefix-safe constraints (used in validity gate):
# ------------------------------------------------------------
#   alternate_response(Closed, EOS)
#   alternate_response(Create SW anomaly, Assign seriousness)
#   alternate_response(Create SW anomaly, Closed)
#   alternate_response(Create SW anomaly, EOS)
#   alternate_response(Create SW anomaly, INVALID)
#   alternate_response(Create SW anomaly, Insert ticket)
#   alternate_response(Create SW anomaly, RESOLVED)
#   alternate_response(Create SW anomaly, Require upgrade)
#   alternate_response(Create SW anomaly, Resolve SW anomaly)
#   alternate_response(Create SW anomaly, Resolve ticket)
#   alternate_response(Create SW anomaly, Schedule intervention)
#   alternate_response(Create SW anomaly, Take in charge ticket)
#   alternate_response(Create SW anomaly, VERIFIED)
#   alternate_response(Create SW anomaly, Wait)
#   alternate_response(INVALID, Assign seriousness)
#   alternate_response(INVALID, Closed)
#   alternate_response(INVALID, Create SW anomaly)
#   alternate_response(INVALID, EOS)
#   alternate_response(INVALID, Insert ticket)
#   alternate_response(INVALID, RESOLVED)
#   alternate_response(INVALID, Require upgrade)
#   alternate_response(INVALID, Resolve SW anomaly)
#   alternate_response(INVALID, Resolve ticket)
#   alternate_response(INVALID, Schedule intervention)
#   alternate_response(INVALID, Take in charge ticket)
#   alternate_response(INVALID, VERIFIED)
#   alternate_response(INVALID, Wait)
#   alternate_response(Insert ticket, Assign seriousness)
#   alternate_response(Insert ticket, Closed)
#   alternate_response(Insert ticket, Create SW anomaly)
#   alternate_response(Insert ticket, EOS)
#   alternate_response(Insert ticket, INVALID)
#   alternate_response(Insert ticket, RESOLVED)
#   alternate_response(Insert ticket, Require upgrade)
#   alternate_response(Insert ticket, Resolve SW anomaly)
#   alternate_response(Insert ticket, Resolve ticket)
#   alternate_response(Insert ticket, Schedule intervention)
#   alternate_response(Insert ticket, Take in charge ticket)
#   alternate_response(Insert ticket, VERIFIED)
#   alternate_response(Insert ticket, Wait)
#   alternate_response(RESOLVED, Assign seriousness)
#   alternate_response(RESOLVED, Closed)
#   alternate_response(RESOLVED, Create SW anomaly)
#   alternate_response(RESOLVED, EOS)
#   alternate_response(RESOLVED, INVALID)
#   alternate_response(RESOLVED, Insert ticket)
#   alternate_response(RESOLVED, Require upgrade)
#   alternate_response(RESOLVED, Resolve SW anomaly)
#   alternate_response(RESOLVED, Resolve ticket)
#   alternate_response(RESOLVED, Schedule intervention)
#   alternate_response(RESOLVED, Take in charge ticket)
#   alternate_response(RESOLVED, VERIFIED)
#   alternate_response(RESOLVED, Wait)
#   alternate_response(Require upgrade, Assign seriousness)
#   alternate_response(Require upgrade, Closed)
#   alternate_response(Require upgrade, Create SW anomaly)
#   alternate_response(Require upgrade, EOS)
#   alternate_response(Require upgrade, INVALID)
#   alternate_response(Require upgrade, Insert ticket)
#   alternate_response(Require upgrade, RESOLVED)
#   alternate_response(Require upgrade, Resolve SW anomaly)
#   alternate_response(Require upgrade, Resolve ticket)
#   alternate_response(Require upgrade, Schedule intervention)
#   alternate_response(Require upgrade, Take in charge ticket)
#   alternate_response(Require upgrade, VERIFIED)
#   alternate_response(Require upgrade, Wait)
#   alternate_response(Resolve SW anomaly, Assign seriousness)
#   alternate_response(Resolve SW anomaly, Closed)
#   alternate_response(Resolve SW anomaly, Create SW anomaly)
#   alternate_response(Resolve SW anomaly, EOS)
#   alternate_response(Resolve SW anomaly, INVALID)
#   alternate_response(Resolve SW anomaly, Insert ticket)
#   alternate_response(Resolve SW anomaly, RESOLVED)
#   alternate_response(Resolve SW anomaly, Require upgrade)
#   alternate_response(Resolve SW anomaly, Resolve ticket)
#   alternate_response(Resolve SW anomaly, Schedule intervention)
#   alternate_response(Resolve SW anomaly, Take in charge ticket)
#   alternate_response(Resolve SW anomaly, VERIFIED)
#   alternate_response(Resolve SW anomaly, Wait)
#   alternate_response(Schedule intervention, Assign seriousness)
#   alternate_response(Schedule intervention, Closed)
#   alternate_response(Schedule intervention, Create SW anomaly)
#   alternate_response(Schedule intervention, EOS)
#   alternate_response(Schedule intervention, INVALID)
#   alternate_response(Schedule intervention, Insert ticket)
#   alternate_response(Schedule intervention, RESOLVED)
#   alternate_response(Schedule intervention, Require upgrade)
#   alternate_response(Schedule intervention, Resolve SW anomaly)
#   alternate_response(Schedule intervention, Resolve ticket)
#   alternate_response(Schedule intervention, Take in charge ticket)
#   alternate_response(Schedule intervention, VERIFIED)
#   alternate_response(Schedule intervention, Wait)
#   alternate_response(VERIFIED, Assign seriousness)
#   alternate_response(VERIFIED, Closed)
#   alternate_response(VERIFIED, Create SW anomaly)
#   alternate_response(VERIFIED, EOS)
#   alternate_response(VERIFIED, INVALID)
#   alternate_response(VERIFIED, Insert ticket)
#   alternate_response(VERIFIED, RESOLVED)
#   alternate_response(VERIFIED, Require upgrade)
#   alternate_response(VERIFIED, Resolve SW anomaly)
#   alternate_response(VERIFIED, Resolve ticket)
#   alternate_response(VERIFIED, Schedule intervention)
#   alternate_response(VERIFIED, Take in charge ticket)
#   alternate_response(VERIFIED, Wait)
#   alternate_response(Wait, Closed)
#   alternate_response(Wait, Resolve ticket)
#   alternate_succession(Create SW anomaly, INVALID)
#   alternate_succession(Create SW anomaly, Insert ticket)
#   alternate_succession(Create SW anomaly, RESOLVED)
#   alternate_succession(Create SW anomaly, Require upgrade)
#   alternate_succession(Create SW anomaly, Resolve SW anomaly)
#   alternate_succession(Create SW anomaly, Schedule intervention)
#   alternate_succession(Create SW anomaly, VERIFIED)
#   alternate_succession(INVALID, Create SW anomaly)
#   alternate_succession(INVALID, Insert ticket)
#   alternate_succession(INVALID, RESOLVED)
#   alternate_succession(INVALID, Require upgrade)
#   alternate_succession(INVALID, Resolve SW anomaly)
#   alternate_succession(INVALID, Schedule intervention)
#   alternate_succession(INVALID, VERIFIED)
#   alternate_succession(Insert ticket, Create SW anomaly)
#   alternate_succession(Insert ticket, INVALID)
#   alternate_succession(Insert ticket, RESOLVED)
#   alternate_succession(Insert ticket, Require upgrade)
#   alternate_succession(Insert ticket, Resolve SW anomaly)
#   alternate_succession(Insert ticket, Schedule intervention)
#   alternate_succession(Insert ticket, VERIFIED)
#   alternate_succession(RESOLVED, Create SW anomaly)
#   alternate_succession(RESOLVED, INVALID)
#   alternate_succession(RESOLVED, Insert ticket)
#   alternate_succession(RESOLVED, Require upgrade)
#   alternate_succession(RESOLVED, Resolve SW anomaly)
#   alternate_succession(RESOLVED, Schedule intervention)
#   alternate_succession(RESOLVED, VERIFIED)
#   alternate_succession(Require upgrade, Create SW anomaly)
#   alternate_succession(Require upgrade, INVALID)
#   alternate_succession(Require upgrade, Insert ticket)
#   alternate_succession(Require upgrade, RESOLVED)
#   alternate_succession(Require upgrade, Resolve SW anomaly)
#   alternate_succession(Require upgrade, Schedule intervention)
#   alternate_succession(Require upgrade, VERIFIED)
#   alternate_succession(Resolve SW anomaly, Create SW anomaly)
#   alternate_succession(Resolve SW anomaly, INVALID)
#   alternate_succession(Resolve SW anomaly, Insert ticket)
#   alternate_succession(Resolve SW anomaly, RESOLVED)
#   alternate_succession(Resolve SW anomaly, Require upgrade)
#   alternate_succession(Resolve SW anomaly, Schedule intervention)
#   alternate_succession(Resolve SW anomaly, VERIFIED)
#   alternate_succession(Schedule intervention, Create SW anomaly)
#   alternate_succession(Schedule intervention, INVALID)
#   alternate_succession(Schedule intervention, Insert ticket)
#   alternate_succession(Schedule intervention, RESOLVED)
#   alternate_succession(Schedule intervention, Require upgrade)
#   alternate_succession(Schedule intervention, Resolve SW anomaly)
#   alternate_succession(Schedule intervention, VERIFIED)
#   alternate_succession(VERIFIED, Create SW anomaly)
#   alternate_succession(VERIFIED, INVALID)
#   alternate_succession(VERIFIED, Insert ticket)
#   alternate_succession(VERIFIED, RESOLVED)
#   alternate_succession(VERIFIED, Require upgrade)
#   alternate_succession(VERIFIED, Resolve SW anomaly)
#   alternate_succession(VERIFIED, Schedule intervention)
#   chain_response(Closed, EOS)
#   chain_response(Create SW anomaly, Assign seriousness)
#   chain_response(Create SW anomaly, Closed)
#   chain_response(Create SW anomaly, EOS)
#   chain_response(Create SW anomaly, INVALID)
#   chain_response(Create SW anomaly, Insert ticket)
#   chain_response(Create SW anomaly, RESOLVED)
#   chain_response(Create SW anomaly, Require upgrade)
#   chain_response(Create SW anomaly, Resolve SW anomaly)
#   chain_response(Create SW anomaly, Resolve ticket)
#   chain_response(Create SW anomaly, Schedule intervention)
#   chain_response(Create SW anomaly, Take in charge ticket)
#   chain_response(Create SW anomaly, VERIFIED)
#   chain_response(Create SW anomaly, Wait)
#   chain_response(INVALID, Assign seriousness)
#   chain_response(INVALID, Closed)
#   chain_response(INVALID, Create SW anomaly)
#   chain_response(INVALID, EOS)
#   chain_response(INVALID, Insert ticket)
#   chain_response(INVALID, RESOLVED)
#   chain_response(INVALID, Require upgrade)
#   chain_response(INVALID, Resolve SW anomaly)
#   chain_response(INVALID, Resolve ticket)
#   chain_response(INVALID, Schedule intervention)
#   chain_response(INVALID, Take in charge ticket)
#   chain_response(INVALID, VERIFIED)
#   chain_response(INVALID, Wait)
#   chain_response(Insert ticket, Assign seriousness)
#   chain_response(Insert ticket, Closed)
#   chain_response(Insert ticket, Create SW anomaly)
#   chain_response(Insert ticket, EOS)
#   chain_response(Insert ticket, INVALID)
#   chain_response(Insert ticket, RESOLVED)
#   chain_response(Insert ticket, Require upgrade)
#   chain_response(Insert ticket, Resolve SW anomaly)
#   chain_response(Insert ticket, Resolve ticket)
#   chain_response(Insert ticket, Schedule intervention)
#   chain_response(Insert ticket, Take in charge ticket)
#   chain_response(Insert ticket, VERIFIED)
#   chain_response(Insert ticket, Wait)
#   chain_response(RESOLVED, Assign seriousness)
#   chain_response(RESOLVED, Closed)
#   chain_response(RESOLVED, Create SW anomaly)
#   chain_response(RESOLVED, EOS)
#   chain_response(RESOLVED, INVALID)
#   chain_response(RESOLVED, Insert ticket)
#   chain_response(RESOLVED, Require upgrade)
#   chain_response(RESOLVED, Resolve SW anomaly)
#   chain_response(RESOLVED, Resolve ticket)
#   chain_response(RESOLVED, Schedule intervention)
#   chain_response(RESOLVED, Take in charge ticket)
#   chain_response(RESOLVED, VERIFIED)
#   chain_response(RESOLVED, Wait)
#   chain_response(Require upgrade, Assign seriousness)
#   chain_response(Require upgrade, Closed)
#   chain_response(Require upgrade, Create SW anomaly)
#   chain_response(Require upgrade, EOS)
#   chain_response(Require upgrade, INVALID)
#   chain_response(Require upgrade, Insert ticket)
#   chain_response(Require upgrade, RESOLVED)
#   chain_response(Require upgrade, Resolve SW anomaly)
#   chain_response(Require upgrade, Resolve ticket)
#   chain_response(Require upgrade, Schedule intervention)
#   chain_response(Require upgrade, Take in charge ticket)
#   chain_response(Require upgrade, VERIFIED)
#   chain_response(Require upgrade, Wait)
#   chain_response(Resolve SW anomaly, Assign seriousness)
#   chain_response(Resolve SW anomaly, Closed)
#   chain_response(Resolve SW anomaly, Create SW anomaly)
#   chain_response(Resolve SW anomaly, EOS)
#   chain_response(Resolve SW anomaly, INVALID)
#   chain_response(Resolve SW anomaly, Insert ticket)
#   chain_response(Resolve SW anomaly, RESOLVED)
#   chain_response(Resolve SW anomaly, Require upgrade)
#   chain_response(Resolve SW anomaly, Resolve ticket)
#   chain_response(Resolve SW anomaly, Schedule intervention)
#   chain_response(Resolve SW anomaly, Take in charge ticket)
#   chain_response(Resolve SW anomaly, VERIFIED)
#   chain_response(Resolve SW anomaly, Wait)
#   chain_response(Schedule intervention, Assign seriousness)
#   chain_response(Schedule intervention, Closed)
#   chain_response(Schedule intervention, Create SW anomaly)
#   chain_response(Schedule intervention, EOS)
#   chain_response(Schedule intervention, INVALID)
#   chain_response(Schedule intervention, Insert ticket)
#   chain_response(Schedule intervention, RESOLVED)
#   chain_response(Schedule intervention, Require upgrade)
#   chain_response(Schedule intervention, Resolve SW anomaly)
#   chain_response(Schedule intervention, Resolve ticket)
#   chain_response(Schedule intervention, Take in charge ticket)
#   chain_response(Schedule intervention, VERIFIED)
#   chain_response(Schedule intervention, Wait)
#   chain_response(VERIFIED, Assign seriousness)
#   chain_response(VERIFIED, Closed)
#   chain_response(VERIFIED, Create SW anomaly)
#   chain_response(VERIFIED, EOS)
#   chain_response(VERIFIED, INVALID)
#   chain_response(VERIFIED, Insert ticket)
#   chain_response(VERIFIED, RESOLVED)
#   chain_response(VERIFIED, Require upgrade)
#   chain_response(VERIFIED, Resolve SW anomaly)
#   chain_response(VERIFIED, Resolve ticket)
#   chain_response(VERIFIED, Schedule intervention)
#   chain_response(VERIFIED, Take in charge ticket)
#   chain_response(VERIFIED, Wait)
#   chain_succession(Create SW anomaly, INVALID)
#   chain_succession(Create SW anomaly, Insert ticket)
#   chain_succession(Create SW anomaly, RESOLVED)
#   chain_succession(Create SW anomaly, Require upgrade)
#   chain_succession(Create SW anomaly, Resolve SW anomaly)
#   chain_succession(Create SW anomaly, Schedule intervention)
#   chain_succession(Create SW anomaly, VERIFIED)
#   chain_succession(INVALID, Create SW anomaly)
#   chain_succession(INVALID, Insert ticket)
#   chain_succession(INVALID, RESOLVED)
#   chain_succession(INVALID, Require upgrade)
#   chain_succession(INVALID, Resolve SW anomaly)
#   chain_succession(INVALID, Schedule intervention)
#   chain_succession(INVALID, VERIFIED)
#   chain_succession(Insert ticket, Create SW anomaly)
#   chain_succession(Insert ticket, INVALID)
#   chain_succession(Insert ticket, RESOLVED)
#   chain_succession(Insert ticket, Require upgrade)
#   chain_succession(Insert ticket, Resolve SW anomaly)
#   chain_succession(Insert ticket, Schedule intervention)
#   chain_succession(Insert ticket, VERIFIED)
#   chain_succession(RESOLVED, Create SW anomaly)
#   chain_succession(RESOLVED, INVALID)
#   chain_succession(RESOLVED, Insert ticket)
#   chain_succession(RESOLVED, Require upgrade)
#   chain_succession(RESOLVED, Resolve SW anomaly)
#   chain_succession(RESOLVED, Schedule intervention)
#   chain_succession(RESOLVED, VERIFIED)
#   chain_succession(Require upgrade, Create SW anomaly)
#   chain_succession(Require upgrade, INVALID)
#   chain_succession(Require upgrade, Insert ticket)
#   chain_succession(Require upgrade, RESOLVED)
#   chain_succession(Require upgrade, Resolve SW anomaly)
#   chain_succession(Require upgrade, Schedule intervention)
#   chain_succession(Require upgrade, VERIFIED)
#   chain_succession(Resolve SW anomaly, Create SW anomaly)
#   chain_succession(Resolve SW anomaly, INVALID)
#   chain_succession(Resolve SW anomaly, Insert ticket)
#   chain_succession(Resolve SW anomaly, RESOLVED)
#   chain_succession(Resolve SW anomaly, Require upgrade)
#   chain_succession(Resolve SW anomaly, Schedule intervention)
#   chain_succession(Resolve SW anomaly, VERIFIED)
#   chain_succession(Schedule intervention, Create SW anomaly)
#   chain_succession(Schedule intervention, INVALID)
#   chain_succession(Schedule intervention, Insert ticket)
#   chain_succession(Schedule intervention, RESOLVED)
#   chain_succession(Schedule intervention, Require upgrade)
#   chain_succession(Schedule intervention, Resolve SW anomaly)
#   chain_succession(Schedule intervention, VERIFIED)
#   chain_succession(VERIFIED, Create SW anomaly)
#   chain_succession(VERIFIED, INVALID)
#   chain_succession(VERIFIED, Insert ticket)
#   chain_succession(VERIFIED, RESOLVED)
#   chain_succession(VERIFIED, Require upgrade)
#   chain_succession(VERIFIED, Resolve SW anomaly)
#   chain_succession(VERIFIED, Schedule intervention)
#   co_existence(Assign seriousness, Closed)
#   co_existence(Assign seriousness, Resolve ticket)
#   co_existence(Assign seriousness, Take in charge ticket)
#   co_existence(Closed, Assign seriousness)
#   co_existence(Closed, EOS)
#   co_existence(Closed, Resolve ticket)
#   co_existence(Closed, Take in charge ticket)
#   co_existence(Create SW anomaly, INVALID)
#   co_existence(Create SW anomaly, Insert ticket)
#   co_existence(Create SW anomaly, RESOLVED)
#   co_existence(Create SW anomaly, Require upgrade)
#   co_existence(Create SW anomaly, Resolve SW anomaly)
#   co_existence(Create SW anomaly, Schedule intervention)
#   co_existence(Create SW anomaly, VERIFIED)
#   co_existence(EOS, Closed)
#   co_existence(EOS, Resolve ticket)
#   co_existence(INVALID, Create SW anomaly)
#   co_existence(INVALID, Insert ticket)
#   co_existence(INVALID, RESOLVED)
#   co_existence(INVALID, Require upgrade)
#   co_existence(INVALID, Resolve SW anomaly)
#   co_existence(INVALID, Schedule intervention)
#   co_existence(INVALID, VERIFIED)
#   co_existence(Insert ticket, Create SW anomaly)
#   co_existence(Insert ticket, INVALID)
#   co_existence(Insert ticket, RESOLVED)
#   co_existence(Insert ticket, Require upgrade)
#   co_existence(Insert ticket, Resolve SW anomaly)
#   co_existence(Insert ticket, Schedule intervention)
#   co_existence(Insert ticket, VERIFIED)
#   co_existence(RESOLVED, Create SW anomaly)
#   co_existence(RESOLVED, INVALID)
#   co_existence(RESOLVED, Insert ticket)
#   co_existence(RESOLVED, Require upgrade)
#   co_existence(RESOLVED, Resolve SW anomaly)
#   co_existence(RESOLVED, Schedule intervention)
#   co_existence(RESOLVED, VERIFIED)
#   co_existence(Require upgrade, Create SW anomaly)
#   co_existence(Require upgrade, INVALID)
#   co_existence(Require upgrade, Insert ticket)
#   co_existence(Require upgrade, RESOLVED)
#   co_existence(Require upgrade, Resolve SW anomaly)
#   co_existence(Require upgrade, Schedule intervention)
#   co_existence(Require upgrade, VERIFIED)
#   co_existence(Resolve SW anomaly, Create SW anomaly)
#   co_existence(Resolve SW anomaly, INVALID)
#   co_existence(Resolve SW anomaly, Insert ticket)
#   co_existence(Resolve SW anomaly, RESOLVED)
#   co_existence(Resolve SW anomaly, Require upgrade)
#   co_existence(Resolve SW anomaly, Schedule intervention)
#   co_existence(Resolve SW anomaly, VERIFIED)
#   co_existence(Resolve ticket, Assign seriousness)
#   co_existence(Resolve ticket, Closed)
#   co_existence(Resolve ticket, EOS)
#   co_existence(Resolve ticket, Take in charge ticket)
#   co_existence(Schedule intervention, Create SW anomaly)
#   co_existence(Schedule intervention, INVALID)
#   co_existence(Schedule intervention, Insert ticket)
#   co_existence(Schedule intervention, RESOLVED)
#   co_existence(Schedule intervention, Require upgrade)
#   co_existence(Schedule intervention, Resolve SW anomaly)
#   co_existence(Schedule intervention, VERIFIED)
#   co_existence(Take in charge ticket, Assign seriousness)
#   co_existence(Take in charge ticket, Closed)
#   co_existence(Take in charge ticket, Resolve ticket)
#   co_existence(VERIFIED, Create SW anomaly)
#   co_existence(VERIFIED, INVALID)
#   co_existence(VERIFIED, Insert ticket)
#   co_existence(VERIFIED, RESOLVED)
#   co_existence(VERIFIED, Require upgrade)
#   co_existence(VERIFIED, Resolve SW anomaly)
#   co_existence(VERIFIED, Schedule intervention)
#   exactly(Closed, n=1)
#   existence(Assign seriousness, n=1)
#   existence(Closed, n=1)
#   existence(Resolve ticket, n=1)
#   existence(Take in charge ticket, n=1)
#   response(Assign seriousness, Closed)
#   response(Assign seriousness, EOS)
#   response(Assign seriousness, Resolve ticket)
#   response(Assign seriousness, Take in charge ticket)
#   response(Closed, EOS)
#   response(Create SW anomaly, Assign seriousness)
#   response(Create SW anomaly, Closed)
#   response(Create SW anomaly, EOS)
#   response(Create SW anomaly, INVALID)
#   response(Create SW anomaly, Insert ticket)
#   response(Create SW anomaly, RESOLVED)
#   response(Create SW anomaly, Require upgrade)
#   response(Create SW anomaly, Resolve SW anomaly)
#   response(Create SW anomaly, Resolve ticket)
#   response(Create SW anomaly, Schedule intervention)
#   response(Create SW anomaly, Take in charge ticket)
#   response(Create SW anomaly, VERIFIED)
#   response(Create SW anomaly, Wait)
#   response(INVALID, Assign seriousness)
#   response(INVALID, Closed)
#   response(INVALID, Create SW anomaly)
#   response(INVALID, EOS)
#   response(INVALID, Insert ticket)
#   response(INVALID, RESOLVED)
#   response(INVALID, Require upgrade)
#   response(INVALID, Resolve SW anomaly)
#   response(INVALID, Resolve ticket)
#   response(INVALID, Schedule intervention)
#   response(INVALID, Take in charge ticket)
#   response(INVALID, VERIFIED)
#   response(INVALID, Wait)
#   response(Insert ticket, Assign seriousness)
#   response(Insert ticket, Closed)
#   response(Insert ticket, Create SW anomaly)
#   response(Insert ticket, EOS)
#   response(Insert ticket, INVALID)
#   response(Insert ticket, RESOLVED)
#   response(Insert ticket, Require upgrade)
#   response(Insert ticket, Resolve SW anomaly)
#   response(Insert ticket, Resolve ticket)
#   response(Insert ticket, Schedule intervention)
#   response(Insert ticket, Take in charge ticket)
#   response(Insert ticket, VERIFIED)
#   response(Insert ticket, Wait)
#   response(RESOLVED, Assign seriousness)
#   response(RESOLVED, Closed)
#   response(RESOLVED, Create SW anomaly)
#   response(RESOLVED, EOS)
#   response(RESOLVED, INVALID)
#   response(RESOLVED, Insert ticket)
#   response(RESOLVED, Require upgrade)
#   response(RESOLVED, Resolve SW anomaly)
#   response(RESOLVED, Resolve ticket)
#   response(RESOLVED, Schedule intervention)
#   response(RESOLVED, Take in charge ticket)
#   response(RESOLVED, VERIFIED)
#   response(RESOLVED, Wait)
#   response(Require upgrade, Assign seriousness)
#   response(Require upgrade, Closed)
#   response(Require upgrade, Create SW anomaly)
#   response(Require upgrade, EOS)
#   response(Require upgrade, INVALID)
#   response(Require upgrade, Insert ticket)
#   response(Require upgrade, RESOLVED)
#   response(Require upgrade, Resolve SW anomaly)
#   response(Require upgrade, Resolve ticket)
#   response(Require upgrade, Schedule intervention)
#   response(Require upgrade, Take in charge ticket)
#   response(Require upgrade, VERIFIED)
#   response(Require upgrade, Wait)
#   response(Resolve SW anomaly, Assign seriousness)
#   response(Resolve SW anomaly, Closed)
#   response(Resolve SW anomaly, Create SW anomaly)
#   response(Resolve SW anomaly, EOS)
#   response(Resolve SW anomaly, INVALID)
#   response(Resolve SW anomaly, Insert ticket)
#   response(Resolve SW anomaly, RESOLVED)
#   response(Resolve SW anomaly, Require upgrade)
#   response(Resolve SW anomaly, Resolve ticket)
#   response(Resolve SW anomaly, Schedule intervention)
#   response(Resolve SW anomaly, Take in charge ticket)
#   response(Resolve SW anomaly, VERIFIED)
#   response(Resolve SW anomaly, Wait)
#   response(Resolve ticket, Closed)
#   response(Resolve ticket, EOS)
#   response(Schedule intervention, Assign seriousness)
#   response(Schedule intervention, Closed)
#   response(Schedule intervention, Create SW anomaly)
#   response(Schedule intervention, EOS)
#   response(Schedule intervention, INVALID)
#   response(Schedule intervention, Insert ticket)
#   response(Schedule intervention, RESOLVED)
#   response(Schedule intervention, Require upgrade)
#   response(Schedule intervention, Resolve SW anomaly)
#   response(Schedule intervention, Resolve ticket)
#   response(Schedule intervention, Take in charge ticket)
#   response(Schedule intervention, VERIFIED)
#   response(Schedule intervention, Wait)
#   response(Take in charge ticket, Closed)
#   response(Take in charge ticket, Resolve ticket)
#   response(VERIFIED, Assign seriousness)
#   response(VERIFIED, Closed)
#   response(VERIFIED, Create SW anomaly)
#   response(VERIFIED, EOS)
#   response(VERIFIED, INVALID)
#   response(VERIFIED, Insert ticket)
#   response(VERIFIED, RESOLVED)
#   response(VERIFIED, Require upgrade)
#   response(VERIFIED, Resolve SW anomaly)
#   response(VERIFIED, Resolve ticket)
#   response(VERIFIED, Schedule intervention)
#   response(VERIFIED, Take in charge ticket)
#   response(VERIFIED, Wait)
#   response(Wait, Closed)
#   response(Wait, EOS)
#   response(Wait, Resolve ticket)
#   succession(Assign seriousness, Closed)
#   succession(Assign seriousness, Resolve ticket)
#   succession(Assign seriousness, Take in charge ticket)
#   succession(Closed, EOS)
#   succession(Create SW anomaly, INVALID)
#   succession(Create SW anomaly, Insert ticket)
#   succession(Create SW anomaly, RESOLVED)
#   succession(Create SW anomaly, Require upgrade)
#   succession(Create SW anomaly, Resolve SW anomaly)
#   succession(Create SW anomaly, Schedule intervention)
#   succession(Create SW anomaly, VERIFIED)
#   succession(INVALID, Create SW anomaly)
#   succession(INVALID, Insert ticket)
#   succession(INVALID, RESOLVED)
#   succession(INVALID, Require upgrade)
#   succession(INVALID, Resolve SW anomaly)
#   succession(INVALID, Schedule intervention)
#   succession(INVALID, VERIFIED)
#   succession(Insert ticket, Create SW anomaly)
#   succession(Insert ticket, INVALID)
#   succession(Insert ticket, RESOLVED)
#   succession(Insert ticket, Require upgrade)
#   succession(Insert ticket, Resolve SW anomaly)
#   succession(Insert ticket, Schedule intervention)
#   succession(Insert ticket, VERIFIED)
#   succession(RESOLVED, Create SW anomaly)
#   succession(RESOLVED, INVALID)
#   succession(RESOLVED, Insert ticket)
#   succession(RESOLVED, Require upgrade)
#   succession(RESOLVED, Resolve SW anomaly)
#   succession(RESOLVED, Schedule intervention)
#   succession(RESOLVED, VERIFIED)
#   succession(Require upgrade, Create SW anomaly)
#   succession(Require upgrade, INVALID)
#   succession(Require upgrade, Insert ticket)
#   succession(Require upgrade, RESOLVED)
#   succession(Require upgrade, Resolve SW anomaly)
#   succession(Require upgrade, Schedule intervention)
#   succession(Require upgrade, VERIFIED)
#   succession(Resolve SW anomaly, Create SW anomaly)
#   succession(Resolve SW anomaly, INVALID)
#   succession(Resolve SW anomaly, Insert ticket)
#   succession(Resolve SW anomaly, RESOLVED)
#   succession(Resolve SW anomaly, Require upgrade)
#   succession(Resolve SW anomaly, Schedule intervention)
#   succession(Resolve SW anomaly, VERIFIED)
#   succession(Resolve ticket, Closed)
#   succession(Resolve ticket, EOS)
#   succession(Schedule intervention, Create SW anomaly)
#   succession(Schedule intervention, INVALID)
#   succession(Schedule intervention, Insert ticket)
#   succession(Schedule intervention, RESOLVED)
#   succession(Schedule intervention, Require upgrade)
#   succession(Schedule intervention, Resolve SW anomaly)
#   succession(Schedule intervention, VERIFIED)
#   succession(Take in charge ticket, Closed)
#   succession(Take in charge ticket, Resolve ticket)
#   succession(VERIFIED, Create SW anomaly)
#   succession(VERIFIED, INVALID)
#   succession(VERIFIED, Insert ticket)
#   succession(VERIFIED, RESOLVED)
#   succession(VERIFIED, Require upgrade)
#   succession(VERIFIED, Resolve SW anomaly)
#   succession(VERIFIED, Schedule intervention)

# %%
# --- Generate counterfactual explanation for a single prefix ---
# Pick a test case that is still in-progress (no EOS), so the model is less
# certain and minimal counterfactuals are more interesting.
# We scan for a case with moderate prediction confidence.
import numpy as np

# Find a good candidate: in-progress prefix with uncertain prediction
best_idx, best_prob = None, 1.0
for i in range(min(200, len(dataset))):
    cat_t, num_t, _ = dataset[i]
    act = cat_t[0]
    # Skip completed traces (contain EOS = index 5)
    if (act == 5).any():
        continue
    cat_in = [c.unsqueeze(0) for c in cat_t]
    num_in = [n.unsqueeze(0) for n in num_t]
    with torch.no_grad():
        preds = model((cat_in, num_in))[0]
        logits = preds[0]["Activity_mean"][0]
        p = torch.softmax(logits, dim=-1)
        top_p = p.max().item()
    if 0.4 < top_p < best_prob:
        best_idx, best_prob = i, top_p

test_idx = best_idx if best_idx is not None else 86
print(f"Selected test_idx={test_idx} (top_p={best_prob:.3f})")

cat_tuple, num_tuple, case_id = dataset[test_idx]

# Show original prefix
print(f"\nCase: {case_id}")
df_orig = decoder.decode_sequence(cat_tuple, num_tuple, case_id=case_id)
display(df_orig)

# Prepare inputs for explain()
cat_tensors = [c.unsqueeze(0) for c in cat_tuple]
num_tensors = [n.unsqueeze(0) for n in num_tuple]

# Generate explanation (target_class=None means any different prediction)
explanation = rp.explain(cat_tensors, num_tensors, target_class=None)
print(explanation)
# Out:
# Selected test_idx=51 (top_p=0.495)
#
# Case: Case 1061
#                 Activity  Resource Variant index seriousness   customer  \
# 0     Assign seriousness   Value 8          17.0     Value 1  Value 231
# 1     Assign seriousness   Value 8          17.0     Value 1  Value 231
# 2  Take in charge ticket  Value 13          17.0     Value 1  Value 231
# 3                   Wait  Value 13          17.0     Value 1  Value 231
# 4         Resolve ticket  Value 13          17.0     Value 1  Value 231
#
#     product responsible_section seriousness_2 service_level service_type  \
# 0  Value 12             Value 1       Value 1       Value 2      Value 1
# 1  Value 12             Value 1       Value 1       Value 2      Value 1
# 2  Value 12             Value 1       Value 1       Value 2      Value 1
# 3  Value 12             Value 1       Value 1       Value 2      Value 1
# 4  Value 12             Value 1       Value 1       Value 2      Value 1
#
#   support_section workgroup  case_elapsed_time  event_elapsed_time  \
# 0         Value 1   Value 1       0.000000e+00        9.633033e+05
# 1         Value 1   Value 1       1.600000e+01        1.606250e+01
# 2         Value 1   Value 1       5.201629e+05        5.201470e+05
# 3         Value 1   Value 1       2.521179e+06        2.001016e+06
# 4         Value 1   Value 1       3.198710e+06        6.775310e+05
#
#     day_in_week  seconds_in_day    Case ID
# 0  1.000000e+00    32105.000000  Case 1061
# 1  1.000000e+00    32120.998047  Case 1061
# 2 -2.384186e-07    33868.000000  Case 1061
# 3  2.000000e+00    47683.996094  Case 1061
# 4  3.000000e+00    34015.000000  Case 1061
# Original: Resolve ticket (p=0.495), prefix_len=5
# REVISED+ Counterfactual Explanation
# ============================================================
# Original: Resolve ticket (idx=11, p=0.495)
# Prefix length: 5 events
# Target: any different class
# Constraints: 507 prefix-safe, 1088 total
# Search: 1000 evaluated, 664 valid, 17.7s
#
# Top 5 counterfactuals:
#   [1] -> Closed (p=0.904) | prox=20.427 sparse=5 feas=0.287 plaus_def=1.00 plaus_opt=0.98 score=1.2841
#   [2] -> Closed (p=0.905) | prox=20.214 sparse=5 feas=0.448 plaus_def=1.00 plaus_opt=0.98 score=1.2975
#   [3] -> EOS (p=0.998) | prox=24.316 sparse=5 feas=0.237 plaus_def=1.00 plaus_opt=0.99 score=1.3276
#   [4] -> Closed (p=0.879) | prox=25.556 sparse=5 feas=0.460 plaus_def=0.99 plaus_opt=0.97 score=1.3714
#   [5] -> Closed (p=0.901) | prox=29.509 sparse=6 feas=0.715 plaus_def=1.00 plaus_opt=0.98 score=1.3789

# %%
# --- Compare original vs counterfactual prefixes ---
if explanation.counterfactuals:
    best = explanation.get_best()

    print("=" * 80)
    print("ORIGINAL PREFIX")
    print(f"Prediction: {explanation.original_prediction_name} (p={explanation.original_probability:.3f})")
    print(f"Prefix length: {explanation.prefix_len} events")
    print("=" * 80)
    display(df_orig)

    print(f"\n{'=' * 80}")
    print("BEST COUNTERFACTUAL PREFIX")
    print(f"Prediction: {best.counterfactual_prediction_name} (p={best.counterfactual_probability:.3f})")
    cf_prefix_len = len(best.activity_sequence)
    print(f"Prefix length: {cf_prefix_len} events (delta={cf_prefix_len - explanation.prefix_len:+d})")
    print(f"Proximity: {best.proximity:.3f}  Sparsity: {best.sparsity}")
    print(f"Feasibility: {best.feasibility:.3f}")
    print(f"Plausibility (definite): {best.plausibility_definite:.2f}")
    print(f"Plausibility (optimistic): {best.plausibility_optimistic:.2f}")
    print(f"Combined score: {best.combined_score:.4f}")
    print("=" * 80)

    # Decode the counterfactual
    cf_cat = tuple(best.cat_sequence)
    cf_num = tuple(best.num_sequence[:, i] for i in range(best.num_sequence.shape[1])) if best.num_sequence is not None else num_tuple
    df_cf = decoder.decode_sequence(cf_cat, cf_num, skip_padding=False)
    display(df_cf)
else:
    print("No counterfactuals found. Try increasing n_search_rounds or noise_scale.")
# Out:
# ================================================================================
# ORIGINAL PREFIX
# Prediction: Resolve ticket (p=0.495)
# Prefix length: 5 events
# ================================================================================
#                 Activity  Resource Variant index seriousness   customer  \
# 0     Assign seriousness   Value 8          17.0     Value 1  Value 231
# 1     Assign seriousness   Value 8          17.0     Value 1  Value 231
# 2  Take in charge ticket  Value 13          17.0     Value 1  Value 231
# 3                   Wait  Value 13          17.0     Value 1  Value 231
# 4         Resolve ticket  Value 13          17.0     Value 1  Value 231
#
#     product responsible_section seriousness_2 service_level service_type  \
# 0  Value 12             Value 1       Value 1       Value 2      Value 1
# 1  Value 12             Value 1       Value 1       Value 2      Value 1
# 2  Value 12             Value 1       Value 1       Value 2      Value 1
# 3  Value 12             Value 1       Value 1       Value 2      Value 1
# 4  Value 12             Value 1       Value 1       Value 2      Value 1
#
#   support_section workgroup  case_elapsed_time  event_elapsed_time  \
# 0         Value 1   Value 1       0.000000e+00        9.633033e+05
# 1         Value 1   Value 1       1.600000e+01        1.606250e+01
# 2         Value 1   Value 1       5.201629e+05        5.201470e+05
# 3         Value 1   Value 1       2.521179e+06        2.001016e+06
# 4         Value 1   Value 1       3.198710e+06        6.775310e+05
#
#     day_in_week  seconds_in_day    Case ID
# 0  1.000000e+00    32105.000000  Case 1061
# 1  1.000000e+00    32120.998047  Case 1061
# 2 -2.384186e-07    33868.000000  Case 1061
# 3  2.000000e+00    47683.996094  Case 1061
# 4  3.000000e+00    34015.000000  Case 1061
# ================================================================================
# BEST COUNTERFACTUAL PREFIX
# Prediction: Closed (p=0.904)
# Prefix length: 5 events (delta=+0)
# Proximity: 20.427  Sparsity: 5
# Feasibility: 0.287
# Plausibility (definite): 1.00
# Plausibility (optimistic): 0.98
# Combined score: 1.2841
# ================================================================================
#                  Activity Resource Variant index seriousness  customer  \
# 0                   <pad>    <pad>         <pad>       <pad>     <pad>
# 1                   <pad>    <pad>         <pad>       <pad>     <pad>
# 2                   <pad>    <pad>         <pad>       <pad>     <pad>
# 3                   <pad>    <pad>         <pad>       <pad>     <pad>
# 4                   <pad>    <pad>         <pad>       <pad>     <pad>
# 5                   <pad>    <pad>         <pad>       <pad>     <pad>
# 6                   <pad>    <pad>         <pad>       <pad>     <pad>
# 7                   <pad>    <pad>         <pad>       <pad>     <pad>
# 8                   <pad>    <pad>         <pad>       <pad>     <pad>
# 9                   <pad>    <pad>         <pad>       <pad>     <pad>
# 10                  <pad>    <pad>         <pad>       <pad>     <pad>
# 11                  <pad>    <pad>         <pad>       <pad>     <pad>
# 12                  <pad>    <pad>         <pad>       <pad>     <pad>
# 13     Assign seriousness  Value 8         <pad>     Value 1     <pad>
# 14  Take in charge ticket  Value 8          17.0     Value 1   Value 5
# 15  Take in charge ticket  Value 2          17.0     Value 1  Value 22
# 16                   Wait  Value 2           2.0     Value 1  Value 22
# 17         Resolve ticket  Value 2           2.0     Value 1  Value 22
#
#     product responsible_section seriousness_2 service_level service_type  \
# 0     <pad>               <pad>         <pad>         <pad>        <pad>
# 1     <pad>               <pad>         <pad>         <pad>        <pad>
# 2     <pad>               <pad>         <pad>         <pad>        <pad>
# 3     <pad>               <pad>         <pad>         <pad>        <pad>
# 4     <pad>               <pad>         <pad>         <pad>        <pad>
# 5     <pad>               <pad>         <pad>         <pad>        <pad>
# 6     <pad>               <pad>         <pad>         <pad>        <pad>
# 7     <pad>               <pad>         <pad>         <pad>        <pad>
# 8     <pad>               <pad>         <pad>         <pad>        <pad>
# 9     <pad>               <pad>         <pad>         <pad>        <pad>
# 10    <pad>               <pad>         <pad>         <pad>        <pad>
# 11    <pad>               <pad>         <pad>         <pad>        <pad>
# 12    <pad>               <pad>         <pad>         <pad>        <pad>
# 13  Value 1             Value 1       Value 1       Value 2      Value 1
# 14  Value 1             Value 1       Value 1       Value 2      Value 1
# 15  Value 1             Value 1       Value 1       Value 2      Value 1
# 16  Value 1             Value 1       Value 1       Value 2      Value 1
# 17  Value 1             Value 1       Value 1       Value 2      Value 1
#
#    support_section workgroup  case_elapsed_time  event_elapsed_time  \
# 0            <pad>     <pad>       1.109730e+06        1.077318e+06
# 1            <pad>     <pad>       1.313320e+05        4.048428e+05
# 2            <pad>     <pad>      -7.472294e+05       -1.888624e+05
# 3            <pad>     <pad>      -1.008029e+06       -1.794516e+05
# 4            <pad>     <pad>      -1.018559e+06       -4.278688e+04
# 5            <pad>     <pad>      -9.594452e+05        6.327538e+04
# 6            <pad>     <pad>      -8.797938e+05        1.640451e+05
# 7            <pad>     <pad>      -7.839970e+05        2.771936e+05
# 8            <pad>     <pad>      -6.710479e+05        4.052318e+05
# 9            <pad>     <pad>      -5.420280e+05        5.401425e+05
# 10           <pad>     <pad>      -4.023379e+05        6.661355e+05
# 11           <pad>     <pad>      -2.746549e+05        7.628535e+05
# 12           <pad>     <pad>      -1.506735e+05        8.439889e+05
# 13         Value 1   Value 1       8.102788e+04        9.991009e+05
# 14         Value 1   Value 1       1.241538e+05        2.665969e+04
# 15         Value 1   Value 1       3.220206e+05        1.973256e+05
# 16         Value 1   Value 1       1.193891e+06        8.272514e+05
# 17         Value 1   Value 1       3.035915e+06        2.292383e+06
#
#     day_in_week  seconds_in_day
# 0      2.535683    32979.285156
# 1      3.038005    29572.035156
# 2      2.956426    39720.664062
# 3      2.816238    43998.199219
# 4      2.669814    44880.714844
# 5      2.552911    44818.515625
# 6      2.453350    44346.070312
# 7      2.358061    43550.203125
# 8      2.260248    42348.898438
# 9      2.155302    40528.488281
# 10     2.008955    37854.007812
# 11     1.714313    34431.074219
# 12     1.225206    29399.011719
# 13     0.456575    29595.312500
# 14     0.095171    31185.464844
# 15    -0.021878    36214.917969
# 16     1.149487    41065.179688
# 17     2.972132    39298.710938

# %%
# --- Show all top-k counterfactuals ---
import pandas as pd

if explanation.counterfactuals:
    rows = []
    for i, cf in enumerate(explanation.counterfactuals):
        rows.append({
            'rank': i + 1,
            'prediction': cf.counterfactual_prediction_name,
            'probability': f"{cf.counterfactual_probability:.3f}",
            'prefix_len': len(cf.activity_sequence),
            'activities': ' -> '.join(activity_names[a] for a in cf.activity_sequence),
            'proximity': f"{cf.proximity:.2f}",
            'sparsity': cf.sparsity,
            'feasibility': f"{cf.feasibility:.3f}",
            'plaus_def': f"{cf.plausibility_definite:.2f}",
            'plaus_opt': f"{cf.plausibility_optimistic:.2f}",
            'score': f"{cf.combined_score:.4f}",
        })

    df_cfs = pd.DataFrame(rows)
    print(f"Original: {' -> '.join(activity_names[a] for a in explanation.original_activity_sequence)}")
    print(f"Original prediction: {explanation.original_prediction_name} (p={explanation.original_probability:.3f})")
    print()
    display(df_cfs)
# Out:
# Original: Assign seriousness -> Assign seriousness -> Take in charge ticket -> Wait -> Resolve ticket
# Original prediction: Resolve ticket (p=0.495)
#    rank prediction probability  prefix_len  \
# 0     1     Closed       0.904           5
# 1     2     Closed       0.905           5
# 2     3        EOS       0.998           5
# 3     4     Closed       0.879           5
# 4     5     Closed       0.901           6
#
#                                           activities proximity  sparsity  \
# 0  Assign seriousness -> Take in charge ticket ->...     20.43         5
# 1  Assign seriousness -> Assign seriousness -> Ta...     20.21         5
# 2  Assign seriousness -> Take in charge ticket ->...     24.32         5
# 3  Assign seriousness -> Assign seriousness -> Ta...     25.56         5
# 4  Assign seriousness -> Assign seriousness -> Ta...     29.51         6
#
#   feasibility plaus_def plaus_opt   score
# 0       0.287      1.00      0.98  1.2841
# 1       0.448      1.00      0.98  1.2975
# 2       0.237      1.00      0.99  1.3276
# 3       0.460      0.99      0.97  1.3714
# 4       0.715      1.00      0.98  1.3789
