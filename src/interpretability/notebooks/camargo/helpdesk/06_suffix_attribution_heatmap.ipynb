# %% [markdown]
# # 06 — Suffix Attribution Heatmap (Camargo Helpdesk)
#
# Port of the henryk `06_suffix_attribution_heatmap` notebook for the Camargo baseline.
#
# Camargo is a single-step predictor, so there is no real 'suffix over multiple decoder steps'. Instead we pick a case + prefix length, then roll the prediction forward one activity at a time (greedy auto-regressive), computing Integrated Gradients at every step with respect to the predicted class at that step. The heatmap rows are features (Activity embedding, Resource embedding, case_elapsed_time) and the columns are prefix positions (padded-left, so the last column is the most recent event).

# %%
import sys
from pathlib import Path

_current = Path().resolve()
while _current != _current.parent:
    if (_current / 'src').is_dir() and (_current / 'encoded_data').is_dir():
        break
    _current = _current.parent
_camargo_dir = _current / 'src' / 'interpretability' / 'notebooks' / 'camargo'
for p in [_current, _current / 'src', _camargo_dir]:
    if str(p) not in sys.path:
        sys.path.insert(0, str(p))

import _camargo_utils as utils
import numpy as np
import torch
import matplotlib.pyplot as plt
from matplotlib.colors import TwoSlopeNorm

SPEC = utils.HELPDESK_SHAREDCAT_ROLES_NGRAM
model = utils.load_camargo_model(_current, SPEC)
dataset = utils.load_test_dataset(_current, SPEC)
window = SPEC.ngram_size or utils.compute_window(dataset)
predictor = utils.CamargoPredictor(model, SPEC, window)
idx_to_name = predictor.idx_to_name
eos_idx = predictor.eos_idx
ACT_IDX = SPEC.cat_indices[0]
RES_IDX = SPEC.cat_indices[1]
CET_IDX = SPEC.num_indices[0]
feature_names = ['Activity', 'Resource', 'case_elapsed_time']
print(f'{SPEC.name} | window={window}')
# Out:
# Data set categories:  ([('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15}), ('Role', 9, {'EOS': 1, 'Role_1': 2, 'Role_2': 3, 'Role_3': 4, 'Role_4': 5, 'Role_5': 6, 'Role_6': 7, 'Role_7': 8})], [('case_elapsed_time', 1, {})])
# Model input features:  [['Activity', 'Role'], ['case_elapsed_time']]
# Embeddings:  ModuleList(
#   (0): Embedding(16, 8)
#   (1): Embedding(9, 5)
# )
# Total embedding feature size:  13
# Number of numerical features:  1
# Input feature size (shared LSTM, cat-only):  13
# Cells hidden size:  50
# Number of LSTM layer:  1
# /Users/philippeichhorn/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/torch/nn/modules/rnn.py:990: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Helpdesk (SharedCat + Roles, n-gram=5) | window=5

# %% [markdown]
# ## Config

# %%
CASE_NAME = 'Case 1016'   # change to any test case
PREFIX_LENGTH = 1         # prefix length to analyse
MAX_SUFFIX_STEPS = 6      # how many auto-regressive steps to roll
IG_STEPS = 50

# %%
cats_full = nums_full = None
for i in range(len(dataset)):
    if dataset[i][2] == CASE_NAME:
        cats_full, nums_full, _ = dataset[i]
        break
if cats_full is None:
    raise ValueError(f'Case {CASE_NAME!r} not found in test set')
acts_raw = cats_full[ACT_IDX].tolist()
nonzero = [i for i, a in enumerate(acts_raw) if a != 0]
start = nonzero[0]
useful_len = len(nonzero)
while useful_len > 0 and acts_raw[start + useful_len - 1] == eos_idx:
    useful_len -= 1
print(f'Case {CASE_NAME} | activities: {[idx_to_name.get(acts_raw[start + k]) for k in range(useful_len)]}')
# Out:
# Case Case 1016 | activities: ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Closed']

# %%
# Auto-regressive rollout starting from the prefix. At every step compute IG.
cats_win, nums_win = utils.make_prefix_window(
    cats_full, nums_full, start=start, prefix_length=PREFIX_LENGTH,
    window=window, spec=SPEC,
)
heatmaps = []  # list of (target_class_name, feat_matrix [n_features, window], prefix_labels)
cur_cats = [c.clone() for c in cats_win]
cur_nums = [n.clone() for n in nums_win]
for step in range(MAX_SUFFIX_STEPS):
    pred_idx, probs = predictor.predict_batch(cur_cats, cur_nums)
    target = int(pred_idx.item())
    target_name = idx_to_name.get(target, f'<{target}>')
    cat_attrs, num_attrs = utils.compute_integrated_gradients(
        model, cur_cats, cur_nums, target_class=target, n_steps=IG_STEPS
    )
    mat = utils.attributions_to_matrix(cat_attrs, num_attrs, feature_names).numpy()
    # Column labels: name of activity at each position, <pad> for empty slots
    acts_window_values = cur_cats[0][0].tolist()
    col_labels = [idx_to_name.get(a, '<pad>') if a != 0 else '<pad>' for a in acts_window_values]
    heatmaps.append({'step': step, 'target': target_name, 'confidence': float(probs[0, target].item()),
                     'mat': mat, 'col_labels': col_labels})
    if target_name == 'EOS':
        break
    # Roll window left by 1 and drop-in the predicted activity at the last slot
    cur_cats[0] = torch.cat([cur_cats[0][:, 1:], torch.tensor([[target]], dtype=cur_cats[0].dtype)], dim=1)
    # Keep resource and case_elapsed_time rolling from ground truth if available
    gt_pos = start + PREFIX_LENGTH + step
    if gt_pos < start + useful_len:
        cur_cats[1] = torch.cat([cur_cats[1][:, 1:], cats_full[RES_IDX][gt_pos].view(1, 1)], dim=1)
        cur_nums[0] = torch.cat([cur_nums[0][:, 1:], nums_full[CET_IDX][gt_pos].view(1, 1)], dim=1)
    else:
        cur_cats[1] = torch.cat([cur_cats[1][:, 1:], torch.zeros(1, 1, dtype=cur_cats[1].dtype)], dim=1)
        cur_nums[0] = torch.cat([cur_nums[0][:, 1:], torch.zeros(1, 1, dtype=cur_nums[0].dtype)], dim=1)
print(f'Generated {len(heatmaps)} IG heatmaps')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 13
#      11 target = int(pred_idx.item())
#      12 target_name = idx_to_name.get(target, f'<{target}>')
# ---> 13 cat_attrs, num_attrs = utils.compute_integrated_gradients(
#      14     model, cur_cats, cur_nums, target_class=target, n_steps=IG_STEPS
#      15 )
#      16 mat = utils.attributions_to_matrix(cat_attrs, num_attrs, feature_names).numpy()
#      17 # Column labels: name of activity at each position, <pad> for empty slots
#
# File ~/IdeaProjects/XAI-Probabilistic_Suffix_Prediction_U-ED-LSTM_pub/src/interpretability/notebooks/camargo/_camargo_utils.py:388, in compute_integrated_gradients(model, cats_window, nums_window, target_class, n_steps)
#     385     return _forward_from_embeddings(model, emb_cats, nums)
#     387 ig = IntegratedGradients(forward_for_ig)
# --> 388 cat_attr, num_attr = ig.attribute(
#     389     inputs=(embedded_cats, nums_stacked),
#     390     baselines=(torch.zeros_like(embedded_cats), torch.zeros_like(nums_stacked)),
#     391     target=int(target_class),
#     392     n_steps=n_steps,
#     393 )
#     394 # Split the combined categorical attribution back to per-feature
#     395 dims = [e.embedding_dim for e in model.embeddings]
#
# File ~/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/captum/log/dummy_log.py:39, in log_usage.<locals>._log_usage.<locals>.wrapper(*args, **kwargs)
#      35 @wraps(func)
#      36 # pyre-fixme[53]: Captured variable `func` is not annotated.
#      37 # pyre-fixme[3]: Return type must be annotated.
#      38 def wrapper(*args: Any, **kwargs: Any):
# ---> 39     return func(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/captum/attr/_core/integrated_gradients.py:289, in IntegratedGradients.attribute(self, inputs, baselines, target, additional_forward_args, n_steps, method, internal_batch_size, return_convergence_delta)
#     277     attributions = _batch_attribution(
#     278         self,
#     279         num_examples,
#    (...)    286         method=method,
#     287     )
#     288 else:
# --> 289     attributions = self._attribute(
#     290         inputs=formatted_inputs,
#     291         baselines=formatted_baselines,
#     292         target=target,
#     293         additional_forward_args=additional_forward_args,
#     294         n_steps=n_steps,
#     295         method=method,
#     296     )
#     298 if return_convergence_delta:
#     299     start_point, end_point = baselines, inputs
#
# File ~/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/captum/attr/_core/integrated_gradients.py:368, in IntegratedGradients._attribute(self, inputs, baselines, target, additional_forward_args, n_steps, method, step_sizes_and_alphas)
#     365 expanded_target = _expand_target(target, n_steps)
#     367 # grads: dim -> (bsz * #steps x inputs[0].shape[1:], ...)
# --> 368 grads = self.gradient_func(
#     369     forward_fn=self.forward_func,
#     370     inputs=scaled_features_tpl,
#     371     target_ind=expanded_target,
#     372     additional_forward_args=input_additional_args,
#     373 )
#     375 # flattening grads so that we can multilpy it with step-size
#     376 # calling contiguous to avoid `memory whole` problems
#     377 scaled_grads = [
#     378     grad.contiguous().view(n_steps, -1)
#     379     * torch.tensor(step_sizes).float().view(n_steps, 1).to(grad.device)
#     380     for grad in grads
#     381 ]
#
# File ~/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/captum/_utils/gradient.py:128, in compute_gradients(forward_fn, inputs, target_ind, additional_forward_args)
#     110 r"""
#     111 Computes gradients of the output with respect to inputs for an
#     112 arbitrary forward function.
#    (...)    124                 arguments) if no additional arguments are required
#     125 """
#     126 with torch.autograd.set_grad_enabled(True):
#     127     # runs forward pass
# --> 128     outputs = _run_forward(forward_fn, inputs, target_ind, additional_forward_args)
#     129     # _run_forward may return future of Tensor,
#     130     # but we don't support it here now
#     131     # And it will fail before here.
#     132     outputs = cast(Tensor, outputs)
#
# File ~/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/captum/_utils/common.py:588, in _run_forward(forward_func, inputs, target, additional_forward_args)
#     585 inputs = _format_inputs(inputs)
#     586 additional_forward_args = _format_additional_forward_args(additional_forward_args)
# --> 588 output = forward_func(
#     589     *(
#     590         # pyre-fixme[60]: Concatenation not yet support for multiple variadic
#     591         #  tuples: `*inputs, *additional_forward_args`.
#     592         (*inputs, *additional_forward_args)
#     593         if additional_forward_args is not None
#     594         else inputs
#     595     )
#     596 )
#     597 if isinstance(output, torch.futures.Future):
#     598     return output.then(lambda x: _select_targets(x.value(), target))
#
# File ~/IdeaProjects/XAI-Probabilistic_Suffix_Prediction_U-ED-LSTM_pub/src/interpretability/notebooks/camargo/_camargo_utils.py:385, in compute_integrated_gradients.<locals>.forward_for_ig(emb_cats, nums)
#     384 def forward_for_ig(emb_cats, nums):
# --> 385     return _forward_from_embeddings(model, emb_cats, nums)
#
# File ~/IdeaProjects/XAI-Probabilistic_Suffix_Prediction_U-ED-LSTM_pub/src/interpretability/notebooks/camargo/_camargo_utils.py:350, in _forward_from_embeddings(model, embedded_cats, nums_stacked)
#     348 else:
#     349     x = embedded_cats
# --> 350 out_seq, _ = model.shared_lstm(x)  # [B, T, H]
#     351 y = model.bn1(out_seq.transpose(1, 2)).transpose(1, 2)  # [B, T, H]
#     352 _, (h_act, _) = model.lstm_act(y)
#
# File ~/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/torch/nn/modules/rnn.py:1118, in LSTM.forward(self, input, hx)
#    1110     c_zeros = torch.zeros(
#    1111         self.num_layers * num_directions,
#    1112         max_batch_size,
#    (...)   1115         device=input.device,
#    1116     )
#    1117     hx = (h_zeros, c_zeros)
# -> 1118     self.check_forward_args(input, hx, batch_sizes)
#    1119 else:
#    1120     if is_batched:
#
# File ~/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/torch/nn/modules/rnn.py:1015, in LSTM.check_forward_args(self, input, hidden, batch_sizes)
#    1009 def check_forward_args(
#    1010     self,
#    1011     input: Tensor,
#    1012     hidden: tuple[Tensor, Tensor],  # type: ignore[override]
#    1013     batch_sizes: Tensor | None,
#    1014 ) -> None:
# -> 1015     self.check_input(input, batch_sizes)
#    1016     self.check_hidden_size(
#    1017         hidden[0],
#    1018         self.get_expected_hidden_size(input, batch_sizes),
#    1019         "Expected hidden[0] size {}, got {}",
#    1020     )
#    1021     self.check_hidden_size(
#    1022         hidden[1],
#    1023         self.get_expected_cell_size(input, batch_sizes),
#    1024         "Expected hidden[1] size {}, got {}",
#    1025     )
#
# File ~/.local/share/virtualenvs/XAI-Probabilistic_Suffix_Prediction_U-ED-L-p9C7deWr/lib/python3.12/site-packages/torch/nn/modules/rnn.py:316, in RNNBase.check_input(self, input, batch_sizes)
#     312     raise RuntimeError(
#     313         f"input must have {expected_input_dim} dimensions, got {input.dim()}"
#     314     )
#     315 if self.input_size != input.size(-1):
# --> 316     raise RuntimeError(
#     317         f"input.size(-1) must be equal to input_size. Expected {self.input_size}, got {input.size(-1)}"
#     318     )
#
# RuntimeError: input.size(-1) must be equal to input_size. Expected 13, got 14

# %%
n = len(heatmaps)
fig, axes = plt.subplots(n, 1, figsize=(10, 2 + 1.6 * n), squeeze=False)
all_vmax = max((np.abs(h['mat']).max() for h in heatmaps), default=1.0) or 1.0
for i, h in enumerate(heatmaps):
    ax = axes[i, 0]
    norm = TwoSlopeNorm(vmin=-all_vmax, vcenter=0, vmax=all_vmax)
    im = ax.imshow(h['mat'], cmap='RdBu_r', aspect='auto', norm=norm, interpolation='nearest')
    ax.set_yticks(range(len(feature_names)))
    ax.set_yticklabels(feature_names, fontsize=9)
    ax.set_xticks(range(len(h['col_labels'])))
    ax.set_xticklabels(h['col_labels'], rotation=45, ha='right', fontsize=7)
    ax.set_title(f"Step {h['step']}: predicting {h['target']} ({h['confidence']*100:.1f}%)", fontsize=9)
    plt.colorbar(im, ax=ax, shrink=0.8)
fig.suptitle(f"Camargo {SPEC.name} — IG attribution rollout | {CASE_NAME} | prefix_len={PREFIX_LENGTH}",
             fontsize=11, fontweight='bold', y=1.01)
plt.tight_layout()
plt.show()

# %%
# Per-feature total |attribution| across all rollout steps
import pandas as pd
totals = np.sum(np.stack([np.abs(h['mat']).sum(axis=1) for h in heatmaps], axis=0), axis=0)
summary = pd.DataFrame({'Feature': feature_names, 'Total |attribution|': totals}).sort_values('Total |attribution|', ascending=False)
summary
# Out:
#              Feature  Total |attribution|
# 0           Activity             1.259787
# 1           Resource             0.451618
# 2  case_elapsed_time             0.101187
